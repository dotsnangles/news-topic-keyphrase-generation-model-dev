# %%
import os
import re
import warnings

import pandas as pd
import numpy as np
import torch

from transformers import (
    AutoConfig, AutoTokenizer, AutoModelForSeq2SeqLM, 
    Seq2SeqTrainingArguments, Seq2SeqTrainer, 
    DataCollatorForSeq2Seq, 
)

from datasets import load_metric, Dataset

import wandb
import nltk

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jake/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
NGPU = torch.cuda.device_count()
NCPU = os.cpu_count()
NGPU, NCPU
# Out:
# (1, 16)

# %% [markdown]
# # Paths and Names

# %%
### paths and names

PROJECT_NAME = 'news-topic-keyphrase-generation-model-dev'
RUN_ID = 'v2'

DATA_PATH = 'data/preprocess_v2.pickle'

MODEL_CHECKPOINT = 'ainize/kobart-news'
model_name = re.sub(r'[/-]', r'_', MODEL_CHECKPOINT).lower()

METRIC_NAME = 'rouge'

NOTEBOOK_NAME = './train.ipynb'

ROOT_PATH = './'
SAVE_PATH = os.path.join(ROOT_PATH, '.log')

run_name = f'{model_name}_{RUN_ID}'
output_dir = os.path.join(SAVE_PATH, run_name)

print(run_name)
print(output_dir)

# !mkdir -p {SAVE_PATH}
# Out:
# ainize_kobart_news_v2
# ./.log/ainize_kobart_news_v2

# %%
# %env WANDB_PROJECT={PROJECT_NAME}
# %env WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# %env WANDB_LOG_MODEL=true
# %env WANDB_WATCH=all
wandb.login()
# Out:
# env: WANDB_PROJECT=news-topic-keyphrase-generation-model-dev
# env: WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# env: WANDB_LOG_MODEL=true
# env: WANDB_WATCH=all
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find {NOTEBOOK_PATH}.
# wandb: Currently logged in as: dotsnangles. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Training Args

# %%
report_to="wandb"

num_train_epochs = 15
per_device_train_batch_size = 2
per_device_eval_batch_size = 2
gradient_accumulation_steps = 1

optim = 'adamw_torch' # 'adamw_torch' or 'adamw_hf'

learning_rate = 3e-6 * NGPU
weight_decay = 0.01
adam_epsilon = 1e-8

lr_scheduler_type = 'cosine' # 'linear', 'cosine', 'cosine_with_restarts', 'polynomial', 'constant', 'constant_with_warmup'
warmup_ratio = 0

save_total_limit = 2

load_best_model_at_end = True
metric_for_best_model = 'eval_loss'

save_strategy = "epoch"
evaluation_strategy = "epoch"

logging_strategy = "steps"
logging_first_step = True 
logging_steps = int(500 / NGPU)

predict_with_generate=True
generation_max_length=128
# generation_num_beams=5

fp16 = False

# %% [markdown]
# # Model & Tokenizer & Metric

# %% [markdown]
# - 모델과 토크나이저, 그리고 평가지표를 계산하는 데 사용할 함수를 불러옵니다.
# - 모델의 config에는 사용하지 않는 설정이 포함되어 있습니다. 삭제합니다.

# %%
config = AutoConfig.from_pretrained(MODEL_CHECKPOINT)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT, config=config)
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
metric = load_metric(METRIC_NAME)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/496M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/302 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/682k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %% [markdown]
# # Functions

# %% [markdown]
# - 모델 훈련을 위해 전처리를 수행해주는 함수를 선언합니다.
# - 입력 문장이 input이 되고 요약문이 label이 됩니다.
# - tokenizer를 사용해 input_ids로 변환하고 입력값에는 attention_mask를 생성해줍니다.
# - 입력 문장에 prefix를 추가하여 성능 실험을 해볼 수 있으나 지금은 적용하지 않겠습니다.

# %%
prefix = "generate keyphrases: "

max_input_length = 512
max_target_length = 128

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["input_text"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True, padding="max_length")

    labels = tokenizer(examples["target_text"], max_length=max_target_length, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %% [markdown]
# - 모델의 예측값과 위에서 전처리한 라벨을 활용하여 평가지표를 출력하는 함수를 선언합니다.
# - ROUGE를 평가지표로 사용합니다.
#     - ROUGE-N (N-gram) scoring
#     - ROUGE-L (Longest Common Subsequence) scoring
#         - sentence-level: Compute longest common subsequence (LCS) between two pieces of text. Newlines are ignored. This is called rougeL in this package.
#         - summary-level: Newlines in the text are interpreted as sentence boundaries, and the LCS is computed between each pair of reference and candidate sentences, and something called union-LCS is computed. This is called rougeLsum in this package.

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# # Inputs and Labels

# %% [markdown]
# - csv로 저장된 데이터를 불러와 9:1로 훈련과 검증에 사용합니다.
# - 선언한 전처리 함수를 적용하여 데이터세트를 생성합니다.

# %%
data_df = pd.read_pickle(DATA_PATH)

# %%
dataset = Dataset.from_pandas(data_df).shuffle(seed=100).train_test_split(0.2)
train_dataset = dataset['train']
eval_dataset = dataset['test']

# %%
train_dataset = train_dataset.map(preprocess_function, 
                                  batched=True, 
                                  num_proc=NCPU, 
                                  remove_columns=train_dataset.column_names)

eval_dataset = eval_dataset.map(preprocess_function, 
                                batched=True, 
                                num_proc=NCPU, 
                                remove_columns=eval_dataset.column_names)
print(train_dataset)
print(eval_dataset)
# Out:
# Map (num_proc=16):   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map (num_proc=16):   0%|          | 0/317 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 1268
# })
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 317
# })

# %%
tokenizer.decode(train_dataset['input_ids'][0])
# Out:
# '<s>generate keyphrases: 공정위, 대기업 기업결합 심사 5년간 918건 \'모두 승인\' 경쟁제한성 판단 4건은 우선승인 뒤 시정조치송재호 "시장독점·경쟁제한 우려...피해자는 국민"송재호 더불어민주당 의원. 2021.9.30/뉴스1 © News1 오대일 기자 서미선 기자 = 공정거래위원회 기업결합심사에서 최근 5년간 대기업집단 기업결합은 단 한 건도 금지된 사례가 없는 것으로 드러났다. 7일 국회 정무위원회 송재호 더불어민주당 의원이 공정위로부터 받은 자료를 분석한 결과, 2017년부터 2021년 6월까지 최근 5년간 자산규모 5조원 이상 대기업집단 기업결합 총 918건은 모두 승인됐다. 금액으로는 145조3000억원 규모다. 공정위는 이 중 4건은 경쟁제한성이 있다고 판단해 시정조치를 내렸다. 우선 기업결합을 승인하되 보완적 조치 이행을 공정위가 관리한다는 것이다. 2018년 CJ헬로비전의 하나방송 인수, 2019년 SK텔레콤의 콘텐츠연합플랫폼 등 인수, 2019년 LG유플러스의 CJ헬로 등 인수, 지난해 SK브로드밴드의 티브로드 등 인수에서 시정조치가 부과됐다. 올해 상반기 기준 대기업집단 기업결합은 196건, 금액은 23조2000억원으로 전체 국내 기업결합의 절반에 가까운 46.4%, 결합금액은 전체의 76.8%를 차지했다. 지난해 같은 기간보다 건수는 87%, 금액은 3배 가까이 증가했다. 송 의원은 "대기업집단 기업결합은 신산업 성장동력 확보에서 긍정적 역할도 있지만, 잠재적 경쟁자를 인수합병해 시장을 독점</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenizer.decode(train_dataset['labels'][0])
# Out:
# '<s>심사,승인,대기업 기업결합,공정위</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %% [markdown]
# # Train

# %% [markdown]
# - 상단에서 선언한 HP와 각종 변수들로 training_args를 생성합니다.

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    run_name=run_name,
    report_to=report_to,

    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,

    optim=optim,

    learning_rate=learning_rate,
    weight_decay=weight_decay,
    adam_epsilon=adam_epsilon,

    lr_scheduler_type=lr_scheduler_type,
    warmup_ratio=warmup_ratio,

    save_total_limit=save_total_limit,

    load_best_model_at_end=load_best_model_at_end,
    metric_for_best_model=metric_for_best_model,

    save_strategy=save_strategy,
    evaluation_strategy=evaluation_strategy,

    logging_strategy=logging_strategy,
    logging_first_step=logging_first_step, 
    logging_steps=logging_steps,

    predict_with_generate=predict_with_generate,
    generation_max_length=generation_max_length,
    # generation_num_beams=generation_num_beams,

    fp16=fp16,
)

# %% [markdown]
# - 배치 단위로 padding처리를 하여 훈련 속도를 높히기 위해 data_collator를 선언합니다.
# - 생성한 객체들을 trainer에 포함시켜 훈련 준비를 마칩니다.

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, padding=True)

trainer = Seq2SeqTrainer(
    model=model,
    
    args=training_args,
    
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    
    tokenizer=tokenizer,
    data_collator=data_collator,
    
    compute_metrics=compute_metrics,
)

# %% [markdown]
# - 훈련을 시작합니다.

# %%
trainer.train()
# Out:
# wandb version 0.14.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/jake/codes/news-topic-keyphrase-generation-model-dev/wandb/run-20230411_123446-vcddenv8</code>
# Syncing run <strong><a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/vcddenv8' target="_blank">ainize_kobart_news_v2</a></strong> to <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev</a>
#  View run at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/vcddenv8' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/vcddenv8</a>
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='9510' max='9510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9510/9510 45:29, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.520800</td>
#       <td>0.338340</td>
#       <td>15.044000</td>
#       <td>1.682400</td>
#       <td>14.980600</td>
#       <td>14.997000</td>
#       <td>28.053600</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.343300</td>
#       <td>0.301407</td>
#       <td>17.210400</td>
#       <td>2.731700</td>
#       <td>16.941300</td>
#       <td>16.998900</td>
#       <td>27.589900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.303000</td>
#       <td>0.297739</td>
#       <td>19.097600</td>
#       <td>3.962700</td>
#       <td>18.926100</td>
#       <td>18.922500</td>
#       <td>27.993700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.245000</td>
#       <td>0.288719</td>
#       <td>19.242900</td>
#       <td>3.639000</td>
#       <td>19.284200</td>
#       <td>19.312200</td>
#       <td>27.902200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.224400</td>
#       <td>0.286380</td>
#       <td>21.321400</td>
#       <td>5.576100</td>
#       <td>21.143800</td>
#       <td>21.167300</td>
#       <td>27.164000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.204500</td>
#       <td>0.289023</td>
#       <td>19.784400</td>
#       <td>4.887300</td>
#       <td>19.622000</td>
#       <td>19.750800</td>
#       <td>26.646700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.191700</td>
#       <td>0.290580</td>
#       <td>18.111700</td>
#       <td>4.404400</td>
#       <td>18.000100</td>
#       <td>17.881500</td>
#       <td>25.233400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.172100</td>
#       <td>0.294094</td>
#       <td>19.702600</td>
#       <td>4.415200</td>
#       <td>19.492000</td>
#       <td>19.336100</td>
#       <td>25.217700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.157200</td>
#       <td>0.298028</td>
#       <td>18.628200</td>
#       <td>4.878700</td>
#       <td>18.270800</td>
#       <td>18.182200</td>
#       <td>25.697200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.151900</td>
#       <td>0.300880</td>
#       <td>18.992600</td>
#       <td>4.385700</td>
#       <td>18.734500</td>
#       <td>18.544800</td>
#       <td>25.804400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.153200</td>
#       <td>0.301729</td>
#       <td>18.758100</td>
#       <td>4.683800</td>
#       <td>18.550700</td>
#       <td>18.310100</td>
#       <td>25.154600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.138600</td>
#       <td>0.303114</td>
#       <td>18.912800</td>
#       <td>4.225800</td>
#       <td>18.738700</td>
#       <td>18.504600</td>
#       <td>25.785500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.143500</td>
#       <td>0.303829</td>
#       <td>19.246000</td>
#       <td>4.386500</td>
#       <td>18.972700</td>
#       <td>18.821500</td>
#       <td>25.397500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.133100</td>
#       <td>0.303945</td>
#       <td>18.718100</td>
#       <td>4.413700</td>
#       <td>18.435900</td>
#       <td>18.299100</td>
#       <td>25.495300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.135600</td>
#       <td>0.304005</td>
#       <td>18.968600</td>
#       <td>4.413700</td>
#       <td>18.756900</td>
#       <td>18.576300</td>
#       <td>25.564700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9510, training_loss=0.2072348799677928, metrics={'train_runtime': 2728.9424, 'train_samples_per_second': 6.97, 'train_steps_per_second': 3.485, 'total_flos': 5798593717862400.0, 'train_loss': 0.2072348799677928, 'epoch': 15.0})

# %% [markdown]
# - 옵티마이저 스테이트를 포함한 훈련 재개에 사용할 파일들을 삭제해줍니다.
# - 추후 불러올 모델과 토크나이저 관련 파일만 남겨둡니다.

# %%
# keep = [
#     'added_tokens.json',
#     'config.json',
#     'pytorch_model.bin',
#     'special_tokens_map.json',
#     'tokenizer.json',
#     'tokenizer_config.json',
#     'vocab.txt'
# ]

# ckpts = os.listdir(output_dir)
# for ckpt in ckpts:
#     ckpt = os.path.join(output_dir, ckpt)
#     for item in os.listdir(ckpt):
#         if item not in keep:
#             os.remove(os.path.join(ckpt, item))

# %% [markdown]
# # Generate

# %% [markdown]
# - 훈련을 마치면 Evaluation Loss 기준 Best 모델이 로드되어 있습니다.
# - trainer는 Greedy Search를 수행하도록 설정되어 있습니다.
# - Evaluation 데이터를 활용해 모델의 출력을 간단히 살펴봅니다.

# %%
preds = trainer.predict(eval_dataset)

# %%
for data, pred in zip(eval_dataset, preds.predictions):
    context = tokenizer.decode(data['input_ids'], skip_special_tokens=True)
    summary = tokenizer.decode(data['labels'], skip_special_tokens=True)
    pred = tokenizer.decode(pred[2:], skip_special_tokens=True)
    # print(f'입력: {context}')
    print(f'정답: {summary}')
    print(f'예측: {pred}', end='\n\n')
# Out:
# 정답: 체험 마케팅 강화,휴테크,게임,롯데백화점 중동점 브랜드관,안마의자
# 예측: 휴테크,롯데백화점 중동점 브랜드관,체험 마케팅,위드 코로나
#
# 정답: 루카 모드리치,안첼로티,레알마드리드,카세미루
# 예측: 크카모는 버뮤다 삼각지대
#
# 정답: 식중독 주의보,식중독 발생,식중독 환자,식중독 예방
# 예측: 식중독 주의보,기온,식중독 예방 6대 수칙,식중독,1.6°C,1월,식중독
#
# 정답: 황금빛골드바 이벤트,음악 저작권 거래,뮤직카우
# 예측: 음악카우,황금빛골드바 어텀 이벤트 실시,음악 저작권 거래 플랫폼,연속 이벤트,순금 골드바
#
# 정답: 신현빈,재벌집 막내아들,재회,김신록,송중기,순양백화점
# 예측: 재집 막내아들 송중기,김신록,김신록,김신록,재회
#
# 정답: 상장사가 가상자산 발행,발행 규제,자본연 보고서
# 예측: 상장사의 코인발행,규제,자본시장연구원,상장사,코인발행,자본시장 교란,코인발행,규제
#
# 정답: 원불교,나상호 교정원장,교단혁신특별위원회,대각개교절,간담회
# 예측: 대상호 교정원장,대각개교절,교단 혁신,제107주년 대각개교절,제발절,대신혁명,교단혁신특별위원회
#
# 정답: 홈런,알몬테,kbo 리그
# 예측: K몬테,2021 신한은행 SOL KBO리그,KT 위즈,KT 위즈,KBO리그
#
# 정답: 건강 피부,40세 생얼,양미라
# 예측: 40세 생얼,양미라,젊은 피부,인스타그램
#
# 정답: 여야,회동,원내대표,박준영,타협,막판,인준
# 예측: 박준영 사퇴,인준 대치,여야 원내대표 담판,박준영 해수부 장관 후보자,인사
#
# 정답: 노진혁,시작,kbo리그
# 예측: 노진혁,시작이 좋아,23일 오후,2021 신한은행 SOL KBO리그,NC 다이노스,키움 히어로즈,경기,2회초,천전안타를 치고
#
# 정답: 한미,워싱턴,KIDD회의,전작권 논의,한미통합국방협의체 회의,한반도 안보정세 평가,완전한 비핵화
# 예측: 한,미통합국방협의체 회의,전작권 논의,KIDD회의,한반도 안보정세 평가,한반도의 완전한 비핵화 및 항구적 평화정착,대북정책 공조 방안
#
# 정답: 윤순진 위원장,산업통상자원부,국정감사
# 예측: 윤순진,산업통상자원중소벤처기업위원회,국정감사, 질의,답변,윤순진,탄소중립위원회,산업통상자원부
#
# 정답: 특금법,가상자산 거래소,등록,0곳,은성수 금융위원장,거래소 자체 상황,요인
# 예측: 가상자산 거래소,폐쇄,금융위원장,폐쇄,국내 가상자산 거래소
#
# 정답: 마약류관리법,음주운전,구속영장,마약,차량 난동,대한민국,울산
# 예측: 운주운전,실탄 11발,도주차량,경찰,감금
#
# 정답: 코미디,불편,재미,경계,고민,피식대학,빵송국
# 예측: 유드맨스터,유튜브 코미디,피식대학,스튜디오,정영준
#
# 정답: 냉면집,날씨
# 예측: 더면집,더워진 날씨,냉면집
#
# 정답: beijing olympics,snowboarding,medalist
# 예측: seympics,snowboarding d87fc065b,left,generate keyphrases
#
# 정답: 우방국,양측 관세당국,관세청,터키 관세당국,제7차 한-터키 관세청장회의,협력강화,수출기업
# 예측: 관제청 제7차 한-터키 관세청장회의,원산지 검증 협력
#
# 정답: fury,press conference,boxing,wilder,US
# 예측: boxer,borld,press,buxer,five it,trena,toxer
#
# 정답: 야당 상임위원장,공략,예산 확보,송하진
# 예측: 송하진 전북도지사,국가예산 확보,전라유학진흥원 건립,국가국가예산 확보,전라유학진흥원,새만금 지역 간 연결도로 건설,새만금 내부개발 촉진,새만금 지역 간 연결도로 건설
#
# 정답: 추가 확진,원주,유흥업소발,춘천,확산
# 예측: 흥천,원주,유흥업소발 n차 감염,확진판정,유흥업소 종사자,권한업소 종사자,수도권 확진자,배우자
#
# 정답: 설날 상차림 투고박스,런치스페셜,힐튼 가든 인 서울 강남
# 예측: 설튼 가든 인 서울 강남,설날 상차림 투고박스
#
# 정답: 박보영,tvN,어느 날 우리 집 현관으로 멸망이 들어왔다,연기력,케미력,믿보 배우,인간과 초월적 존재의 로맨스
# 예측: 어망망,박보영
#
# 정답: 삼성라이온즈,이승민
# 예측: 이승민,2승 도전
#
# 정답: 바흐,방일 연기,스포츠 스타들 '올림픽 취소론' 가세
# 예측: 바흐,올림픽 취소론,코로나19,올림픽,코로나19 긴급사태
#
# 정답: 권순욱,복막암 4기,투병 근황,가수 보아,뮤직비디오 감독,인스타그램,기적
# 예측: 권순욱,복막암 4기 투병,인스타그램,장문의 글,복막암
#
# 정답: 히라이 가즈오,실적,소니,소니 턴어라운드
# 예측: 출니,이단아,소니부활,출세,전자 왕국,슈퍼맨저,슈퍼쇼크
#
# 정답: 아우디 딜러,2021 아우디 딜러 어워즈,탑 아우디언,코로나19,고진모터스,한서모터스
# 예측: 20더디,2021 아우디 딜러 어워즈,세일,A/S,영업원 시상
#
# 정답: 충북 오전 5~40mm 장맛비,오후 시간당 20mm 이상 소나기,호우특보
# 예측: 충북지역은 대체로 흐리고 오전,장맛비,오후,대기불안정에 의한 돌풍,천둥,번개,시간당 20mm 이상의 강한 소나기,호우특보,호우특보,호우
#
# 정답: 배터리경량화,환경규제,국제항공운송협회,항공기
# 예측: 배비경,배터리 경량화,배터리
#
# 정답: 도쿄올림픽,최종예선,리투아니아,남자농구
# 예측: 남투아니아,한국 남자농구
#
# 정답: 보건의료서비스,초고령화사회,박재범 구청장,마을건강센터,부산
# 예측: 초고령사회,초고령화사회,박재범 부산 남구청장,초고령화사회 대비,초고령화남구,초고령사회
#
# 정답: 기후 변화 시위,그레타 툰베리,유럽
# 예측: 유럽 곳곳 기후 변화 시위,학생들 대거 참여,기후를 위한 학교 파업,기후를 위한 학교 파업,독일 브란덴부르크 문 앞,영국 유엔기후변화협약 당사국회의,학생들 대거 참여
#
# 정답: 정부,무주택자,1주택자,부동산 정책 보완,국회,협의,부동산 정책
# 예측: 부동산 정책 보완,국회와 협의,홍남기 경제부총리 겸 기획재정부 장관,부동산 정책 보완,실수요자
#
# 정답: 표영호,방송 복귀,유튜브 채널 푸하하TV,정호근의 심야신당,사업,장사,소상공인
# 예측: 표영호,장사나 하지 뭐,장사나 하지,백종원,표영호
#
# 정답: 롯데칠성음료,무라벨 탄산수,트레비 ECO,출시,아이시스 8.0 ECO,칠성사이다 ECO,무라벨 동참
# 예측: 롯데칠성음료,친환경,트레비,무라벨 탄산수
#
# 정답: 르노삼성,판매,전년 동기 대비 28%,내수,수출,QM6,LPG모델
# 예측: 르노삼성,4월 9344대 판매,내수/수출,전년 동기 대비 28% 감소,지난달 내수,수출,판매
#
# 정답: 탈출러,대탈출4,강호동,백사회
# 예측: 대사회,강호동,대탈출4,김종민,동동현,신동,유병재,피오,백사회
#
# 정답: 독립만세,송은이,AKMU,김민석,재재,프로그램 종영,소감
# 예측: 송만세,송은이,AKMU,김민석,재재
#
# 정답: british,soccer,league,premier,english
# 예측: Bremier League,britain,poodlia,player publications,britain,poodlia
#
# 정답: 경기,키움,이승호,한화
# 예측: 이승호,경기 끝내자
#
# 정답: 공익채널 다문화TV,명사 초청 대담프로,장성철이 만난 사람과 사람들,다문화 사회,사회통합,MC 장성철,이승율 이사장
# 예측: 공익채널 다문화TV,명사와 나누는 다문화 대담,장성철이 만난 사람과 사람들,명사 초청 대담프로
#
# 정답: 금융 위기,붕괴 조짐,중국 부동산 시장
# 예측: 중국 부동산 시장,붕괴 조짐,국제 신용평가사 스탠더드앤드푸어스,중국 전역에 200만채,중국 대출,29.1%,금융 위기
#
# 정답: 무직타이거 빼빼로,세븐일레븐,MZ세대,단독 출시
# 예측: 무Z세대,무직타이거,무직아빠,편의점,세븐일레븐,무직아빠,뚱랑이 캐릭터,KOTD,무직 허니버터아몬드빼빼로
#
# 정답: 일출,첫 일출,팔월
# 예측: 팔월 첫 일출,포토친구갤러리
#
# 정답: LG전자,장애인 접근성 자문단,한국장애인소비자연합,접근성 전문가,가전제품,접근성 평가,지표 개발
# 예측: 장애인 접근성 자문단,LG전자,장애인 접근성 자문단,서울 여의도 LG트윈타워,한국장애인소비자연합 대표, 윤대식 LG전자 대외협력담당 전무
#
# 정답: 춘천,일교차,강원
# 예측: 강원, 내일 일교차 커,춘천 오전 17도·오후 28도
#
# 정답: 화이자 접종,국민청원,안면마비,언어장애
# 예측: 화이자 접종 후 안면마비,언어장애,국민 청원 등장
#
# 정답: 75개 해외기업,화상면접,청년 200명 채용,고용노동부,KOTRA,한국산업인력공단,2021 상반기 해외 취업 화상 면접 주간
# 예측: 고용상 면접,해외 취업 화상 면접 주간, 75개 해외기업,화상 면접,청년 200명 채용,고용노동부,12일 KOTRA,한국산업인력공단
#
# 정답: 김단비,우리은행,FA,여자농구
# 예측: 우리단비,우리은행,자유계약선수,아산 우리은행
#
# 정답: 권리금 없음,유리창 메모,이대앞 상가들,폐업 상태,임대문의,코로나19,대학가 상권
# 예측: 권리금 없음.고대,이화여대
#
# 정답: 삼성바이오,모더나 백신 위탁생산,삼성바이로직스,조선일보,보도,삼성바이오,모더나
# 예측: 삼성바이오로직스,기자내용,백신 위탁생산
#
# 정답: 임혜숙,과학기술정보통신부 장관,임명 강행,김정숙 여사,청와대,발끈,정만호
# 예측: 임기숙,임정숙,김정숙,임명 강행,청와대,김정숙,품격 지켜라,정만호
#
# 정답: 날,무더운,,아침,소나기,미세먼지,비오고
# 예측: 가을,기상청,입추,가을,기상청,전국 소나기,기상청,강원도,충청권,경북권내륙,경남권
#
# 정답: 이찬원,팬미팅,생애 두 번째,시계,유튜브 채널,COVID-19 방역 수칙,사회적 거리두기
# 예측: 팬바보,이찬원,팬미팅,이찬원,데이트 팬미팅,이찬원,이찬원,유튜브채널
#
# 정답: 낮 최고기온,북동부,빗방울,산지,제주,고기압
# 예측: 제주주,낮 최고기온 28~29도,제주국제공항,제주지방기상청,5일
#
# 정답: 노지훈,장모,응급실,살림하는 남자들 시즌2
# 예측: 노지훈,장모 업고 응급실 行수술,수술,청천벽력 같은 진단,KBS 2TV 예능 프로그램 '살림하는 남자들 시즌2',장모
#
# 정답: 경기게임문화센터,월 1회,게임문화 세미나,경기도,보호자,청소년,비대면 온라인 생방송
# 예측: 경기게임문화센터,월 1회 '경기 게임문화 세미나',게임문화 활성화 전담 센터,경기게임문화센터,게임과 관련된 직업을 갖고 싶은 청소년
#
# 정답: 히밥,김희철,호동
# 예측: 김동철,히밥,인스타그램,인스타그램,카톡,술트리트파이터,호동 형,히밥 먹성,인스타그램
#
# 정답: 추미애,경솔·무책임,철회하라,이낙연 의원직 사퇴
# 예측: 추미애,의원직 사퇴,이낙연,무책임,철회
#
# 정답: 뉴욕증시,인플레이션 우려,기술주,다우지수,나스닥지수,스탠더드앤드푸어스500지수,경제 지표
# 예측: 뉴욕증시,인플레이션 우려,나스닥 지수,다우존스30산업평균지수
#
# 정답: 팝업,스토어,방문,남주혁,디올 갤러리아,백화점
# 예측: 남주혁,디올 갤러리아 백화점 팝업 스토어,입점 스토어 방문
#
# 정답: 유영재,경찰수업,제이월드,이미지,연기변신
# 예측: 유영재,KBS2 새 월화드라마,경찰수업,출연
#
# 정답: 롯데 조지훈 응원단장,응원
# 예측: 롯데 조지훈,지원단장,서울 잠실야구장,2021 신한은행 SOL KBO리그,두산 베어스,롯데 자이언츠
#
# 정답: 씨엘,아시아계 혐오 반대,캠페인 동참,팀베리체리,#스톱 아시안 헤이트,리프트,무료·할인 차량 탑승
# 예측: 씨엘,아프리카계 혐오 반대 캠페인,미국 차량 공유 업체,리프트,미국
#
# 정답: 박상기,조국,안양지청 수사외압,이광철,김학의 전 법무부 차관,이성윤,긴급출국금지 요청서
# 예측: 안양지청,김학의 전 법무부 차관,출금금,출금금지,조국과 이광철,김광주,조국 전 법무부 장관
#
# 정답: 제주경찰청,여성폭력 대응 TF팀
# 예측: 제주경찰청,여성폭력 대응 TF팀,여성폭력 범죄,위기대응 체계,여성폭력 대응
#
# 정답: 하나님의 사랑,게리채프먼
# 예측: 하나리 채프먼,선물
#
# 정답: 공항,크래비티 태영,일본 출국,더 스타 넥스테이지
# 예측: 크래비티 태영,더 스타 넥스테이지,공연
#
# 정답: SSG 오원석,2021 KBO리그,롯데 자이언츠,SSG 랜더스,부산 사직구장
# 예측: SSG 오원석,2021 KBO리그,롯데 자이언츠,롯데 자이언츠,롯데 자이언츠,SSG 랜더스,경기
#
# 정답: MLB,롭 맨프레드,경기 취소,선수 압박,메이저리그 노사
# 예측: M 선수 압박,MLB 사무국,MLB트레이드루머스,FAFA,한달 취소,한달
#
# 정답: 인생 류현진,양키스 전,승리 날려
# 예측: 류인진,양키스,불펜 난조,류승
#
# 정답: 한국수입자동차협회,수입상용차,스카니아
# 예측: 수입월드,수입상용차,68대 판매,수입 상용차,67대
#
# 정답: 김남선 CFO,최수연 CEO,네이버,주주총회
# 예측: 최이버 최수연 대표,김남선,책임 경영,자회사 주식,1억 800만원 매입,경영진
#
# 정답: 한국통신연대,대법관 후보,윤석열 제주지법원장,신한일보,오석준 제주지법원장
# 예측: 윤정부 첫 대법관 후보,오석준 제주지법원장
#
# 정답: 아울러 임용모 장관정책보좌관 박재준가 보건복지부의 이양조명센터에 강요 집행하는 보건복지부의
# 예측: 과장과장
#
# 정답: 관세청,신성장 산업,관세행정,코로나19,신산업,인천지역,바이오
# 예측: 관세청,신성장 산업 발전을 위한 관세행정 집중 지원,바이오,반도체,자동차
#
# 정답: 유의,인권기구,교통안전
# 예측: 강원,교통안전 유의 유의,5~20mm 비,교통안전 유의
#
# 정답: 하이트진로,필라이트,브랜드 패키지,리뉴얼,발포주 브랜드,소비자,패키지 디자인
# 예측: 하이트진로,출시 5년차 필라이트 브랜드 패키지 리뉴얼,리뉴얼,상쾌한 청량감,국내산 100% 보리,저온숙성공법,맥아와 보리 환상 비율
#
# 정답: 천우희,앵커,신하균
# 예측: 천우희,변수 흡수해 표현하는 배우,신하균,미스터리 스릴러,앵커,신하균,최면 치료 과정
#
# 정답: 넷플릭스,공개 하루 만에 전세계 1위,정이,강수연,유작
# 예측: 넷플릭스,배우 고 강수연,유작,넷플릭스,넷플릭스
#
# 정답: 막차,거리두기,완화,서울 지하철,심야,코로나19
# 예측: 거리철도,새벽 1시 막차,거리두기,서울교통공사
#
# 정답: 2023 산청세계전통의양항노화 엑스포 조직위,동의보감,경상남도,산청군,,
# 예측: 20청세계전통의약항노화엑스포조직위 사무처,2023년 9월 15일부터,10월 19일까지,'미래의 약속,세계 속의 전통의약'을 주제로,산청 동의보감촌,한방의료클러스터 일원
#
# 정답: 송교창,현대모비스,유재학,한국가스공사,KCC
# 예측: K교창,현대모비스,양 팀,KCC,전주 KCC,울산 현대모비스,23일 전주실내체육관에서 열린 2021~2022시즌 정규리그 경기
#
# 정답: 한국유통학회,비대면 시대,오프라인 트랜스포메이션,대한상공회의소,춘계학술대회,정지영 현대백화점 부사장,더현대 서울의 성공전략
# 예측: 춘계학술대회,한국유통학회,비대면 시대의 오프라인 트랜스포메이션,춘계학술대회
#
# 정답: 안나 셰르바코바,러시아 피겨스케이팅 여자 싱글
# 예측: 러시아겨스케이팅 시니어 그랑프리 시리즈,여자 싱글 쇼트프로그램,러시아 여자 싱글 선수들의 경쟁
#
# 정답: 김건희 오빠,타진요,윤석열 대선후보,유흥주점
# 예측: 윤진열,타진요,증명서 위조,증명서
#
# 정답: 원호,올블랙,서울 강서구,방화동,김포국제공항,제주도,개인 일정
# 예측: 올호 고장,올블랙,제주도,김포국제공항,김포국제공항
#
# 정답: 강제추행,오거돈,권력형 성범죄,검찰
# 예측: 오거돈,부산시장,임직원 추행 혐의,재판,상속인
#
# 정답: KLPGA,박민지,2승달성
# 예측: K여자프로골프,박민지,시즌 2승,KLPGA투어
#
# 정답: 후원금,조광일,홀트아동복지회,학대피해아동 돕기
# 예측: 쇼미더머니 10,조광일,홀트아동복지회,후원금 전달,쇼미더머니 10,우승,
#
# 정답: 진구,시청각장애인,내겐 너무 소중한 너
# 예측: 시청감각장애인,진구,시청각장애인,지원법
#
# 정답: 우먼스 폰탄카 와플 베얼리 그린',나이키,11일 국내 발매
# 예측: 나이키,우먼스 폰탄카 와플 베얼리 그린,11일 국내 발매,폰탄카 와플,스포츠,트랙디자인
#
# 정답: 대박부동산,장나라,정용화,폐건물,비명,긴급상황,생활밀착형 퇴마 드라마
# 예측: 장대희,정용화,납치현장,대박부동산,장나라,정용화,긴급상황
#
# 정답: 아이스크리에이티브,일상 공감 콘텐츠 V컬러링,크리에이터 '된다'
# 예측: 크컬러링,크리에이터,크리에이터 지적재산권,V컬러링,아이스크리에이티브
#
# 정답: 오리온 강을준 감독,할로웨이,이대성,오용준
# 예측: 고양 오리온,프로농구,원주 DB,이대성,이승현,이정현
#
# 정답: 국민의힘,원내대표,김기현,윤호중,원내대표 선거,윤석열,대표 권한대행
# 예측: 국민의힘 원내대표,김기현,윤호중,대여 전략
#
# 정답: 미 캘리포니아주,마스크 의무화 유지,질병통제예방센터(CDC),백신 접종 완료자,마스크 착용 해제,사업체·점포 전면 재개,마크 갤리 보건복지부 장관
# 예측: 미 캘리포니아주,마스크 의무화 유지,백신 접종 완료자,실내외,마스크
#
# 정답: 김태환 부상,울산현대,홍명보 감독
# 예측: 무패 이어가려는 홍명보,태환
#
# 정답: 김치 발효,유산균 발효,발효과학,풀무원,발효 김치,유산균,류코노스톡
# 예측: 풀무원,발효과학,풀무원 톡톡김치,전 제품 리뉴얼,한국 김치만의 독창적인 특징인 '발효 풍미',한국인이 가장 좋아하는 '겨울 김장김치의 시원한 발효 감칠맛',발효과학,풀무원 톡톡김치
#
# 정답: 남욱 변호사,700억,유동규,김만배,대장동 개발,화천대유,성남도시개발공사
# 예측: 김욱 변호사,유동규,천화동인 4호 실소유주,대장동 개발 로비·특혜 의혹 사건
#
# 정답: THAILAND,AMNESTY,PROTEST,HUMAN RIGHTS
# 예측: ToAILAND HUMAN RIGHTS,Thailand,20May 2021,a,mnesty International demonstration
#
# 정답: 비비고 국물요리,유명 노포 음식,비비고 특설렁탕,비비고 특양지곰탕
# 예측: CJ제일제당,비비고 냉동 국물요리 신제품,비비고 특설렁탕,비비고 특양지곰탕
#
# 정답: 현대비앤지스틸,회사채 수요예측,2700억원 주문,모집액의 5배 이상,500억원 규모 회사채 발행,만기 3년,신용등급 A
# 예측: 현대비앤지스틸,사전자 수요예측,2700억주,현대비앤지스틸,증액 발행
#
# 정답: 한미약품,실적,R&D,성과,연구개발
# 예측: 한미약품,연구개발 성과 필요한 시점
#
# 정답: 문재인 대통령,국무총리임명장 수여,김부겸
# 예측: 국부총리,김부겸,문재인 대통령, 임명장 수여
#
# 정답: 최병암 산림청장,벌채 현황 점검,충북 제천시 봉양읍,사유림,산림경영계획 인가,임목수확,장마철 대비
# 예측: 최채 현황,최병암 산림청장,제천시 관계자,제천시
#
# 정답: 산사태,고속도로,통제
# 예측: 산원,하산운터널,도로 통제,부사고,도로
#
# 정답: 국토부 소화물 인증제 선정,우아한청년들·바로고,생활물류서비스산업발전법
# 예측: 우아한청년들,바로고,국토부 소화물 인증제
#
# 정답: government,protest,colombia,strike
# 예측: sOLOMA,STRIKE,aoponstrators,march during the,colombia,government,goververgia,ga,ga,ga,ga
#
# 정답: 음원,록밴드,발매,유튜브,블루바이닐,밴드 더발룬티어스,백예린
# 예측: 백예린,더 발룬티어스,정규 1집 발매,정식 데뷔 블루바이닐,백예린,사운드클라우드,유튜브 음원 공개
#
# 정답: 구세주,신인왕,이재
# 예측: 신인왕 강력 후보,구세주 역할,신인 이재현
#
# 정답: 스토킹 피해,유튜버 릴카
# 예측: BJ 릴카,스토킹 피해,신변의 위협,스토킹 범죄
#
# 정답: 정다운,UFC 트렁크쇼,박준용,(주)신한코리아,UFC브랜드
# 예측: U한 UFC 중량급 쌍두마차,정다운,박준용,정다운
#
# 정답: 영국철도노조,최대규모 파업,임금인상,구조조정 중단요구
# 예측: 영국 철도노조,최대규모 파업,기차역,노조원,노조원 약 4만명,임금인상
#
# 정답: SK스토아,선물하기 전문관,온라인 선물하기 서비스,고도화,전 상품 확대 적용,인기상품 추천,카테고리별/브랜드별/가격대별
# 예측: SK스토아,선물하기 전문관,SK스토아몰,온라인 선물하기 기능,전 상품 확대 적용,인기상품을 선물 용도에 따라 카테고리별/브랜드별/가격대별로 나눠 고객에게 추천해준다.
#
# 정답: 한컷,삼우실
# 예측: 삼우실,한컷,커플룩,외혼
#
# 정답: 철원 공설운동장,김호중,2022평화콘서트,철원군
# 예측: 김호중,김호중,강원 철원군 철원 공설운동장,KBS 2022 평화콘서트,우리, 이곳에서,콘서트
#
# 정답: 정진운,경리,4년 열애,마침표,2AM,나인뮤지스,YNK엔터테인먼트
# 예측: 정정운,경리,꽃신 커플,결혼,더불어,더불어,미스틱스토리,미스틱스토리,결혼
#
# 정답: 윤봉길,김구 선생,아름다운 만남 특별기획전,윤봉길의사기념관
# 예측: 특별군 기획전,김구 선생,예산군,예산군,윤봉길의사기념관
#
# 정답: 심석희,징계 효력 정지 가처분,쇼트트랙
# 예측: 심석희,징계 효력 정지 가처분 신청,쇼트트랙,베이징 동계올림픽
#
# 정답: 전여빈,대세,넷플릭스 영화,tvN 드라마,엄태구,송중기,양극단의 역할
# 예측: 전여빈,무표정,무한 말,몸은 여려도 눈은 뜨거워 보여야 했다,대세
#
# 정답: 전희철 감독,KGC,SK
# 예측: K희철 감독,KGC인삼공사 정관장 프로농구 정규리그 홈경기,KGC전 첫 승,전희철 감독,유머슛,KGC
#
# 정답: SK쉴더스,사이버가드,보안서비스,구독형 라인업 강화
# 예측: SK쉴더스,구독형 보안 서비스,사이버가드,구독형
#
# 정답: 대구시향,쇼팽,신예 피아니스트 임주희,발레리 게르기예프,임주희
# 예측: 신주희,쇼팽,정기연주회,대구시립교향악단,정기연주회,정명훈,러시아 음악의 차르,세계적 지휘자 발레리 게르기예프,부사르트,모차르트,피가로의 결혼
#
# 정답: 김지민,박영진,김준호,JDB엔터테인먼트,유민상,김민경,유쾌한 웃음
# 예측: 김준호,박나래,JDB엔터 친필,신년 인사,새해 웃음 폭탄 예고,JDB엔터,김선호,유민상,김지민,김지민,유민상,김민경
#
# 정답: 이재명,윤석열,5·18 메시지,더불어민주당,경기지사,노무현 전 대통령,서거 12주기
# 예측: 이재명,윤,5·18 메시지,광광열,5·18 메시지,여권 인사,공격,대권주자,윤 전 총장은
#
# 정답: 민주당,헌법 파괴,검수완박,모든 방안 강구,대통력직인수위원회
# 예측: 검수완박,국회,국힘,국정 저지
#
# 정답: 자율주행,테슬라 오토파일럿,운전대 손 떼고,화장,나홀로 뒷자리 탑승,사망자,부상자
# 예측: 자율주행,화장,나홀로 뒷자리 탑승,테슬라 모델3 운전자
#
# 정답: 현세린,OK저축은행 박세리INVITATIONAL
# 예측: 현세린,비바람,비바람,충주 실크리버 컨트리클럽,OK저축은행,박세리,INVITATIONAL
#
# 정답: 반갑지만,'조심',추석 연휴 코로나,가족
# 예측: 추,연휴,코로나,조심,Noneyphrases
#
# 정답: 비주얼,태국재벌,신주아,원피스,포즈
# 예측: 태국재벌,신주아,운동장,대저택 드레스룸,나홀로 패션쇼
#
# 정답: 조선통신사선,선상박물관,문화재청 국립해양문화재연구소,체험형 문화공간,선상박물관 문화기행,역사문화자원,대한민국 4대 관광도시
# 예측: 선상박물관,해양문화재단,조선통신사선
#
# 정답: 이효리,2세 계획,이유,엄마의 희생,노력,사랑
# 예측: 이리,2세 계획 전한 이유
#
# 정답: 천우희,마카롱,형형색색 마카롱,비주얼,비와 당신의 이야기
# 예측: 천우희,형형색색 마카롱,먹기 아까운 비주얼,인스타그램 스토리,인스타그램 스토리,사진
#
# 정답: 연쇄 충돌
# 예측: 경기차들,중앙선 넘어 연쇄 충돌,5명 다쳐
#
# 정답: 윤대통령,'캄보디아 환아',대통령실 초청
# 예측: 윤대통령 부부,대통령실 초청,캄보디아 환아,대통령실 초청 None
#
# 정답: 대장동,유동규,재판,김만배,남욱,정영학,연기
# 예측: 유장동,김만배·남욱,첫 재판 연기
#
# 정답: 삼성 라이온즈,포항 경기,13연패,2022 프로야구
# 예측: 13연패,약속의 땅,삼성,포항,삼성 라이온즈,2022,26일
#
# 정답: 준우승 김태형,두산 베어스
# 예측: 준우승,김태형 감독,KT 위즈,준우승,KT,미니클
#
# 정답: 강석우,스타 2세,강석우 딸,아빠를 부탁해
# 예측: 스타석우 딸,강다은,스타 2세
#
# 정답: 이브,시청률,방송된 tvN 수목드라마,복귀작,서예지
# 예측: 서예지 복귀작,시청률 하락세,시청률 반등,서예지,이브
#
# 정답: 루친스키,첫 안타 허용,잠실야구장,2021 KBO리그,NC 다이노스,LG 트윈스,경기
# 예측: 루친스키,첫 안타를 허용,잠실야구장,2021 KBO리그 NC 다이노스,LG 트윈스
#
# 정답: 물리치료 버스 운영,의료취약지 이동 물리치료 버스
# 예측: 강진군보건소,의료취약지 이동 물리치료 버스 운영,옴천면 황곡경로당,옴천면 황곡경로당,지역주민,병원통원 불편함 해소
#
# 정답: 흉기,테이저건,60대,임신한 아내,검거
# 예측: 임대성,임신,경찰관,테이저건,경찰관
#
# 정답: 김미연,집 공개,서초,여의도,SNS,새 집,높은 층고
# 예측: 김미연,서초,집,김미연,인터넷,SNS,미니미니언
#
# 정답: 최애템,에녹,한강,의문의 여성,손태진,디너쇼 미션,불타는 트롯맨
# 예측: 에녹,한강,손태진,가방,프로그램 불타는 트롯맨,t롯맨
#
# 정답: 김기현,구미 기업인,간담회,국민의힘,당 대표 권한대행,원내대표,20일
# 예측: 김기현,구미 기업인,간담회,인사말,김대현
#
# 정답: 야놀자 맛집 서비스,레스토랑
# 예측: 야집 서비스,야놀자,비대면 온라인,맛집 서비스,국내 웨이팅 서비스 기업 '나우버스킹'
#
# 정답: 2PM 옥택연,임신,결혼,황찬성,축하,동현배
# 예측: 2PM,황찬성,옥택연,임신
#
# 정답: 치명적 뒤태 자랑하는 아들과 아침 일상,양미라
# 예측: 아미라,아들 아들,아들 아침,인스타그램,굿모닝,민들레베이비D+335,아들 서태,인스타그램
#
# 정답: 지역22번째,대전 90대,확진자,신종 코로나 바이러스
# 예측: 대전대 확진자,17일 만에 숨져,미국 질병통제예방센터,2019 신종 코로나바이러스 모형도,대전,신종 코로나바이러스
#
# 정답: CJ온스타일,공식 론칭,채널 통합,라이브 취향 쇼핑플랫폼,모바일 큐레이션,애플리케이션,고객 취향
# 예측: 취J온스타일,TV·모바일 경계 넘나드는 취향쇼핑,CJ온스타일,공식 론칭,TV·모바일 경계 넘나드는 취향쇼핑
#
# 정답: 외눈 표현 논란,추미애 전 법무부 장관,정면 반박,장애인 비하,야당과 여당 중진 의원,사과 요구,김어준의 뉴스공장
# 예측: 외눈,표현,추미애,비하,차별,비하,비하
#
# 정답: 부산시,건축물 철거공사,분별해체 의무화,건설폐기물,재활용 극대화,폐합성수지,폐보드류
# 예측: 건설시,500m2 이상 건축물 철거공사 시,분별해체 의무화,건설폐기물,분별해체
#
# 정답: 봄기운,환절기,니트 베스트,레트로,가성비템,스타일링
# 예측: 니트 베스트,옷장 속 든든한 가성비 아이템,니트 베스트,데님 팬츠,데님 스타일링
#
# 정답: 단풍 풍경,평양
# 예측: 북한양의 가을 단풍 풍경,조선중앙TV,모란봉,천리마거리,단풍 풍경,가을 단풍 풍경,북한,조선중앙TV
#
# 정답: 강철부대,UDT 김상욱,2049 시청률 전체 1위,채널A,SKY,예능프로그램,육탄전
# 예측: 리얼철대대,UDT,김상욱,리얼 특수대대,동시간 연합작전
#
# 정답: 벌금형,협박,배상,공갈미수,불륜
# 예측: 불불회,불륜,상간남 협박,법원,불륜,공갈미수,불륜
#
# 정답: 롯데,프랑코,선발 출격,부산 사직구장,2021 KBO 프로야구,SSG 랜더스,롯데 자이언츠 경기
# 예측: 롯데 프랑코 선발,부산 사직구장,2021 KBO 프로야구,SSG 랜더스,롯데 자이언츠
#
# 정답: ROMANTIC DAY 2021,오반,피아노맨,박재정,컬래버 레이션,빈첸,임수
# 예측: 오반,빈첸,박재정X피아노맨,임수,컬래버 싱글,연말,로멘틱팩토리 콘서트,선공개,이별,코로나19 이슈,코로나19
#
# 정답: 남부발전,한국에너지정보문화재단,빛드림 사업,ESG 경영
# 예측: 에너지에너지정보문화재단,남부발전,업무협약 체결,ESG 경영 선도를 위한 빛드림 사업,탄소중립 실현,남부발전 태양광 설비 지원
#
# 정답: 장성우,kbo 리그,희생번트
# 예측: 장성우,KT 위즈,KT위즈,키움 히어로즈,KT위즈,KT위즈,KT위즈,KT위즈,KBO 리그
#
# 정답: 쿠팡,김범석,1분기 매출액,42억 달러,상장,뉴욕증권거래소,매출 성장
# 예측: 로팡,로켓적자,매출액,분기 실적,분기
#
# 정답: 잠실구장,2021 KBO리그,LG 트윈스,한화 이글스,미세먼지
# 예측: 잠실구장, 뿌연 하늘,2021 KBO리그,LG 트윈스,한화 이글스,경기 취소
#
# 정답: 2022년도 도시재생 뉴딜,산청군,옥산지구 도시재생,뉴딜공모 사전준비
# 예측: 옥청군 옥산지구 도시재생,총사업비 165억원,옥산지구 도시재생 뉴딜 공모,신청대상사업 활성화 계획,현장 컨설팅
#
# 정답: 북악산,파란 하늘,서울도심
# 예측: 파파 하늘,정병혁 기자,서울,북악산,서울 도심
#
# 정답: 해인사,팔만대장경,중도,원각스님,부처님
# 예측: 해만대장경,원각 스님,중도의 마음,코로나19,해인사,장경판전
#
# 정답: 맞춤형 콘텐츠,세라젬,리서치,부모님 연구소
# 예측: 세라젬,국내 기업,'부모님 연구소',전 세대를 아우르는 공감대 형성과 가족 간 화합 도모,리서치 보고서
#
# 정답: 허위 세금계산서,전인장,삼양식품 회장,항소심,감형,페이퍼컴퍼니,기소
# 예측: 허허 세금계산서,전인장 삼양식품 회장,허위 세금계산서
#
# 정답: 2021 전국농민총궐기,행진
# 예측: 전국농민총궐기,행진
#
# 정답: 빅뱅 태양,컴백 암시,34번째 생일,팬들,고마움,인스타그램 스토리,메시지
# 예측: 빅효린,빅뱅 태양,컴백,인스타그램,컴백,정규 활동
#
# 정답: 최수영,침수,한효주,양치승,성훈,재난지원금,김주헌
# 예측: 한치승,체육관,한효주,한수영,진서연,한효주,한효주,한효주,한효주,한효주,최수영,진서연,한효승
#
# 정답: 쌍용차,조사보고서 제출,기업계속 가치,한영회계법인
# 예측: 한영회계법인,조사보고서 제출,쌍용차,기업계속 가치 6200억원,청산 가치
#
# 정답: 코로나 19,시상식,2021 서울빛초롱축제 한지 등 디자인 공모전,서울관광재단,전소희
# 예측: 20빛초롱축제 한지 등 디자인 공모전,서울관광재단,전소희씨의 '별처럼 빛나는 고양이',서울시
#
# 정답: 전유진 달성군수 후보 선거사무소 개소
# 예측: 전유진,대구 달성군수 후보,선거사무소,개소식,인사말,대구경북의 유일한 청년여성 후보,청년여성 후보
#
# 정답: 두산 베어스,유희관,개인 통산 100승,KBO리그 통산 32번째,장호연,장원준,프로 12년 차 시즌
# 예측: 두산 베어스,유희관,개인 통산 100승,KBO리그 통산 32번째,두산과 전신 OB,소속 선수,장호연 장원준
#
# 정답: 가상인간,세아,조손가정,스마일게잍,,기부금
# 예측: 스마일게이트,가상 인간 '세아',조손가정 지원,기부
#
# 정답: 대한불교 천태총,단양 구인사,나경원 전 의원
# 예측: 단경원 전 의원,단양 구인사 방문,대한불교 천태총,총본산 충북 단양 구인사,무원 스님,경내
#
# 정답: 이재명,국민의힘,화천대유
# 예측: 이재명,화천대유,국민의힘,더불어민주당,대권주자,더불어민주당
#
# 정답: 서건창,통산 1200안타,대기록 달성,2021 KBO리그,한화 이글스,키움 히어로즈,경기
# 예측: 서건창,통산 1200안타,통산 1200안타,2021 KBO리그,한화 이글스
#
# 정답: venice,biennale,architecture
# 예측: Italy,venice,Italy,pavilion
#
# 정답: 지식재산권 침해,메타버스,상표권위반,퍼블리시티권 침해
# 예측: 아타버스 플랫폼,이미 '의류'
#
# 정답: 방탄소년단,비티에스 퍼미션 투 댄스 온 스테이지,LA 공연,콘서트
# 예측: 방탄소년단 LA 콘서트,비티에스 퍼미션 투 댄스 온 스테이지,프레닝 무대,무대,오랜만,정국
#
# 정답: 롯데 자이언츠,5연패 탈출,KBO리그,KIA 타이거즈,17-9 승리,안치홍,딕슨 마차도
# 예측: 롯데,KBO리그,17-9,17-9,롯데 자이언츠,2021 KBO리그 홈경기,KBO리그
#
# 정답: 생활습관 개선,심장,소변,항생제,역류,선천적·후천적 이유,질환
# 예측: 위류성,심장,소변,항생제,식도
#
# 정답: 산림치유,코로나19,장계향문화체험교육원,치유관광 예비 협력지구
# 예측: 치체부,치유관광,경상북도,웰니스 관광 협력지구,경상북도 선정,풍기인삼축제
#
# 정답: 이의리,아쉬운 강판,광주-기아챔피언스필드,2021 KBO 프로야구,LG 트윈스,KIA 타이거즈,선두타자 오지환
# 예측: 이의리 강판,강판,강판,이의리,2021 KBO 프로야구,LG 트윈스, KIA 타이거즈,강판
#
# 정답: 모다페 홍보대사,한예리,서울 중구 더 플라자 호텔,MODAFE 2021,기자간담회,영화 '미나리',제40회 국제현대무용제
# 예측: 모다페,한예리,국제현대무용제,제40회 국제현대무용제,한국예술종합학교 전통예술원
#
# 정답: 무리뉴,맨체스터 유나이티드,에릭바이
# 예측: 맨유,조세 무리뉴,맨체스터 유나이티드
#
# 정답: 최지만,복귀 후 3경기 연속 안타와 타점,무릎 부상,결승타 포함 멀티히트,팀 6연승 견인,볼티모어 오리올스 경기,라인업
# 예측: 최AL전,최지만,티히트,팀 6연승,볼티모어 오리올스,전담
#
# 정답: 이육사 탄생,온라인 문화제,비대면 문화제,성북문화원 유튜브,일제감정기,중국,조선
# 예측: 민족시인 이육사,발생 117주년,성북구,유튜브,성북문화원 유튜브,성북문화원 유튜브 생중계
#
# 정답: 담양 농특산물,담양장터
# 예측: 담양 농특산물 쇼핑몰,담양장터,온라인 쇼핑몰,담양장터
#
# 정답: 바이에른 뮌헨,아스톤빌라,카니 추쿠에메카,잉글랜드 16세 최고 재능,유럽 구단들,풋볼인사이더,리버풀
# 예측: 풋이에른 뮌헨,잉글랜드 16세 최고 재능,스스톤빌라,추쿠에메카
#
# 정답: 실점,양현종,포수,칭찬,메이저리그,텍사스 레인저스,호세 트레비노
# 예측: 양현종,포수,미국 텍사스 레인저스
#
# 정답: 로맥,박종훈,노브랜드 버거 100호점
# 예측: 노노버 버거 100호점 오픈,박종훈·로맥,로맥,노브랜드 버거 100호점
#
# 정답: 발대식,프랜차이즈산업,상생협의회
# 예측: 프랜차이즈산업 상생협의회, 프랜차이즈산업 상생협의회,발대식
#
# 정답: 경기도,공동주택감사,부적정 적발
# 예측: 경기도,상반기 공동주택 감사,입주민에게 손해를 입힌 관리주체와 입주자대표회의,부적정 사례,부정사례,원감감사,민원감사,기획감사
#
# 정답: pandemic,covid19,russia,coronavirus
# 예측: Russia,Russia,Russia,recoronavirus,legonavirus
#
# 정답: 티그라이 내전,에티오피아,인권침해
# 예측: U USTR,에티오피아,말리,기니 특혜관세 대상 제외,에티오피아
#
# 정답: 한인 여성,종신직 의원,연아 마틴 의원,세계한인정치인협의회
# 예측: 연아 마틴,정치,총리,종신직 의원
#
# 정답: KT위즈,이대은,박시은
# 예측: 선두 수성,마법사 군단,KT 위즈,10월
#
# 정답: 김기현,국민의힘 당 대표 권한대행,원내대표,문재인 대통령,면담 요청,장관 후보자 3명,김부겸 국무총리 후보자 인준
# 예측: 김기현,인사권자,문대통령,면담,인사권자,인사권
#
# 정답: 문재인 대통령,광주글로벌모터스,준공 기념행사,발언
# 예측: 문재인 대통령,광주글로벌모터스,준공 기념행사,언급행사,언급행사,2021.4.29
#
# 정답: 진천군 보건소,민원업무,보건소,재개
# 예측: 진북 진천군보건소,민원업무,원스톱,코로나19 확산 방지,일반진료,한방진료,치과진료, 물리치료,건강진단결과서 발급,제증명
#
# 정답: 허참,간암 투병,별세
# 예측: 가족오락관 MC,허참,간암 투병중,빈소
#
# 정답: 국내 발생,원숭이두창,잠복기 입국
# 예측: 무증상 잠복기,원숭이두창,감시,감시,감시,방역 강화,감시,발열체크
#
# 정답: 축구 광팬,축구장,루이스 밀링턴,방문,일본팬
# 예측: 전세계 축구장,영국,영국 팬,영국
#
# 정답: 가상 인플루언서,모델,한국경제,로지,홍보대사
# 예측: 모델·홍보대사,오로지
#
# 정답: 수아레즈,완벽투,고우석,세이브,LG,NC,잠실구장
# 예측: 수아레즈,LG,NC,홈경기,수아레즈,고우석 세이브
#
# 정답: 한국P&G 팸퍼스,아르모니,프리미엄 기저귀
# 예측: 한국P&G,아르모니,오코텍스 스탠다드 100,스킨헬스얼라이언,코튼
#
# 정답: 빈센조,김영웅,송중기
# 예측: 빈센조,김영웅웅
#
# 정답: 정치적 논란,고발장,검·경,공수처,무혐의,중립성 시비
# 예측: 고수처장,고발장,이성윤 황제조사,공수처장
#
# 정답: 북한,노동당 기관지,노동신문,1950년대 전후 복구건설 시기,천리마 시대,투쟁 강조,오늘의 시련
# 예측: 북한,노동신문,1950년대 복구건설 시기,천리마 시대,투쟁,시련
#
# 정답: 신세계면세점 부산점,소외계층 청소년 장학금,장학금 지원
# 예측: 신세계면세점 부산점,소외계층 청소년 장학금,장학금 지원,부산공동모금회,부산시청,부산점 점장,부산 지역민
#
# 정답: 넬리 코르다,고진영,lpga,펠리칸 챔피언십,BMW 레이디스 챔피언십
# 예측: 고진영,넬리 코르다,한국 군단
#
# 정답: 덕온공주체,국립한글박물관,한글날,덕온공주,한글
# 예측: 덕온공주 글씨로 만든 '덕온공주체' 2종 무료 배포,국립한글박물관,덕온공주 친필 자료 글씨체,세로쓰기용
#
# 정답: 김소연,이상우,펜트하우스,유튜브 채널,모노튜브,카페,스태프들
# 예측: 김소연,이상우 등장,김소연 월드 #3,SBS 드라마,펜트하우스,스콘,케이크
#
# 정답: 최지만,결승타,생일 선물,복귀
# 예측: 메이타,최지우,메이저리그,볼티모어
#
# 정답: 에스파,귀가,코로나19,음성 판정
# 예측: 카파,윈터,닝닝,코로나19 음성 판정 후 귀가
#
# 정답: 단식농성,비대위원장,의정부시의회,박지현
# 예측: 박지현,더불어민주당 전 비대위원장,단식농성,의정부시의원
#
# 정답: 임대주택,신혼희망타운,노형욱 국토교통부 장관,행복주택,중형 공급,공공임대
# 예측: 노형욱 국토부 장관,신혼희망타운,중형 공급 확대,국토부 유튜브 채널,주택정책,주택
#
# 정답: 조코 위도도,기지 건설,인도네시아,발사 기지,비악섬,뉴욕타임스,원주민
# 예측: 우주 우주선,비악섬,인도네시아
#
# 정답: 독립만세,송은이,몸무게 커밍아웃,홈메이드 다이어트용 간식,고구마 말랭이,수제 곶감,무청 시래기
# 예측: 독립만세,송은이,홈메이드 다이어트용 간식 만들기,로망,로망,JTBC독립만세
#
# 정답: 호우특보,비,강원
# 예측: 강원,10개 시군 호우특보,강풍,강동,인근,화천 광덕산,철원 85 mm
#
# 정답: 이낙연,봉축법요식,조계사,부처님 오신날
# 예측: 봉축법요식,더불어민주당 이낙연 전 대표,2021,2055년 부처님 오신날 봉축법요식,서울 종로구 조계사,불기 2565년 부처님 오신날
#
# 정답: 야놀자,여기어때,여행플랫폼,광고모델
# 예측: 여행 플랫폼 여기어때,업계 1위,방송,연예인,광고모델
#
# 정답: 공공·금융개혁,세계 5강,이재명 후보,신경제 비전 선포식
# 예측: 이재명 더불어민주당 대선구,공공·금융개혁,신경제 비전,국민소득 5만달러,주가 5000 돌파,과학기술혁신 부총리·기후에너지부 신설,과학기술혁신 부총리제,과학기술혁신 부총리제,국가 과학기술 혁신 혁신
#
# 정답: 보이스4,빌런,tvN,시즌4,112 신고센터 대원들,골든타임,범죄 현장
# 예측: 김이스4,김재욱,권율·박병은,시즌4,신빌런 등장
#
# 정답: 주4일제,대선 이슈,주 52시간 근무,대한민국 사회,미국 기업,스페인 정부 차원,일본 실험
# 예측: 주4일제,우리나라,주52시간,주5일제,주4.5일,근로기준법 개정안,국회의회 통과
#
# 정답: 윤석열,대통령 집무실,공약이행,김용현,안보공백,예산편성
# 예측: 윤석열 대통령 당선자,용현
#
# 정답: 사조펫푸드,프리미엄 펫푸드,벤티 그레인프리,반려동물
# 예측: K푸드 전문기업,사조펫푸드,K쇼핑,펫푸드 '벤티 그레인프리,K쇼핑,K쇼핑 판매방송,사조펫푸드,K쇼핑
#
# 정답: 넷마블·코웨이,동해안,기부,산불성금,산불피해,희망브리지
# 예측: 넷불성금 동참,동해안 산불 피해,복구,희망브리지,산불성금 동참,산불성금 동참,종단대순진리회
#
# 정답: 코인,시장,비트코인,나쁜놈,기업,금융
# 예측: 코인 그리고 머스크,금융가 나쁜놈,금융가 나쁜놈,금융가
#
# 정답: coronavirus,nepal,covid19,pandemic
# 예측: Npal,condown,confirmed,population,confirmed,confirmed,cases of the new coronavirus variant,cathmandu,nepal,20May 2021
#
# 정답: 문 대통령,애브릴 헤인스,미국 국가정보국 국장,접견,청와대
# 예측: 애커릴 헤인스,미 국가정보국장 접견
#
# 정답: 감자,북한,과학기술,증산
# 예측: 감자 증산
#
# 정답: 청년당원,유승민,후보,경선
# 예측: 유승민,유승민,2030 청년당원 간담회,2030
#
# 정답: 손흥민,울버햄튼,선발 출전,리그 18호골,차범근,역대 최고,토트넘 홋스퍼 스타디움
# 예측: 손흥민,챔피언스리그,울브스전 선발 출전,차붐 대기록,18호골,차범근,챔피언스리그
#
# 정답: 빗썸,한국채택국제회계기준 변환 재무제표상,비덴트,연합뉴스,올해1분기 빗썸코리아
# 예측: 비신,비트코인 내재 변동성,비트코인
#
# 정답: 이강인,바야돌리드전,선발 출전,발렌시아,메스타야 스타디움,스페인 프리메라리가,35라운드
# 예측: 이강인,바야돌리드,2020-21시즌 스페인 프리메라리가,발렌시아,발렌시아
#
# 정답: 엔하이픈,켈리 클락슨 쇼,퍼포먼스,인기,미국
# 예측: 엔리 클락슨 쇼,엔하이픈,미국 인기 토크쇼,전세계,환호 무대
#
# 정답: 뒷자석,불에 탄 시신,원주,승용차 화재
# 예측: 승 승용차 뒷좌석,시신,원주소방서,원주 판부면 금대리
#
# 정답: K-WATER 한강유역본부,교육물품 기부
# 예측: 한-water 한강유역본부,교육물품 기부 현장
#
# 정답: 중대본,김부겸 총리,정부서울청사,코로나19,중앙재단안전대책본부
# 예측: 김부겸 총리,코로나19,중대본 발언,중앙재난안전대책본부 회의,김부겸 총리
#
# 정답: 오승환,KBO리그,500경기 출장,세이브 달성,대구 삼성라이온즈파크,삼성 라이온즈,LG 트윈스
# 예측: 오승환,KBO리그 500경기 출장,세이브,대구 삼성라이온즈파크,삼성 라이온즈
#
# 정답: 윤석열,힌남노,대비,빌딩풍,선조치,후보고
# 예측: 힌남노,윤석열,대통령,위기관리센터
#
# 정답: 월드 오브 탱크,스팀 출시,워게이밍,MMO 액션 게임,인기 타이틀
# 예측: 워게이밍,월드 오브 탱크,스팀,스팀 출시,스팀,온라인 게임
#
# 정답: 대권 행보,정세균 총리,대구 방문
# 예측: 대세 행보,대권 행보,정세균 전 총리,대구 방문
#
# 정답: 인공지능,창원 LG스마트파크,로봇 기술,5세대 이동통신,로봇,물류로봇,부품 적시 조달
# 예측: LG대스마트파크,디지털 트윈 기술,생산라인,물류로봇
#
# 정답: 양현,리드를 지켜라,서울 구로구,고척스카이돔,2021 신한은행 SOL KBO리그,KT 위즈,키움 히어로즈
# 예측: 양현 리드를 지켜라,서울 구로구,고척스카이돔,2021 신한은행 SOL KBO리그,KT 위즈,키움 히어로즈,경기
#
# 정답: 창원,용인,특례시,수원,고양,-------------------------------------
# 예측: 특례시,경기도,수원,고양,용인시,창원시,특례시,기초단체의 법적지위 유지,광역시 수준의 행정,재정권,특례시
#
# 정답: 김부겸,국무총리,17일 오후,서울,여의도,국회,송영길
# 예측: 김부겸,더불어민주당,김부겸 총리
#
# 정답: 견본주택 오픈,파주 운정신도시,사전예약,제일풍경채 2차 그랑베뉴
# 예측: 제일건설,파주 운정신도시 제일풍경채,2기신도시,A10블록,2기신도시,A10,23층,총 660가구 규모,59m2,84m2,104m2,2기신도시,A10블록,2기신도시 중,두개 택지지구
#
# 정답: 반려견 루니,차태현,멍뭉이,유연석,15년만의 재회,'멍뭉이'
# 예측: 멍유로,연유석x차태현,15년만의 재회
#
# 정답: 진구,부드러운 눈빛,서울 자양동,롯데시네마 건대입구,영화 '내겐 너무 소중한 너',언론시사회,질의응답
# 예측: 진구,서울 자양동 롯데시네마 건대입구,영화,내겐 너무 소중한 너,언론시사회
#
# 정답: cp 심포지엄,우수 사례,일동제약,esg 경영,공정거래위원회
# 예측: 공정GCP 심포지엄,일동제약,공정위 CP,경영성과,CP 운영
#
# 정답: 롯데칠성음료,처음처럼,신규 광고,제니
# 예측: 롯데칠성음료, 처음처럼 신규 광고 온에어,인터넷 채널, TV,인터넷 채널
#
# 정답: 펠로시,미국 하원의장,위안부 문제,정의,문재인 대통령,워싱턴 국회의사당,청와대 국민소통수석
# 예측: 낸로시 미국 하원의장,미국 의회,한반도 비핵화,코로나19 극복,기후변화 대응,미국 의회
#
# 정답: 이미주,러블리즈 하트
# 예측: 러수 이미주,러블리즈 하트,SBS 파워FM,두시탈출 컬투쇼
#
# 정답: 코로나19 여파,보은군,신화여행축제,두해 연속 취소,충북 보은 속리산,신종 코로나바이러스 감염증,예방 차원
# 예측: 코로나19,보은군 '신화여행축제' 두해 연속 취소,코로나19 예방,코로나19 예방,코로나19 예방,축제 취소
#
# 정답: 경기미래교육파주캠퍼스,경기도평생교육진흥원,찾아가는 영어교육
# 예측: 경미래교육파주캠퍼스,오는 11월 25일까지,학교 밖 청소년,사회적 배려계층 청소년 20명,찾아가는 영어교육,코로나19,교육 사각지대 해소
#
# 정답: 개혁입법,건설안전특별법,민주노총 건설노조,결의대회
# 예측: 건설노조,총력투쟁 결의대회,행진,건설안전특별법 제정 및 개혁입법 쟁취
#
# 정답: 김강률,최용제,두산 베어스,SSG 랜더스,경기,8-5 승리,2021 신한은행 SOL KBO리그
# 예측: 두강률,최용제,2021 신한은행 SOL KBO리그,두산 베어스
#
# 정답: 롯데칠성음료,전년동기,영업이익,순이익
# 예측: 롯데칠성음료,1분기 영업이익,작년 동기 대비,416.2% 증가,롯데칠성음료,영업이익,롯데칠성음료
#
# 정답: 가정법원,윤정희,성년후견,면접조사,알츠하이머병,프랑스 거주,바이올리니스트 백진희
# 예측: 알법한 면담,성년후견,윤정희,서울가정법원
#
# 정답: 국고 지원,학교 예산,줌 유료화,교육부
# 예측: 교육 유료화,교육부
#
# 정답: 일론머스크,테슬라,버니센더스 상원의원,부유세
# 예측: 샌론 머스크 테슬라 최고경영자,샌더스 상원의원
#
# 정답: 화요청백전,모태범,홍현희,쩍벌,굴욕,스피드스케이팅 선수,청백팀
# 예측: 화요청백전,모태범,홍현희,쩍벌,굴욕 선사
#
# 정답: 석유공사,친환경 선도 기업,환골탈태,탄소 감축 노력,코로나 사태,석유 수요 급감,생존을 위한 유연성
# 예측: 친석유공사,환골탈태,탄소 감축,코로나 사태,핵심,핵심,국제유가,국제유동,탄소
#
# 정답: 항저우 亞 게임 유도 사령탑,김미정,여자 유도 대표팀 사령탑
# 예측: 김미정,황희태,항저우 亞 게임 유도 사령탑,김미정,여자 지도자,대한유도회,항저우아시안게임 여자대표팀
#
# 정답: 탕웨이,페르소나,마리끌레르,헤어질결심
# 예측: 헤질 결심
#
# 정답: 밤 초콜릿 테린,요리책,프랑스 쿡북,재료,조리법,한국 포털 사이트,김수연 세미콜론 편집자
# 예측: 밤콜릿 테린,프랑스 요리책,프랑스 쿡북
#
# 정답: 주택화재,완주 카센터
# 예측: 완 완주 카센터,불씨,불씨,카센터 뒷편 주택
#
# 정답: 김맹윤씨,부친상
# 예측: 김맹윤씨,김맹윤씨,서울시 서대문구 신촌 세브란스병원 장례식장 특2호실, 발인 3일,경기 광주시 소망교실,장지 경기 광주시 소망교실,
#
# 정답: 수출물량지수,교역조건,수입지수,상승세,한국은행,무역지수,교역조건
# 예측: 수출물량 지수,수출 호조,수입지수
#
# 정답: 몽고메리,삼성 '비밀병기',kbo리그 데뷔전,허삼영 감독
# 예측: 몽고메리,KBO리그,KBO리그,데뷔전,KBO리그,스트라이크존,허삼영 감독
#
# 정답: 삼성전자,Neo QLED 8K,영상 'Neo LIFE',소비자 라이프스타일,이시영,류준열,글로벌 TV 시장
# 예측: 삼성전자,Neo QLED 8K,소비자의 다양한 라이프스타일
#
# 정답: 홍경·최정운,영화부문 남녀신인상 수상,백상예술대상
# 예측: 홍경·최정운,영화부문 남녀신인상 수상,홍경,최정운,백상예술대상,김도윤,류수영,박승준,이봉근,홍경이 후보
#
# 정답: 네이버 라인,넵튠,보드게임
# 예측: 넵드게임,넵튠,네이버 라인,일본 보드게임 공략,3Q 출시,모바일 버전,마그넷,카카오게임즈 계열사
#
# 정답: 확진자,백신,백전투입,제주,확산세
# 예측: 제주진료소,확진자,코로나19 확산세,확진자
#
# 정답: 포항 스틸러스,리그 최강 공격력,이번 시즌,득점 차이,결정력 문제,외국인 선수들,이적
# 예측: 미항,미스터리,상대,공격력,파워리,상대,팔라시오스,리그 전체 1위
#
# 정답: 임금피크제 선배,임금피크제 세대 갈등,임금피크제,금융계
# 예측: 임금계,임금피크제,세대갈등,금융권,금융권
#
# 정답: 허경민,우리 투수 믿음직해요,KBO리그,두산베어스
# 예측: 허경민,2021 KBO리그,두산베어스,SSG
#
# 정답: 새학기 개학,학부모·워킹맘 발동동,돌봄,확산세,확진
# 예측: 새학사,확진자,확진,확진,확진자,확진자,비행
#
# 정답: 안마의자,정수기,SK매직,인덕션,일본 굿 디자인어워드
# 예측: SK매직,디자인어워드,보더리스 인덕션,스탠드형 직수 얼음정수기,소파형 안마의자
#
# 정답: 고민시,미성년자 음주 논란,사과,서울 영등포구,KBS 별관,KBS 2TV 새 월화드라마,오월의 청춘
# 예측: 고고동시, 미성년자 음주 논란 사과,서울 영등포구 KBS 별관,KBS 2TV 새 월화드라마드라마,오월의 청춘
#
# 정답: 트롯매직유랑단,진해성,녹화
# 예측: 진해성,'트롯매직유랑단' 녹화,서울 여의도 KBS,녹화
#
# 정답: 삼성TV·LG냉장고 더오른다,원자재·물류비 부담,물류난
# 예측: 삼성TV·LG냉장고,러시아발 '원자재·물류비',가격
#
# 정답: 김주형,컷 오프,서요섭,KPGA,신한동해오픈
# 예측: 서동은,신금융그룹,KPGA선수권,김주형,신한동해오픈,KPGA선수권
#
# 정답: 언니네이발관,이석원,윤여정,아카데미 수상,조영남,강한 불쾌감,블로그
# 예측: 이석원,조영남,아카데미상 수상,마지막 수상,마지막 자아,아카데미상 수상,이석원,한심
#
# 정답: montreal,reax,hockey,stanley cup
# 예측: Sontreal Reax, Stanley Cup,montreal,swednesday,kockey Stanley Cup,finals betweens
#
# 정답: 럽스타그램,송지효,김종국,주꾸미 게임,런닝맨
# 예측: 김지국과 송지효,셀카,양세찬,럽스타그램,주꾸미 게임,김종국,송지효
#
# 정답: 사내이사,삼성전자,연봉,경영진,사외이사,보수
# 예측: 삼성년원,평균 연봉,최고 경영진 5인,평균 연봉 63억원,삼성전자,금융위원회와 한국거래소
#
# 정답: 해운대,해운대 해수욕장
# 예측: 해운대,해운대,시민들
#
# 정답: 악재,한화,인대,골절,발목,노수광,KBO리그
# 예측: 한화의 악재,노수광,부상,4주 진단,발목 골절,염좌,한화 이글스,한화 외야수 노수광
#
# 정답: 지한솔,KLPGA 투어 E1 채리티오픈
# 예측: KLPGA 투어 E1 채리티오픈,하민송,지한솔,2R 선두,하민송
#
# 정답: 스크린골프,한국골프장 스크린골프 시장 공략,LG 프로빔
# 예측: 스크 스크린골프,LG,김캐디,업무협약,골프앱,스크린골프,김캐디
#
# 정답: 유라시아 경제통합,광역두만강협력 프로젝트
# 예측: 광역생두만강협력,GTI,유라시아 경제통합 플랫폼,유라시아 경제통합 플랫폼,GTI,유라시아,유라시아,글로벌투자통상국장,전홍진 중국 옌볜대 객좌교수
#
# 정답: 곡성군,유근기 군수,청년농업인,육성 확대,릴레이 캠페인,농촌진흥청,응원 릴레이
# 예측: 유성군 유근기 군수,청년농업인,농촌진흥청,챌린지
#
# 정답: 문재인 대통령,조 바이든 미국 대통령,첫 정상회담,한반도 비핵화,백신 확보,쿼드,배터리
# 예측: 백,백신,백신 공급 허브,조 바이든,문재인 대통령,바이든 미국 대통령
#
# 정답: 전속계약,정의제,HB엔터테인먼트
# 예측: 배우제, HB엔터테인먼트,전속계약,주상욱,안재현,배우
#
# 정답: 애드리브,이상한 변호사 우영우,연기 장인,강기영
# 예측: 애기 장인,우영우,애드리브,강기영,연기 장인,ENA채널 수목드라마,이상한 변호사 우영우
#
# 정답: 러시아산 석유,쥐스탱 트뤼도,석유 수입 단계적 중단,미국,젤렌스키 우크라이나 총리,정상회의,G7
# 예측: G7,러시아산 석유 단계적 중단,푸틴 경제,G7 정상회의,미국,러시아산 에너지 의존,트뤼도,우크라이나
#
# 정답: 방탄소년단,소파이 스타디움,보랏빛 물결
# 예측: 보 로스앤젤레스 소파이 스타디움,방탄소년단,대면 콘서트,보랏빛 물결,대면 콘서트
#
# 정답: 크리스찬 루부탱,더보이즈 영훈
# 예측: 더보이즈 영훈,더비들,더보이즈 영훈,팝업스토어,포토콜
#
# 정답: 한강공원,이상한 소리,CCTV 감지,촬영,똑똑한 가로등,스마트폴,서울시
# 예측: 스마트강원서 이상한 소리나면 CCTV,스마트 가로등 설치,스마트도시 기반시설,스마트폴
#
# 정답: Spain,horses,Morocco,Migrants
# 예측: sorber,spain,tuesday,tuesday,tues,spain,tuesday,tuesday,spain,tuesday
#
# 정답: 함지훈,모비스,골밑 돌파,프로농구
# 예측: 함지훈,프로농구,프로농구 4강 플레이오프,KGC,모비스
#
# 정답: 코로나19,중대본 회의,권덕철 장관,중앙재난안전대책본부 1차장,서울 종로구,정부서울청사,신종 코로나바이러스 감염증
# 예측: 코로나19,중앙재난안전대책본부,권덕철,중앙재난안전대책본부 1차장,중앙재난안전대책본부 회의
#
# 정답: 낮 최고 25도,밤부터 먹구름,내일 전국 비소식,기상청,수도권 충청권 전라권 제주도,낮 기온 20도 내외,일교차 큼
# 예측: 내,전국 대부분 맑다,낮 최고 25도,비소식,비소식,전국 비소식,전국 비소식,전국
#
# 정답: 한덕수 총리,태국 총리,기념촬영
# 예측: 한덕수 총리
#
# 정답: 데 헤아,의문의 일러스트,관심,SNS,나루토,철조망,데일리 메일
# 예측: 데 헤아,의문 일러스트,데일리 메일,SNS,일본 에니메이션,나루토
#
# 정답: 이태원,핼러윈,일상회복,코로나19 방역
# 예측: 이러운 핼러윈 데이,이태원 거리
#
# 정답: 김건희,코미디,특검법
# 예측: 김동희 특검법,코미디
#
# 정답: 윤석열,소득보장정책,토론회
# 예측: 윤석열 정부,소득보장 정책 토론회,인하대 사회복지학과 윤홍식 교수,노동시민사회 새정부 정책 제안 연속 토론회
