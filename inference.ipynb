# %%
import os
import warnings

import pandas as pd
import torch

from transformers import (
    AutoConfig, AutoTokenizer, AutoModelForSeq2SeqLM, 
    Seq2SeqTrainingArguments, Seq2SeqTrainer, 
    DataCollatorForSeq2Seq, 
)

from datasets import Dataset

import nltk

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jake/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
NGPU = torch.cuda.device_count()
NCPU = os.cpu_count()
NGPU, NCPU
# Out:
# (1, 16)

# %% [markdown]
# # Paths and Names

# %%
### paths and names

DATA_PATH = 'data/preprocess_v2.pickle'
MODEL_CHECKPOINT = '.log/ainize_kobart_news_v2/checkpoint-3170'

# %% [markdown]
# # Training Args

# %%
per_device_train_batch_size = 2
per_device_eval_batch_size = 2
gradient_accumulation_steps = 1

predict_with_generate=True
generation_max_length=128

# %% [markdown]
# # Model & Tokenizer & Metric

# %% [markdown]
# - 모델과 토크나이저, 그리고 평가지표를 계산하는 데 사용할 함수를 불러옵니다.
# - 모델의 config에는 사용하지 않는 설정이 포함되어 있습니다. 삭제합니다.

# %%
config = AutoConfig.from_pretrained(MODEL_CHECKPOINT)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT, config=config)
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

# %% [markdown]
# # Functions

# %% [markdown]
# - 모델 훈련을 위해 전처리를 수행해주는 함수를 선언합니다.
# - 입력 문장이 input이 되고 요약문이 label이 됩니다.
# - tokenizer를 사용해 input_ids로 변환하고 입력값에는 attention_mask를 생성해줍니다.
# - 입력 문장에 prefix를 추가하여 성능 실험을 해볼 수 있으나 지금은 적용하지 않겠습니다.

# %%
prefix = "generate keyphrases: "

max_input_length = 512
max_target_length = 128

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["input_text"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True, padding="max_length")

    labels = tokenizer(examples["target_text"], max_length=max_target_length, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %% [markdown]
# # Inputs and Labels

# %%
data_df = pd.read_pickle(DATA_PATH)

# %%
dataset = Dataset.from_pandas(data_df).shuffle(seed=100).train_test_split(0.2, seed=100)
train_dataset = dataset['train']
eval_dataset = dataset['test']

# %%
train_dataset = train_dataset.map(preprocess_function, 
                                  batched=True, 
                                  num_proc=NCPU, 
                                  remove_columns=train_dataset.column_names)

eval_dataset = eval_dataset.map(preprocess_function, 
                                batched=True, 
                                num_proc=NCPU, 
                                remove_columns=eval_dataset.column_names)
print(train_dataset)
print(eval_dataset)
# Out:
# Map (num_proc=16):   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map (num_proc=16):   0%|          | 0/317 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 1268
# })
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 317
# })

# %%
tokenizer.decode(train_dataset['input_ids'][0])
# Out:
# '<s>generate keyphrases: 광주시, 물류운송 드론 기술개발 공모 선정 광주시가 2백킬로그램급 화물운송용 드론 기술개발 공모사업에 선정됐습니다. 이번 사업은 오는 2025년까지 수소연료전지를 기반으로 최대 시속 백킬로미터의 속도로 탑재 중량 2백 킬로그램급 드론개발과 실증 사업 기반을 구축하는 것입니다. 광주시는 지난 1월 LIG넥스원 등과 화물용 드론 개발 업무협약을 체결했으며, 수소연료전지 기술 개발과 함께 물류 운송용 드론 시장 선점을 통한 지역 산업 성장에도 도움이 될 것으로 크게 기대하고 있습니다. 최송현</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenizer.decode(train_dataset['labels'][0])
# Out:
# '<s>광주시,물류운송 드론,기술개발 공모,선정,2백킬로그램급 화물운송용 드론,2025년,수소연료전지</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %% [markdown]
# # Train

# %% [markdown]
# - 상단에서 선언한 HP와 각종 변수들로 training_args를 생성합니다.

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir='./.temp',
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,

    predict_with_generate=predict_with_generate,
    generation_max_length=generation_max_length,
)

# %% [markdown]
# - 배치 단위로 padding처리를 하여 훈련 속도를 높히기 위해 data_collator를 선언합니다.
# - 생성한 객체들을 trainer에 포함시켜 훈련 준비를 마칩니다.

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, padding=True)

trainer = Seq2SeqTrainer(
    model=model,
    
    args=training_args,
    
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %% [markdown]
# - 훈련을 시작합니다.

# %%
# trainer.train()

# %% [markdown]
# - 옵티마이저 스테이트를 포함한 훈련 재개에 사용할 파일들을 삭제해줍니다.
# - 추후 불러올 모델과 토크나이저 관련 파일만 남겨둡니다.

# %%
# keep = [
#     'added_tokens.json',
#     'config.json',
#     'pytorch_model.bin',
#     'special_tokens_map.json',
#     'tokenizer.json',
#     'tokenizer_config.json',
#     'vocab.txt'
# ]

# ckpts = os.listdir(output_dir)
# for ckpt in ckpts:
#     ckpt = os.path.join(output_dir, ckpt)
#     for item in os.listdir(ckpt):
#         if item not in keep:
#             os.remove(os.path.join(ckpt, item))

# %% [markdown]
# # Generate

# %% [markdown]
# - 훈련을 마치면 Evaluation Loss 기준 Best 모델이 로드되어 있습니다.
# - trainer는 Greedy Search를 수행하도록 설정되어 있습니다.
# - Evaluation 데이터를 활용해 모델의 출력을 간단히 살펴봅니다.

# %%
preds = trainer.predict(eval_dataset)
# Out:
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='158' max='159' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [158/159 01:02 < 00:00, 2.52 it/s]
#     </div>

# %%
for data, pred in zip(eval_dataset, preds.predictions):
    context = tokenizer.decode(data['input_ids'], skip_special_tokens=True)
    summary = tokenizer.decode(data['labels'], skip_special_tokens=True)
    pred = tokenizer.decode(pred[2:], skip_special_tokens=True)
    # print(f'입력: {context}')
    print(f'정답: {summary}')
    print(f'예측: {pred}', end='\n\n')
# Out:
# 정답: 지한솔,KLPGA 투어 E1 채리티오픈
# 예측: KLPGA 투어 E1 채리티오픈,하민송,지한솔,2R 선두,하민송
#
# 정답: 박명수,한수민,딸,데이트,사춘기,민서,SNS
# 예측: 박박수,한수민,딸,데이트,사춘기,예원학교 한국무용과
#
# 정답: 크리스찬 루부탱,더보이즈 영훈
# 예측: 더보이즈 영훈,더비들,더보이즈 영훈,팝업스토어,포토콜
#
# 정답: 롯데 자이언츠,5연패 탈출,KBO리그,KIA 타이거즈,17-9 승리,안치홍,딕슨 마차도
# 예측: 롯데,KBO리그,17-9,17-9,롯데 자이언츠,2021 KBO리그 홈경기,KBO리그
#
# 정답: 프랑스 축구,선두 파리 생제르맹,복통,콘테 감독,담낭염
# 예측: 파SG,음바페 실축,프랑스 축구,파리 생제르맹,승리
#
# 정답: 김치 발효,유산균 발효,발효과학,풀무원,발효 김치,유산균,류코노스톡
# 예측: 풀무원,발효과학,풀무원 톡톡김치,전 제품 리뉴얼,한국 김치만의 독창적인 특징인 '발효 풍미',한국인이 가장 좋아하는 '겨울 김장김치의 시원한 발효 감칠맛',발효과학,풀무원 톡톡김치
#
# 정답: 카카오,태·조·이·방·원,코스피지수,코스닥지수,인터넷,삼전은 '5만전자',신고가
# 예측: 코스전은 '5만전자',태·조·이·방·원
#
# 정답: 이별 리콜,성유리 외모 지적
# 예측: 외별 지적,성유리,이별 리콜,연인,사랑,이별
#
# 정답: 남다름,박서준,이른 나이에 자진 입대,정해인,유승호
# 예측: 박서준,남다름,이른 나이에 자진 입대,이승호,유승호
#
# 정답: 신세계면세점 부산점,소외계층 청소년 장학금,장학금 지원
# 예측: 신세계면세점 부산점,소외계층 청소년 장학금,장학금 지원,부산공동모금회,부산시청,부산점 점장,부산 지역민
#
# 정답: 전유진 달성군수 후보 선거사무소 개소
# 예측: 전유진,대구 달성군수 후보,선거사무소,개소식,인사말,대구경북의 유일한 청년여성 후보,청년여성 후보
#
# 정답: 전용면적 84m2,첫 '20억 아파트',경기도
# 예측: 경기도 첫 '20억 아파트',전용면적 84m2 아파트,20억 클럽,공공 주도 공급,비현실적인 '공공 주도 공급',풍선효과
#
# 정답: K리그1,K리그2,주민규,김현욱,다이내믹 포인트,파워랭킹,경기 데이터
# 예측: k리그,주민규,K리그2김현욱,다이내믹 포인트,파워랭킹,리그1
#
# 정답: 줄리어스·파타푸티안,올해 노벨 생리의학상
# 예측: 올해리어스·파타푸티안,올해 노벨 생리의학상,
#
# 정답: 주택화재,완주 카센터
# 예측: 완 완주 카센터,불씨,불씨,카센터 뒷편 주택
#
# 정답: 이재명 지원금,김부겸,중앙선대위 회의,재난지원금 추가지급
# 예측: 재재 여력이 있다는 이재명 지원금,민주당 이재명 대선 후보,재난지원금 추가 지급,김부겸,당정 갈등
#
# 정답: 함지훈,모비스,골밑 돌파,프로농구
# 예측: 함지훈,프로농구,프로농구 4강 플레이오프,KGC,모비스
#
# 정답: 검정고시,충북도교육청,만학,장옥순 할머니,손수춘 할아버지,대원대,극동대
# 예측: 장학 대학생,장옥순 할머니,손수춘씨,대원대,극동대 입학
#
# 정답: 박범계,더불어민주당,법무부,검수완박,김의겸,의원
# 예측: 박범계 의원,법무부 시행령 개정 관련 기자회견,기자회견,기자회견,검수완박,검수완박
#
# 정답: 아카데미 여우조연상 윤여정,연기발자취
# 예측: 아여정,아카데미 여우조연상,연기발자취
#
# 정답: 양양군,공중화장실,금지행위,강력 단속,안전하고 위생적인 이용 환경,캠핑 관광객,수도·전기시설 무단사용
# 예측: 양양군,공중화장실,금전단속,안전하고 위생적인 사용환경,안전,안전,안전,안전
#
# 정답: 특별할 것 없는 그리운 일상,고즈넉한 풍경,경북,상주,낙동강
# 예측: 특별천대,상락,낙동강 제1경,경천대
#
# 정답: 전적,삼성,kt
# 예측: 수적
#
# 정답: 권성동,기업,노동부,근로자,주52시간제,고용노동부
# 예측: 고용성동,주 52시간 개편안,노동부,고용노동부
#
# 정답: 이태원 사고,이재용,현대차그룹 회장,합동분양소,이태원 참사 추모
# 예측: 이생원 참사,이재용,이재용,이재용 회장,이태원
#
# 정답: 국제우주정거장,우주선,협력,비상,소유즈,미국,러시아
# 예측: 국제우주정거장,우주선
#
# 정답: 아스트라제네카,접종 시작,서울 금천구보건소,의료진,신종 코로나바이러스,2차 접종,백신 접종
# 예측: 아스트라제네카,백신 접종,2차 접종 시작,2월 26일
#
# 정답: 호러어드벤처 게임,바이오하자드 빌리지,출시,게임피아,캡콤아시아,PS4,PS5
# 예측: 호러어드벤처 게임,바이오하자드 빌리지,캡콤아시아,게임피아,캡콤아시아,게임아트
#
# 정답: 리듬체조,국가대표 선수,신수지,골프
# 예측: 신수지,골프채 들고 역대급 미모,시원한 미소,인스타그램,골프,골프,골프,신수지,베트남어
#
# 정답: 한예리,더 플라자 호텔,다이아몬드홀,MODAFE 2021,기자간담회,환한 미소
# 예측: 한예리,환한미소,서울 중구 더 플라자 호텔 다이아몬드홀,MODAFE 2021,기자간담회,홍보대사,기념촬영
#
# 정답: 모범택시,이호철,쌍둥이,이솜,증거 찾기,고군분투,이유준 죽음
# 예측: 모범택시,이호철,쌍둥이,증거 찾기,이유준 죽음,드라마,모범택시,시신없는 살인사건
#
# 정답: 대전 인공지능 이음마루,인공지능 산업 육성,개방형 혁신 공간,인공지능
# 예측: 대전 인공지능 이음마루,인공지능 산업 육성,대전테크노파크,인공지능 스타트업 관계자,대전시 정책방향,인공지능 정책방향,인공지능 이음마루
#
# 정답: 충북화장시설,백신 유급휴가제,부산지역
# 예측: 백지역 7개 중견기업,백신 유급휴가제,부산시
#
# 정답: 대한외국인,MSG워너비,KCM,오종혁,원슈타인,김동규,강철부대
# 예측: 대한외국인,KCM,강철부대,원슈타인,PRG워너비,노래,승승장구,KCM,승승장구,대한외국인
#
# 정답: 딸,럭셔리,최선정,비키니,하와이,수영
# 예측: 선은숙 며느리,최선정,비키니 자태,하와이
#
# 정답: LALISA',스우파,리정 지효 이삭,MV 출연,YGX,블랙핑크 리사
# 예측: 스무보,리정 지효,리사,블랙핑크 리사,MV 출연,스우파,리정
#
# 정답: 윤순진 위원장,산업통상자원부,국정감사
# 예측: 윤순진,산업통상자원중소벤처기업위원회,국정감사, 질의,답변,윤순진,탄소중립위원회,산업통상자원부
#
# 정답: 키움,선발,이강철,고영표,kt위즈,연승 기록,11연승
# 예측: 키움,약했던,KT,KT위즈,KBO 리그,준플레이오프,KBO 리그,토종 에이스,KBO 리그
#
# 정답: 한일 과거사 이견,G7,북한 도발 자제,비핵화 협상 참여,김부겸,국무총리 후보자,인사청문회
# 예측: 한일 과거사,비핵화 협상 참여,G7,북한 도발 자제,코로나19,국무총리 후보자,국무총리
#
# 정답: bmx,2020,testing,japan,olympics,tokyo
# 예측: tokyo,2020,test event at Ariake Urban Sports Park,tokyo,tokyo,2020,test event ata,tokyo,tokyo,tokyo,tokyo,2020
#
# 정답: 네이버 라인,넵튠,보드게임
# 예측: 넵드게임,넵튠,네이버 라인,일본 보드게임 공략,3Q 출시,모바일 버전,마그넷,카카오게임즈 계열사
#
# 정답: 고 강수연,한국영화,영화인생,발인
# 예측: 한국 강수연,한국영화,반세기 동안의 영화인생,한국영화,세계에 알린
#
# 정답: 학폭 의혹,고소장 제출,손석구
# 예측: 학폭 의혹,고소장 제출,배우 손석구,고소장 제출,인스타그램,학폭 의혹
#
# 정답: 정치적 논란,고발장,검·경,공수처,무혐의,중립성 시비
# 예측: 고수처장,고발장,이성윤 황제조사,공수처장
#
# 정답: 컬투쇼,슈퍼스타K2,데이드리머,존박,노래,이무진
# 예측: 컬투쇼,존박,이무진,감동,감동,데이드리머,음악,감동,어플렌드
#
# 정답: 김흥수,열애,문야엘,
# 예측: 열애,김흥수,사랑,스카이 브릿지 데이트,김흥수
#
# 정답: 김주형,컷 오프,서요섭,KPGA,신한동해오픈
# 예측: 서동은,신금융그룹,KPGA선수권,김주형,신한동해오픈,KPGA선수권
#
# 정답: 뱅크샐러드 마이데이터 인증서,초개인화,뱅크샐러드
# 예측: 뱅크샐러드,초개인화,마이데이터,뱅크샐러드
#
# 정답: 산사태·침수 주의,50mm 폭우,충남 부여군 부여읍
# 예측: 충사태,침수 주의,충남 부여군 부여읍
#
# 정답: 문재인 전 대통령,시위,평산마을,퇴임100일,여름휴가
# 예측: 문재인전 대통령 사저,공지,평산마을,퇴임 100일 행사,시민단체
#
# 정답: 아무튼 출근,미주기자,홍지은,목조주택,건축탐구 집
# 예측: 미주 방송기자,밥벌이,홍지은,MBC 미주 기자,목조주택,건축탐구-집
#
# 정답: 영하권,추위,체감온도,울산,강풍예비특보,건조주의보
# 예측: 울산하추위, 체감온도,강풍예비특보,울산
#
# 정답: -> 박정천,무력사용,특수한 수단,한미연합훈련,끔찍한 대가
# 예측: 북한,김정천,한미 연합훈련,특수한 수단,탄도미사일,비질런트 스톰,비질런트 스톰,비질런트 스톰,비난,비경쟁훈련
#
# 정답: 리니지2 레볼루션,최고레벨 확장,신규 에피소드,혼돈의 글루디오,업데이트,넷마블,글루디오 영지
# 예측: 리니지2 레볼루션,최고레벨 확장,신규 에피소드,혼돈의 글루디오
#
# 정답: 성훈,전우애,돈봉투,폭우 피해,양치승,
# 예측: 태우 피해,성훈,양치승,성훈,의리
#
# 정답: fashion week,nigeria
# 예측: Nigeria,Saturday,Oct,20,2021,2201
#
# 정답: 용산구청장 박희영,할 수 있는 건 다 했다,현상,이태원 핼러윈 행사
# 예측: 용산구청장,용산구청장,핼러윈 행사,현상,축제
#
# 정답: 베어즈베스트 청라,김민주,롯데 오픈
# 예측: 롯데민주,롯데 오픈,아홉 번째 대회,인천 베어즈베스트 청라
#
# 정답: 승부처,여름,코스피,글로벌 증시,백신 접종,경제 활동 정상화,기업 실적
# 예측: 올 정점과 테이퍼링 리스크,코스피,글로벌 증시,백신 접종,백신 접종,경제 활동 정상화,기업 실적,각각 높은 저축률,미국의 경기 부양책
#
# 정답: CTA 부사장인터뷰,제이미 카플란,CES 2023
# 예측: 제이미 카플란,CES 부사장,CES 2023
#
# 정답: 확진자,전남,기존 확진자,감염경로,역학조사
# 예측: 전진서 확진자,기존 확진자의 접촉자,감염경로 확인,역학조사
#
# 정답: 웰리카,럭키박스,이벤트,포토리뷰,유산균,프로바이오틱스,저분자 피쉬콜라겐
# 예측: 웰리카,럭키박스,참가자,10명 선정,웰리카 더블유 100억 유산균,패밀리 프로바이오틱스, 다이어트 프로바이오틱스,피쉬콜라겐
#
# 정답: 혼자 사는 사람들,정다은,공승연,영화,롯데시네마,건대입구,언론시사회
# 예측: 혼자 사는 사람들,정다은,공승연,영화,전화,사회초년생
#
# 정답: 윌엔터테인먼트,업무 종료,김소은,매니지먼트
# 예측: 윌엔터테인먼트,김소은,계약 종료,배우
#
# 정답: 포르쉐코리아,한독상공회의소,아우스 빌둥,특성화,마이스터고등학교,독일식 인재양성 프로그램,인재양성
# 예측: 포르쉐코리아,한독상공회의소,아우스빌둥,업무협약,실습,교육,이론 교육 프로그램
#
# 정답: 감독 장민석,유소년축구
# 예측: 장민석 감독,왕년의 스타,축구대회 준우승,왕년의SUN FC,지도자
#
# 정답: 마동석,김동현,범죄도시2
# 예측: 김동현,범죄도시2,마동석,이동현,인스타그램,인스타그램
#
# 정답: 로켓펀치,연희,윤경,시크한 연희,미소 윤경,서울 마포구 합정동,울림엔터테인먼트 사옥
# 예측: 로펀치,연희,윤경,시크한 연희,미미
#
# 정답: 독립만세,송은이,몸무게 커밍아웃,홈메이드 다이어트용 간식,고구마 말랭이,수제 곶감,무청 시래기
# 예측: 독립만세,송은이,홈메이드 다이어트용 간식 만들기,로망,로망,JTBC독립만세
#
# 정답: 장성우,kbo 리그,희생번트
# 예측: 장성우,KT 위즈,KT위즈,키움 히어로즈,KT위즈,KT위즈,KT위즈,KT위즈,KBO 리그
#
# 정답: 강진,후쿠시마,미야기현,도호쿠
# 예측: 강진피해,도호쿠,도호쿠,도호쿠,도호쿠,도호쿠,도호쿠,도호쿠,도호쿠
#
# 정답: 빈센조,김영웅,송중기
# 예측: 빈센조,김영웅웅
#
# 정답: 방역,변이,오미크론,입국,임시생활시설,남아공,PCR
# 예측: 정부,오미크론 변이 확산,남아프리카공화국 등 8개국 입국 제한,중앙방역대책본부,방역 대책,방역강화국가,위험국가,격리면제 제외국가,방역강화국가
#
# 정답: 모두의주차장,쏘카,모두컴퍼니
# 예측: 쏘두의주차장,모두컴퍼니,주유,주차 관련 서비스
#
# 정답: 헤어진 여자친구,흉기난동,징역형
# 예측: 헤어진 여자친구,흉기난동,징역형
#
# 정답: 러시아산 석유,쥐스탱 트뤼도,석유 수입 단계적 중단,미국,젤렌스키 우크라이나 총리,정상회의,G7
# 예측: G7,러시아산 석유 단계적 중단,푸틴 경제,G7 정상회의,미국,러시아산 에너지 의존,트뤼도,우크라이나
#
# 정답: 자율주행,테슬라 오토파일럿,운전대 손 떼고,화장,나홀로 뒷자리 탑승,사망자,부상자
# 예측: 자율주행,화장,나홀로 뒷자리 탑승,테슬라 모델3 운전자
#
# 정답: 김주하,황연주,2021-2022 V리그
# 예측: 김주하,황연주,2021 V-리그,현대건설,흥국생명
#
# 정답: 신규 선임,대한제당,강승우,,,,
# 예측: 대한제당,강승우 대표 신규 선임,대한제당,25일,정기주주총회와 이사회,김기영 대표이사,임기 만료
#
# 정답: 내연기관차,사전 계약,현대차,1만8000대 돌파,캐스퍼
# 예측: 내연기관차,캐스퍼,예약,1만 8940대 돌파,국내 자동차 브랜드 최초 온라인,온라인,국내 자동차 브랜드,온라인
#
# 정답: 단풍 풍경,평양
# 예측: 북한양의 가을 단풍 풍경,조선중앙TV,모란봉,천리마거리,단풍 풍경,가을 단풍 풍경,북한,조선중앙TV
#
# 정답: 금리인하요구권,대출,농협·수협·신협 등 상호금융업권
# 예측: 농협인하요구권,농협,수협,신협,금리인하요구권
#
# 정답: 제주시장 후보자,인사청문회,농지법 위반
# 예측: 제주시장 후보자 인사청문,농지법 위반,청문회
#
# 정답: 충청 메가시티,계룡시,공주시,세종,미니 신도시,대전
# 예측: 충,세종,미니 신도시,충청 메가시티,공주,계룡
#
# 정답: 프로미스나인,이나경,가벼운 출근길,서울 영등포구,KBS본관,KBS 쿨FM,DAY6의 키스 더 라디오
# 예측: 프로미스나인,이나경, 출근길 발걸음
#
# 정답: 출간,편스토랑,레시피,류수영,요리책,박솔미
# 예측: 류리책 출간 고민,편스토랑,류수영,박솔미
#
# 정답: 오심,스물다섯 스물하나,금메달,보나,김태리
# 예측: 스다,스물다섯 스물하나,김태리,보나 꺾고 금메달,오심 논란,오심 논란에,보나,김태리
#
# 정답: 경찰,불가리스 논란,남양유업,압수수색,허위·과장 광고 혐의,식품의약품안전처,식품표시광고법 위반
# 예측: 경찰,불가리스 논란,남양유업,불가리스 논란,서울경찰청,금융범죄수사대,허위·과장 광고를 한 혐의로
#
# 정답: 5·18 강연회,전국 언론인 초청,광주전남기협
# 예측: 5전남기협,5·18 강연회,전국 언론인 초청,5.18 왜곡처벌법과 진상규명,역사기행
#
# 정답: k리그,이동준,쐐기골
# 예측: K기골,이동준,K리그,울산 현대
#
# 정답: 제20대 대통령선거 예비후보 등록,원희룡
# 예측: 제선거관리위원회,제20대 대통령선거 예비후보 등록,원희룡,국민의힘,대권 주자인 원희룡
#
# 정답: 잠실주공5단지,재건축 심의,보류,오세훈 효과,송파구,서울시,정비계획안
# 예측: 송심 보류,오세훈 효과,송파구 잠실주공5단지
#
# 정답: 중국리스크,나토 정상회의,불균형 외교,북한 미사일 대응,정의당
# 예측: 중국 리스크,중국 리스크,윤석열,나토 정상회의,불균형 외교,신냉전 체제
#
# 정답: 콘셉트,오토바이 군단,혜은이,김청,달력제작,박원숙 같이 삽시다
# 예측: 달선녀,달력제작,김청,김청
#
# 정답: 핫이슈 형신,무대 사로잡는 카리스마 눈빛,ISSUE MAKER
# 예측: 핫이슈 형신,효대 사로잡는 카리스마 눈빛,28일 서울 광장동 예스24라이브홀,데뷔 앨범,ISSUE MAKER
#
# 정답: 정부,노마스크,예방접종 완료자
# 예측: 정부,예방접종 완료자 일상회복 지원 방안,노마스크,반포 한강공원,마스크 착용 의무
#
# 정답: 30분,누스레트 괵체,레스토랑,솔트배,스테이크
# 예측: 누만원대 스테이크,누스레트,브리핑,영국 런던,누스레트,호텔
#
# 정답: 디 오픈 우승,캐머런 스미스,LIV,골프
# 예측: 디 오픈 우승 캐머런 스미스,LIV,골프 선수
#
# 정답: 리스크 예방,금감원,종합검사,우리금융
# 예측: 금금융,종합검사,법규,검사 매뉴얼,리스크 예방 성격,금융감독원,종합검사
#
# 정답: 사우디 후원,LIV 골프 시리즈,PGA투어
# 예측: 사우디 후원,LIV 골프 시리즈,2월말 개막전,멕시코,미국,사우디아라비아,사우디아라비아
#
# 정답: amd,뉴욕증시 상승,어닝서프라이즈,알파벳
# 예측: 어닝 서프라이즈,알파벳,뉴욕증시 상승 견인
#
# 정답: 보건의료서비스,초고령화사회,박재범 구청장,마을건강센터,부산
# 예측: 초고령사회,초고령화사회,박재범 부산 남구청장,초고령화사회 대비,초고령화남구,초고령사회
#
# 정답: 온앤오프 효진,만두덕후,손만두 레시피,U+아이돌Live 앱,아돌라스쿨,단기 속성 인강,만두 예쁘게 빚기 대회
# 예측: 온앤오프 효진,만두덕후,만두 레시피,아이돌 그룹 온앤오프 효진,만두빚기 장인,버디utiful 한 끼 상차림 과정,U+아이돌Live 앱의 오리지널 콘텐츠 ‘아돌라스쿨’에서 단기 속성 인강
#
# 정답: -> 설현,인형같은 외모,청룡시리즈어워드
# 예측: 청 설현,인형같은 외모,청룡시리즈어워즈 레드카펫,국내 최초 오리지널 스트리밍 시리즈,넷플릭스,디즈니+,애플TV+
#
# 정답: SK바이오사이언스,코로나19 백신,제조 및 품질,유럽인증,EU-GMP 인증,아스트라제네카,노바백스
# 예측: SK바이오사이언스,코로나19 백신,유럽인증,EU-GMP
#
# 정답: 이렘,일산,예쁨주의보,MBC드림센터,대한외국인,녹화
# 예측: 예쁨주의보,방송이렘,일산,예쁨주의보
#
# 정답: 산다라박,YG엔터테인먼트,전속계약 만료,17년 인연,2NE1,CL,박봄
# 예측: 2GE1,산다라박, YG엔터테인먼트,전속계약 만료,17년 인연,2NE1,산다라박
#
# 정답: 원불교,나상호 교정원장,교단혁신특별위원회,대각개교절,간담회
# 예측: 대상호 교정원장,대각개교절,교단 혁신,제107주년 대각개교절,제발절,대신혁명,교단혁신특별위원회
#
# 정답: 옐런,금리 인상 발언,미국 재무장관,연방준비제도 (Fed),통화정책,기준금리 인상,긴축 일정
# 예측: 금리런,금리 인상 발언,경제 과열,금리 인상,미국 연방준비제도,통화정책 행보
#
# 정답: 기독교,한국기독교역사연구소,한국,강연,일본
# 예측: 한국독교,한국기독교역사연구소,한국기독교사,일본,강연
#
# 정답: 블랙팬서,부산 영선미니아파트,영화 변호인,흰여울마을,쌈마이웨이
# 예측: 영화,변호인,흑백마을
#
# 정답: 영동,한파 특보
# 예측: 강파 특보,강원 영동 새벽,한파 특보
#
# 정답: 기업브랜드 광고,케펜텍,올해의 광고PR상,광고PR상,제일헬스사이언스
# 예측: 케의 광고PR상,케펜텍,광고PR상,기업·브랜드 광고,금상,한국광고PR실학회
#
# 정답: 박범계,대검수사정보정책관실 폐지
# 예측: 박범계,대검 수사정보정책관실,폐지 검토,국감 즈음 결론
#
# 정답: 화재,신불당,귀뚜라미보일러 공장,불길 잡혀
# 예측: 귀불당,귀뚜라미보일러 공장 불길 잡혀,A동,A동,신불당,충남 아산,귀뚜라미보일러 공장,불길 잡기,인명피해
#
# 정답: 신임 CEO·CFO 영입,게임스톱,아마존 임원 출신
# 예측: 게임스톱,아마존,임직원 출신,최고재무책임자,신임 CEO,CFO 영입
#
# 정답: 바이든정부,회의,한미일,정보기관장,박지원,일본
# 예측: 바이든정부,한미일 정보수장회의,박지원 국가정보원장,한미일 정보기관장회의,일본으로 출국
#
# 정답: 울산 유흥업계 집단 반발,집합금지 해제
# 예측: 유흥업계,집합금지 해제
#
# 정답: 롯데,선발투수,스트레일리,부산 사직구장,KBO 프로야구,SSG 랜더스,롯데 자이언츠
# 예측: 롯데,선발투수,스트레스일리,부산 사직구장,SSG 랜더스,롯데 자이언츠
#
# 정답: 친환경 산업,바다의 시대,강원도와 동해
# 예측: 친환경산업,동해시,북평산업단지,산악지형
#
# 정답: 허위 세금계산서,전인장,삼양식품 회장,항소심,감형,페이퍼컴퍼니,기소
# 예측: 허허 세금계산서,전인장 삼양식품 회장,허위 세금계산서
#
# 정답: 캐서린 타이 美 USTR 대표,리셉션
# 예측: 캐서린 타이 美 USTR 대표,리셉션,포시즌스호텔,포시즌스
#
# 정답: 이대녀,폭력,피해자,황예진법,젠더,공약,이대남
# 예측: 이대남,이대녀,젠더 공약,제20대 대통령선거 후보 초청 1차 토론회
#
# 정답: 연천 군부대,화이자백신,돌파감염
# 예측: 연천 군부대,코로나19 백신 접종,확진자,화이자
#
# 정답: 아마추어 배그 모바일대회,크래프톤,미래에셋증권 펍지 모바일
# 예측: 크래프톤,아마추어 배그 모바일대회,미래에셋증권 PMOC,대회 개최,PMOC 2021 하반기,PMPS 시즌2 개최,배틀그라운드 모바일 e스포츠,풀뿌리 e스포츠대회를 적극 육성
#
# 정답: 딜리버리,대본리딩,출연진
# 예측: 딜리버리,출연진
#
# 정답: ATP 단식 우승,이형택,권순우,쾌거,아스타나오픈 대회
# 예측: 권순우,이형택,아스타나오픈 대회 단식,ATP 투어 단식 우승,이형택 이후,18년 만에
#
# 정답: 류승룡,성유빈,김희원,오나라,장르만 로맨스
# 예측: 류승룡,오나라,김희원,류승룡,장르만 로맨스,11월 개봉
#
# 정답: 오세훈,서울시장,복심,강철원,서울시 정무조정실장,서울시 특보 내정,미래전략특별보좌관
# 예측: 오세훈,서울시장,복심,서울시 특보,강철원,서울시 정무조정실장,미래전략특별보좌관
#
# 정답: 동계올림픽,시진핑,코로나19,베이징,대면정상외교
# 예측: 코시,대면 정상 외교,코로나19,동계올림픽 개최,대면 외교,코로나19 발생,중국 국가주석,동계올림픽 개회식,정상급 외빈
#
# 정답: 보치아,김한수,금메달,최예진,정호원,도쿄 패럴림픽
# 예측: 보치아,9연속 금메달 획득,보치아 페어 시상식,최예진,정호원,김한수
#
# 정답: 이홍정,한국기독교교회협의회 총무,27일 오전,경기도 파주시 장단면,통일부 남북출입사무소 북단 DMZ 통문,4.27 판문점선언 3주년 기념행사,발언
# 예측: 이홍정,한국기독교교회협의회 총무
#
# 정답: 문학 새 책,에스에프 소설,마거릿 애트우드
# 예측: 에 새 책 <시녀 이야기>,미친 아담,에스에프 소설,마거릿 애트우드,유스토피아
#
# 정답: 귀여움,이가영,모습,SK텔레콤 챔피언십 2021
# 예측: 귀여움,SK쉴러스,SK텔레콤 챔피언십,1라운드 경기,김해영
#
# 정답: 통화기록,화재 전달시점 공방,SK C&C,화재,카카오 먹통 사태
# 예측: SK재전달시점 공방,SK C&C,화재전파,카카오,현장전파,물재 전파,통화기록
#
# 정답: 한덕수 총리,태국 총리,기념촬영
# 예측: 한덕수 총리
#
# 정답: GS건설,봉담자이 라피네,견본주택 오픈,경기도 화성시,동화지구,아파트,전용면적
# 예측: GS건설,봉담자이 라피네,견본주택 14일 오픈,경기도 화성시
#
# 정답: 유선호,1박2일 시즌4,로드 버라이어티,딘딘,세상 어색한 첫 만남
# 예측: 1딘딘,유선호,친해지길
#
# 정답: 배우 박소이,마우스
# 예측: 마마우트,박소이,박현수
#
# 정답: 추미애,전 법무부 장관,검찰 때리기,천하를 어지럽혀,사건 덮은 기교,안습할 정도,페이스북
# 예측: 추미애,검찰 때리기,검찰조직,천하를 어지럽혀,사건 덮은 기교는 안습할 정도
#
# 정답: 멈춰,30여 명 대피,롤러코스터,에버랜드
# 예측: 에화재,에버랜드,롤러코스터,추석 연휴,
#
# 정답: 티아라 지연,단발병,매력쟁이,서울 영등포구,KBS,드라마 '이미테이션',제작발표회
# 예측: 티아라, 지연,단발병,매력쟁이,KBS, 드라마 '이미테이션'
#
# 정답: 이강인,선발,구보,마요르카,그라나다
# 예측: 이강인,구보,공격,그라나다전,마요르카,선수단
#
# 정답: 진구,부드러운 눈빛,서울 자양동,롯데시네마 건대입구,영화 '내겐 너무 소중한 너',언론시사회,질의응답
# 예측: 진구,서울 자양동 롯데시네마 건대입구,영화,내겐 너무 소중한 너,언론시사회
#
# 정답: 월요일,비내리,이슬비,출근
# 예측: 비내리는 월요일,이슬비,서울 광화문네거리
#
# 정답: 유민상,고생끝에 밥이 온다,우리결혼했어요,이수지,문세윤,찐친
# 예측: 유민상,우결,나만,어플,그리고
#
# 정답: 보상,정책,필수의료 공백,의료 인력
# 예측: 의대 정원 확대,필수의료 공백,의료 인력 부족,중증·응급,소아
#
# 정답: 한국유통학회,비대면 시대,오프라인 트랜스포메이션,대한상공회의소,춘계학술대회,정지영 현대백화점 부사장,더현대 서울의 성공전략
# 예측: 춘계학술대회,한국유통학회,비대면 시대의 오프라인 트랜스포메이션,춘계학술대회
#
# 정답: 대구,유나이티드 시티,2021 아시아축구연맹 챔피언스리그,안용우,에드가,세징야,이근호
# 예측: 대구,유나이티드 시티,ACL 조별리그,세징야,에드가,이근호
#
# 정답: 소음,포항제철소,주물선 고로,발파 해체,포스코,연기,방음 울타리
# 예측: 포물선 고로,발파 해체,포항제철소,포항제철소,발파해체,발파
#
# 정답: 전남동부,충청권,경상권,천둥·번개 동반,비 전국 확대,전라권,경상서부
# 예측: 내,전국적 비 소식,충청권,제주
#
# 정답: 유라시아 경제통합,광역두만강협력 프로젝트
# 예측: 광역생두만강협력,GTI,유라시아 경제통합 플랫폼,유라시아 경제통합 플랫폼,GTI,유라시아,유라시아,글로벌투자통상국장,전홍진 중국 옌볜대 객좌교수
#
# 정답: 비트코인 피싱 피해 예방,FDS,코빗,피싱사이트,가상자산거래소
# 예측: 비트코인 피싱 피해 예방,코빗,FDS,5,000만 원 상당 비트코인 피싱 피해 예방,피싱 사이트,입금처,코빗 심사팀
#
# 정답: 핫 시리얼 시장 개척,포스트 화이버 오트밀,동서식품
# 예측: 핫시리얼 시장 개척,포스트 화이버 오트밀,동서식품,핫 시리얼,핫시리얼,시장
#
# 정답: 넷플릭스,마이네임,장률
# 예측: 넷플릭스,마이네임,장률,매력적인 미소,넷플릭스 시리즈,제작발표회
#
# 정답: 제주경찰청,여성폭력 대응 TF팀
# 예측: 제주경찰청,여성폭력 대응 TF팀,여성폭력 범죄,위기대응 체계,여성폭력 대응
#
# 정답: 퇴원,박근혜,박정희,묘역,참배
# 예측: 퇴일,박정희,퇴원후 묘역,퇴원
#
# 정답: 공공·금융개혁,세계 5강,이재명 후보,신경제 비전 선포식
# 예측: 이재명 더불어민주당 대선구,공공·금융개혁,신경제 비전,국민소득 5만달러,주가 5000 돌파,과학기술혁신 부총리·기후에너지부 신설,과학기술혁신 부총리제,과학기술혁신 부총리제,국가 과학기술 혁신 혁신
#
# 정답: 인명피해,사찰 화재,상북면
# 예측: 상북면 소재 사찰 화재,인명 피해,목조건물 소실,인명 피해 없어, 원인은 조사중
#
# 정답: 내추럴발란스,블루엔젤,봉사
# 예측: 내추럴발란스,블루엔젤 봉사
#
# 정답: 티샷,박현경,전남 영암,사우스링스영암CC,크리스 F&C 제43회 KLPGA 챔피언십,최종라운드
# 예측: 박샷,박현경
#
# 정답: 카카오 VX,골프 연습장,프렌즈 아카데미,프랜차이즈 사업,론칭,전문가들의 다양한 레슨 커리큘럼,쾌적한 연습 공간
# 예측: 프카오 VX,골프 연습장,프렌즈 아카데미,프렌즈 스크린
#
# 정답: 김기현,국민의힘 당 대표 권한대행,원내대표,문재인 대통령,면담 요청,장관 후보자 3명,김부겸 국무총리 후보자 인준
# 예측: 김기현,인사권자,문대통령,면담,인사권자,인사권
#
# 정답: 실점,양현종,포수,칭찬,메이저리그,텍사스 레인저스,호세 트레비노
# 예측: 양현종,포수,미국 텍사스 레인저스
#
# 정답: 레이싱걸 포스,신수지,황금 골반,테슬라
# 예측: 레이싱걸 포스,신수지,테슬라
#
# 정답: 비전 2023,서울,자율주행차,오세훈 시장
# 예측: 20율주행차 300대,서울,자율주행비전,2030
#
# 정답: 통일부,이준석,여성가족부,진중권
# 예측: 여성준석,통일부,여성가족부,여성부 폐지,진중권
#
# 정답: 메가존클라우드,위셋,글로벌 멘토링 프로그램,한국여성과학기술인육성재단,인재육성
# 예측: 메가존클라우드,위셋,글로벌 멘토링 프로그램,성료,메가존클라우드,한국여성과학기술인육성재단,여성 이공계 대학생 대상 글로벌 멘토링 프로그램,디지털 및 클라우드 직무
#
# 정답: 특금법,가상자산 거래소,등록,0곳,은성수 금융위원장,거래소 자체 상황,요인
# 예측: 가상자산 거래소,폐쇄,금융위원장,폐쇄,국내 가상자산 거래소
#
# 정답: 재선 도전,공교육 표준,노옥희 울산교육감,공식출마
# 예측: 공옥 도전,노옥희,공교육 표준,노 교육감
#
# 정답: 스토킹 피해,유튜버 릴카
# 예측: BJ 릴카,스토킹 피해,신변의 위협,스토킹 범죄
#
# 정답: 출근길,조이,동물농장
# 예측: 상농장,동물농장,김대령,SBS 목동,동물농장
#
# 정답: 성추행피해,대통령이 직접,해군,국방부,성폭력 사건,대책마련
# 예측: 성,성폭력,피해자,피해자,이동사,이유,이유,이번
#
# 정답: 티샷,김민규,야물딱진 파워,경기도 성남시 남서울 골프장,대한골프협회 주관,GS칼텍스 매경오픈,3라운드 골프대회
# 예측: 티샷,김민규,GS칼텍스 매경오픈,3라운드 골프대회,1번 홀, 1번 홀
#
# 정답: 이강인,바야돌리드전,선발 출전,발렌시아,메스타야 스타디움,스페인 프리메라리가,35라운드
# 예측: 이강인,바야돌리드,2020-21시즌 스페인 프리메라리가,발렌시아,발렌시아
#
# 정답: 진화,불
# 예측: 경기,야산,불,진화,인명,산림
#
# 정답: 더보이즈,주연,코로나 확진자,밀접접촉,자가격리,코로나19 검사,음성 판정
# 예측: 더보이즈,주연,코로나 확진자,밀접접촉,자가격리
#
# 정답: 앤오디션,케이,하이브 레이블즈 재팬,의주,니콜라스,타키
# 예측: 하이브 레이블즈 재팬,앤오디션,전 세계 방영,앤오디션,일본 방송,유튜브 방영,아이랜드
#
# 정답: 아파트 증여,역대최고,세금인상
# 예측: 아파트 증여,역대 최고 동영상,아파트 증여,역대 최고 동영상
#
# 정답: 여자친구 예린,매력 밝은 성격,팔색조 매력,특유의 밝은 성격
# 예측: 여자친구 예린,민소매 원피스 입고 뇌쇄적 눈빛
#
# 정답: 원주천,침수,범람
# 예측: 원원주,강원 원주천,범람,범람,백부지역,큰 비가 이어지는
#
# 정답: AFGHANISTAN,BOMNG
# 예측: Afghan,afghanistan,bore,explosive devices
#
# 정답: 맨시티 감독,아스널,과르디올라
# 예측: 맨스널,아스널,맨시티 감독,과르디올라
#
# 정답: 방위사업청,해상감시레이더 양산 계약,LIG넥스원,1640억원 규모,해상감시레이더-II,주요 해안과 도서지역,선박과 항공기 탐지
# 예측: 방위사업청,해상감시레이더 양산 계약,상당수 해안,도상 및 도서지역,선박과 항공기 탐지,탐지
#
# 정답: 백신접종,코로나 사망자 감소세,베트남 호찌민시
# 예측: 백신접종,코로나 사망자,백신접종,코로나
#
# 정답: 진상 규명,사망자,울산 피해자,가습기 살균제,실태조사
# 예측: 울산습지 살균제,울산피해자,18명 사망
#
# 정답: 코미디 축제,부코페,부산 국제 코미디 페스티벌
# 예측: 코9회 부코페,폐막,코미디 축제,부코페,폐막까지 3일,코미디 축제 이어간다
#
# 정답: 로봇,오세훈,착공식,4차산업 혁명,로봇인공지능과학관,
# 예측: 오봇인공지능과학관,오세훈,착공식 시삽,시공 로봇,로보3
#
# 정답: 서울시,재개발 구역,6대 규제완화
# 예측: 서울시,재개발 6대 규제완화,주거정비지수제,공공기획 전면 도입,공공기획 전면,재정구역 지정기간 단축
#
# 정답: 아이언소스,퍼블리싱 솔루션,슈퍼소닉,라이브 게임즈,정식 론칭,개발자들,게임 관리
# 예측: 아이언소스,퍼블리싱 솔루션 슈퍼소닉,라이브 게임즈,정식 론칭,앱 경제,앱 경제,비지니스 플랫폼,게임 출시,게임 관리,게임 측정지표,게임의 관리,성장 촉진
#
# 정답: 한국자유총연맹부산광역시지부,충혼탑 참배
# 예측: 한국자유총연맹부산광역시지부,충혼탑 참배,한국자유총연맹부산광역시지부,3일 신한춘 회장
#
# 정답: 생활용품,락앤락,밀키트,프로모션,다회용기,ESG경영
# 예측: 다업계,ESG경영,협업,다회용기 사용 확대,쓰레기,업사이클링
#
# 정답: 용인문화재단,우리 용인 효 콘서트,가정의 달,온 가족,용인포은아트홀,국악,클래식
# 예측: 용인문화재단,우리 용인 효 콘서트,인문화재단,가정의 달,온 가족이 즐길 수 있는 공연,용인포은아트홀,국악, 클래식,재즈,공연
#
# 정답: 로맥,박종훈,노브랜드 버거 100호점
# 예측: 노노버 버거 100호점 오픈,박종훈·로맥,로맥,노브랜드 버거 100호점
#
# 정답: 백신 접종,개정대책,코로나19,2차 접종 시작
# 예측: 백신 접종,집단면역 '속도전'
#
# 정답: 중국,육류가격 급등,급등,인용,삼겹살,한우 값,농축수산물
# 예측: 한우 값 폭등,중국,중국 SNS 웨이보,중국 최대 규모의 포털 사이트 바이두,한국 물가,중국 SNS 웨이보,중국 최대 규모의 포털 사이트 바이두,한우 값 폭등 소식에 중국인,포털 검색어 2위
#
# 정답: 이지현,미소와 함께 브이,경기도 안산 대부도,아일랜드cc,교촌 허니 레이디스 오픈,2라운드,1번홀
# 예측: 이지일,이지현,미소와 함께 브이,경기도 안산 대부도,아일랜드cc,교촌 허니 레이디스 오픈,2라운드,1번홀,티샷
#
# 정답: 브레이브걸스 유나,‘After ‘We Ride’’
# 예측: 브브걸스 유나,신보 포토 티저,인형 같은 비주얼,브브걸스 유나
#
# 정답: 언니네이발관,이석원,윤여정,아카데미 수상,조영남,강한 불쾌감,블로그
# 예측: 이석원,조영남,아카데미상 수상,마지막 수상,마지막 자아,아카데미상 수상,이석원,한심
#
# 정답: 마인,단체 포스터,tvN 새 토일드라마,강인한 여성들의 이야기,백미경 작가,이나정 감독,이보영
# 예측: 마인 단체 포스터,이보영-김서형
#
# 정답: 송파 플래티넘,리모델링,분양,신규아파트,청약
# 예측: 송파 플래티넘,청약 대흥행,공동주택 리모델링,신규아파트 분양,송파 더 플래티넘
#
# 정답: 철원 공설운동장,김호중,2022평화콘서트,철원군
# 예측: 김호중,김호중,강원 철원군 철원 공설운동장,KBS 2022 평화콘서트,우리, 이곳에서,콘서트
#
# 정답: 김홍조,루키 인비테이셔널,한화생명 E스포츠,카리스,캠프원
# 예측: 카리스,김홍조
#
# 정답: 조이,레드벨벳,미모
# 예측: 레렌타인,미모
#
# 정답: 안나 셰르바코바,러시아 피겨스케이팅 여자 싱글
# 예측: 러시아겨스케이팅 시니어 그랑프리 시리즈,여자 싱글 쇼트프로그램,러시아 여자 싱글 선수들의 경쟁
#
# 정답: JP모건 헥스케어 콘퍼런스,7개 의약품 생산공장 구축,롯데바이오로직스,바이오의약품 공장 단지
# 예측: 바이오바이오로직스,국내 3개 의약품 생산공장 구축,2030년까지 총 3.7조 투자 계획,부지 물색 중,주식상장,국내 증시 상장,2030년까지 약 3조7000억원,기업공개를 통해 1조원 이상 자체 조달,바이오의약품 공장 조성 계획
#
# 정답: S-OIL,제 15회 챔피언십,홍란
# 예측: 제시안,S-OIL 챔피언십,2라운드,첫 타구
#
# 정답: 갈비뼈 금,서경석,오은영의 금쪽 상담소
# 예측: 서비석,갈비뼈 금,건강검진
#
# 정답: 탈출러,대탈출4,강호동,백사회
# 예측: 대사회,강호동,대탈출4,김종민,동동현,신동,유병재,피오,백사회
#
# 정답: 삼성 승리,한국가스공사
# 예측: 프로가스공사,대구체육회,삼성에 83-77,대구
#
# 정답: 빕스,라방,샐러드바 할인권,11번가,라이브11,스모크 우드박스 채끝등심 스테이크,
# 예측: 빕스,11번가 라방,샐러드바 할인권,라이브11,라이브11,캠핑
#
# 정답: 4연승,전남,안양,리그,전남 드래곤즈,광양 축구전용구장,하나원큐 K리그2
# 예측: 4연승 행진,전남 드래곤즈,안양,리그 1위 도전,하나원큐 K리그2 2021 9라운드 FC 안양,홈경기
#
# 정답: 현세린,OK저축은행 박세리INVITATIONAL
# 예측: 현세린,비바람,비바람,충주 실크리버 컨트리클럽,OK저축은행,박세리,INVITATIONAL
#
# 정답: 템페스트,ON and On,컴백
# 예측: 템페스트,3개월만 컴백 확정,가요계 거센 폭풍 예고
#
# 정답: 이동욱,배드 앤 크레이지
# 예측: 이동욱,만찢남,명품,이동욱,인스타그램,인스타그램
#
# 정답: 한지혜,검사,태교법,신상출시 펀스토랑,동화,돼지고기,태교
# 예측: 한지혜,검사 남편 태교법 10년만에 임신,KBS2 예능프로그램 '신상출시 편스토랑',돼지고기,동화
#
# 정답: 블루프리즘,SaaS RPA 플랫폼,사용량 기반 과금 모델,클라우드 관리형 서비스형소프트웨어,로보틱프로세스자동화,유연한 대응,디지털 워커
# 예측: 블블프리즘,SaaS RPA 플랫폼,사용량 기반 과금 모델,클라우드 관리형 서비스형소프트웨어 로보틱프로세스자동화 플랫폼,사용량 기반,디지털 워커
#
# 정답: 바흐,방일 연기,스포츠 스타들 '올림픽 취소론' 가세
# 예측: 바흐,올림픽 취소론,코로나19,올림픽,코로나19 긴급사태
#
# 정답: 수아레즈,완벽투,고우석,세이브,LG,NC,잠실구장
# 예측: 수아레즈,LG,NC,홈경기,수아레즈,고우석 세이브
#
# 정답: 공인중개사 시험,스윗메가 인증챌린지,수험생,메가랜드,세법 이송원 구원 특강
# 예측: 공인중개사 시험,메가랜드,세법 이송원 구원 특강,수험생 대상,세법 1타 강사, 이송원 교수가 고민,연구한 특별한 구원 솔루션
#
# 정답: 농심,지역사회,사랑의 신라면,기부,해피펀드
# 예측: 농심,사랑의 신라면,5300여박스,지역사회에 기부
#
# 정답: 건강 피부,40세 생얼,양미라
# 예측: 40세 생얼,양미라,젊은 피부,인스타그램
#
# 정답: 홍콩,-> 하이트진로,미국,'테라',싱가포르,수출
# 예측: 하이트진로,미국,싱가포르,홍콩,테라 수출,미국,세일
#
# 정답: 맑은 하늘,황사,서울 영등포구,63스퀘어,도심 위,파란하늘,국립환경과학원
# 예측: 맑색 하늘,황사,서울 영등포구,63스퀘어,도심위로 파란하늘,국립환경과학원
#
# 정답: 주인공,목소리를 구분하는 방법,이홍내
# 예측: 이목목소리 구분하는 방법,이홍내,라이징 행보,tvN,오프닝-목소리를 구분하는 방법,다양한 표현력
#
# 정답: 코로나19,중대본 회의,권덕철 장관,중앙재난안전대책본부 1차장,서울 종로구,정부서울청사,신종 코로나바이러스 감염증
# 예측: 코로나19,중앙재난안전대책본부,권덕철,중앙재난안전대책본부 1차장,중앙재난안전대책본부 회의
#
# 정답: european,aquatics,hungary,championships
# 예측: HuNGARY,championships,budapest,HUNGARY
#
# 정답: 반려견 루니,차태현,멍뭉이,유연석,15년만의 재회,'멍뭉이'
# 예측: 멍유로,연유석x차태현,15년만의 재회
#
# 정답: 재보선,여당 패배원인,페미니즘,20대 남성,이남자,팩트체크,민주당
# 예측: 재보선,페미니즘,20대 남성,이남자,민주당
#
# 정답: 회색곰,여성,덫,미국 몬태나주,사살
# 예측: 회색곰,사살,미국 몬태나주,캠핑,여성 습격,회색곰,사살
#
# 정답: 보스턴 침몰,류현진,설욕전,19일,미국 플로리다주 더니든 TD볼파크,2021 미국프로야구 메이저리그,보스턴 레드삭스
# 예측: 보스턴 침몰,류현진,설욕전,미국 플로리다주 더니든 TD볼파크,2021 미국프로야구 메이저리그 보스턴,홈경기 선발 등판
#
# 정답: 백신접종,휴식일,kbo
# 예측: 백신접종 휴식일,KBO,귀기울인,KBO
#
# 정답: 격차,이재명,윤석열,실시간 대선후보 지지도 주례 조사
# 예측: 한국석박,이재명,윤석열,격차,격차,심상정
#
# 정답: 성장관리방안,처인·기흥 지역,용인시
# 예측: 성장관리방안,처인구,기흥 15개 지역,성장관리방안 수립,14일 주민 공람
#
# 정답: 에너지차관,박기영,통상교섭본부장,여한구
# 예측: 산업기여부,통상교섭본부장,박기영,산업통상자원부,기획조정실장,기기영
#
# 정답: 김소연,완판여왕,셀트리온스킨큐어,셀큐어 전속모델,홈쇼핑 방송,화이트 에너지 멜라 앰플 2X,판매 방송
# 예측: 김소연,셀트리온스킨큐어,전속모델,화이트에너지 멜라 앰플 2X,판매 방송
#
# 정답: 문재인 대통령,조 바이든 미국 대통령,첫 정상회담,한반도 비핵화,백신 확보,쿼드,배터리
# 예측: 백,백신,백신 공급 허브,조 바이든,문재인 대통령,바이든 미국 대통령
#
# 정답: 박병호,답답하네요,15일 오후,서울 고척스카이돔,2021 신한은행 SOL KBO리그,키움 히어로즈,한화 이글스
# 예측: 박병호,답답하네요,2021 신한은행 SOL KBO리그,키움 히어로즈,한화 이글스
#
# 정답: 경주시,이건희 기증품,박물관·미술관,유치 경쟁,문화재 및 근현대 미술품 전시공간,국내 대표급 관광지,신라 관련 유물
# 예측: 경주시,이건희 기증품,유치 경쟁,국내 대표 관광지
#
# 정답: 히밥,김희철,호동
# 예측: 김동철,히밥,인스타그램,인스타그램,카톡,술트리트파이터,호동 형,히밥 먹성,인스타그램
#
# 정답: cycling,giro d'italia,italy
# 예측: gyclamen jersey,generaly,ITALY,gIRO D'ITALIA epa09,generate,giro d'Italia,guardia,guardia
#
# 정답: 윤봉길,김구 선생,아름다운 만남 특별기획전,윤봉길의사기념관
# 예측: 특별군 기획전,김구 선생,예산군,예산군,윤봉길의사기념관
#
# 정답: 국제표준화기구,국제표준화기구 회장 도전,브리핑
# 예측: 국제표준화기구,이상훈 국가기술표준원장,조성환 현대모비스 대표이사,국제표준화기구 회장 도전
#
# 정답: kbo 리그,김재윤,역전
# 예측: 김재윤,역전타,김재윤,SSG 위즈,경기
#
# 정답: 주호영,국민의힘,당권레이스,원내대표,차기 당대표 선거 출마,기자회견,당 쇄신 방안
# 예측: 주호영,국민의힘,차기 당대표 선거,출사표,국민의힘,전당대회,출범
#
# 정답: 박상학,자유북한운동연합 대표,대북 전단 살포 혐의,조사 거부,경찰청,소환 조사,무고 주장
# 예측: 대상학
#
# 정답: 두번째 남편,차서원,엄현경,MBC 일일드라마
# 예측: 두 번째 남편,차서원,엄현경,MBC 일일드라마
#
# 정답: 새벽 아파트,17층 불 소동,세대 내 흡연,화재신고,경기 의정부시 신곡동,재산피해,인명피해 없음
# 예측: 새벽 아파트 17층 불 소동,세대 내 흡연,소방서 추산 263만원의 재산피해,인명피해
#
# 정답: 무결점,아이들 미연,미모
# 예측: 미결점 미모,아이들 미연,서울 영등포구 롯데백화점 영등포점
#
# 정답: 방탄소년단 진,클라우드맥주,광고 화보
# 예측: 방탄소년단 진,클라우드 롤링페이퍼, 신선함,청량감 전한 화보장
#
# 정답: 신인왕,두산,정철원,양의지
# 예측: 신인왕,두산 베어스,정철원,신인왕 배터리,역대 2라운드,20홀드,20홀드,20홀드,2022년 KBO리그,신인왕
#
# 정답: 감염병 극복,이건희,중앙감염병 전문병원 건립
# 예측: 감병병 극복,이건희,기금,의원장,기금,재난
#
# 정답: 농협은행,ESG경영,상생경영,제1회 대한민국 리딩금융 ESG 어워드,친환경경영,지배구조,녹색금융
# 예측: NS,농협은행,환경·사회책임·지배구조,상생경영,환경·사회책임·지배구조,국내 최초,2021 대한민국 리딩금융 ESG 어워드
#
# 정답: 군 병사,단체휴가,본격 시행,서울역,군장병,예방적 격리,병영생활관
# 예측: 군 병사,단체휴가
#
# 정답: mideast,ceasefire,gaza,israel
# 예측: MIDEAST,al-Qassam,gaza City,conflict in Gaza City,27 May 2021
#
# 정답: 비메모리,반도체,매출 1조원,DB하이텍,공급부족,코로나19,8인치 파운드리
# 예측: 8운드리,수익 향상,8인치 파운드리
#
# 정답: 임금피크제 선배,임금피크제 세대 갈등,임금피크제,금융계
# 예측: 임금계,임금피크제,세대갈등,금융권,금융권
#
# 정답: 70대 실종 이튿날 숨진 채 발견
# 예측: 나물 캐러 갔다 실종,충주 산척면 강변,A씨 실종,충주 산척면
#
# 정답: 개막식,제15회 고양-한스타 SBO 연예인야구리그,인순이
# 예측: 인순이,제15회 고양-한스타 SBO 연예인야구리그,공놀이야
#
# 정답: 용인시,행정타운,공공기관,청렴실천 공동협약,용인교육지원청,용인동부경찰서,용인세무서
# 예측: 용인시,행정타운 공공기관,청렴실천 공동협약,용인교육지원청,용인동부경찰서,용인세무서,용인우체국
#
# 정답: 에어프레미아,객실승무원 수료식,교육훈련,코로나19,항공업계,채용시장,국토교통부
# 예측: 에어프레미아,1기 객실승무원 수료식,교육훈련,교육훈련,코로나19,항공업계 채용
#
# 정답: 김수영문학상,최재원,나랑 하고 시픈게 뭐에여?
# 예측: 최수영문학상,최재원,나랑 하고 시픈게 뭐에여?,최 시인,문학상,내용과 형식에서 거침없고 자유로웠던 김수영의 첨단의 언어를 계승,선정 사유가
#
# 정답: 혁신 금융 테스트베드,기업은행,IBK 퍼스트랩
# 예측: 기업BK기업은행,혁신 금융 테스트베드,기업 모집,혁신 금융 서비스
#
# 정답: 빛의 마술사,신카이 마코토 감독,일본 애니메이션,기획전,상영,시네마캐슬,작품 7편
# 예측: 빛의 마술사,신카이 마코토 감독,기획전,시네마캐슬,작품 7편
#
# 정답: 가격,휘발유,l당 2000원,경유,국제 휘발유,유류세
# 예측: 휘,경유,l당 2000원,유류세 인하,휘고
#
# 정답: 빅토리콘텐츠,인사말,권태호 대리
# 예측: 빅토리콘텐츠 권태호 대리,빅토리콘텐츠 얼라이언스,출범식
#
# 정답: 세계 68명 고위급 인사들,2050 탄소중립 공동대응,온실가스 감축,파리기후협약
# 예측: 세계 68명 고위급 인사들,2050 탄소중립 공동대응,파리기후협약,2021 P4G 서울 녹색미래 정상회의,2050 탄소 중립,중국 녹색 회복
#
# 정답: 관련28명,추가확진,대구,누적47명,유흥주점
# 예측: 유흥주점 관련 28명,대구 0시 이후,유흥주점
#
# 정답: 노영민 전 대통령 비서실장,민주당,충북지사,광역단체장 면접
# 예측: 민주당,광역단체장 면접,부산·울산·경남·충북,충북,노영민 전 대통령 비서실장,충북지사
#
# 정답: 현대차그룹,휠체어 전동화 키트,장애인 이동편의,수동휠체어,보급사업,한국장애인단체총연맹,전달식
# 예측: 장애인차동차,전동화 키트 지원,장애인 이동편의,현대차그룹,한국장애인단체총연맹,수동휠체어 전동화키트 보급사업
#
# 정답: 밴텀급 배틀로얄,조제 알도,챔피언 알저메인 스털링,UFC
# 예측: UFC 밴텀급,조제 알도,챔피언 알저메인 스털링,UFC
#
# 정답: 머지포인트 사태,환불,머지플러스,피해자
# 예측: 머지포인트 사태,환불,대형 환불,대형마트,피해자,피해자,피해자,머지플러스
#
# 정답: 일본군 위안부 피해,수요시위,소녀상 철거
# 예측: 일본군 위안부 피해자 문제,정기 수요시위,소녀상 철거,일본군 위안부 피해자 문제
#
# 정답: social crisis,protests,Panama,Laurentino Cortizo
# 예측: posts of medicines,Panama,Laurentino Cortizo,president of Panama,2022년
#
# 정답: 오늘부터 무해하게,공효진,이천희,해먹
# 예측: K해먹,공효진,이천희,전혜진,KBS 2TV,오늘부터 무해하게
#
# 정답: 세포유전자 CDMO,유전자치료제,마티카바이오,생산허브,판교,차바이오,위탁생산개발업체
# 예측: 세포유전자 CDMO,톱5,차바이오,미국법인 마티카바이오 간담회
#
# 정답: 일본 경제,민간소비,글로벌 성장세,설비투자,회복
# 예측: 한국경제,하반기 일본 경제 전망
#
# 정답: 시니어용,54홀 경기,liv 시리즈,타이거 우즈,PGA투어
# 예측: 골프니어용,LIV,골프 황제 타이거 우즈,54홀 경기,LIV 시리즈,골프,LIV
#
# 정답: 니로EV,장기렌털 전기차 무료충전,아이오닉5,EV6,SK 렌터카
# 예측: SK렌터카,아이오닉5·EV6,장기렌털,무료 충전
#
# 정답: 18세 투표권,노회찬,정치,국민연대,만18세 선거권,공직선거법 개정안,학교폭력 현황
# 예측: 18세 투표권,노회찬,19금
#
# 정답: K-WATER 한강유역본부,교육물품 기부
# 예측: 한-water 한강유역본부,교육물품 기부 현장
#
# 정답: 알버트 비어만 사장,현대차그룹,피터 슈라이어 사장,퇴진,인사
# 예측: 알버트 비어만,이번주 인사,피터 슈라이어
#
# 정답: 카카오,역성장,영업이익,실적 쇼크,기업지배구조,글로벌 경기 침체,어닝쇼크
# 예측: 카카오는,올 3분기 매출 1조8587억원,영업이익 11% 역성장,올 3분기 글로벌 경기 침체,이벤트 쇼크
#
# 정답: 400개 협력사,소액주주,코스닥,쌍용차,줄도산 위기,에디슨 EV,매각
# 예측: 코스닥,400개 협력사,절약사,합병 무산,에디슨 EV,코스닥 후폭풍
#
# 정답: 현대비앤지스틸,회사채 수요예측,2700억원 주문,모집액의 5배 이상,500억원 규모 회사채 발행,만기 3년,신용등급 A
# 예측: 현대비앤지스틸,사전자 수요예측,2700억주,현대비앤지스틸,증액 발행
#
# 정답: 이재명 경선 승리 소식
# 예측: 이재명 경선 승리 소식,당내 아웃사이더,부동산 스캔들 딛고 승리
#
# 정답: 계룡세계군문화 엑스포,해군
# 예측: 계룡세계군문화 엑스포,해군 홍보 부스,해군,전투함 보고
#
# 정답: 해밀 상호문화교류센터,하나금융그룹,함영주 하나금융그룹 부회장
# 예측: 해밀 상호문화교류센터,하나금융그룹,함영주 하나금융그룹 부회장,준공식,준공식식
#
# 정답: 생활습관 개선,심장,소변,항생제,역류,선천적·후천적 이유,질환
# 예측: 위류성,심장,소변,항생제,식도
#
# 정답: 밥심,마리아,한국 아이돌,데뷔,감량,30kg,미스트롯2
# 예측: 미심,마리아,한국 아이돌,미스트롯2,미스트롯2,한국 사람보다 더 한국인 같은,대한외국인
#
# 정답: 왓챠,5월 라인업,국내 예능 프로그램,해외 영화 및 시리즈,독점 콘텐츠,노는 브로,리틀 조
# 예측: 왓챠,노는 브로,국내 예능 프로그램,해외 영화 및 시리즈,3개 라인업,국내외,익스클루시브 콘텐츠,국내 예능 프로그램
#
# 정답: 실종 이틀만에 숨진 채,40대 여성,의암포
# 예측: 실박 이틀만에,40대 여성,춘천 의암호
#
# 정답: 삼성·LG,넷플릭스,광고,동영상 서비스,TV플러스,LG채널
# 예측: 삼성·LG,유료시청,동영상 서비스,TV플랫폼 제공,유튜브
#
# 정답: 4연패,단독 꼴찌 추락,롯데,야수가 투수로 등판,김민수,배성근,허문회 감독
# 예측: 4연패,단독 꼴찌 추락,롯데,김민수,배성근,3연투,3연투,3연투,감독,3연투,코치,한결경기,대패
#
# 정답: baseball,padres,New York Mets,Luis Rojas
# 예측: bets,baseball,baseball,new York Mets,manager Luis Rojas,baseball,baseball,padres,baseball,padres,baseball,baseball,padres,baseball,padres,Friday,Friday,June 4,201, in San Diego
#
# 정답: 박종훈,롯데 자이언츠,선발 출격,랜더스,김원형 감독
# 예측: 박종훈,SSG,랜더스,대체 선발,2021.05.12
#
# 정답: 피아니스트 김수연,2021년 몬트리올 국제 음악 콩쿠르,1위 수상,금호문화재단,금호영재 출신,상금,음반 제작
# 예측: 몬니스트 김수연,2021 몬트리올 국제 음악 콩쿠르,금호문화재단,금호영재 출신 바이올리니스트 조진주,최예은, 김봄소리를
#
# 정답: 소액 재테크방법,채굴기 임대 서비스,비트코인 구스,론칭,가상화폐,비트코인,채굴 사업
# 예측: 비트코인 구스,비트코인 투자 플랫폼,채굴기 임대 서비스,가상화폐,가상화폐,투자
#
# 정답: 채은성,역전 홈런,서울 잠실야구장,2021 신한은행 SOL KBO리그,한화 이글스,LG 트윈스,더블헤더 1차전 경기
# 예측: 채은성,역전 홈런,서울 잠실야구장,2021 신한은행 SOL KBO리그,한화 이글스,LG 트윈스,더불어헤더 1차전 경기
#
# 정답: 솔루스첨단소재,항공우주용 특수동박,양산,에어버스,공급,낙뢰 방호 시스템,서킷포일 룩셈부르크
# 예측: 솔루스첨단소재,항공우주용 특수동박,양산에 성공,에어버스,동박사업본부,동박 생산 기지
#
# 정답: 양희준,뮤지컬,스웨그 에이지: 외쳐,조선!,언론시사회,간담회,서울 광진구 롯데시네마 건대입구점
# 예측: 양희준,조선!,언론시사회,언론시사회,조선!
#
# 정답: 비트코인,상승세,암호화폐,암호화폐 거래소,빗썸,시세
# 예측: 비트코인,상승세,서울 강남구,암호화폐 거래소
#
# 정답: 콜라보 컬렉션,휠라,푸시버튼
# 예측: 휠라 휠라,푸시버튼,콜라보 컬렉션 론칭,디자이너 박승건,푸시버튼
#
# 정답: 6시 내고향,MC 활약,오정연,30주년,아나운서 출신,방송인,KBS 1TV
# 예측: 6정연,6시 내고향,MBC 활약,30주년,30주년,KBS 1TV,KBS 32기 공채 아나운서
#
# 정답: 우방국,양측 관세당국,관세청,터키 관세당국,제7차 한-터키 관세청장회의,협력강화,수출기업
# 예측: 관제청 제7차 한-터키 관세청장회의,원산지 검증 협력
#
# 정답: 방탄소년단,비티에스 퍼미션 투 댄스 온 스테이지,LA 공연,콘서트
# 예측: 방탄소년단 LA 콘서트,비티에스 퍼미션 투 댄스 온 스테이지,프레닝 무대,무대,오랜만,정국
#
# 정답: 한강변,말똥게,장항습지,버드나무 군락
# 예측: 한강변,장항습지,말똥게,국토 속 밀림
#
# 정답: kt 위즈,lg트윈스,이강철 감독,강백호,2021 kbo리그
# 예측: 20강 KBO리그 LG 트윈스,KT 위즈,강백호,KBO리그 LG 트윈스
#
# 정답: 권순우,오픈 남자단식 1회전,US오픈,탈락
# 예측: 권순우,US오픈 남자단식,1회전,미국 뉴욕,빌리진 킹 내셔널 테니스 센터,1회전,미국
#
# 정답: 공직자의 이해충돌 방지법,전현희 국민권익위원장
# 예측: 전현희 위원장,공직자의 이해충돌 방지법,특별강연,원주 국민건강보험공단
#
# 정답: 유벤투스,3년 만에,코파이탈리아 우승,아탈란타,2-1,2020-2021시즌,결승전
# 예측: 유벤투스,코파이탈리아 우승,아탈란타,2020-2021시즌,우승
#
# 정답: 육아,하영이,장윤정,연우,물건너온 아빠들,쟈오리징
# 예측: 장윤정,순둥이 아들 연우,하영이
#
# 정답: 영결식,황기성 감독,배우 안성기,가톨릭대학교서울성모병원 장례식장,고 이춘연 대표,배우 권해효,이창동 감독
# 예측: 영결식,황기성 감독,배우 안성기,안성기,가톨릭대학교서울성모병원 장례식장,배우 권해효,이창동 감독,이명동 감독,이준익 감독,배우 이병헌,김규리
#
# 정답: 런닝맨,헤어스타일,스타일,송지효,윤은혜,커피프린스
# 예측: 런닝맨,송지효,개소리야,자세한,헤어스타일,숏컷,숏컷
#
# 정답: 아이브 이서,대체불가 비주얼
# 예측: 아이브 이서,대체불가 비주얼,이서,화보
#
# 정답: 디캠프,심리교육,창업자 심리교육
# 예측: 디캠프,창업자 심리교육,김정현 분당서울대학교병원 정신건강의학과 교수,국내 스타트업 창업자 정신건강 실태조사
#
# 정답: 보건복지부,아동권리보장원,제18회 '가정위탁의 날',온라인 기념식,위탁부모,위탁아동,가정위탁지원센터 종사자
# 예측: 복지부,가정위탁의 날,온라인 기념식,복지부,아동권리보장원,복지부 장관 표창
