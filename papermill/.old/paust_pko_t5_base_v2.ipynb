# %%
import os
import re
import warnings

import pandas as pd
import numpy as np
import torch

from transformers import (
    AutoConfig, AutoTokenizer, AutoModelForSeq2SeqLM, 
    Seq2SeqTrainingArguments, Seq2SeqTrainer, 
    DataCollatorForSeq2Seq, 
)

from datasets import load_metric, Dataset

import wandb
import nltk

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jake/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
NGPU = torch.cuda.device_count()
NCPU = os.cpu_count()
NGPU, NCPU
# Out:
# (1, 16)

# %% [markdown]
# # Paths and Names

# %%
### paths and names

PROJECT_NAME = 'news-topic-keyphrase-generation-model-dev'
RUN_ID = 'v2'

DATA_PATH = 'data/preprocess_v2.pickle'

MODEL_CHECKPOINT = 'paust/pko-t5-base'
model_name = re.sub(r'[/-]', r'_', MODEL_CHECKPOINT).lower()

METRIC_NAME = 'rouge'

NOTEBOOK_NAME = './train.ipynb'

ROOT_PATH = './'
SAVE_PATH = os.path.join(ROOT_PATH, '.log')

run_name = f'{model_name}_{RUN_ID}'
output_dir = os.path.join(SAVE_PATH, run_name)

print(run_name)
print(output_dir)

# !mkdir -p {SAVE_PATH}
# Out:
# paust_pko_t5_base_v2
# ./.log/paust_pko_t5_base_v2

# %%
# %env WANDB_PROJECT={PROJECT_NAME}
# %env WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# %env WANDB_LOG_MODEL=true
# %env WANDB_WATCH=all
wandb.login()
# Out:
# env: WANDB_PROJECT=news-topic-keyphrase-generation-model-dev
# env: WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# env: WANDB_LOG_MODEL=true
# env: WANDB_WATCH=all
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find {NOTEBOOK_PATH}.
# wandb: Currently logged in as: dotsnangles. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Training Args

# %%
report_to="wandb"

num_train_epochs = 15
per_device_train_batch_size = 2
per_device_eval_batch_size = 2
gradient_accumulation_steps = 1

optim = 'adamw_torch' # 'adamw_torch' or 'adamw_hf'

learning_rate = 3e-6 * NGPU
weight_decay = 0.01
adam_epsilon = 1e-8

lr_scheduler_type = 'cosine' # 'linear', 'cosine', 'cosine_with_restarts', 'polynomial', 'constant', 'constant_with_warmup'
warmup_ratio = 0

save_total_limit = 2

load_best_model_at_end = True
metric_for_best_model = 'eval_loss'

save_strategy = "epoch"
evaluation_strategy = "epoch"

logging_strategy = "steps"
logging_first_step = True 
logging_steps = int(500 / NGPU)

predict_with_generate=True
generation_max_length=128
# generation_num_beams=5

fp16 = False

# %% [markdown]
# # Model & Tokenizer & Metric

# %% [markdown]
# - 모델과 토크나이저, 그리고 평가지표를 계산하는 데 사용할 함수를 불러옵니다.
# - 모델의 config에는 사용하지 않는 설정이 포함되어 있습니다. 삭제합니다.

# %%
config = AutoConfig.from_pretrained(MODEL_CHECKPOINT)

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT, config=config)
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
metric = load_metric(METRIC_NAME)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# # Functions

# %% [markdown]
# - 모델 훈련을 위해 전처리를 수행해주는 함수를 선언합니다.
# - 입력 문장이 input이 되고 요약문이 label이 됩니다.
# - tokenizer를 사용해 input_ids로 변환하고 입력값에는 attention_mask를 생성해줍니다.
# - 입력 문장에 prefix를 추가하여 성능 실험을 해볼 수 있으나 지금은 적용하지 않겠습니다.

# %%
prefix = "generate keyphrases: "

max_input_length = 512
max_target_length = 128

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["input_text"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True, padding="max_length")

    labels = tokenizer(examples["target_text"], max_length=max_target_length, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %% [markdown]
# - 모델의 예측값과 위에서 전처리한 라벨을 활용하여 평가지표를 출력하는 함수를 선언합니다.
# - ROUGE를 평가지표로 사용합니다.
#     - ROUGE-N (N-gram) scoring
#     - ROUGE-L (Longest Common Subsequence) scoring
#         - sentence-level: Compute longest common subsequence (LCS) between two pieces of text. Newlines are ignored. This is called rougeL in this package.
#         - summary-level: Newlines in the text are interpreted as sentence boundaries, and the LCS is computed between each pair of reference and candidate sentences, and something called union-LCS is computed. This is called rougeLsum in this package.

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# # Inputs and Labels

# %% [markdown]
# - csv로 저장된 데이터를 불러와 9:1로 훈련과 검증에 사용합니다.
# - 선언한 전처리 함수를 적용하여 데이터세트를 생성합니다.

# %%
data_df = pd.read_pickle(DATA_PATH)

# %%
dataset = Dataset.from_pandas(data_df).shuffle(seed=100).train_test_split(0.2)
train_dataset = dataset['train']
eval_dataset = dataset['test']

# %%
train_dataset = train_dataset.map(preprocess_function, 
                                  batched=True, 
                                  num_proc=NCPU, 
                                  remove_columns=train_dataset.column_names)

eval_dataset = eval_dataset.map(preprocess_function, 
                                batched=True, 
                                num_proc=NCPU, 
                                remove_columns=eval_dataset.column_names)
print(train_dataset)
print(eval_dataset)
# Out:
# Map (num_proc=16):   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map (num_proc=16):   0%|          | 0/317 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1268
# })
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 317
# })

# %%
tokenizer.decode(train_dataset['input_ids'][0])
# Out:
# 'generate keyphrases: 김정섭 공주시장 "유구 채석단지 지정 시 광범위한 피해 우려" 김정섭 공주시장이 7일 정례브리핑을 열고 채석단지 개발에 대해 공식적으로 우려를 표명하고 있다. /공주시 제공 정례브리핑서 "주민 의견 청취해 산림청장에 적극 전달" 김정섭 공주시장이 7일 정례브리핑을 열고 유구읍 채석단지 개발에 대해 공식적으로 우려를 표명했다. 김 시장은 "채석단지 지정 시 발생 가능한 광범위한 피해를 우려한다"며 "주민들의 소중한 의견을 청취해 지정권자인 산림청장에게 적극적으로 전달할 예정"이라고 밝혔다. 이어 "지난 2015년 의당면, 2019년 정안면에서 토석 채취와 관련해 주민들의 강한 반대가 있어 무산된 사실이 있다"며 "생업도 뿌리치고 채석단지 지정 반대를 위해 활동하는 여러 시민들의 입장에서 대응할 것"이라고 덧붙였다. 또 "자연환경을 기반으로 현재까지 시에서 유구읍에 색동수국정원, 유구천 살리기 등의 사업을 추진해 왔다"며 "채석단지 지정이 통과된다면 모든 사업이 퇴색되고 장기적인 환경 피해가 발생할 것으로 예상된다"고 강조했다. 골재 생산 업체는 유구읍 녹천리 관불산 인근에 채석단지 지정을 위한 환경영향평가 초안을 제출하고 지난 5월까지 약 7개월간 주민 의견을 수렴했지만 3300건에 달하는 의견과 함께 2100여명의 탄원서 제출로 반발에 부딪혔다. 주민들은 의견서에서 "석분‧미세먼지 등의 비산으로 반경 2km 이내 인구 밀집지역 각종 피해, 라돈, 석면 등</s>'

# %%
tokenizer.decode(train_dataset['labels'][0])
# Out:
# '김정섭 공주시장,유구 채석단지 지정,피해 우려</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %% [markdown]
# # Train

# %% [markdown]
# - 상단에서 선언한 HP와 각종 변수들로 training_args를 생성합니다.

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    run_name=run_name,
    report_to=report_to,

    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,

    optim=optim,

    learning_rate=learning_rate,
    weight_decay=weight_decay,
    adam_epsilon=adam_epsilon,

    lr_scheduler_type=lr_scheduler_type,
    warmup_ratio=warmup_ratio,

    save_total_limit=save_total_limit,

    load_best_model_at_end=load_best_model_at_end,
    metric_for_best_model=metric_for_best_model,

    save_strategy=save_strategy,
    evaluation_strategy=evaluation_strategy,

    logging_strategy=logging_strategy,
    logging_first_step=logging_first_step, 
    logging_steps=logging_steps,

    predict_with_generate=predict_with_generate,
    generation_max_length=generation_max_length,
    # generation_num_beams=generation_num_beams,

    fp16=fp16,
)

# %% [markdown]
# - 배치 단위로 padding처리를 하여 훈련 속도를 높히기 위해 data_collator를 선언합니다.
# - 생성한 객체들을 trainer에 포함시켜 훈련 준비를 마칩니다.

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, padding=True)

trainer = Seq2SeqTrainer(
    model=model,
    
    args=training_args,
    
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    
    tokenizer=tokenizer,
    data_collator=data_collator,
    
    compute_metrics=compute_metrics,
)

# %% [markdown]
# - 훈련을 시작합니다.

# %%
trainer.train()
# Out:
# wandb version 0.14.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/jake/codes/news-topic-keyphrase-generation-model-dev/wandb/run-20230411_101440-lha8ky15</code>
# Syncing run <strong><a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/lha8ky15' target="_blank">paust_pko_t5_base_v2</a></strong> to <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev</a>
#  View run at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/lha8ky15' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/lha8ky15</a>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='9510' max='9510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9510/9510 1:41:28, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>14.487200</td>
#       <td>2.447541</td>
#       <td>3.109300</td>
#       <td>0.441600</td>
#       <td>3.064400</td>
#       <td>3.126000</td>
#       <td>94.334400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.353100</td>
#       <td>0.408058</td>
#       <td>11.426100</td>
#       <td>1.405700</td>
#       <td>11.143200</td>
#       <td>11.179100</td>
#       <td>24.539400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.642600</td>
#       <td>0.265997</td>
#       <td>16.548900</td>
#       <td>3.740900</td>
#       <td>15.698300</td>
#       <td>15.704100</td>
#       <td>28.375400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.295000</td>
#       <td>0.239667</td>
#       <td>18.810700</td>
#       <td>4.057800</td>
#       <td>17.933400</td>
#       <td>18.059500</td>
#       <td>28.006300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.261800</td>
#       <td>0.228481</td>
#       <td>20.204200</td>
#       <td>4.797200</td>
#       <td>19.329600</td>
#       <td>19.399700</td>
#       <td>27.309100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.246200</td>
#       <td>0.222539</td>
#       <td>19.745600</td>
#       <td>3.958200</td>
#       <td>18.892200</td>
#       <td>18.943000</td>
#       <td>26.817000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.233500</td>
#       <td>0.218430</td>
#       <td>20.454700</td>
#       <td>4.758200</td>
#       <td>19.498000</td>
#       <td>19.465700</td>
#       <td>27.665600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.224600</td>
#       <td>0.216070</td>
#       <td>21.004600</td>
#       <td>4.497300</td>
#       <td>20.138300</td>
#       <td>20.113800</td>
#       <td>26.694000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.221300</td>
#       <td>0.214330</td>
#       <td>20.438200</td>
#       <td>4.061200</td>
#       <td>19.520400</td>
#       <td>19.527200</td>
#       <td>25.845400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.213800</td>
#       <td>0.212267</td>
#       <td>21.237600</td>
#       <td>4.429400</td>
#       <td>20.394300</td>
#       <td>20.217500</td>
#       <td>26.744500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.216400</td>
#       <td>0.212225</td>
#       <td>21.067700</td>
#       <td>3.927100</td>
#       <td>20.019000</td>
#       <td>20.106400</td>
#       <td>26.489000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.208400</td>
#       <td>0.211575</td>
#       <td>22.051800</td>
#       <td>4.771000</td>
#       <td>21.109200</td>
#       <td>21.071600</td>
#       <td>26.485800</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.215800</td>
#       <td>0.211350</td>
#       <td>21.663700</td>
#       <td>4.530600</td>
#       <td>20.776800</td>
#       <td>20.696900</td>
#       <td>26.230300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.207000</td>
#       <td>0.211216</td>
#       <td>22.055400</td>
#       <td>4.530600</td>
#       <td>21.224000</td>
#       <td>21.069900</td>
#       <td>26.545700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.208600</td>
#       <td>0.211193</td>
#       <td>21.899900</td>
#       <td>4.530600</td>
#       <td>21.004300</td>
#       <td>20.903300</td>
#       <td>26.583600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9510, training_loss=1.1181987142462586, metrics={'train_runtime': 6085.9148, 'train_samples_per_second': 3.125, 'train_steps_per_second': 1.563, 'total_flos': 1.384213439840256e+16, 'train_loss': 1.1181987142462586, 'epoch': 15.0})

# %% [markdown]
# - 옵티마이저 스테이트를 포함한 훈련 재개에 사용할 파일들을 삭제해줍니다.
# - 추후 불러올 모델과 토크나이저 관련 파일만 남겨둡니다.

# %%
# keep = [
#     'added_tokens.json',
#     'config.json',
#     'pytorch_model.bin',
#     'special_tokens_map.json',
#     'tokenizer.json',
#     'tokenizer_config.json',
#     'vocab.txt'
# ]

# ckpts = os.listdir(output_dir)
# for ckpt in ckpts:
#     ckpt = os.path.join(output_dir, ckpt)
#     for item in os.listdir(ckpt):
#         if item not in keep:
#             os.remove(os.path.join(ckpt, item))

# %% [markdown]
# # Generate

# %% [markdown]
# - 훈련을 마치면 Evaluation Loss 기준 Best 모델이 로드되어 있습니다.
# - trainer는 Greedy Search를 수행하도록 설정되어 있습니다.
# - Evaluation 데이터를 활용해 모델의 출력을 간단히 살펴봅니다.

# %%
preds = trainer.predict(eval_dataset)

# %%
for data, pred in zip(eval_dataset, preds.predictions):
    context = tokenizer.decode(data['input_ids'], skip_special_tokens=True)
    summary = tokenizer.decode(data['labels'], skip_special_tokens=True)
    pred = tokenizer.decode(pred[2:], skip_special_tokens=True)
    # print(f'입력: {context}')
    print(f'정답: {summary}')
    print(f'예측: {pred}', end='\n\n')
# Out:
# 정답: 탕화쿵푸마라탕,다온시스템 클린세이버,업무협약 체결,건강한 식음료 문화,코로나 극복,외식업 변화,중국 전통 음식
# 예측: 화쿵푸마라탕,다온시스템 클린세이버,업무협약 체결,탕화쿵푸마라탕,다온시스템 클린세이버,코로나 시대,건강한 식음료 문화,다온시스템 클린세이버,업무협약 체결
#
# 정답: government,protest,colombia,strike
# 예측: OLOMBIA,PROTESTS,STRIKE
#
# 정답: 로봇,오세훈,착공식,4차산업 혁명,로봇인공지능과학관,
# 예측: 게임문화센터,게임문화 세미나,경기게임문화센터,게임업계 종사자,정신건강 전문의
#
# 정답: 지역22번째,대전 90대,확진자,신종 코로나 바이러스
# 예측:  90대 확진자,신종 코로나바이러스 감염증,감염증
#
# 정답: 전남남도,진단검사,요양병원,요양시설 종사자,고위험 시설,코로나 19
# 예측: 19,요양병원,요양시설,종사자 진단검사,강화,감염위험,감염경로,접종유무
#
# 정답: 보협인석탑,문화재보호법,입수경위,동국대,천안국보,불법입수
# 예측: 협인석탑,천안 국보,보협인석탑,입수 경위,공개,충남도국외소재문화재 실태조사단,천안시,문화재보호법
#
# 정답: 인스타그램,시선강탈,정하나,미모
# 예측:  출신 정하나,개미허리,시선강탈,개미허리
#
# 정답: 황금빛골드바 이벤트,음악 저작권 거래,뮤직카우
# 예측: 카우,황금골드바 어텀 이벤트,음악 저작권료 연금 나와라 뚝딱,친구 초대 1+1,음악 저작권 거래 플랫폼,뮤직카우
#
# 정답: 출근길,조이,동물농장
# 예측: 벨벳,조이,동물농장
#
# 정답: 공인중개사 시험,스윗메가 인증챌린지,수험생,메가랜드,세법 이송원 구원 특강
# 예측: 랜드,세법,이송원 구원 특강,메가스터디,공인중개사 인강 전문 브랜드,메가랜드,세법
#
# 정답: 케이원엔터테인먼트,-> 이지훈,전속계약 체결
# 예측: ,케이원엔터테인먼트,전속계약 체결,배우 이지훈
#
# 정답: 서울대 정시 경쟁률,연세대
# 예측: ,연세대,정시 경쟁률,4.13대 1,서울대,4.76대 1,일반전형
#
# 정답: 인명피해,사찰 화재,상북면
# 예측: ,상북면 소재 사찰,목조건물 소실,인명 피해,원인,조사중,화재
#
# 정답: 국립서울현충원,김정숙,문재인
# 예측: 서울현충원,문재인 대통령,김정숙 여사,현충탑
#
# 정답: 히트 메이커,조영수 프로듀서,미스트롯2,양지은,데뷔,사는 맛,인터뷰 영상
# 예측:  메이커,조영수,양지은,이선희,양희은,미스트롯2
#
# 정답: 루카쿠,베르너,독일 분데스리가,첼시,리그,허드슨-오도이
# 예측: ,공격진,구멍 숭숭,성골 유스 윙어도,이적설,도르트문트,RB 라이프치히로,이적설,도르트문트
#
# 정답: 러시아 출신,슈퍼스타 오베치킨,평화,전쟁
# 예측: 치킨,평화 호소,러시아 출신 NHL 슈퍼스타,러시아 출신 NHL 슈퍼스타,러시아 출신 NHL 슈퍼스타
#
# 정답: 반도체 공급 부족,삼성SDI,하나금융투자
# 예측: SDI,반도체 공급 부족 영향,하나금투,반도체 공급 부족
#
# 정답: 최수영,침수,한효주,양치승,성훈,재난지원금,김주헌
# 예측: 승,최수영,성훈,진서연,헬스 트레이너,재난 지원금,한효주,최수영,성훈
#
# 정답: 덕온공주체,국립한글박물관,한글날,덕온공주,한글
# 예측: 온공주 글씨체,한글박물관,한글날,한글날,한글 궁체 자료,한글 궁체 자료,한글 궁체 자료
#
# 정답: 이은지,제주종합경기장,실내수영장,2021 경영 국가대표 선발대회,여자 배영 50m 결승,출발,기록: 28초52
# 예측: 지,힘찬 출발,제주종합경기장,실내수영장,2021 경영 국가대표 선발대회
#
# 정답: 연정훈,한가인,1박2일시즌4,결혼기념일
# 예측: 정훈,문세윤,연애상담사,유부클럽,연애 상담사,결혼기념일 잊었던
#
# 정답: 고 강수연,한국영화,영화인생,발인
# 예측: 수연,고인,영화 그 자체,영결식,영화인,유지태,강수연
#
# 정답: LG,로베르토 라모스,선발 제외,17일,잠실 삼성전,올시즌 4번째,타율 0.238
# 예측: G,라모스,선발 제외,로베르토 라모스,선발라인업,LG,로베르토 라모스,선발 제외
#
# 정답: 수아레즈,완벽투,고우석,세이브,LG,NC,잠실구장
# 예측: G,NC,수아레즈,고우석 세이브,LG,NC
#
# 정답: 추성훈,쩍 갈라진 근육질,컴백,노화
# 예측: ,노화,쩍 갈라진 근육질,컴백,인스타그램,야노시호,추성훈
#
# 정답: 메시,수아레스,린가드,래시포드,축구계,브로맨스 커플,호흡
# 예측: 맨스,축구계,브로맨스,커플,메시,수아레스,린가드,래시포드
#
# 정답: 카카오,역성장,영업이익,실적 쇼크,기업지배구조,글로벌 경기 침체,어닝쇼크
# 예측: ,먹통사태,실적 쇼크,카카오판교아지트,데이터센터
#
# 정답: 원트,스트릿우먼파이터 온더 스테이지
# 예측: 트,힘 넘치는 무대,화제의 콘서트
#
# 정답: 가상자산 폭락,롱포지션,비트코인 선물 거래,레버리지 투자,가상자산 선물 거래량,폭증,이더리움 선물 거래량
# 예측:  투자,가상자산 선물,투기 끝판왕,가상자산 선물 거래량,4배 폭증,123RF
#
# 정답: 대우조선해양건설,5000억 아리울 해상풍력 업무협약,새만금,해상풍력발전
# 예측: ,해상풍력,5000억 아리울 해상풍력 업무협약,대우조선해양건설,100MW급,대규모 단지 조성사업,EPC
#
# 정답: 최지만,복귀 후 3경기 연속 안타와 타점,무릎 부상,결승타 포함 멀티히트,팀 6연승 견인,볼티모어 오리올스 경기,라인업
# 예측: 지만,BAL전 결승타,멀티히트,부상 공백,복귀,3경기 연속 안타,타점
#
# 정답: 송파 플래티넘,리모델링,분양,신규아파트,청약
# 예측:  플래티넘,리모델링,송파구 오금동,리모델링,일반분양,송파구 오금동,리모델링
#
# 정답: 왕립도서관,규장각,창덕궁,주합루,서향각,희우정,천석정
# 예측: 장각,가을과 어울어진 왕립도서관,규장각,주합루
#
# 정답: 롯데온,할인 행사,롯데그룹,쇼핑 편의성,쇼핑 통합 온라인 쇼핑몰
# 예측: 온,대대적 반격,온세상 새로고침,롯데온,시스템 불안 요소,개선,롯데쇼핑
#
# 정답: 아우디 딜러,2021 아우디 딜러 어워즈,탑 아우디언,코로나19,고진모터스,한서모터스
# 예측: ,2021 아우디 딜러 어워즈,탑 아우디언,세일즈,A/S,마케팅 부문
#
# 정답: 생활습관 개선,심장,소변,항생제,역류,선천적·후천적 이유,질환
# 예측: ,생활습관 개선,위산·정맥혈,생활습관 개선,역류 질환,생활습관 개선,심장·소변
#
# 정답: 호우특보,비,강원
# 예측: 특보,강원도,10개 시·군,호우경보,내일까지 80mm,더 내려,춘천,원주
#
# 정답: 강원도,쇠고기,물가상승률,돼지고기,해조류,수입 쇠고기,시장
# 예측: 선수권 결선리그,한국 여자핸드볼,세계선수권 결선리그,한국 여자핸드볼,결선리그
#
# 정답: 반갑지만,'조심',추석 연휴 코로나,가족
# 예측:  연휴,코로나,조심,조심,조심
#
# 정답: 서울 전역 대설주의보 해제,세종로 사거리,대설주의보
# 예측:  전역 대설주의보 해제,기상청,서울 전역,대설주의보
#
# 정답: 공인인증제도 폐지,전자서명법 시행,공인인증서 폐지법,민간인증서 활용도,개정 전자서명법,생체인증,블록체인
# 예측: 인증서 폐지법,새 전자서명법,공인인증서 폐지법,생체인증,블록체인,블록체인,블록체인,블록체인
#
# 정답: Venezia square,MILITARY,PRESIDENTIAL GUARD,ITALY,REPUBLIC DAY,Rome
# 예측: TALY,REPUBLIC DAY,EPA/Corazzieri,Rome,Italy
#
# 정답: 비판,언론중재법,국제언론단체,날 선 반응,송영길
# 예측: 중재법 비판,송영길,국제언론단체,언론중재법 비판,뭣도 모르니까
#
# 정답: 이재명,대선 후보,자율주행차
# 예측: 주행차 오토비,이재명,더불어민주당,대선 후보,대전 유성구,한국전자통신연구원
#
# 정답: 가계대출,전체 주택담보대출,고강도 대출,마이너스통장,기업대출,코로나19,전세대출
# 예측: 권 가계대출,은행권 대출,코로나19,은행권 대출,9월 증가액,역대 최대 증가,기업대출
#
# 정답: 언론중재법 개정안,신중론,필리버스터
# 예측: 중재법 필리버스터,여·야,신중론,신중론,민주당,본회의
#
# 정답: 남양유업,매매예약완결권,매각,대유홀딩스
# 예측: 유업,매각,점입가경,대유위니아,홍원식 회장,계약 해제,조건부 매각,매각 작업,매각 작업
#
# 정답: 노동자,추락,울산조선소,현대중공업,사망
# 예측: 업체 노동자,추락,사망,현대중공업 울산조선소서,협력업체 노동자,추락
#
# 정답: 인기를 끌었다.,할인 혜택,머지포인트
# 예측: 포인트,폭탄 돌리기,자영업자 피해,머지플러스,가맹점,20% 할인,가맹점,가맹점,결제
#
# 정답: 티샷,박현경,전남 영암,사우스링스영암CC,크리스 F&C 제43회 KLPGA 챔피언십,최종라운드
# 예측: 현경,사우스링스영암CC,크리스 F&C 제43회 KLPGA 챔피언십,최종라운드
#
# 정답: 김태환 부상,울산현대,홍명보 감독
# 예측:  이어가려는 홍명보,체력적 부분,김태환,부상,대구FC,하나원큐 K리그1 2021 30라운드,울산 현대,대구FC
#
# 정답: 성추행피해,대통령이 직접,해군,국방부,성폭력 사건,대책마련
# 예측:  사망 사건,군,대체 뭘 혁신했나,공군,장 모 중사,강제추행,군,군 혁신,대통령,군 혁신
#
# 정답: 유사독재,문재인 대통령,윤석열 후보,소수정예 선거운동
# 예측: ,소수정예 선거운동,유사 독재,문재인 대통령,저격
#
# 정답: 스폰서,지이수,수목드라마
# 예측: 이수,스폰서,온라인제작보고회,지이수
#
# 정답: 고쳐 쓰기,과소비 사회,친환경,지속가능한 지구,행복감,자연에 대한 이해,유한한 자원
# 예측:  쓰며 얻게 되는 것들,과소비 사회,환경,자원,쓰레기
#
# 정답: CJ온스타일,공식 론칭,채널 통합,라이브 취향 쇼핑플랫폼,모바일 큐레이션,애플리케이션,고객 취향
# 정답: 2021 전국농민총궐기,행진
# 예측: ,전국농민총궐기,국회 인근,2021년 전국농민총궐기
#
# 정답: 부산시,시내버스 안전기준 점검,위반사항 26건 적발,시내버스 운행업체 28곳,시민 안전,엔진 상태,타이어 마모상태
# 예측: 시내버스,관리 불량,위반사항,위반사항,점검,시정명령,행정처분,개선명령,시정명령
#
# 정답: 리듬체조,국가대표 선수,신수지,골프
# 예측: 체조 전 국가대표 선수 신수지,골프채 들고 역대급 미모,시원한 미소
#
# 정답: 비니,청량하게
# 예측: ,청량하게,청량하게
#
# 정답: 한국유통학회,비대면 시대,오프라인 트랜스포메이션,대한상공회의소,춘계학술대회,정지영 현대백화점 부사장,더현대 서울의 성공전략
# 예측:  시대의 오프라인 트랜스포메이션,한국유통학회,춘계학술대회,비대면 시대,오프라인 트랜스포메이션
#
# 정답: 문재인 전 대통령,시위,평산마을,퇴임100일,여름휴가
# 예측:  전 대통령,여름휴가,국민의힘,집회,시위
#
# 정답: 부동산 증여,자녀,서울 집합건물,소유권 이전등기 통계,연령대별 비중,40대 미만,40~50대
# 예측:  부동산 증여,주수요층,연령대,부동산 증여,주수요층,연령대,2020년 1분기,40대 미만 수증인 비중,2020년 1분기
#
# 정답: 에스파,귀가,코로나19,음성 판정
# 예측: ,카리나,윈터,닝닝,코로나19 음성 판정,귀가,SM엔터테인먼트,SM엔터테인먼트
#
# 정답: 여성 납치,승합차,뉴스파이터
# 예측: BN 뉴스파이터,승합차,문 열리더니,길가던 여성 납치,400m 추격
#
# 정답: 동계올림픽,시진핑,코로나19,베이징,대면정상외교
# 예측: ,대면 정상 외교,올림픽,베이징,베이징,코로나19,중국,러시아
#
# 정답: 자립준비청년 생애 주기별 지원책,두나무
# 예측: 나무,자립준비청년,생애 주기별 지원책 제공,블록체인 및 핀테크 전문 기업,브라더스키퍼,사회연대은행
#
# 정답: 아시아경제,다보스포럼,귀국,나경원,스위스 다보스,유세지원,자유한국당
# 예측: ,다보스포럼,귀국,유세지원,반기문,문재인 대통령,가치외교
#
# 정답: 코로나19,자가검사키트,콜센터,서울 성동구
# 예측: 검사키트,콜센터,코로나19,자가검사키트,콜센터,서울 성동구,콜센터
#
# 정답: 단풍 풍경,평양
# 예측: ,가을 단풍 풍경,단풍 풍경
#
# 정답: 일본 경제,민간소비,글로벌 성장세,설비투자,회복
# 예측:  경제,완만한 회복세,속도,둔화,글로벌 인플레이션 압력,일본 경제,수출,설비투자,회복
#
# 정답: 알몸여성,보배드림,도로한복판,공연음란죄
# 예측:  여성,교통정리,경찰,경찰,경찰
#
# 정답: 보건노조,총파업,김승두,코로나19 병상,김부겸
# 예측:  국무총리,코로나19 병상,서울시립서북병원,의료현장,의료현장
#
# 정답: 대박부동산,장나라,정용화,폐건물,비명,긴급상황,생활밀착형 퇴마 드라마
# 예측: 부동산,장나라,정용화,폐건물,긴급상황,납치 현장
#
# 정답: AFGHANISTAN,BOMBING
# 예측: FGHANISTAN,BOMBING,Kabul,Afghanistan
#
# 정답: 프로바이오틱스,인증,hy 3총사,판매량,대박,식약처,성장세
# 예측:  인증,액상 3총사,판매량,대박,식약처 인증
#
# 정답: 경남 주간 평균 확진자,확진자,신종코로나바이러스
# 예측: ,신종 코로나바이러스 감염증,확진자 수,5주째 증가세 지속,확진자 수,58명,코로나19 대응 브리핑,감염경로 조사자 수 비율,감염경로 조사자 수 비율
#
# 정답: 삼성 라이온즈,포항 경기,13연패,2022 프로야구
# 예측: 의 땅,삼성 라이온즈,13연패,삼성 라이온즈,키움 히어로즈,8-0 삼성 라이온즈,2022 프로야구,삼성 라이온즈,키움 히어로즈
#
# 정답: 보이스4,이하나,초청력
# 예측: 4,이하나,빌런,보이스4,심판의 시간,빌런,보이스4
#
# 정답: 석유공사,친환경 선도 기업,환골탈태,탄소 감축 노력,코로나 사태,석유 수요 급감,생존을 위한 유연성
# 예측:  뚫고 하이킥,석유공사,친환경 선도 기업,환골탈태
#
# 정답: 지성,죽음,김혜순 시인,시집,문학
# 예측: ,죽으면 달은 누굴 돌지,김혜순 시인,문학과지성 시인선,567호,코로나19,지구,엄마,죽음
#
# 정답: 빅토리콘텐츠,인사말,권태호 대리
# 예측: 콘텐츠 권태호 대리,인사말,이미지 원본
#
# 정답: 50세 이상,전립선암,전립선암 환자
# 예측: 암,50세 이상,조심해야 할까,가족력 있으면 40대부터 검진 필요,서구식 생활,고령층
#
# 정답: 2021 미스코리아,부산‧울산 선발대회,당선자들,BN그룹,협찬,감사,본사 방문
# 예측: 코리아,부산‧울산 선발대회,BN그룹,방문,협찬,협찬
#
# 정답: 전북,세징야,대구,무패행진
# 예측: 징야,세징야,전북,무패행진
#
# 정답: 조선통신사선,선상박물관,문화재청 국립해양문화재연구소,체험형 문화공간,선상박물관 문화기행,역사문화자원,대한민국 4대 관광도시
# 예측: 박물관 문화기행,조선통신사선,해양문화,체험형 문화공간,목포,해양문화,체험형 문화공간
#
# 정답: KT위즈,이대은,박시은
# 예측: 위,선두 지키기,마법사 군단,잠실구장,두산,위닝시리즈
#
# 정답: 산다라박,YG엔터테인먼트,전속계약 만료,17년 인연,2NE1,CL,박봄
# 예측: 박,YG엔터테인먼트,전속계약,17년 인연,YG 떠난다,2NE1,YG
#
# 정답: 충북 오전 5~40mm 장맛비,오후 시간당 20mm 이상 소나기,호우특보
# 예측:  5~40mm 장맛비,충북,기상청,기상특보
#
# 정답: 미우새,신동엽,부친상,녹화 연기
# 예측: ,부친상,미우새,녹화 연기,SBS '미운우리새끼'
#
# 정답: 한국자유총연맹부산광역시지부,충혼탑 참배
# 예측: 자유총연맹부산광역시지부,충혼탑 참배,한국자유총연맹부산광역시지부
#
# 정답: 뱅크샐러드 마이데이터 인증서,초개인화,뱅크샐러드
# 예측: 샐러드,라이프 전반,초개인화,마이데이터,자산관리 플랫폼,데이터 기반 자산관리 플랫폼,초개인화
#
# 정답: 김기현,구미 기업인,간담회,국민의힘,당 대표 권한대행,원내대표,20일
# 예측: ,구미 기업인과 간담회,국민의힘,김기현
#
# 정답: 롯데,선발투수,스트레일리,부산 사직구장,KBO 프로야구,SSG 랜더스,롯데 자이언츠
#
# 정답: SSG 랜더스,박종훈,인대손상
# 예측:  출국 전 박종훈,SSG 랜더스,김원형 감독,사과,박훈
#
# 정답: 신현빈,재벌집 막내아들,재회,김신록,송중기,순양백화점
# 예측: 집 막내아들,신현빈,송중기가 신현빈과 재회,김신록,해임 위기,신현빈
#
# 정답: albania,diplomacy,Viktor Orban,Edi Rama
# 예측: UNGARY,ALBANIA,DIPLOMACY,EPA/Szilard Koszticsak
#
# 정답: 특금법,가상자산 거래소,등록,0곳,은성수 금융위원장,거래소 자체 상황,요인
# 예측: 위원장,가상자산 거래소,특금법,가상자산 거래소,폐쇄,금융위원회,가상자산 거래소
#
# 정답: 변수,유고,대선 돌발,대장동 키맨,유한기
# 예측: 동 키맨,유한기,대선 돌발 변수,윗선 연결고리,이재명,유서
#
# 정답: 방송작가노조,부당해고
# 예측: 작가노조,부당해고,근로자성 인정하라,KBS전주
#
# 정답: 디크런치,현욱,O.V,확진,가요계,코로나19,선제 검사
# 예측: 크런치,코로나19 확진,가수,감염증 확진,가수
#
# 정답: 단식농성,비대위원장,의정부시의회,박지현
# 예측: 현,더불어민주당,단식농성,의정부 시의원,방문
#
# 정답: 날씨정보,뉴스오늘,동영상,포근한 봄 날씨
# 예측:  주의,포근한 봄날씨,일교차 주의,서울,대전,광주,부산,대구
#
# 정답: 홍준표,파탄 난 국정,정권교체,한 알의 밀알
# 예측: ,국정 세우고,정권교체,한 알의 밀알 되고자,국정 세우고
#
# 정답: 영화비즈니스,영화사 올,김윤미 대표,지니스 커뮤니케이션,오케이 마담,롯데시네마,씨네클래스
# 예측: 시네마,로카,영화비즈니스,전문 아카데미,롯데시네마,그럼에도 불구하고
#
# 정답: 이별도 리콜이 되나요?,아이들 우기,이별리콜
# 예측: 리콜,아이들 우기,이별도 리콜,KBS 2TV,이별도 리콜,일일 플래너,아이들 우기
#
# 정답: 이범수,후배 존중,자전차왕 엄복동
# 예측: ,자전차왕 엄복동,실패,부족·미흡,제작 실패,부족·미흡,제작
#
# 정답: 쿠팡,김범석,정의선,현대차,총수,공시대상기업집단,상호출자제한기업집단
# 예측: ,김범석,현대차,정의선,동일인,지정,공정거래위원회,공시대상기업집단,지정
#
# 정답: 코로나바이러스 감염증,신규 확진자 발생,감염재생산지수 1 이하
# 예측: 바이러스 감염증,확진자,백신 접종,세자릿수 확진자,백신 접종
#
# 정답: 레반도스프키,바이에른뮌핸,바로셀로나,챔피언스리그 조별리그
# 예측:  뮌헨,선발 명단 공개,로베르트 레반도프스키,뮌헨 폭격,바르셀로나 이적,바르셀로나 이적
#
# 정답: 노량진 수산시장,갈등 해결,시민단체,권명숙,서울진보연대 집행위원장,14일 오전,서울시청 앞
# 예측:  수산시장 갈등 해결,시민단체,권명숙,서울진보연대,권명숙
#
# 정답: 한국여자프로골프,엘크루-TV조선 프로 셀러브리티 2021,손연정
# 예측: 연정,엘크루-TV조선 프로 셀러브리티 2021,경기도 안산 아일랜드 CC,한국여자프로골프 투어
#
# 정답: 2022년도 도시재생 뉴딜,산청군,옥산지구 도시재생,뉴딜공모 사전준비
# 예측: 군,옥산지구 도시재생 뉴딜 공모,마중물사업,도시재생 뉴딜 공모,사전준비 컨설팅,마중물사업,도시재생 뉴딜 공모,도시재생 뉴딜 공모
#
# 정답: 백악관,연휴,바이든,뉴캐슬
# 예측: ,노동절 연휴,백악관 복귀,조 바이든,노동절 연휴
#
# 정답: 현대글로비스,가정의 달,홀몸 어르신,반려식물,전달,식료품,금전수
# 예측: 글로비스,가정의 달,홀몸 어르신,후원품 전달,코로나19,돌봄
#
# 정답: 유지어터 권미진,딸 웃는게 똑같네,인스타그램,힐링 미소,2007년 MBC 팔도모창대회,KBS 공채 25기 개그우먼,개그콘서트-헬스걸
# 예측: 미진,딸 웃는게 똑같네,유지어터,권미진,KBS2 '개그콘서트-헬스걸',50kg 뺀,유지어터
#
# 정답: 테슬라,사망 사고,운전자 오토파일럿,도로교통안전국
# 예측: ,오토파일럿,사망 사고,살인죄,기소,미국 로스앤젤레스 카운티 검찰,살인죄
#
# 정답: 트롯매직유랑단,진해성,녹화
# 예측: 성,폭발하는 카리스마,트롯매직유랑단,트롯매직유랑단,녹화
#
# 정답: 이준석 대표,제8회 전국동시지방선거
# 예측: ,제주대서 식사,이준석 대표,제8회 전국동시지방선거
#
# 정답: CTA 부사장인터뷰,제이미 카플란,CES 2023
# 예측:  카플란,CTA 부사장,CES 2023 폐막을,세계 최대 가전·IT 전시회
#
# 정답: 시트콤,내일 지구가 망해버렸으면 좋겠어,6월 18일 공개,티저포스터,넷플릭스 오리지널 시리즈,국제 기숙사 학생들,사랑과 우정
# 예측:  오리지널 시리즈,내일 지구가 망해버렸으면 좋겠어,티저포스터,개성가득 티저포스터,시트콤
#
# 정답: 최은우,klpga,티샷,제43회klpga챔피언십
# 예측: 은우,바닷 바람 뚫고 날리는 티샷,사우스링스 영암 카일필립스A B,KLPGA챔피언십
#
# 정답: 스토킹 피해,유튜버 릴카
# 예측:  피해,BJ 릴카,스토킹 피해,죽고 싶지 않아,신변의 위협 느껴
#
# 정답: EPL,황희찬,호날두
# 예측: ,시즌 초반,황희찬,맨유,이적
#
# 정답: 전속고발권 폐지,대책,공정위,문제,주병기 교수
# 예측: 캠프,전속고발권 폐지,특단대책,공정위,삼성 웰스토리,사내급식 일감 몰아주기
#
# 정답: tennis,250,atp,2021,switzerland,world tour
# 예측: WITZERLAND TOUR,ATP 250 WORLD TOUR
#
# 정답: 블루프리즘,SaaS RPA 플랫폼,사용량 기반 과금 모델,클라우드 관리형 서비스형소프트웨어,로보틱프로세스자동화,유연한 대응,디지털 워커
# 예측:  관리형 서비스형소프트웨어,로보틱프로세스자동화 플랫폼,사용량 기반 과금 모델 출시,블루프리즘,SaaS RPA 플랫폼,클라우드 관리형 서비스형소프트웨어,로보틱프로세스자동화 플랫폼
#
# 정답: 제정,노란봉투법,정의당,위기 농성 돌입
# 예측: ,노란봉투법 제정,농성,국회 본관 앞 계단,노란봉투법
#
# 정답: 김부겸 총리,국민 통합,오영식,총리 비서실장,참모진,임기 시작,문재인 대통령
# 예측:  총리,국민통합,오영식 비서실장,문재인 대통령,김부겸 총리,임명장 수여식,기념촬영,김부겸 총리실,임종석
#
# 정답: 인사청문회,여야 원내대표,김부겸 국무총리 후보자,장관 후보자,국회 법제사법위원장,상임위원장 재배분,더불어민주당
# 예측: 청문회,여야,김부겸 국무총리 후보자,법사위 재배분,빅딜론,김부겸 국무총리 후보자,인사청문보고서 채택
#
# 정답: uefa euro 2020,hungary,soccer,tomas soucek,frenkie de Jong
# 예측: UNGARY,SOCCCER,UEFA EURO,2020
#
# 정답: 체포영장,가세연,채널,유튜브,강용석,가로세로연구소,김세의
# 예측:  채널,가세연 출연진,체포영장 집행,경찰,강용석·김세의,가세연 출연진
#
# 정답: 레스터 시티,맨체스터 유나이티드,맨체스터 시티,우승 확정,2-1 승리,프리미어리그,36라운드
# 예측: 윈쥐,레스터,맨체스터 유나이티드,맨체스터 시티,맨체스터 유나이티드,맨체스터 유나이티드
#
# 정답: 준우승 김태형,두산 베어스
# 예측:  감독,한국시리즈 준우승,두산 베어스,KT 위즈,한국시리즈 4차전,KT 위즈,우승
#
# 정답: 전용면적 84m2,첫 '20억 아파트',경기도
# 예측: 도,20억 아파트,매매신고,과천 중앙동,과천푸르지오써밋,전용면적 84m2
#
# 정답: 가상 인플루언서,모델,한국경제,로지,홍보대사
# 예측: ·홍보대사,국가대표 얼굴,얼굴,미국 경제 매체 비즈니스인사이더,가상 인플루언서,한국,미국,탄자니아,태국
#
# 정답: 홍준표,복당 반대,당 배신했다,비판,국민의힘,하태경 의원,바른미래당
# 예측:  반대,홍준표,국민의힘,탈당파,복당 반대
#
# 정답: 롯데칠성음료,처음처럼,신규 광고,제니
# 예측: 칠성음료,처음처럼 신규 광고,제니,소주다운 맛,콘셉트로 리뉴얼,제니
#
# 정답: 아스트라제네카,접종 시작,서울 금천구보건소,의료진,신종 코로나바이러스,2차 접종,백신 접종
# 예측: 스트라제네카 2차 접종,금천구보건소,신종 코로나바이러스 감염증,아스트라제네카 백신 2차 접종,서울 금천구보건소
#
# 정답: 중소기업벤처기업부,중기부,사업연계형 기술개발 지원사업,중소기업
# 예측: 벤처기업부,사업연계형 기술개발 지원사업,10대 과제 선정,혁신역량 확충,팜오일 규제,팜오일 메틸에테르설폰산염 개발
#
# 정답: 2021 MSI,4강,결승전,대진,일정,담원 기아,매드 라이온스
# 예측: SI,MSI,4강·결승전,MSI,MSI,4강·결승전,MSI
#
# 정답: 농성 해제,본사 농성,농성 합의안 도출,하이트진로,민주노총 공공운수노조 화물연대 조합원
# 예측: 진로,본사 농성,합의안,교섭원 투표,교섭 해제,교섭 결렬
#
# 정답: 대학배구,경희대,명지대,2연승,조 선두,2021 KUSF U리그 대학배구대회,남대부 A조경기
# 예측: ,명지대,대학배구,명지대,남대부 A조,2021 KUSF U리그,대학배구
#
# 정답: 권리금 없음,유리창 메모,이대앞 상가들,폐업 상태,임대문의,코로나19,대학가 상권
# 예측: 앞 상가,권리금 없음,임대문의,임대문의,임대문의
#
# 정답: 용아장성,불법등반,설악산
# 예측: 장성,불법 산행,불법 산행,설악산 용아장성
#
# 정답: 혁신 금융 테스트베드,기업은행,IBK 퍼스트랩
# 예측:  금융 테스트베드,IBK 퍼스트랩,3기 참여기업,IBK 퍼스트랩
#
# 정답: 뉴욕증시,인플레이션 우려,기술주,다우지수,나스닥지수,스탠더드앤드푸어스500지수,경제 지표
# 예측: 증시,인플레이션 우려,다우 1.36%,상승,나스닥
#
# 정답: 영화,류화영,사잇소리
# 예측: 화영,러블리 비주얼,인스타그램,인스타
#
# 정답: 종전선언,비핵화,이도훈
# 예측: 훈,평화협정,종전선언,비핵화 논의,평화협정,한반도평화교섭본부장
#
# 정답: 대권 행보,정세균 총리,대구 방문
# 예측:  전 총리,대구 방문,코로나19 백신 2차 접종,화이자사 코로나19 백신 2차 접종
#
# 정답: 삼성서울병원,CJ 4DPLEX,가상현실-바이오피드백 모션체어,의료기기 개발,업무협약 (MOU),우울,불안
# 예측: 서울병원,디지털치료연구센터,VR-바이오피드백 모션체어,의료기기 개발,MOU,삼성서울병원,디지털치료연구센터
#
# 정답: 국민제안,경제난 돌파 해법,국민제안 심사위원회
# 예측: 제안,국민제안,국민제안,심사위원회,최저임금 차등 적용,국민제안,국민 제안,국민 공감형,생활밀착형,직종별 차등 적용
#
# 정답: 충북,먹깨비,정체기,대대적인 홍보,돌파구,배달앱,활성화 지원사업
# 예측: ,먹깨비,홍보,정체기,민간주도 배달앱,홍보,판로
#
# 정답: 손흥민,울버햄튼,선발 출전,리그 18호골,차범근,역대 최고,토트넘 홋스퍼 스타디움
# 예측: ,울브스전,차범근,대기록 경신,토트넘 홋스퍼 스타디움,프리미어리그 36라운드,EPL 17골,리그 18호골
#
# 정답: 이의리,아쉬운 강판,광주-기아챔피언스필드,2021 KBO 프로야구,LG 트윈스,KIA 타이거즈,선두타자 오지환
# 예측: 리,아쉬운강판,아쉬운강판
#
# 정답: LG전자,장애인 접근성 자문단,한국장애인소비자연합,접근성 전문가,가전제품,접근성 평가,지표 개발
# 예측: G전자,장애인 접근성 자문단,LG전자,가전제품,접근성 전문가
#
# 정답: 수산물 물가 안정,해양 신산업,국가전략산업 육성
# 예측: ,물가 동향 점검,윤석열 대통령,국가전략산업,수산물 물가 안정
#
# 정답: 원주천,침수,범람
# 예측: ,범람,원주천,중부지방,기록적인 폭우
#
# 정답: 갱단들,인명 피해,총격전,리토랄 교도소,에콰도르 교도소
# 예측:  교도소,총격전,수감자,사망,마약 밀매,갱단들 소행
#
# 정답: 해인사,팔만대장경,중도,원각스님,부처님
# 예측: 대장경,원각 스님,코로나19,국민에게 공개,국민에게 공개,백신 접종,코로나19 확산 저지
#
# 정답: 김홍조,루키 인비테이셔널,한화생명 E스포츠,카리스,캠프원
# 예측: 리스,김홍조,한화생명e스포츠,전문 트레이닝 센터,캠프원
#
# 정답: 이채원,크로스컨트리
# 예측: 채원,자신과의 싸움,크로스컨트리 대표팀,베이징 동계올림픽
#
# 정답: 기후 변화 시위,그레타 툰베리,유럽
# 예측:  곳곳 기후 변화 시위,학생들,환경운동가,그레타 툰베리,학생들,시위
# 예측: ,윤석열,꿈에 내가 나타나는듯,악몽 꾸다 깰 것,더불어민주당,국방포럼 세미나,KBS,국방포럼
#
# 정답: 합의,문제,초부자,예산안,박홍근,사업,감액
# 예측: 근,예산안,감액,예결위,예결위,예결위,예결위
#
# 정답: 한국간호협회,간호법 제정,윤석열 당선인,국민의힘 윤석열
# 예측: 협회,윤석열 당선인,조속한 간호법 제정 요청,간호협회
#
# 정답: 유흥업소 점주들,경찰 대치,20일 오후,한국유흥음식업중앙회,한국단란주점업중앙회,한국콜라텍협회,관계자 및 업주들
# 예측: 업소 점주들,경찰 대치,유흥업소 점주들,서울시청 내부,집합금지 해제,손실보상법
#
# 정답: 함장,천안함,전우회,안종민,휘문교교사,막말
# 예측: 함 막말,전우회,천안함 사건,휘문고 교사,천안함 사건
#
# 정답: GS건설,봉담자이 라피네,견본주택 오픈,경기도 화성시,동화지구,아파트,전용면적
# 예측: 자이 라피네,견본주택,GS건설,동화지구,A-3블록,아파트 8개 동,총 750가구,광역 교통망이 갖춰진다,봉담2지구,과천,수원,용인,사당,금정역
#
# 정답: 광화문광장,재개장,재구조화
# 예측: 광장,재개장,광화문광장,시민 개방,나무 5000그루 심어,세종문화회관 외벽,미디어아트,광화문광장
#
# 정답: 하이브,BTS,코스피,인수합병,리스크,
# 예측: 소년단,하이브,악재,리스크 대응,시험대,상장,방탄소년단,엔터사,엔데믹,방탄소년단
#
# 정답: 양양군,공중화장실,금지행위,강력 단속,안전하고 위생적인 이용 환경,캠핑 관광객,수도·전기시설 무단사용
# 예측: 군,공중화장실 내 금지행위,강력 단속,금지행위,불법촬영 범죄,화장실 내 숙식행위
#
# 정답: 오승환,KBO리그,500경기 출장,세이브 달성,대구 삼성라이온즈파크,삼성 라이온즈,LG 트윈스
# 예측: ,KBO리그,500경기 출장,세이브,대구 삼성라이온즈파크,KBO리그
#
# 정답: 배우 주현영,인턴 기자,SNL 코리아
# 예측:  기자,배우 주현영,SNL 코리아
#
# 정답: 베베파파,바베파파,한국프로야구선수협회,업무협약
# 예측: 야구선수협회,베베파파,업무협약,도담아이,한국프로야구선수협회
#
# 정답: 유럽클럽대항전,'로베르트 레반도프스키',발롱도르,홀란드,MVP
# 예측: 베르트 레반도프스키,발롱도르,MVP,뮐러,분데스리가,독일클럽대항전
#
# 정답: 70대 실종 이튿날 숨진 채 발견
# 예측:  캐러 갔다 실종,70대,실종
#
# 정답: 창원경상국립대학교병원,건강보험심사평가원,유방암,위암,적정성평가,1등급,전문인력 구성 여부
# 예측: 암,위암,적정성평가,창원경상국립대학교병원,건강보험심사평가원,위암
#
# 정답: 홈씨씨인테리어,고단열 디자인창호,윈도우5+
# 예측: CC글라스,고단열 디자인창호,윈도우5+,KCC글라스,윈도우5+
#
# 정답: BAT 로스만스,궐련형 전자담배,글로 프로 슬림,위해 저감 제품 확대
# 예측: 련형 전자담배,글로 프로 슬림,BAT로스만스,신제품,글로 프로 슬림
#
# 정답: 승부처,여름,코스피,글로벌 증시,백신 접종,경제 활동 정상화,기업 실적
# 예측: 퍼링 리스크,경기 정점,테이퍼링 리스크,승부처,경기 정점,테이퍼링 위험
#
# 정답: 중국,손준호,중국슈퍼리그,프리미어리그,유시쯔쉰왕,EPL,리그랭킹 하락
# 예측: 준호,EPL 진출,중국슈퍼리그,중국슈퍼리그,2022-23 잉글랜드 프리미어리그,취업비자,중국슈퍼리그
#
# 정답: 결혼,서동균,동기 마지막 한 남자,박준형
# 예측: 균,결혼,박준형,동기,서동균,결혼
#
# 정답: 프리미엄 자산관리,하나금융투자,Club1한남WM센터
# 예측: 금융투자,Club1한남WM센터,Club1한남WM센터
#
# 정답: 국민의 힘 이준석대표,호남,기념국민생활관
# 예측: 의힘 이준석,전남도당 당협위원장 회의,기념촬영,전남,순천,팔마종합운동장
#
# 정답: 뉴진스 하니-다니엘,출국길,제37회 골든디스크어워즈
# 예측: 진스 하니-다니엘,두근두근 출국길,골든디스크어워즈,제37회 골든디스크어워즈
#
# 정답: 남부발전,한국에너지정보문화재단,빛드림 사업,ESG 경영
# 예측: 발전,에너지정보문화재단,빛드림 사업,업무협약 체결,ESG 경영선도,빛드림 사업,추진 업무협약,ESG 경영선도
#
# 정답: 故 이한동 전 국무총리,빈소,조문,홍준표 의원,서울 광진구,건국대학교병원 장례식장
# 예측: 동,전 국무총리,빈소,홍준표 의원,빈소
#
# 정답: 확진자,전남,기존 확진자,감염경로,역학조사
# 예측: 자,감염병,감염경로,감염병,전남,감염병
#
# 정답: LG전자,장애인과 소통,접근성,장애인 접근성 자문단,한국장애인소비자연합,전문가,시각·청각·지체장애
# 예측: G전자,제품 개발단계,장애인과 소통,LG전자,접근성 자문단,장애인 접근성 전문가,시각·청각·지체장애
#
# 정답: 이재용 시찰 가능성,삼성바이오로직스,세계최대 삼바 4공장
# 예측: 바이오로직스,송도 4공장,이재용 시찰,제약·바이오 업계,제약·바이오 업계,제약·바이오 업계
#
# 정답: 내차팔기 홈서비스,최다 판매 모델,케이카 내차팔기,국내 중고차 기업
# 예측: 차 팔 때,K Car,내차팔기 홈서비스,카카오톡,모바일,판매 견적 신청
#
# 정답: 배터리경량화,환경규제,국제항공운송협회,항공기
# 예측: ,비행기,전기차,독일 DHL,국제민간항공기구,환경규제
#
# 정답: 문학 새 책,에스에프 소설,마거릿 애트우드
# 예측:  이야기,소설,김욱,소설,소설,소설,소설
#
# 정답: 전희철 감독,KGC,SK
# 예측: 희철 감독,KGC전,3연패,KGC전
#
# 정답: 최다 검색여행지,하나투어,일본,코타키나발루,오사카,나트랑,다낭
# 예측: 투어,검색 여행,일본,괌,다낭,오사카,싱가포르,검색량,검색어
#
# 정답: 모범택시,이호철,쌍둥이,이솜,증거 찾기,고군분투,이유준 죽음
# 예측: 철,쌍둥이,이유준,시신없는 살인사건,이유준,이솜
#
# 정답: 인민소비품 품평회,북한,노동신문
# 예측: 강도,공산품 품평회,결함,분석총화,북한,노동당 기관지,노동신문
#
# 정답: 넷마블·코웨이,동해안,기부,산불성금,산불피해,희망브리지
# 예측: 브리지,넷마블·코웨이,산불성금,동해안 산불 피해 복구,전국재해구호협회
