# %%
import os
import re
import warnings

import pandas as pd
import numpy as np
import torch

from transformers import (
    AutoConfig, AutoTokenizer, AutoModelForSeq2SeqLM, 
    Seq2SeqTrainingArguments, Seq2SeqTrainer, 
    DataCollatorForSeq2Seq, 
)

from datasets import load_metric, Dataset

import wandb
import nltk

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jake/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
NGPU = torch.cuda.device_count()
NCPU = os.cpu_count()
NGPU, NCPU
# Out:
# (1, 16)

# %% [markdown]
# # Paths and Names

# %%
### paths and names

PROJECT_NAME = 'news-topic-keyphrase-generation-model-dev'
RUN_ID = 'v1'

DATA_PATH = './data/total_2513_samples.pickle'

MODEL_CHECKPOINT = 'paust/pko-t5-base'
METRIC_NAME = 'rouge'

NOTEBOOK_NAME = './train.ipynb'

ROOT_PATH = './'
SAVE_PATH = os.path.join(ROOT_PATH, '.log')

model_name = re.sub(r'[/-]', r'_', MODEL_CHECKPOINT).lower()
run_name = f'{model_name}_{RUN_ID}'
output_dir = os.path.join(SAVE_PATH, run_name)

# !mkdir -p {SAVE_PATH}

# %%
# %env WANDB_PROJECT={PROJECT_NAME}
# %env WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# %env WANDB_LOG_MODEL=true
# %env WANDB_WATCH=all
wandb.login()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find {NOTEBOOK_PATH}.
# env: WANDB_PROJECT=news-topic-keyphrase-generation-model-dev
# env: WANDB_NOTEBOOK_NAME={NOTEBOOK_PATH}
# env: WANDB_LOG_MODEL=true
# env: WANDB_WATCH=all
# wandb: Currently logged in as: dotsnangles. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Training Args

# %%
report_to="wandb"

num_train_epochs = 30
per_device_train_batch_size = 2
per_device_eval_batch_size = 2
gradient_accumulation_steps = 1

optim = 'adamw_torch' # 'adamw_torch' or 'adamw_hf'

learning_rate = 3e-6 * NGPU
weight_decay = 0.01
adam_epsilon = 1e-8

lr_scheduler_type = 'cosine' # 'linear', 'cosine', 'cosine_with_restarts', 'polynomial', 'constant', 'constant_with_warmup'
warmup_ratio = 0

save_total_limit = 2

load_best_model_at_end = True
metric_for_best_model = 'eval_loss'

save_strategy = "epoch"
evaluation_strategy = "epoch"

logging_strategy = "steps"
logging_first_step = True 
logging_steps = int(500 / NGPU)

predict_with_generate=True
generation_max_length=64
# generation_num_beams=5

fp16 = False

# %% [markdown]
# # Model & Tokenizer & Metric

# %% [markdown]
# - 모델과 토크나이저, 그리고 평가지표를 계산하는 데 사용할 함수를 불러옵니다.
# - 모델의 config에는 사용하지 않는 설정이 포함되어 있습니다. 삭제합니다.

# %%
config = AutoConfig.from_pretrained(MODEL_CHECKPOINT)

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT, config=config)
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
metric = load_metric(METRIC_NAME)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# # Functions

# %% [markdown]
# - 모델 훈련을 위해 전처리를 수행해주는 함수를 선언합니다.
# - 입력 문장이 input이 되고 요약문이 label이 됩니다.
# - tokenizer를 사용해 input_ids로 변환하고 입력값에는 attention_mask를 생성해줍니다.
# - 입력 문장에 prefix를 추가하여 성능 실험을 해볼 수 있으나 지금은 적용하지 않겠습니다.

# %%
prefix = "key phrase generation: "

max_input_length = 512
max_target_length = 64

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["input_text"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True, padding="max_length")

    labels = tokenizer(examples["target_text"], max_length=max_target_length, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %% [markdown]
# - 모델의 예측값과 위에서 전처리한 라벨을 활용하여 평가지표를 출력하는 함수를 선언합니다.
# - ROUGE를 평가지표로 사용합니다.
#     - ROUGE-N (N-gram) scoring
#     - ROUGE-L (Longest Common Subsequence) scoring
#         - sentence-level: Compute longest common subsequence (LCS) between two pieces of text. Newlines are ignored. This is called rougeL in this package.
#         - summary-level: Newlines in the text are interpreted as sentence boundaries, and the LCS is computed between each pair of reference and candidate sentences, and something called union-LCS is computed. This is called rougeLsum in this package.

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# # Inputs and Labels

# %% [markdown]
# - csv로 저장된 데이터를 불러와 9:1로 훈련과 검증에 사용합니다.
# - 선언한 전처리 함수를 적용하여 데이터세트를 생성합니다.

# %%
data_df = pd.read_pickle(DATA_PATH)

# %%
data_df
# Out:
#                                             input_text  \
# 0    다음 달부터 15억 초과 주택 대출 허용…ltv 50%도 다음 달부터는 무주택자의 ...
# 1    송혜교x장기용 "끝까지 사랑일 거야" ..애절함 폭발 '지헤중', 순간 최고 9% ...
# 2    1개당 3만원? 자가검사키트 막판 사재기...정부 "17일 이후 해소" 사진=온라인...
# 3    돌싱글즈 유세윤 어릴 적 부모님 이혼사실 몰라.. 父해외 출장 간 줄 [스타뉴스 공...
# 4                  내릴 땐 '찔끔', 올릴 땐 '확'…휘발유 가격, 급속도로 인상
# ..                                                 ...
# 392  T1 잔류 선택한 '페이커' 이상혁 "내가 돌아왔다" '페이커' 이상혁이 T1에 잔...
# 393  영국 철도노조 30여년 만에 최대규모 파업…기차역 텅 비어 임금인상·구조조정 중단 ...
# 394  ‘밥심’ 마리아 “韓 아이돌 데뷔가 꿈→30kg 감량” 매경닷컴 MK스포츠 손진아 ...
# 395  손연정 '멀리 멀리'  24일 경기도 안산 아일랜드 CC에서 열린 한국여자프로골프 ...
# 396  황의조, 결승골 도움…보르도, 5연패 탈출 김도용 기자 = 프랑스 리그1 FC 지롱...
#
#                                            target_text              prefix
# 0                                 주택담보대출,ltv 규제 완화,dsr  extract keywords:
# 1            송혜교,장기용,사랑,애절함,지헤중,최고 시청률,민여사,강정자,윤수완,신유정  extract keywords:
# 2                                               자가검사키트  extract keywords:
# 3                        돌싱글즈,유세윤,부모님 이혼,해외 출장,빈하영,정윤식  extract keywords:
# 4                                         가격 인상,휘발유 가격  extract keywords:
# ..                                                 ...                 ...
# 392                                      잔류,이상혁,페이커,T1  extract keywords:
# 393                      영국철도노조,최대규모 파업,임금인상,구조조정 중단요구  extract keywords:
# 394  밥심,마리아,한국 아이돌,데뷔,감량,30kg,미스트롯2,올 하트,외국인 참가자,SB...  extract keywords:
# 395                한국여자프로골프,엘크루-TV조선 프로 셀러브리티 2021,손연정  extract keywords:
# 396                                     결승골,황의조,보르도,도움  extract keywords:
#
# [2513 rows x 3 columns]

# %%
dataset = Dataset.from_pandas(data_df).shuffle(seed=100).train_test_split(0.2)
train_dataset = dataset['train']
eval_dataset = dataset['test']

# %%
train_dataset = train_dataset.map(preprocess_function, 
                                  batched=True, 
                                  num_proc=NCPU, 
                                  remove_columns=train_dataset.column_names)

eval_dataset = eval_dataset.map(preprocess_function, 
                                batched=True, 
                                num_proc=NCPU, 
                                remove_columns=eval_dataset.column_names)
print(train_dataset)
print(eval_dataset)
# Out:
# Map (num_proc=16):   0%|          | 0/2010 [00:00<?, ? examples/s]
# Map (num_proc=16):   0%|          | 0/503 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 2010
# })
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 503
# })

# %%
tokenizer.decode(train_dataset['input_ids'][0])
# Out:
# 'key phrase generation: 임영웅, \'다시 만날 수 있을까\'로 엠카 1위...영웅시대 감사합니다 [ten★] [텐아시아=조준원 기자]가수 임영웅이 근황을 전했다. 임영웅은 12일 임영웅의 공식 인스타그램에는 "아티스트 임영웅 mnet ‘엠카운트다운’ 1위, 영웅시대 여러분, 감사합니다"라는 글과 함께 두 장의 사진을 게재했다. 공개된 사진 속 mnet \'엠카운트다운\'에서 1위를 차지한 뒤 트로피 인증샷을 남기고 있는 임영웅의 모습이 담겨 있다. 한편 임영웅은 2일 정규 1집 \'im hero\'(아임 히어로)를 발매했다.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenizer.decode(train_dataset['labels'][0])
# Out:
# '임영웅,엠카운트다운,영웅시대,아임 히어로 발매</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %% [markdown]
# # Train

# %% [markdown]
# - 상단에서 선언한 HP와 각종 변수들로 training_args를 생성합니다.

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    run_name=run_name,
    report_to=report_to,

    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,

    optim=optim,

    learning_rate=learning_rate,
    weight_decay=weight_decay,
    adam_epsilon=adam_epsilon,

    lr_scheduler_type=lr_scheduler_type,
    warmup_ratio=warmup_ratio,

    save_total_limit=save_total_limit,

    load_best_model_at_end=load_best_model_at_end,
    metric_for_best_model=metric_for_best_model,

    save_strategy=save_strategy,
    evaluation_strategy=evaluation_strategy,

    logging_strategy=logging_strategy,
    logging_first_step=logging_first_step, 
    logging_steps=logging_steps,

    predict_with_generate=predict_with_generate,
    generation_max_length=generation_max_length,
    # generation_num_beams=generation_num_beams,

    fp16=fp16,
)

# %% [markdown]
# - 배치 단위로 padding처리를 하여 훈련 속도를 높히기 위해 data_collator를 선언합니다.
# - 생성한 객체들을 trainer에 포함시켜 훈련 준비를 마칩니다.

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, padding=True)

trainer = Seq2SeqTrainer(
    model=model,
    
    args=training_args,
    
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    
    tokenizer=tokenizer,
    data_collator=data_collator,
    
    compute_metrics=compute_metrics,
)

# %% [markdown]
# - 훈련을 시작합니다.

# %%
trainer.train()
# Out:
# wandb version 0.14.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/jake/codes/news-topic-keyphrase-generation-model-dev/wandb/run-20230410_115943-fwbz4oqt</code>
# Syncing run <strong><a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/fwbz4oqt' target="_blank">paust_pko_t5_base_v1</a></strong> to <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev</a>
#  View run at <a href='https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/fwbz4oqt' target="_blank">https://wandb.ai/dotsnangles/news-topic-keyphrase-generation-model-dev/runs/fwbz4oqt</a>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='26374' max='30150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26374/30150 4:20:03 < 37:14, 1.69 it/s, Epoch 26.24/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.231000</td>
#       <td>1.594958</td>
#       <td>9.254600</td>
#       <td>1.445900</td>
#       <td>9.075700</td>
#       <td>9.119800</td>
#       <td>54.954300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.813600</td>
#       <td>0.557981</td>
#       <td>15.793800</td>
#       <td>2.696400</td>
#       <td>15.354300</td>
#       <td>15.430300</td>
#       <td>31.111300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.632800</td>
#       <td>0.486895</td>
#       <td>17.914000</td>
#       <td>3.757100</td>
#       <td>17.416400</td>
#       <td>17.478400</td>
#       <td>32.566600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.577300</td>
#       <td>0.466830</td>
#       <td>18.716100</td>
#       <td>3.943600</td>
#       <td>18.255200</td>
#       <td>18.255800</td>
#       <td>31.188900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.516700</td>
#       <td>0.453396</td>
#       <td>17.434200</td>
#       <td>3.406100</td>
#       <td>16.872000</td>
#       <td>16.834700</td>
#       <td>31.334000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.524500</td>
#       <td>0.443857</td>
#       <td>19.319400</td>
#       <td>4.046600</td>
#       <td>18.817600</td>
#       <td>18.768200</td>
#       <td>30.198800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.493700</td>
#       <td>0.436659</td>
#       <td>19.514000</td>
#       <td>3.820100</td>
#       <td>19.010000</td>
#       <td>19.020400</td>
#       <td>28.180900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.488100</td>
#       <td>0.434352</td>
#       <td>19.947800</td>
#       <td>3.819600</td>
#       <td>19.396800</td>
#       <td>19.427000</td>
#       <td>29.270400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.479400</td>
#       <td>0.432945</td>
#       <td>20.289800</td>
#       <td>4.242100</td>
#       <td>19.935500</td>
#       <td>19.955200</td>
#       <td>28.612300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.467900</td>
#       <td>0.428887</td>
#       <td>20.183600</td>
#       <td>3.611800</td>
#       <td>19.598500</td>
#       <td>19.641300</td>
#       <td>26.697800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.453200</td>
#       <td>0.425967</td>
#       <td>20.733400</td>
#       <td>4.720000</td>
#       <td>20.206200</td>
#       <td>20.167600</td>
#       <td>28.310100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.439600</td>
#       <td>0.423249</td>
#       <td>20.627900</td>
#       <td>4.302400</td>
#       <td>19.987800</td>
#       <td>20.085800</td>
#       <td>27.101400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.434200</td>
#       <td>0.422333</td>
#       <td>21.501300</td>
#       <td>4.220400</td>
#       <td>20.916300</td>
#       <td>21.017900</td>
#       <td>31.097400</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.413900</td>
#       <td>0.423535</td>
#       <td>20.748500</td>
#       <td>4.068300</td>
#       <td>20.235900</td>
#       <td>20.264300</td>
#       <td>25.065600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.421500</td>
#       <td>0.422970</td>
#       <td>21.174600</td>
#       <td>4.617400</td>
#       <td>20.709200</td>
#       <td>20.795600</td>
#       <td>26.075500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.424400</td>
#       <td>0.421741</td>
#       <td>20.880700</td>
#       <td>4.532900</td>
#       <td>20.347900</td>
#       <td>20.415500</td>
#       <td>26.831000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.410200</td>
#       <td>0.421010</td>
#       <td>20.599600</td>
#       <td>4.179300</td>
#       <td>20.220900</td>
#       <td>20.266400</td>
#       <td>28.463200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.415900</td>
#       <td>0.420525</td>
#       <td>20.878900</td>
#       <td>4.768200</td>
#       <td>20.398800</td>
#       <td>20.455900</td>
#       <td>27.002000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.419600</td>
#       <td>0.420760</td>
#       <td>21.125900</td>
#       <td>4.641000</td>
#       <td>20.649100</td>
#       <td>20.701500</td>
#       <td>28.139200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.408900</td>
#       <td>0.422460</td>
#       <td>20.749500</td>
#       <td>4.651200</td>
#       <td>20.359600</td>
#       <td>20.367500</td>
#       <td>27.675900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.397500</td>
#       <td>0.422117</td>
#       <td>20.798500</td>
#       <td>4.701700</td>
#       <td>20.399500</td>
#       <td>20.440000</td>
#       <td>27.550700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.397500</td>
#       <td>0.421519</td>
#       <td>20.619800</td>
#       <td>4.788200</td>
#       <td>20.116900</td>
#       <td>20.134000</td>
#       <td>26.725600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.395200</td>
#       <td>0.420716</td>
#       <td>21.181800</td>
#       <td>4.551700</td>
#       <td>20.620200</td>
#       <td>20.623300</td>
#       <td>27.884700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.399800</td>
#       <td>0.422397</td>
#       <td>20.941700</td>
#       <td>4.704000</td>
#       <td>20.342200</td>
#       <td>20.429400</td>
#       <td>26.711700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.386300</td>
#       <td>0.421953</td>
#       <td>20.731000</td>
#       <td>4.583900</td>
#       <td>20.177100</td>
#       <td>20.170700</td>
#       <td>26.868800</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.397500</td>
#       <td>0.421842</td>
#       <td>20.521400</td>
#       <td>4.524400</td>
#       <td>20.006300</td>
#       <td>20.026400</td>
#       <td>26.713700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=30150, training_loss=0.7454467680442393, metrics={'train_runtime': 17408.7047, 'train_samples_per_second': 3.464, 'train_steps_per_second': 1.732, 'total_flos': 4.38843693072384e+16, 'train_loss': 0.7454467680442393, 'epoch': 30.0})

# %% [markdown]
# - 옵티마이저 스테이트를 포함한 훈련 재개에 사용할 파일들을 삭제해줍니다.
# - 추후 불러올 모델과 토크나이저 관련 파일만 남겨둡니다.

# %%
# keep = [
#     'added_tokens.json',
#     'config.json',
#     'pytorch_model.bin',
#     'special_tokens_map.json',
#     'tokenizer.json',
#     'tokenizer_config.json',
#     'vocab.txt'
# ]

# ckpts = os.listdir(output_dir)
# for ckpt in ckpts:
#     ckpt = os.path.join(output_dir, ckpt)
#     for item in os.listdir(ckpt):
#         if item not in keep:
#             os.remove(os.path.join(ckpt, item))

# %% [markdown]
# # Generate

# %% [markdown]
# - 훈련을 마치면 Evaluation Loss 기준 Best 모델이 로드되어 있습니다.
# - trainer는 Greedy Search를 수행하도록 설정되어 있습니다.
# - Evaluation 데이터를 활용해 모델의 출력을 간단히 살펴봅니다.

# %%
preds = trainer.predict(eval_dataset)

# %%
for data, pred in zip(eval_dataset, preds.predictions):
    context = tokenizer.decode(data['input_ids'], skip_special_tokens=True)
    summary = tokenizer.decode(data['labels'], skip_special_tokens=True)
    pred = tokenizer.decode(pred[2:], skip_special_tokens=True)
    # print(f'입력: {context}')
    print(f'정답: {summary}')
    print(f'예측: {pred}', end='\n\n')
# Out:
# 정답: 에어로스페이스 콘퍼런스,이성용 공군참모총창,국회 국방위원,첨단 과학기술,전시 장비
# 예측: ,에어로스페이스 콘퍼런스,이성용 공군참모총장,서울 공군회관,첨단과학기술,전시장비
#
# 정답: 이은지,제주종합경기장,실내수영장,2021 경영 국가대표 선발대회,여자 배영 50m 결승,출발,기록: 28초52
# 예측: 지,힘찬 출발
#
# 정답: 일상,노홍철,와인 시음회,인스타그램
# 예측: ,와인 시음회,럭셔리한 일상,인스타그램
#
# 정답: 레고랜드 주변,컨벤션 건립 예산안,도의회 상임위 통과,강원국제전시컨벤션센터,제2회 추가경정예산안,원안 가결,토지 매입비,임시주차장,공사비,예산결산특별위원회,본회의,최종 확정
# 예측: 랜드,컨벤션 건립 예산안,도의회 상임위 통과,강원국제전시컨벤션센터,건립 예산안,도의회 상임위 통과,강원도의회 경제건설위원회,제2회 추가경정예산안,강원도 글로벌투자통상국,제2회 추가경정
#
# 정답: 코로나19,확진,이승기
# 예측: ,코로나19 확진,일반 감기 증상,걱정 감사
#
# 정답: 수베로 감독,고척스카이돔,2021 KBO리그,한화 이글스,키움 히어로즈,3연패 탈출,선발 김민우,노시환 3타점,힐리 2타점,김민하 희생타 1타점,6-1 승리,최재훈
# 예측: 마님,수베로 감독,키움 히어로즈,3연패,탈출,한화 이글스,키움 히어로즈,한화 이글스,한화 이글스,키움 히어로즈,2연패,3연승,3연패 탈출,최재훈,노시환,노시환,김민하,희생
#
# 정답: 글로벌 마켓,뉴욕증시,크리스마스,급락
# 예측: 증시,산타,급락
#
# 정답: 신진서,신민준,도전 5번기,한국기원
# 예측: 서,신민준,도전 5번기,한국기원,도전 5전기,
#
# 정답: 아우디 딜러,2021 아우디 딜러 어워즈,탑 아우디언,코로나19,고진모터스,한서모터스,
# 예측: ,2021 아우디 딜러 어워즈,탑 아우디언,세일즈,A/S,마케팅,베스트 딜러사,베스트 세일즈 딜러사,베스트 딜러사,베스트 마케팅 딜러사,고진모터스,아이언모터스,
#
# 정답: 쌀값 폭락,쌀값 안정 대책,쌀값
# 예측:  폭락 대책,전국 8곳 도지사,정부,쌀값 폭락 대책
#
# 정답: 고민시,미성년자 음주 논란,사과,서울 영등포구,KBS 별관,KBS 2TV 새 월화드라마,오월의 청춘,제작발표회,1980년 5월,역사의 소용돌이,희태와 명
# 예측: 시,미성년자 음주 논란,첫 외출,KBS 별관,서울 영등포구 KBS 별관,제작발표회,인사,멜로드라마다
#
# 정답: 두산 팬들,환호,대타 허경민,안타,서울 잠실야구장,2021 신한은행 SOL KBO리그,두산 베어스,키움 히어로즈,경기
# 예측:  팬들,대타 허경민,안타
#
# 정답: kbo 리그,김재윤,역전,
# 예측: 윤,역전타,아쉬움 가득
#
# 정답: 부산변법,수술법,부산대 병원,배용찬 교수,구순구개열
# 예측: 순구개열,부산변법,재건성형
#
# 정답: 소비 부진,폐기되는 배추,해남군
# 예측:  부진,폐기,배추,해남군
#
# 정답: 뱅크샐러드 마이데이터 인증서,초개인화,뱅크샐러드
# 예측: 샐러드,라이프 전반,초개인화,마이데이터,자산관리,데이터,개인화,중립성,친화성,전자서명인증사업자,전자서명인증
#
# 정답: 미우새,신동엽,부친상,녹화 연기
# 예측: ,부친상,미우새,녹화 연기
#
# 정답: 밀리의서재,김중혁 작가,일일 창의력,단편 단독 연재,밀리 오리지널 데일리 연재,전자책과 AI 완독형 오디오북,창의력 키우는 방법,소소하고 재미있게,50가지 창의력 채집 방법,
# 예측: 의 서재,김중혁 작가,일일 창의력,단편 단독 연재,독서 플랫폼,밀리의 서재,김중혁 작가,신작 에세이,일일 창의력,하루하루,전자책,AI 완독형 오디오북,김중혁 작가,
#
# 정답: 정치적 논란,고발장,검·경,공수처,무혐의,중립성 시비
# 예측: ,이성윤 황제조사,정치적 논란,고발장,수사 방해,사찰,수사방해,수사방해,이성윤 특혜조사,부당 주식취득,수사방해,
#
# 정답: 경북 선거구획정위,시·군 선거구획정(안)
# 예측:  선거구획정위,시·군 의원 정수,획정,시·군 의원 정수,선선거구획정위원회,284명,288명,4명 늘어,106개,1개 증가,시·군 의원 선거구,의원
#
# 정답: 생후 2개월 영아,학대 사망,산후도우미,법정서 혐의 부인
# 예측:  2개월 영아,학대 사망,산후도우미,법정,혐의 부인,진실공방,cctv
#
# 정답: 박동원,홈런,서울 고척스카이돔,프로야구 2021 신한은행 SOL KBO리그,키움히어로즈 대 한화이글스 경기,5회말 1사,공감언론 뉴시스,제보
# 예측: 동원,홈런,고척스카이돔,프로야구,신한은행 SOL KBO리그,키움히어로즈
#
# 정답: 중국,북한 도발,대응,변화
# 예측: ,북한,미사일,대응,변화
#
# 정답: 고양이,용품,박람회,케이캣페어
# 예측:  용품 박람회,케이캣페어,개막
#
# 정답: 동의안,군유임야,심의,조례안,추경,정기분 공유재산,예산안,단양군의회,출연금,심사집행
# 예측: 군의회,2022년도 예산안,면밀한 심사,추경,조례안,군유임야 대부기간 갱신,심사
#
# 정답: 교촌에프앤비,치킨조리로봇,
# 예측: ,치킨 조리로봇,개발,협동로봇,치킨 프랜차이즈,로봇 제조업체,뉴로메카,업무협약,협동로봇,치킨 튀김 과정 자동화 시스템,협동로봇
#
# 정답: 한투운용,친환경차·ESG 투자 `주식형 액티브 ETF 2종` 출시
# 예측: 투자신탁운용,친환경차,ESG 투자,액티브 ETF,상장지수펀드,네비게이터 친환경자동차밸류체인 액티브 ETF,유가증권시장,코스닥시장,에프앤가이드,비교지수,에프앤가이드,자동차 산업,자동차
#
# 정답: 숲속,산수유
# 예측: ,포토친구
#
# 정답: 특금법,가상자산 거래소,등록,0곳,은성수 금융위원장,거래소 자체 상황,요인,실명 확인,입출금 계좌,금융위에 사업자 신고,9월 24일,폐쇄,가이드라인 부재,은행연합회,
# 예측: 금법,가상자산 거래소,거래소 폐쇄,은행연합회,가이드라인,은행연합회,실사 검증,은행연합회,자금세탁방지 위험평가 방법론 가이드라인,은행연합회,은행별 의견,확정된 버전,은행별
#
# 정답: 이재명,대선 후보,자율주행차
# 예측: 주행차 오토비,이재명 대선 후보
#
# 정답: 박범계,법무부 장관,20일,정부과천청사,세계인의 날 기념식,축사
# 예측: 인의 날,축사,법무부 장관
#
# 정답: KLPGA,박민지,2승달성,
# 예측: 민지,시즌 2승 달성,한국여자프로골프투어,KLPGA
#
# 정답: 한화 이글스,김태균,52번 영구결번,스페셜 어시스턴트,장종훈,정민철,송진우,KBO리그 대표 우타자,최다안타 2209개,2루타 399개,최다 루타 3557
# 예측: ,김태균,영구결번,영구결번,현역 시절,누적 기록,KBO리그,최다안타,2209개,2루타,역대 4위,4사구는 1249개,4사구는 1249개,역대 5위,4
#
# 정답: nc,김택진,손아섭,나성범,야구
# 예측: 범,택진이형,현질,롯데,손아섭,kt,fa,fa,fa,fa,fa,fa,손아섭,fa,kt,kt,fa
#
# 정답: 이재용 사면,전향적 판단
# 예측:  사면,전향적으로 판단할 필요,국민의힘,김기현
#
# 정답: 홍준표,복당 반대,당 배신했다,비판,국민의힘,하태경 의원,바른미래당,탈당파,SNS,탄핵 대선,위장 평화 지방선거,야당 승리,황교안,미래통합당 대표,질 수밖에 없었던,지난 총선
# 예측: ,복당 반대,국민의힘,탈당파,황교안,한국당,
#
# 정답: 특별 이벤트,카카오게임즈,신규 서버,오딘
# 예측: 게임즈,오딘,티르,특별 이벤트,발할라라이징,모바일 MMORPG,신규 서버 '티르',특별 이벤트,라그나로크
#
# 정답: 최애템,에녹,한강,의문의 여성,손태진,디너쇼 미션,불타는 트롯맨
# 예측: 녹,한강,손태진,집 공개,최애템,의문의 여성,MBN '불타는 트롯맨',
#
# 정답: 보쌈,권유리,사극,현대극,운명을 훔치다,주말드라마,생계형 보쌈꾼,로맨스 퓨전 사극
# 예측: ,권유리,사극,현대극,보쌈-운명을 훔치다
#
# 정답: 갤럭시s22,제품 양산 준비,디자인,변화,울트라,이미지,부품,반도체,스마트폰,색상
# 예측: s22,양산,내년 2월,출시,부품 양산,갤럭시s21,갤럭시s22 플러스,색상,출시 시기,디스플레이서플라이체인,부품 양산,출시 시기,삼성전자
#
# 정답: 전유진 달성군수 후보 선거사무소 개소
# 예측: 유진,달성군수,선거사무소 개소
#
# 정답: 오케이 광자매,홍은희,상상임신 진단
# 예측:  광자매,홍은희,상상임신,산부인과
#
# 정답: britain,lawmaker,killed,david amess
# 예측: ain,lawmaker,killed
#
# 정답: fashion week,nigeria,
# 예측: igeria,Fashion,Week
#
# 정답: 축구 광팬,축구장,루이스 밀링턴,방문,일본팬
# 예측:  팬,축구 광팬,전세계 축구장,122곳,방문,데일리 스타,축구장,축구 경기
#
# 정답: 황신영,세쌍둥이,욕조,
# 예측: 신영,세쌍둥이,욕조,목욕시간
#
# 정답: 천체투영관 운영 확대,국립부산과학관
# 예측: 부산과학관,천체투영관 재개,전시관 운영 확대
#
# 정답: 팁코소프트웨어,포레스터 리서치,포레스터 웨이브,마스터 데이터 관리
# 예측: 코,포레스터 웨이브,마스터 데이터 관리,리더 선정,글로벌 시장조사기관,포레스터리서치,마스터 데이터 관리,리더 선정,비즈니스 템플릿,비즈니스 템플릿,확장성,멀티 도메인,기술 지원,포레스터 리서치,20
#
# 정답: 김남길,권일용 프로파일러,드라마,아일랜드,악의 마음을 읽는 자들,범죄 스릴러,스튜디오S,SBS,연쇄살인 추적기,주인공 송하영,프로파일링 기법
# 예측: ,프로파일러,드라마,주연,아일랜드,열일
#
# 정답: 승부처,여름,코스피,글로벌 증시,백신 접종,경제 활동 정상화,기업 실적,저축률,미국 경기 부양책,2분기,조정,경기 정점 위험,테이퍼링 위험,시차 발생,경제 지표,둔화,침체,
# 예측: 퍼링 리스크,경기 정점,테이퍼링 위험,글로벌 증시,백신 접종,경제 활동 정상화,양호한 기업 실적,미국의 경기 부양책,금융 시장,경기 정점 위험,금융 시장,경기 정점 위험
#
# 정답: 김태원,패혈증,술,후각,미각,청각,시각,기억력
# 예측: ,술,패혈증,후각,미각,청각,기억력,닥터m
#
# 정답: 한국 여자 아이스하키,베이징 올림픽 출전 무산
# 예측:  여자 아이스하키,3전 전패,베이징올림픽 출전 무산
#
# 정답: 통일부,이준석,여성가족부,진중권,
# 예측: ,여성·통일부 폐지,공부가 안돼 뻘짓,여성가족부,여성부 폐지
#
# 정답: 2tv,박준형,김영철,뱀뱀,유정,촌스럽게,갯벌 체험,몸개그,추억의 게임
# 예측: 스럽게,박준형,김영철,뱀뱀,유정,갯벌 체험
#
# 정답: 삼성 승리,한국가스공사
# 예측: 가스공사,삼성,83-77,승리
#
# 정답: 삼성바이오,모더나 백신 위탁생산,삼성바이로직스,조선일보,보도,삼성바이오,모더나,백신 위탁생산,확인 불가,
# 예측: 바이오,모더나 백신 위탁생산,확정된 바 없어
#
# 정답: locarno film festival
# 예측: carno,film,festivalepa
#
# 정답: 전여빈,대세,넷플릭스 영화,tvN 드라마,엄태구,송중기,양극단의 역할,화상 인터뷰,도전,재연,부모님 살해당함,난치병,제주도,무기 밀매상,서울,라이벌 조직,사격 연습
# 예측: 여빈,전여빈,넷플릭스,드라마,엄태구,송중기,엄태구,극중 재연,무기 밀매상,제주도,삼촌,무기 밀매상,제주도,제주도,
#
# 정답: 광주시장 선거,5.18묘지 참배,이용섭 광주시장 예비후보,문영훈 행정부시장,재선
# 예측:  광주시장,예비후보 등록,국립 5·18 민주묘지,참배,시민의 나라 광주,예비후보 등록,선거 운동,문영훈 행정부시장,권한 대행
#
# 정답: 바흐,방일 연기,스포츠 스타들 '올림픽 취소론' 가세
# 예측: ,방일 연기,스포츠 스타,도쿄올림픽 취소론
#
# 정답: 감염병 극복,이건희,중앙감염병 전문병원 건립
# 예측:  기금,감염병 극복,중앙감염병병원 건립,기부금,제자리,코로나19,중앙감염병 전문병원,국립중앙의료원,코로나19 창궐,국가 감염병 극복 지원 사업,적정성 검토,기재부 검토,국립감염
#
# 정답: 홍자,희노애락,미니앨범,술잔,쇼케이스,어쿠스틱
# 예측: 자의 희노애락,술잔,발매,쇼케이스,이별,술,이별,이별,이별,어쿠스틱 기타 플레이,이별,이별,이별,이별,이별,이별,이별,어쿠스틱 기타 플레이,이별,이별,
#
# 정답: 화물파업,동맥경화,물류
# 예측: ,동맥경화,화물파업
#
# 정답: 경기미래교육파주캠퍼스,경기도평생교육진흥원,찾아가는 영어교육
# 예측: 도평생교육진흥원,찾아가는 영어교육,경기미래교육파주캠퍼스,찾아가는 영어교육
#
# 정답: 왕립도서관,규장각,창덕궁,주합루,서향각,희우정,천석정
# 예측: 도서관,규장각,가을,어울어진
#
# 정답: 주호영,수원 세모녀,복지사각 보완,경기 수원
# 예측: ,수원 세 모녀,조문,복지사각,사회보장급여법,개정 검토,복지사각,자살,자살,사회보장급여법,개정
#
# 정답: 빗썸,1분기,지난해 전체 매출,순익,암호화폐 거래소,거래 시장 활성화,거래량 증가,매출액,당기순이익,수수료 수익,비트코인 가격 상승,비덴트,빗썸코리아,빗썸홀딩스 지분
# 예측: ,1분기,매출,당기순이익,암호화폐 거래소,빗썸코리아
#
# 정답: 강석우,스타 2세,강석우 딸,아빠를 부탁해
# 예측: 우 딸 강다은,스타 2세,톱배우 못지않네
#
# 정답: 선발투수,무실점 행진,가빌리오,SSG 랜더스
# 예측: 빌리오,SSG랜더스필드,KT위즈,6이닝 무실점,KBO리그
#
# 정답: 남양유업,매매예약완결권,매각,대유홀딩스
# 예측: 유업,매각,점입가경,대유위니아,홍원식 회장,협약 해제,
#
# 정답: 백신,해외여행 상품 출시,하나투어,지금 떠나는 해외여행,하와이,스위스,몰디브,두바이,백신 접종자 대상,항체 형성,취소 위약금 없음,,,
# 예측: ,해외여행,하나투어,코로나19,여행기획전,여행기획전,하와이,스위스,몰디브,몰디브,두바이
#
# 정답: 코로나19,신규 확진,400명대 유지
# 예측: 19,신규 확진,400명대 유지
#
# 정답: 이태검,기상청 사람들,캐스팅
# 예측: 검,기상청 사람들,드라마,기상청 사람들,tvn,tvn,tvn 퓨전 사극,철인왕후,드라마,
#
# 정답: 탈레반,정부,윤곽,공개
# 예측: ,새 정부 윤곽 공개
#
# 정답: 전속계약,정의제,HB엔터테인먼트
# 예측: 제,HB엔터테인먼트,전속계약,주상욱,안재현,안재현,한솥밥
#
# 정답: 정수현,'무장해제 로맨스',탈북청소년,북한 사투리 마스터
# 예측: 청소년,정수현,무장해제 로맨스,와이낫미디어,국립통일교육원,하이틴 드라마,탈북민,신조어,정수현
#
# 정답: 이주홍문학재단,제20회 이주홍문학축전,코로나19,대면-비대면 행사,이주홍문학상 시상식,아동문학,일반문학,문학연구,상금,학술 세미나,동인지,축전 20주년 기념 특별전,사전예약제
# 예측: 홍문학,향파 이주홍 선생,제20회 이주홍문학축전,비대면,코로나19,문학연구,부산 아동문학,부산 아동문학사,부산 아동문학,
#
# 정답: 안지현,수영복,치어리더,청순 미모
# 예측: 지현,여신급 수영복 자태,인스타그램
#
# 정답: 선진국,자본이득세,코로나19,재정,공해,기업,장기침체,양적완화,인구고령화
# 예측: iu,코로나19,재정,자본이득세,재정 수습,재정 확충,팬데믹,글로벌 경제,재정 확보,규제 완화,양적완화,미국,기준금리,장기침체,양적완화
#
# 정답: 비판,언론중재법,국제언론단체,날 선 반응,송영길
# 예측: ,국제언론단체,언론중재법 비판,뭣도 모르니까
#
# 정답: 날씨,일기예보
# 예측: 의 날씨,남해안,최고 150mm
#
# 정답: 에릭센 '주장 완장' 양보,a 매치,친선 경기,
# 예측: 센,주장 완장,동료,교체
#
# 정답: 익산,양계장,불,진화,전소,병아리,폐사,재산피해,8000만원,인명피해,경찰,소방당국,화재원인,조사
# 예측:  양계장,불,병아리,폐사
#
# 정답: ,당부,분노,보이스 피싱,주의,딘딘
# 예측:  피싱,주의 당부,딘딘,보이스 피싱 사기
#
# 정답: 나이트포커스,갈등,질병,비위,尹측근,조상준
# 예측: ,질병,비위
#
# 정답: 진천군 보건소,민원업무,보건소,재개
# 예측: 소,민원업무,재개,진천군보건소
#
# 정답: 박연정,피겨스케이팅
# 예측: 연정,피겨스케이팅 종별선수권대회
#
# 정답: 서울대 정시 경쟁률,연세대
# 예측:  경쟁률,서울대,연세대,경쟁률,종로학원,경쟁률,경영,정치외교,치의학,치의학,예체능,인문,자연,예체능,인문,예체능,인문,자연,예체능,인문,인문,예체능,경영,정치외교,치의학,치의학
#
# 정답: 서원·클럽디 여성골프대회,총 상금 4억 원,전국 규모 여성 아마추어 골프대회,서원·클럽디 레이디스 골프 챔피언십,연습라운드,예선전,서원힐스,충북 클럽디 보은,클럽디 속리산,
# 예측: ·클럽디 여성골프대회,연습라운드,열전,전국 규모 여성 아마추어 골프대회,연습라운드,전국 규모 여성 아마추어 골프대회,대회
#
# 정답: 데 헤아,의문의 일러스트,관심,SNS,나루토,철조망,데일리 메일,심정 대변,팬들의 반응,맨유,AS로마,유로파리그,딘 핸더슨,입지 흔들,출전 횟수,시즌
# 예측:  헤아,정신 무장,나루토,소환,데 헤아,SNS,수수께끼 같은 사진,데일리 메일,맨유,AS로마,유로파리그,
#
# 정답: 건강 피부,40세 생얼,양미라
# 예측: 미라,40세 생얼,광채 피부,인스타그램,건강한 피부,인스타그램,아이폰 생카메라,피부 보여주시라구요
#
# 정답: 원호,올블랙,서울 강서구,방화동,김포국제공항,제주도,개인 일정
# 예측: ,올블랙,무장하고,제주도,개인 일정,기사제보,보도자료
#
# 정답: 제59회 대통령기 전국장사씨름대회,정상원
# 예측: 기씨름대회,연천중 정상원,금메달
#
# 정답: 새끼두꺼비,서식지
# 예측: 두꺼비,서식지,욱수골
#
# 정답: wkbl(한국여자농구연맹),2021~22 여자프로농구,신인 드래프트,정규리그 개막,올스타전,국가대표팀,플레이
# 예측: kbl,여자프로농구,개막,일정,신인드래프트,용인 삼성생명,청주 kb스타즈,정규리그,챔피언결정전,챔피언결정전,올스타전,챔피언결정전,올스타전,챔피언결정전,플레이오프,챔피언결정전,중계방송 관계로 오후
#
# 정답: 추성훈,쩍 갈라진 근육질,컴백,노화
# 예측: ,노화,쩍 갈라진 근육질,컴백
#
# 정답: 시트콤 '유니콘'
# 예측: ,유니콘,제작발표회
#
# 정답: bmx,2020,testing,japan,olympics,tokyo
# 예측: APAN,OLYMPICS,TOKYO,BMX,EPA/KIMIMASA,2020,Olympics,Tokyo
#
# 정답: 여성 엉덩이 때린 남성 벌금형,추행 혐의
# 예측:  엉덩이 때린 남성,벌금형,인터넷 카페 모임,강제추행,벌금형
#
# 정답: 금감원,상호금융,과도한 수신경쟁
# 예측: ,상호금융,과도한 수신경쟁,내부통제 강화,금융감독원,예적금 과다판매,사고 재발 방지
#
# 정답: 손담비,이규혁,연애,다이어트,야식
# 예측: ,피자지,이규혁,연애,다이어트
#
# 정답: 광화문광장,재개장,재구조화,
# 예측: 광장,재개장,시민 개방,나무 5000그루,세종문화회관,미디어아트
#
# 정답: 조현우,골키퍼
# 예측: 현우,울산 현대,수원 삼성,경기 전반전,수원월드컵경기장,2021 k리그1,37라운드,울산 현대,수원 삼성,경기 전반전,김건희,슛
#
# 정답: ,신생아 살해,20대 부모 구속기소
# 예측: 아,살해,20대 부모,구속기소
#
# 정답: 내일날씨,일기예보
# 예측:  내륙·산지,미세먼지,보통 추위
#
# 정답: 전남도,도민명예기자,사랑애 서포터즈 협약도
# 예측: 도,도민명예기자,사랑애 서포터즈,위촉
#
# 정답: 2021 미스코리아,부산‧울산 선발대회,당선자들,BN그룹,협찬,감사,본사 방문
# 예측: 21 미스코리아,부산‧울산 선발대회,BN그룹,방문
#
# 정답: 윤석열 대통령,태풍 피해,상인들
# 예측:  피해 상인들,윤석열 대통령
#
# 정답: -> 설현,인형같은 외모,청룡시리즈어워드
# 예측: ,청룡시리즈어워즈,레드카펫
#
# 정답: 국가인권위원회,언론중재법,표현의 자유,위축 우려
# 예측: ,언론중재법,신중 검토,언론 자유 위축,언론 자유 위축,언론중재법
#
# 정답: 신세계면세점 부산점,소외계층 청소년 장학금,장학금 지원
# 예측: 면세점 부산점,소외계층 청소년 장학금 지원
#
# 정답: 삼성,이미지센서,모바일,이미지센서 초격차,이세공정 기술력
# 예측: ,모바일 이미지센서,초격차,픽셀,아이소셀,모바일 이미지센서,초격차,화질·해상도,자동초점
#
# 정답: 빅맥 인상,맥도날드,신세계푸드,롯데리아,튀르키예,지진,이재민,삼성전자,현대차,sk,lg
# 예측: 맥,5200원,맥도날드,가격인상,상하이버거,이마트푸드,이마트푸드,이마트푸드,리필스테이션 제품,친환경 소비,친환경 소비,리필스테이션 제품,가격 인상
#
# 정답: 경찰,김오수 검찰청장,아들,부정채용 혐의 없음
# 예측: ,김오수 검찰총장 아들,부정채용 의혹,혐의 없음,국책연구기관,부정채용 의혹
#
# 정답: 앞으로 2주간 모든 내·외국인 입국자,예방접종 관계없이 10일간 격리,나이지리아 방역강화국가·위험국,코로나19
# 예측: ,방역강화국가,위험국가,격리면제 제외 국가,예방접종,격리,10일간 격리
#
# 정답: 복권,불황,판매액,팔림,사람들,구매자
# 예측: 일수록 잘 팔리는 복권,복권 판매액,고물가 기조,복권 판매액,복권 인식조사,복권 판매 금액,복권 인식조사,복권 판매 금액,복권 판매 금액,복권 인식조사,복권 판매 금액,
#
# 정답: 진실게임,ibk기업은행,조송화,언론,접촉,막기,사실무근,무단이탈,계약해지,쿠데타,명예훼손,법률대
# 예측: 게임,조송화,구단,언론 접촉,ibk
#
# 정답: 5G,2년 약정만료,알뜰폰,이동통신 3사,번호이동,상용화,5G 품질,고가 요금제,세종텔레콤,큰사람,KT엠모바일,LG헬로비전,저가 5G 요금제,고용량 데이터 L
# 예측: 폰,5G,약정만료,5G,LTE,총공세
#
# 정답: 백경현 구리시장,교통분야 역점사업 추진
# 예측: 경현 구리시장,교통 분야 역점사업,차질 없이 추진
#
# 정답: 마이네임,한소희,액션 연기,복수,넷플릭스,지우,인간수업,김진민 감독
# 예측: 소희,액션 연기,넷플릭스 오리지널,마이 네임,
#
# 정답: 돌싱글즈,유세윤,부모님 이혼,해외 출장,빈하영,정윤식
# 예측: 싱글즈,유세윤,부모님 이혼사,돌싱남녀,김재열,박효정,배수진,빈하영,정윤식,최준호,추성연,이혼가정,자녀들,
#
# 정답: 백신 접종,개정대책,코로나19,2차 접종 시작
# 예측:  면역,백신 접종,코로나19,충북,아스트라제네카 접종
#
# 정답: 법원,lh 분양원가 공개,분양원가,자료,공개
# 예측: ,lh,분양원가 자료 일부 공개
#
# 정답: 가인,프로포폴 투약,브라운아이드걸스,미스틱스토리
# 예측: 포폴 투약,가인,우울증,벌금형,소속사,공식입장,사과
#
# 정답: 매미,힌남노,태풍,차수벽,피항,마산만,해일,모래주머니
# 예측: ,창원 마산,해일 방지,차수벽 가동,침수,침수,침수,침수,침수,침수,침수,침수,침수,침수,침수
#
# 정답: 대전 인공지능 이음마루,인공지능 산업 육성,개방형 혁신 공간,인공지능
# 예측: 시,인공지능 이음마루,개소,인공지능 산업 육성,개방형 혁신 공간,대전테크노파크,D-Station,12층,개방형 혁신 공간,대전테크노파크,AI스타트업,대전시 협업사업,디지털
#
# 정답: 김연경,여자배구,4강 진출
# 예측: 배구,4강 진출,김연경,5세트의 매직쇼
#
# 정답: pba,sk렌터카
# 예측: 임 파울,히다 오리에,pba 팀 리그,첫 승,벤치 타임아웃,공격권 박탈,김세연,쓰리 뱅크 샷,김세연,수비
#
# 정답: 봐주기,윤석열,의혹보도,부산저축은행,김만배,김병문,화천대유자산관리
# 예측: 배,부산저축은행 봐주기,이양수,변호사,박영수,수사무마
#
# 정답: 글로벌 기술협력 선포,업무협약식
# 예측:  기술협력 선포,글로벌 수요기업,국내 소재·부품·장비 기업,R&D 업무 협약식,참석자들,글로벌 기술협력 선포
#
# 정답: 서지현,검사,손배소,패소,상대,국가,안태근
# 예측: 현 검사,안태근,손배소,패소
#
# 정답: 김진희,남양주시의회,행복마을관리소 운영조례 발의
# 예측: 희 남양주시의원,행복마을관리소 운영조례
#
# 정답: 이미주,러블리즈 하트
# 예측:  하트,이미주,목동 SBS,파워FM,두시탈출 컬투쇼
#
# 정답: 성탄절,한파,폭설,눈,기온
# 예측: 부터 찬바람,곳곳 눈,성탄절,최강 한파
#
# 정답: 김주하,황연주,2021-2022 V리그
# 예측: 하,황연주,도드람 V-리그,현대건설,흥국생명
#
# 정답: 박병호,답답하네요,15일 오후,서울 고척스카이돔,2021 신한은행 SOL KBO리그,키움 히어로즈,한화 이글스,경기,4회말 1사,3루수 파울플라이,아쉬워하고 있다
# 예측: ,2021 신한은행 SOL KBO리그,서울 고척스카이돔,2021 신한은행 SOL KBO리그,키움 히어로즈,한화 이글스,경기
#
# 정답: 이갈이,성장기 자녀
# 예측: 륵드륵,성장기 자녀,이갈이,성장기 자녀,젖니,영구치,부정교합,스트레스,심리적 요인,이갈이,영구치열기,유치,유치열기,부정교합,스트레스,심리적 요인,영구치열기,
#
# 정답: EPL,황희찬,호날두
# 예측: 찬,호날두,맨유,EPL,득점,리그,맨유,맨유,맨유,맨유,맨유,맨유,리버풀,스코틀랜드,그레임 수네스,맨유,맨유,맨유,맨유,맨유,맨유,맨유,올레 군나르 솔샤르 감독,맨유,
#
# 정답: 빅히트 뮤직,방탄소년단,Butter
# 예측: 소년단,버터,일본 강타,오리콘 2주 연속 1위
#
# 정답: 북한은 지금,농촌 살림집 건설
# 예측: ,농촌 살림집 건설,자재,자체 해결
#
# 정답: 상속세폐지,70%투심,공약투하,국민의힘,윤석열,홍준표,최재형,희망지원금
# 예측: 폐지,국민의힘,후보들,공약,정책,국민의힘
#
# 정답: ,잠시,언급,결과,행동,생각,쥐띠,타인과이,관련,쉬어,금전,기회,재물,움직여,진행,바쁘게,움직임
# 예측: 띠,범띠,대인관계,만남,일,지연,금전,재물,다툼,
#
# 정답: 더 워킹데드: 서바이버즈,홍보 영상
# 예측:  워킹데드: 서바이버즈,사전 홍보 영상 공개,모바일 전략시뮬레이션게임,머니게임 출연진,이경영,액션게임
#
# 정답: 재난지원금
# 예측: ,재난지원금,초과세수,이재명 경기지사
#
# 정답: 송영길,더불어민주당 대표,최고위원들,경기 평택항,신컨테이너 터미널,고 이선호 씨,사고현장 점검
# 예측: ,더불어민주당,사고현장 점검
#
# 정답: 손흥민,한 시즌 최다골 타이,두 시즌 연속 10-10 클럽,토트넘 홋스퍼 스타디움,2020~2021시즌,프리미어리그,셰필드 유나이티드,34라운드,1골 1도움,토트넘 4-0 대승,
# 예측: ,한 시즌 최다골 타이,두 시즌 연속 10-10 클럽,잉글랜드 프로축구 프리미어리그,셰필드 유나이티드,2020~2021시즌,프리미어리그,가레스 베일,리그 10번째 도움,EPL
#
# 정답: 김현수 장관,권칠승 장관
# 예측:  장관,권칠승 장관,대화
#
# 정답: 신간 다이제스트,이해하기 쉬운 현대과학 안내서과학은 미래로 흐른다,미래 뒤흔들 4가지 혁신기술앞으로 10년 빅테크 수업,중력이 절실한 청춘에게무중력의 사랑,샤이좌파'에게 보내는
# 예측: 이제스트,과학,미래,혁신기술,미래,빅테크,김승미,조경,김승미,미래,미래,미래
#
# 정답: 여름 자외선,it,뷰티가전
# 예측:  자외선,it,피부,관리
#
# 정답: 이지현 모녀,챔피언십
# 예측: 현 모녀,블루헤런 골프클럽,제22회 하이트진로 챔피언십
#
# 정답: 윤석열,힌남노,대비,빌딩풍,선조치,후보고
# 예측: 남노,박형준,빌딩풍,선조치,후보고,재난 대비 상황 점검회의
#
# 정답: 난청,원인,치료,이명,온라인건강강좌,동아일보,서울아산병원
# 예측: 과 이명의 원인과 치료,동아일보-서울아산병원,온라인 건강강좌
#
# 정답: 그리스도인,인공지능
# 예측: 인,인공지능,기독대학원생연합,온라인,제4회 기독 대학원생 독서나눔 콘서트,기독교세계관학술동역회,
#
# 정답: 시진핑,브릭스,아프간 문제,러시아,중국,미국,상하이협력기구
# 예측: ,브릭스,화상 참석,아프간 문제,논의
#
# 정답: 동양대 게임학부,전문가 초청 특강,동두천 캠퍼스,오프라인과 언택트 방식,게임 산업체,주제: 생각이 특별하면 게임도 특별하다,게임샷 김성태 편집장,비대면 화상회의 플랫폼 줌,게임
# 예측: 대 게임학부,전문가 초청 특강,동두천 캠퍼스,비대면 화상회의 플랫폼,게임샷 김성태 편집장,인문학적 소양,게임 산업체 전문가 초청 특강,인문학적 소양,블루홀 김강석 전
#
# 정답: 오프라인 무인세탁소,키오스크,주문,비트코퍼레이션,스타트업,런드리24,로봇
# 예측: 임금 인상,키오스크,무인세탁소,창업,창업,인건비
#
# 정답: 전남동부,충청권,경상권,천둥·번개 동반,비 전국 확대,전라권,경상서부,강원도,충남북부,수도권
# 예측: ,전국적 비 소식,충청권,천둥·번개 동반,미세먼지 '좋음' 수준,미세먼지 '좋음' 수준,전국 확대,제주도,돌풍,천둥,번개,강한 비강수,중부지방,전라권,경북북부
#
# 정답: 발달장애인,k리그,연맹-스페셜올림픽코리아,업무협약
# 예측: 장애인과 함께 뛰는 k리그,연맹-스페셜올림픽코리아,업무협약 체결
#
# 정답: 박준영 변호사,살인마 오원춘,조선족 차별
# 예측: 준영 변호사,조선족 차별,옥문아들,재심 전문 변호사,살인 오원춘,변호,경험,재판 과정,조사 과정,영장실질심사,조선족 차별,분노,무기징역형,
#
# 정답: 포항 스틸러스
# 예측: 업계,항공업계,특가 할인
#
# 정답: 도쿄하계패럴림픽,100일 앞,경기도 이천시,대한장애인체육회 이천훈련원,미디어데이,휠체어농구 대표선수들,훈련
# 예측: 같은 훈련,도쿄하계패럴림픽
#
# 정답: 서울 청년 마음건강 지원사업,청년몽땅 정보통
# 예측: 건강,서울 무료 심리상담 참여자 추가 모집,서울시,청년 마음건강 지원사업,온라인 자가검진,위기군,고위기군,전문병원,정신건강복지센터,
#
# 정답: 손흥민,아시안 풋볼 어워즈,티탄저우바오
# 예측: ,아시아 풋볼 어워즈,통산 7회 수상
#
# 정답: BAT 로스만스,궐련형 전자담배,글로 프로 슬림,위해 저감 제품 확대
# 예측: AT로스만스,글로 프로 슬림,국내 출시,사업 본격화,디자인 반영,궐련형 전자담배
#
# 정답: 잔류,이상혁,페이커,T1
# 예측: 커,이상혁,T1,잔류,재계약
#
# 정답: 하이브,BTS,코스피,인수합병,리스크,,
# 예측: TS,하이브,악재,리스크 대응,시험대,글로벌 공연,팬덤 유입,북미 공연,이타카홀딩스 인수,북미 공연,팬덤 유입,글로벌 시장 진출,대체불가능한토큰,신사업 확장,
#
# 정답: 순매수,카카오게임즈,,코스닥,기관
# 예측: 게임즈,기관 순매수
#
# 정답: 레이싱모델,성 상품화 논란
# 예측: 기구 모터쇼,레이싱모델,성 상품화 논란
#
# 정답: 테슬라,사망 사고,운전자 오토파일럿,도로교통안전국
# 예측: ,오토파일럿,사망 사고,살인죄 기소
#
# 정답: JP모건 헥스케어 콘퍼런스,7개 의약품 생산공장 구축,롯데바이오로직스,바이오의약품 공장 단지
# 예측: ,롯데,바이오,의약품,CDMO
#
# 정답: 전북,세징야,대구,무패행진
# 예측: 징야,전북,무패행진,대구,스포츠머그
#
# 정답: 강백호,황재균,호잉,kbo 리그,동점,역전,재역전
# 예측: 백호,황재균,호잉,동점-역전,재역전
#
# 정답: 개리 아들 하오,부은 얼굴로 한강 피크닉
# 예측:  아들 하오,한강 피크닉,큐티뽀짝,일상
#
# 정답: 바이든정부,회의,한미일,정보기관장,박지원,일본
# 예측: ,일본,바이든정부,한미일 정보수장회의,참석
#
# 정답: 소공연,소상공인,생활안정자금 지원,소상공인 지원
# 예측: 금융그룹,생활안정자금,지원,선한가게,영세 소상공인,코로나19,지원,우리금융그룹,사랑의열매,사회복지공동모금회,지원 대상,선한가게,영세 소상공인,지원 대상,지원 금액,금융자산,부채,금융자산
#
# 정답: 온라인 판매,식품의약품안전처,의료기기,판매업,제조·수입업자,
# 예측: 기기법 개정안,온라인 판매 허용,식품의약품안전처,의료기기 제조·수입업자,판매업 신고 면제,임상시험 승인 제외대상 개선,식약처,임상시험 승인 제외대상 개선,식약처,판매업 신고 면제
#
# 정답: 자가 진단키트,홍남기 총리직무대행,코로나19,중앙재난안전대책본부,
# 예측:  진단키트,홍남기 총리직무대행
#
# 정답: 김현숙,강석훈,임명,장성민,정무특보,정책특보
# 예측: 훈,김현숙,정무특보,임명,특별고문,윤진식,임태희,박보균,임태희,임태희,임태희,임태희,박보균,임태희,임태희,임태희,임태희,박보균,임태희,임태희,임태희
#
# 정답: 갈비뼈 금,서경석,오은영의 금쪽 상담소
# 예측: 석,갈비뼈 금 간 것,건강검진 결과
#
# 정답: 한미약품,실적,R&D,성과,연구개발
# 예측: 약품,연구개발 성과,목표주가 하향조정
#
# 정답: 옐런,금리 인상 발언,미국 재무장관,연방준비제도 (Fed),통화정책,기준금리 인상,긴축 일정,시그널링,출구전략,전직 연준 의장,의사결정 주체,경제 정책,금리 결정,연준의 독립
# 예측: 의 금리 인상 발언,영향력 크지 않은 이유,금융시장,연준,출구전략,연준 독립성,연준 독립성,
#
# 정답: 에스파,카리나,윈터,놀라운 토요일
# 예측: ,카리나와 윈터,성격,입맛,팀 내 가장 안 맞아,놀토
#
# 정답: 김정숙 여사,문재인,이재명
# 예측:  여사,문재인 전 대통령,경남 양산시,평산마을 사저,이재명 대표 면담
#
# 정답: 인게임 아이템,삼국지 2022,리얼리티 큐브드,사전예약
# 예측: 큐브드,삼국지2022,사전예약,전략시뮬레이션,모바일
#
# 정답: 정은경,일상 회복,규제 완화,일상회복 지원 위원회
# 예측: 경,방역수칙,일상회복,코로나19,거리두기,방역수칙
#
# 정답: 살림남2,박준형,김지혜,몸무게,공개,강제
# 예측: 남2,박준형,김지혜,몸무게,강제 공개
#
# 정답: 뉴욕증시,하락 출발
# 예측: 증시,하락출발,다우,s&p500지수,나스닥지수
#
# 정답: 청소년,우울,불안,건강한 멘탈
# 예측:  우울·불안,건강한 멘탈
#
# 정답: 코로나19 6차 유행 확산,중증·사망 관리,고령층 확진 비율
# 예측: 유행,위중증 환자,고령층,확진자,위험요인
#
# 정답: 8K 디지털 아트,삼성 디지털프라자
# 예측:  디지털프라자,8K 디지털 아트,8K 디지털 아트,8K 화질,예술 작품,전시명,Neo QLED 8K,Big Picture in FOR:REST,전시
#
# 정답: 안정환,이혜원,딸,리원,리환,가족사진
# 예측: ,이혜원,카네기홀,아들,가족사진
#
# 정답: 인공지능대학원,해군교육사,UNIST
# 예측: 교육사,UNIST 인공지능대학원,업무협약식
#
# 정답: 조코 위도도,기지 건설,인도네시아,발사 기지,비악섬,뉴욕타임스,원주민,스페이스X
# 예측: X,인도네시아 원주민,원주민 반발,인도네시아 정부,우주선 발사 기지 건설
#
# 정답: 김영옥,성동일,버르장머리,바퀴 달린 집3,쎈캐
# 예측: 옥,버르장머리,성동일,김희원,공명,바퀴 달린 집3
#
# 정답: 스폰서,지이수,수목드라마
# 예측: 이수,스폰서,온라인제작보고회,포토타임
#
# 정답: 우크라이나 사태,코스피 급락,원/달러 환율 상승,주식시장 타격,산업계 긴장감 고조
# 예측: ,원/달러 환율,긴장감,국내 주식시장,원자재 수급난,러시아,우크라이나 침공,국내 주식시장,원자재 수급난,산업계,전방위 타격
#
# 정답: 칸영화제,박찬욱,송강호,감독상,남자배우상,수상,복수 수상 기록
# 예측:  감독,송강호,남자배우상,칸영화제,최우수감독상,송강호,헤어질 결심
#
# 정답: 효창공원,대선 후보,국민의힘,윤석열,추모식,헌화
# 예측: ,윤석열,국민의힘,대선후보
#
# 정답: ,개정 특정금융정보법,암호화폐 거래소
# 예측:  특정금융정보법,암호화폐 거래소,폐업,암호화폐 증발,개정 특금법
#
# 정답: 남포동,특종세상,명품 조연,모텔,배우
# 예측: ,모텔서 살고 있다,특종세상
#
# 정답: 두산,외인,빅리그,미란다,페르난데스,스톡
# 예측: ,외인 구성,마무리 단계,미란다,스톡,페르난데스,계약 막바지,외인 선수
#
# 정답: 이다희,탄성,클래스,화보,콘셉트,스타일링,프로포션,카리스마,아이덴티티,흑백,컬러,
# 예측: 희,탄성 부르는 클래스가 다른 아우라,6월호 화보,유니크한 스타일링,절제된 무빙,강렬한 카리스마,프로포션,강렬한 카리스마,화보,예술 작품,아우라,화보 컷,예술 작품,아우라,화보 컷,
#
# 정답: 민·관·학,서울교육청,청렴사회,협약
# 예측: 교육 청렴사회 협약,민·관·학
#
# 정답: 이의리,아쉬운 강판,광주-기아챔피언스필드,2021 KBO 프로야구,LG 트윈스,KIA 타이거즈,선두타자 오지환,안타,연속 삼진,교체 전달
# 예측: 리,아쉬운 강판
#
# 정답: 유은혜 부총리,사회부총리 겸 교육부 장관,정부서울청사,제7차 포용국가 실현,사회관계장관회의,참석
# 예측: 관계장관회의,유은혜 부총리
#
# 정답: 은행권,설 명절 이벤트,자금 지원,
# 예측: 은행,설날 특별 자금,이벤트,kb금융쿠폰,1만원권,이벤트,추석 특별 자금,
#
# 정답: 인민소비품 품평회,북한,노동신문
# 예측: 강도,공산품 품평회,결함,분석총화
#
# 정답: 일론머스크,테슬라,버니센더스 상원의원,부유세
# 예측: ,테슬라,부유세,샌더스,상원의원,부유세,부유세,부유세
#
# 정답: 문 대통령,4대그룹,크랩케이크,한미정상회담,오찬,최태원,정의선,구광모,김기남,삼성전자
# 예측:  대통령,4대그룹,크랩케이크,한미정상회담,만찬
#
# 정답: 전적,삼성,kt
# 예측:  95-80,서울 삼성,전적
#
# 정답: 박명수,한수민,딸,데이트,사춘기,민서,SNS,예원학교,한국무용과,결혼,중학교
# 예측: ,한수민,딸,데이트,사춘기,딸바보,딸바보,사진,딸바보,예원학교,한국무용과,예원학교,예원학교,예원학교,예원학교,예원학교,한국무용과,예원학교,예원학교,
#
# 정답: ,가상 경기장,제페토,한국프로스포츠협회
# 예측: 프로스포츠협회,가상 경기장 오픈
#
# 정답: 26살,월수입,300만원,집 포기,1억짜리 차
# 예측:  a7,월수입,차,구매,아우디 a7 유지
#
# 정답: 차기 정책,방송통신,방통위,언론 관련법,진흥 정책
# 예측: 혁 방통위원장,방송통신 거버넌스 일원화,과기정통부 2차관실,분리 정당성도,타당성도,방송통신 산업,융합,규제 정책,진흥 정책,언론중재법 재정안,언론 관련법,언론
#
# 정답: 항저우 亞 게임 유도 사령탑,김미정,여자 유도 대표팀 사령탑,
# 예측: 미정,황희태,항저우 亞 게임 유도 사령탑
#
# 정답: 승점,승자승,다득점,득실차,다승
# 예측: ,승점,득실차,승자승,다득점,다승
#
# 정답: 임금피크제 선배,임금피크제 세대 갈등,임금피크제,금융계
# 예측: 피크제,세대갈등,KB국민은행 노조,임피제 무효,대법원 판결,노조원,업무 경감,노조원,노조원,임피제 무효,대법원 판결,합리적 이유 없이 연령만을 이유로 직원의 임금 삭감
#
# 정답: 브레이브걸스 유나,‘After ‘We Ride’’
# 예측: 걸스 유나,신보 포토 티저 공개,인형 같은 비주얼,미니 5집 리패키지 앨범,Summer Queen,미니 5집 'Summer Queen',
#
# 정답: 유사독재,문재인 대통령,윤석열 후보,소수정예 선거운동
# 예측: ,소수정예 선거운동,유사독재,문재인 대통령,저격
#
# 정답: ,,약사법,비방광고,경쟁사 비방,사용자 체험담,디지털 마케팅
# 예측: 제품 비교,얀센백신,화이자 접종
#
# 정답: 베베파파,바베파파,한국프로야구선수협회,업무협약
# 예측: 야구선수협회,바베파파,업무협약,도담아이
#
# 정답: 강승윤,넉살,연하,연인,결혼
# 예측:  강승윤,결혼,넉살,열애,결혼식
#
# 정답: 음악 프로젝트,한국관광공사,Musical travels,춘천,도시 테마송
# 예측: 관광공사,도시 테마송,Musical Travels
#
# 정답: 명불허전 보수다 시즌5,이준석 대표,
# 예측:  대표,국민의힘,초선의원 공부모임
#
# 정답: ,농협은행,ESG경영,상생경영,제1회 대한민국 리딩금융 ESG 어워드,친환경경영,지배구조,녹색금융,
# 예측: H농협은행,ESG경영,상생경영,금융지주,환경,사회책임,지배구조,금융지주 부문,우수 ESG경영 사례,금융지주 부문,친환경,사회적 책임 경영,지배구조 개선,지속가능한 생태계
#
# 정답: 비행 체험,국민조종사,서울 adex 2021
# 예측: 조종사,비행체험
#
# 정답: 양도소득세,윤석열 정부,코로나19 영업시간,코로나19 방역,추경편성,인수위 출범,코로나19
# 예측:  정부,인수위,국정과제,코로나19 위기 극복,양도소득세 중과세율 한시 배제,민생,부동산,인수위,인수위
#
# 정답: 대우건설,어린이 교통안전,릴레이 챌린지,참여,김형,사장,어린이 보호구역,인식 개선,보호 문화,정착,행정안전부,기관 대표,교통안전표어,촬영,KDB인베스트먼트,정대우,휴맥스EV,푸르웰
# 예측: 건설,어린이 교통안전 릴레이 챌린지,참여
#
# 정답: 춘천,일교차,강원
# 예측: ,일교차,아침,오후
#
# 정답: 에어프레미아,객실승무원 수료식,교육훈련,코로나19,항공업계,채용시장,국토교통부,,
# 예측: 프레미아,1기 객실승무원 수료식,교육훈련 완료
#
# 정답: 두산 베어스,유희관,개인 통산 100승,KBO리그 통산 32번째,장호연,장원준,프로 12년 차 시즌,선발 로테이션,2013년 첫 승,2015년 최다 18승,한국시리즈 우승
# 예측:  유희관,개인 통산 100승,두 자리수 승 도전
#
# 정답: 대권 행보,정세균 총리,대구 방문,
# 예측: ,대구 방문,코로나19 백신,접종
#
# 정답: 통일부,김여정,정세악화,압도적대응,핵·미사일개발,국제사회고립,도발,위협,한반도평화
# 예측: ,한미,정세악화,압도적 대응,북한,도발,위협,국제사회 고립,개탄,핵·미사일 개발,
#
# 정답: 견본주택 오픈,파주 운정신도시,사전예약,제일풍경채 2차 그랑베뉴
# 예측: 건설(주),파주 운정신도시,제일풍경채 2차 그랑베뉴,견본주택 오픈,코로나19 감염 확산 방지,사전예약제 운영,견본주택 오픈,코로나19 감염 확산
#
# 정답: 올림픽,하뉴 유즈루,베이징 동계올림픽,피겨스케이팅,남자,싱글,프리,스케이팅
# 예측: ,하뉴,유즈루,프리 스케이팅
#
# 정답: 윤 특별사면,우병우,변호사,등록,사면,국정농단,공직자,불법사찰
# 예측: 사면,우병우,변호사 등록,박근혜 정부,국정농단 사건,윤석열 정부,공직자 불법 사찰
#
# 정답: 나경원,고양시,당원연수,특강
# 예측: ,고양시(갑),당원연수 특강
#
# 정답: 정우,김유미,허영만,백반기행,키스신,조언
# 예측:  키스신,김유미,백반기행
#
# 정답: kia,윌리엄스 감독,kbo 리그
# 예측:  감독,kia 타이거즈,키움 히어로즈,고척스카이돔,2021 kbo 리그,kia 타이거즈,키움 히어로즈,파죽의 4연승,파죽의 4연승,키움 히어로즈
#
# 정답: 서울시당,선대위출범식,이재명,더불어 민주당 대선 후보
# 예측:  후보,서울시당 선대위 출범식,퍼포먼스
#
# 정답: 박홍근,인사말,윤석열,정권,100일
# 예측: ,박홍근 원내대표,윤석열 정권 100일 평가 토론회
#
# 정답: switzerland,who,doctors,climate change,protest
# 예측: witzerland,doctors,climate change
#
# 정답: ,이준용,플레이디,디지털 광고,허욱헌
# 예측: 디,허욱헌,이준용,디지털 광고 대행 전문기업,KT그룹,디지털 광고 대행 전문기업,기업공개,코로나19 파고,경영 운전대,광고업 집중
#
# 정답: 세계 68명 고위급 인사들,2050 탄소중립 공동대응,온실가스 감축,파리기후협약
# 예측: 50 탄소중립,세계 68명,고위급 인사들,서울 동대문 디자인플라자 정상회의,파리기후변화협약,온실가스 감축 약속,2021 P4G 서울 녹색미래 정상회의,코로나19,포용적인
#
# 정답: 스포츠토토,적중상금,환급금,1년 시효기간,국민체육진흥공단,스포츠토토코리아,국민체육진흥법,체육진흥기금,경기 일정 변화,발매 취소,야구토토,골프토토,영수증,판매점 방문,전액 환불
# 예측: 토토,적중상금,환급금,국민체육진흥법,스포츠토토코리아
#
# 정답: 황대헌,남자 일반부 1000m 준결승전,쇼트트랙
# 예측: 대헌,혼신의 질주,쇼트트랙
#
# 정답: 킬링보이스,어반자카파,추위,라이브,신곡,모르겠어,니가 싫어,목요일 밤,코끝에 겨울,널 사랑하지 않아
# 예측: 보이스,어반자카파,겨울 추위,애절 발라드,혼성 발라드 그룹,'어반자카파','그날의 우리','커피를 마시고','딩고 뮤직',데뷔곡,미니앨범 타이틀곡,이별 예감,이별
#
# 정답: driverless ride hailing
# 예측: mo,driverless ride,hailing
#
# 정답: 호날두,베르바토프,극찬
# 예측: 바토프,호날두,맨체스터 유나이티드,맨체스터 유나이티드,득점 3위,맨체스터 유나이티드,맨체스터 유나이티드,맨체스터 유나이티드
#
# 정답: 페이쇼투 시장,시의원,정치인,브라질,스포츠,격투기
# 예측:  시장,시정 비판 정치인과 격투기,종합격투기
#
# 정답: 나경원,쇄신·통합,정권교체
# 예측: ,당대표 출마
#
# 정답: 인공지능,창원 LG스마트파크,로봇 기술,5세대 이동통신,로봇,물류로봇,부품 적시 조달,5G
# 예측: 공장,LG,냉장고,창원,창원 LG스마트파크,디지털트윈 기술,물류로봇,5G 융합
#
# 정답: 티샷,김민규,야물딱진 파워,경기도 성남시 남서울 골프장,대한골프협회 주관,GS칼텍스 매경오픈,3라운드 골프대회
# 예측: 물딱진 파워,김민규,GS칼텍스 매경오픈
#
# 정답: 로켓펀치,연희,서울,용산구,한남동,블루스퀘어,첫 번째 싱글,링링,쇼케이스,포즈
# 예측: 펀치 연희,쇼케이스,링링
#
# 정답: ice hockey,latvia,world championship
# 예측: atvia,ice hockey,world championship
#
# 정답: 한국판 디즈니,네이버·카카오,돈 되는 웹툰
# 예측: 판 디즈니되나,웹툰,네이버·카카오,한국판 디즈니
#
# 정답: 에이닷 프로농구,오세근,찬스,도요태스
# 예측: 근,찬스,서울 잠실학생체육관,2022-2023 SKT 에이닷 프로농구,서울 SK,안양 KGC,골밑 돌파,SK 수비 사이,골밑 돌파,SK 수비,안양
#
# 정답: cp 심포지엄,우수 사례,일동제약,esg 경영,공정거래위원회
# 예측: 제약,공정위 CP 심포지엄,ESG 경영성과,우수 사례 발표,ESG 경영성과,CP 운영,우수 사례 기업,ESG 경영
#
# 정답: 아만다 홀든,빛나는 화려한 미모
# 예측: 만다 홀든,화려한 미모
#
# 정답: 고딩엄빠2,김가연,딸,발달검사,오열,양육비,치료비,자활근로사업
# 예측: 엄빠2,김가연,4세 딸,발달검사,눈물사태
#
# 정답: 식스팩,복근,기안84,비주얼,다이어트,턱선,유튜브,웹툰
# 예측: 팩 복근,기안84,다이어트,복근,김희민,인스타그램,복근,복근,복근,복근
#
# 정답: 송파 추월서울,서초구,반포·잠원 아파트,반포·잠원동,강남3구,토지거래허가구역,신고가
# 예측: 거래허가구역,반포·잠원,신고가 행진,강남·송파
#
# 정답: ,도쿄올림픽,최종예선,리투아니아,남자농구
# 예측: 농구,도쿄행,리투아니아에 완패
#
# 정답: 혈중 지방,비만,당뇨병,스트레스,대사 질환,치료법
# 예측:  지방,당뇨병,비만,대사성 질환,심혈관 질환,비만,대사 질환,세포 내 스트레스,세라마이드,세포 밖 변화,세포
#
# 정답: 백신 수급 불균형,접종 순서
# 예측:  수급 불안,접종 순서,시민들,화이자 백신,아스트라제네카 백신
#
# 정답: 반도체 공급 부족,삼성SDI,하나금융투자
# 예측: SDI,반도체 공급 부족,하나금투
#
# 정답: 신성,효심,부모님,뇌졸중
# 예측: 심,신성,뇌졸중,죽을 고비,vcr,tv조선,엄마의 봄날,tvN,tv조선
#
# 정답: 재정당국,지출 구조조정,대통령직 인수위원회,한국판 뉴딜
# 예측: 조 추경,재정당국,지출 구조조정,한국판뉴딜,재정당국,
#
# 정답: 교육부,전면 등교 준비,코로나19 방역,대통령 직속 국가교육회의,국민 참여 교육과정 개정,사회적 협의 추진계획,온라인 설문조사,권역별 토론회,청년·청소년 토론회,의견 수렴 결과
# 예측: 부,코로나19 방역,전면 등교 준비
#
# 정답: 서강준,영화진흥위원회,코리안 액터스 200,글로벌 홍보 캠페인,한국 대표 배우,프로젝트,흑백영화,눈빛,아우라,뷰티 인사이드,미안해 사랑해 고마워,해피 뉴 이어,싱어송라이터,라디오 DJ,스페셜 사이트
# 예측:  액터스 200,서강준,영화진흥위원회,글로벌 홍보 캠페인,코리안 액터스 200
#
# 정답: 시즌 첫 승 도전,류현진
# 예측: ,ML 최하위,메이저리그 복귀,신시내티 레즈,선발 출격,토론토 구단,ERA 3.70,신시내티 레즈,신시내티 레즈,2022 메이저리그,신시내티 레즈,첫 승 도전,메이저리그 최저 승률,
#
# 정답: 마동석,김동현,범죄도시2
# 예측: ,김동현,범죄도시2,마동석,마동석
#
# 정답: 백상예술대상,참석,나인우,
# 예측: 우,백상예술대상,시상식,KBS 2TV 드라마,달이 뜨는 강,윤상호 감독,징크스의 연인
#
# 정답: 쿠만 감독,유럽축구,바르셀로나,프리메라리가,
# 예측: ,로날드 쿠만,미래,걱정,바이에른 뮌헨,대패,바이에른 뮌헨,바르셀로나,캄프 누,2021-22시즌 스페인 프리메라리가,그라나다,
#
# 정답: 이은지,코로나19,확진,접종,코빅,방역,지침
# 예측: 우먼 이은지,코로나19 확진,2차 접종 완료
#
# 정답: 민주당,대선 경선 연기론,이재명 지사,반박,당헌 88조 2항,대통령 후보자 선출,180일 전,120일 전,김두관 의원,이낙연,정세균,집단면역,송영길 당 대표,경선일정 조정
# 예측: ,대선 경선 연기론,이재명계,공개 반박
#
# 정답: 광주시,생태계교란,퇴치 사업,가시박,붉은귀거북
# 예측: 박,붉은귀거북,생태계교란 생물 퇴치 사업,광주광역시
#
# 정답: 코로나19,확진자,연속 1천명,3차 대유행,4차 대유행,지역별 비중,주요 감염 사례,밀폐,
# 예측:  9시,국내 코로나19 신규 확진자,1주일 연속 1천명대,지역별 비중,주요 감염 사례,백화점,음식점,직장,교육시설,동호회,지인 모임
#
# 정답: 이선빈,남친,이광수,유재석
# 예측: 빈,이광수,남친,mbti,mbti,남자친구,이광수
#
# 정답: sw협회,sw 기술자 임금,산업계,기준공개,반박
# 예측: w협회,임금,가중평균,산술평균,sw기업,임금 감소,기준공개
#
# 정답: mideast,palestinians,israel,conflict
# 예측: lestinians,israel,conflict,protest
#
# 정답: 스카이스포츠,토트넘,손흥민,모우라,탕귀,맨유,승리
# 예측: 샤르,토트넘,2대1 승리,토트넘,맨유,해리케인,손흥민,모우라,탕귀,토트넘
#
# 정답: 인사청문회,여야 원내대표,김부겸 국무총리 후보자,장관 후보자,국회 법제사법위원장,상임위원장 재배분,더불어민주당,국민의힘,빅딜론,인사 문제
# 예측: 청문회,여야,빅딜론,김부겸 국무총리 후보자,인사청문보고서 채택,상임위원장 재배분,더불어민주당,임혜숙 과학기술정보통신부,박준영 해양수산부,노형욱 국토교통부 장관 후보자,청와대,
#
# 정답: 코미디,불편,재미,경계,고민,피식대학,빵송국,샌드박스,유튜브 채널,정영준,엔터테인먼트 리드,인터뷰,CJ ENM,공개코미디,하락세,방송가,기업계,섭외,한사랑산악회,05학번이즈백
# 예측: 박스,유튜브 코미디,정영준 리드,빵송국,코미디 사업,웃음과 불편,코미디 콘텐츠
#
# 정답: 킹덤,3차 경연,체육대회,비주얼 킹,Mnet,비투비,아이콘,SF9,더보이즈,스트레이 키즈,에이티즈,최강창민,뜀틀,꼬리잡기,계주,이민혁,프니엘,더보이즈 큐,비주얼 킹 투표,
# 예측:  킹,체육대회,Mnet,킹덤,레전더리 워,체육대회
#
# 정답: 민주당,야당탄압,언어도단,본질,사안
# 예측: ,야당 탄압,언어도단,공수처,김웅 의원실 압수수색,공수처,김웅 의원실 압수수색,불법 수사,야당 탄압,고발 사주 의혹,본질 비틀어,사법적 책임 회피,정쟁화,당내
#
# 정답: 코로나19,일일 신규 확진자,4116명
# 예측:  확진자,코로나19,역대 최다
#
# 정답: kb자산운용,글로벌 인프라펀드,수탁고,1조 돌파
# 예측: 운용,글로벌 인프라펀드,수탁고 1조 돌파,호주amp캐피탈,인프라펀드,글로벌 인프라대출펀드,호주 amp캐피탈,양해각서,코로나19,해외운용사,신재생에너지,데이터센터,광섬유 네트워크,인프라시스템,글로벌
#
# 정답: 주호영,국민의힘,당권레이스,원내대표,차기 당대표 선거 출마,기자회견,당 쇄신 방안,야권 통합,대선 관리,도로 영남당 논란,홍문표,조해진,윤영석,조경태,권영세,김웅,
# 예측: ,국민의힘,당권레이스,출사표
#
# 정답: 김소담,미들슛,한방
# 예측: 담,미들슛,신한은행 sl 2022~2023 여자프로농구
#
# 정답: 잔류농약,검사,농산물,대상,확대
# 예측:  잔류농약 검사,350종,확대,울산시 보건환경연구원,개정된 법률,농산물 잔류농약 검사 대상,확대
#
# 정답: 울산 유흥업계 집단 반발,집합금지 해제
# 예측: 금지 해제,유흥업계,집합금지 해제,손실보상 규탄대회,울산 유흥업계,집합금지 해제
#
# 정답: 월요병,스트레스,포스트 코로나,쇼핑,연휴,
# 예측:  코로나 월요병,월요병 극복방법,직장인,휴일,휴가,재택근무,주말의 공포,월요일의 우울,직장인 아빠·엄마,주말의 공포,주말의 공포,주말의 공포,주말의 공포,주말의
#
# 정답: 한효주,안방극장,경찰특공대,해피니스
# 예측: ,행동파 경찰특공대,안방극장 복귀
#
# 정답: 성유진,아이언샷
# 예측: 샷,성유진,베어즈베스트청라cc
#
# 정답: 추신수,홈런 하이파이브
# 예측: ,하이파이브,잠실야구장
#
# 정답: australia,politics,icac,operation,inquiry
# 예측: stralia,politics,icac operation,independent commission
#
# 정답: 박격포,신형 박격포 실전배치
# 예측:  박격포,군,군 운반,기동성,정확도,디지털 기술,신속 이동,전투 피로도,안정성,디지털 장비,정밀 사격 능력,전방부대,화력 지원 능력,디지털 기술
#
# 정답: 양주 석재채취장 붕괴사고 실종자 수색,중대해재해처벌법
# 예측:  석재채취장 붕괴사고,실종자 수색
#
# 정답: 오케이 광자매,홍은희,최대철,하재숙,시청률,이혼,복뎅이,부부,결정,과일바구니,꽃다발,신마리아,엄마,돌직구,분노
# 예측:  광자매,홍은희,복뎅이,최대철,이혼,이혼,이혼
#
# 정답: 김만배 영장,유동규,뇌물 판단,곽상도,화천대유
# 예측: 배 영장,곽상도 50억,유동규 700억,뇌물 판단,구속영장 청구,뇌물 공여 혐의,배임 혐의,횡령 혐의,서울중앙지검,뇌물 공여 혐의,배임 혐의,횡령 혐의,배임 혐의,
#
# 정답: 한지혜,검사,태교법,신상출시 펀스토랑,동화,돼지고기,태교,대만족
# 예측: ,한지혜,검사,태교법,임신,임신,임신,임신
#
# 정답: 현세린,OK저축은행 박세리INVITATIONAL
# 예측: 세린,비바람,OK저축은행,1라운드
#
# 정답: esg,신재생 에너지,레노버,탄소,재활용 소재,사회적 가치창출,stem
# 예측: ,esg 강화,사용전력 90%,신재생 에너지,환경·사회·지배구조,2020-2021 esg 보고서,2026년까지,재활용 소재 사용,탄소 배출 강도,2029-2030년까지
#
# 정답: 경제계 신년인사회,윤석열 대통령,신년회,
# 예측:  대통령,최태원 대한상의 회장,신년회,경제계 신년인사회
#
# 정답: 딜리버리,대본리딩,출연진
# 예측: 드라마,딜리버리,출연진
#
# 정답: 리드오프,삼성 1군 캠프,동의대 출신 리드오프,삼성 캠프 승격
# 예측: 야구,동의대,리드오프,삼성,야구소프트볼협회,야구 예능프로그램,프로 구단,야구팬들,야구 예능프로그램,프로 구단,야구 예능프로그램,일본 오키나와 퓨처스 캠프,박진만 감독,스프링캠프,신인 선수,
#
# 정답: 이낙연,봉축법요식,조계사,부처님 오신날
# 예측: 축법요식,이낙연,더불어민주당,불기 2565년 부처님 오신날,합장,합장
#
# 정답: 금융플랫폼,위법 소지,금융위원회,금융소비자보호법
# 예측: ,금융플랫폼,위법소지,개선방안,카카오페이,금융플랫폼,
#
# 정답: 지한솔,가벼운 인사
# 예측: 한솔,가벼운 인사
#
# 정답: 포항공대,프랑스 국립과학연구소,라이다 축소 기술,초소형 나노 광학,레이저 빔,사물 정보 이미지화
# 예측: 항공대,프랑스 국립과학연구소,라이다 축소 기술 개발
#
# 정답: 김소연,이상우,펜트하우스,유튜브 채널,모노튜브,카페,스태프들,스콘,케이크,선물,도움,남편,개그 코드,깜짝 등장,생크림,극찬,엄마의 반응
# 예측: ,이상우,펜트하우스,꿀뚝뚝
#
# 정답: 세븐일레븐,롯데월드 간편식
# 예측: 월드,사업다각화,닭강정,간편식,세븐일레븐,롯데푸드,김밥,핫도그,샌드위치,도시락,도시락,닭강정
#
# 정답: 살림남2,최민환,재합류
# 예측: 남2,최민환,전역,13kg 감량,다부진 몸매,재합류
#
# 정답: 민생지원금,해남군,소상공인,취약계층
# 예측: 군,소상공인·취약계층,긴급 민생지원금,코로나19,소상공인,취약계층,방역물품지원
#
# 정답: 전립투,조선시대 음식
# 예측: 인의 밥상,전립투,식당,롯데백화점 동탄점,한국인의 밥상
#
# 정답: 남욱,대장동,특혜·로비,의혹,변호사,검찰,체포,수사,증거,진술
# 예측: 욱,검찰,귀국,특혜·로비,인천공항,체포영장,서울중앙지검,인천공항,인천공항,인천지검,긴급호송,김만배,유동규,정영학,위례신도시,
#
# 정답: 티저,투게더,채수빈,도서관,뮤직비디오,규현,공명,신곡,
# 예측: ,투게더,MV 티저 공개,공명,채수빈,친구,이성,봄 노래,여름 노래,가을 노래,썸 노래,설렘 지수,봄 노래,커피 뮤직비디오,학창시절 풋풋했던 과거,설렘 지수,봄
#
# 정답: 모다페 홍보대사,한예리,서울 중구 더 플라자 호텔,MODAFE 2021,기자간담회,영화 '미나리',제40회 국제현대무용제,자가 격리,한국예술종합학교 전통예술원,한국무용
# 예측: 페,한예리,홍보대사,서울 중구 더플라자 호텔,2021,기자간담회,한국예술종합학교 전통예술원,한국무용,한국예술종합학교,한국무용,한국예술종합학교,한국무용,한국예술종합학교,한국무용,한국예술종합
#
# 정답: 박보영,tvN,어느 날 우리 집 현관으로 멸망이 들어왔다,연기력,케미력,믿보 배우,인간과 초월적 존재의 로맨스,예측 불가능한 전개,감각적인 연출,주조연의 열연,판타지
# 예측: ,박보영,시청률,시청률,드라마
#
# 정답: SK바이오사이언스,코로나19 백신,제조 및 품질,유럽인증,EU-GMP 인증,아스트라제네카,노바백스,생산 시설,공정·품질 시스템,유럽의약품청,의약품 제조 및 품질관리기준 인증,
# 예측: K바이오사이언스,코로나19 백신 제조,품질 유럽인증 획득,안동공장 L하우스,아스트라제네카,노바백스,코로나19 백신 후보물질 위탁개발생산 제조,EU-GMP 인증,유럽의약품청,CDM
#
# 정답: ,국제표준화기구,국제표준화기구 회장 도전,브리핑
# 예측: 나라 최초,국제표준화기구 회장 도전
#
# 정답: 성남도개공 초대 사장 경찰 출석,성남도시개발공사
# 예측: 도개공,초대 사장,참고인,조사
#
# 정답: 연예인,산림청,홍보대사 위촉,산림청장,산림청 홍보대사 위촉,2050 탄소중립,,,
# 예측:  홍보대사,남진,이자연,산림청,2050 탄소중립,나무 심기,산림청 홍보대사,산림청 소속 가수,연예인,2050 탄소중립,나무 심기 행사,산림청 홍보대사,2050 탄소중립,나무
#
# 정답: . 무단전재 & 재배포 금지,emp 차단 콘크리트
# 예측: 양회,emp 차단 콘크리트,상용화,산업부산물,emp 차폐 콘크리트,시제품 생산,전기
#
# 정답: 무선 이어폰,LG 톤프리,lg전자,UV 나노케어
# 예측: G전자,무선이어폰,살균,에어팟 프로,삼성 갤럭시 버즈 프로,귀 염증,UV나노 케어,살균 기능,애플 에어팟 프로,삼성 갤럭시 버즈 프로,국내 시장,살균 기능,UV나노 케어,
#
# 정답: 이홍기,에프이타일랜드,1976 할란카운티,
# 예측: ,1976 할란카운티
#
# 정답: 히라이 가즈오,실적,소니,소니 턴어라운드
# 예측: 부활,이단아,출세와 담 쌓던 이단아
#
# 정답: 단식농성,비대위원장,의정부시의회,박지현
# 예측: 현,더불어민주당,단식농성,의정부 시의원
#
# 정답: 미 캘리포니아주,마스크 의무화 유지,질병통제예방센터(CDC),백신 접종 완료자,마스크 착용 해제,사업체·점포 전면 재개,마크 갤리 보건복지부 장관,변화에 준비할
# 예측:  캘리포니아주,마스크 의무화 유지,백신 접종 완료자,캘리포니아주,마스크 착용 지침 개정,
#
# 정답: 탁현민,여사님의 옷장,허무한 논쟁,김정숙 여사
# 예측: 현민,김정숙,금괴,옷값,의혹,경찰수사
#
# 정답: lh 혁신,청렴 서약식
# 예측: h 혁신 선포,청렴 서약식
#
# 정답: 보치아,김한수,금메달,최예진,정호원,도쿄 패럴림픽
# 예측: 치아,금메달,금메달,일본 도쿄,아리아케 체조경기장,2020 도쿄 패럴림픽,대한민국,정호원,김한수,금메달
#
# 정답: 대우건설,LG전자,인공지능,스마트 단지,업무협약,스마트 푸르지오 플랫폼,씽큐 플랫폼,미래형 스마트홈 플랫폼,홈네트워크 기기,연동·제어,지능형 주거 공간,AI 스마트 단지 서비스,20
# 예측: 건설,LG전자,인공지능 스마트 단지 구축 협력
#
# 정답: 신규확진,주말,위중증
# 예측: 확진,3120명,주말,3000명대,위중증,517명
#
# 정답: 컴백,비비,새 EP,인생은 미친X,트랙리스트 공개,파격 콘셉트,싱어송라이터,작사,작곡,스타일링,스토리텔링 시리즈 앨범,멀티테이너,20대의 솔직한 인생,단편소설,BAD SAD AND
# 예측:  D-4,비비,EP,인생은 미친X,트랙리스트,시선싹쓸이
#
# 정답: 몽고메리,욕설,로진백 투척,사과,
# 예측: ,로진백 투척,몽고메리,사과
#
# 정답: AFGHANISTAN,BOMBING
# 예측: FGHANISTAN BOMBING,Kabul,security,officials,scene,bomb blast,epa09241887,kabul,
#
# 정답: 유엔·EU 경고 받은 머스크,트위터,복구,일론제트
# 예측: ,일론 머스크,유엔·EU 경고,정지된 기자들,계정 복구
#
# 정답: 광동제약,제주삼다수,위탁판매,연장
# 예측: 제약,제주삼다수,위탁판매,4년 연장,유통채널,온라인 영업력,브랜드가치 향상,온라인 영업력,온라인 영업
#
# 정답: 목표가 생겼다,MBC 드라마,배우 이시우
# 예측: 가 생겼다,이시우,소름,MBC 드라마
#
# 정답: 송파 플래티넘,리모델링,분양,신규아파트,청약
# 예측:  플래티넘,리모델링,일반분양,송파구 오금동,공동주택 리모델링,청약 대흥행,서울 첫 리모델링 분양,송파구 오금동,
#
# 정답: 반기문,원전,탄소중립,smr,소형원자로(smr)
# 예측: ,원전 없는 탄소중립,smr 강점 활용
#
# 정답: 레인보우 재결합,김재경,레인보우 멤버,연기
# 예측: 경,레인보우 재결합,체력,재결합
#
# 정답: 로켓펀치,연희,윤경,시크한 연희,미소 윤경,서울 마포구 합정동,울림엔터테인먼트 사옥,뉴스엔TV,'니들모해?!',첫 번째 싱글,링링,컴백,8개월만,뉴트로 콘셉트,앨범
# 예측: 펀치,연희,윤경,시크한 연희,미소 윤경
#
# 정답: 김건희 여사,캄보디아 소년,대사관,장경태,진행자,김의겸 의원
# 예측: 태,더불어민주당 최고위원,캄보디아 소년 거주지,요청
#
# 정답: 잉글랜드-이탈리아 유로2020 결승전,잉글랜드,이탈리아
# 예측: ,잉글랜드,유로2020,결승전,후스코어드닷컴,영국 더 선,잉글랜드,잉글랜드 프리미어리그,잉글랜드 프리미어리그
#
# 정답: 자이엔스앤디,신축사업,공사도급약정,523억
# 예측: 에스앤디,신축사업,공사도급약정
#
# 정답: 빌 게이츠,여직원,부적절 성관계,이사회 퇴진 압력,마이크로소프트,월스트리트 저널,멜린다 게이츠,이혼,엔지니어,조사,이사회 의장,사임,브리짓 아널드,대변인,자선 사업
# 예측:  게이츠,여직원,부적절 성관계,이사회 퇴진 압력
#
# 정답: outbreak,virus,reopens,france
# 예측: irus Outbreak France,Paris,Thursday,2021,restaurant terrace
#
# 정답: 윤아,한지민,한지민 애정 폭발,천사가 확실
# 예측: ,한지민,애정,천사가 확실,인스타그램,해피뉴이어
#
# 정답: 북한 열병식 준비,플래닛 랩스,열병식 훈련장
# 예측:  열병식 준비,훈련장,1만3000여명 집결,정찰
#
# 정답: 밴텀급 배틀로얄,조제 알도,챔피언 알저메인 스털링,UFC
# 예측: FC 밴텀급 배틀로얄,조제 알도,참전 챔피언 알저메인 스털링,챔피언 알저메인 스털링
#
# 정답: 생활습관 개선,심장,소변,항생제,역류,선천적·후천적 이유,질환,생활습관,예방·관리법,하부 식도 괄약근,위산,위식도 역류 질환,증상,바렛 식도,식도암,생활습관
# 예측: 성 질환,생활습관 개선,위산·정맥혈,생활습관 개선
#
# 정답: 송영길 더불어민주당 대표,김건희 씨 반말,허은아 비판,남존여비 시각
# 예측: ,김건희,윤석열,남존여비,반말,허은아
#
# 정답: 유영재,경찰수업,제이월드,이미지,연기변신
# 예측: 영재,경찰수업,KBS2,월화드라마,경찰대학교,
#
# 정답: 병무청,사회복무,소통단,제도개선
# 예측: 청,사회복무 소통단,제도개선 제안
#
# 정답: 원불교,나상호 교정원장,교단혁신특별위원회,대각개교절,간담회
# 예측: 불교 나상호 교정원장,교단 혁신,대각개교절,바티칸 공의회,원불교 전서,회수사태,사과
#
# 정답: 성폭력,강압,공군,부사관,
# 예측:  감염,공군 부대,성폭력 사건,강제 감염
#
# 정답: 홍성흔,김정임,몸매관리,마사지,동굴캐슬
# 예측: ,김정임,마사지,동굴캐슬
#
# 정답: 대만,밸런타인데이,혼인신고,동성부부,출산율
# 예측: ,밸런타인데이,혼인신고,동성 부부,화촉
#
# 정답: 회계·컨설팅,러 국영방송,백악관,대러 제재,러 전승절,
# 예측: ,러 국영방송,제재,회계·컨설팅 서비스,제재,우크라이나 전쟁,미국 의회,예산 요청,러시아 전승절,러시아 채널-1,로시야-1,NTV,우크라이나 전쟁,미국 의회,우크라이나 전쟁,미국
#
# 정답: hove albion,soccer,english premier league,manchester city,brighton
# 예측: righton,SOCCER,ENGLISH,PREMIER,LEAGUE
#
# 정답: 이완,이보미,프로골퍼,각선미,인스타그램,근황,스포츠웨어 브랜드,원피스,걸그룹,비율,초동안 20대 비주얼,김태희,한일 수교 50주년,아사히신문,배용준,김연아,인지도,럭셔리 라이프,골프 실력,네티즌들,S
# 예측: 보미,김태희,올케,초미니 원피스,각선미,인스타그램,김태희,골프
#
# 정답: 다승 공동 선두,요키시,뷰캐넌,15승,드류 루친스키
# 예측:  공동 선두,드류 루친스키,요키시,키움,뷰캐넌,삼성 외인,2년 연속 15승 도전
#
# 정답: 변수,유고,대선 돌발,대장동 키맨,유한기,
# 예측: 동 키맨,유한기,대선 돌발 변수
#
# 정답: 레반도스프키,바이에른뮌핸,바로셀로나,챔피언스리그 조별리그
# 예측:  뮌헨,선발 명단 공개,로베르트 레반도프스키,뮌헨 폭격,바르셀로나 이적
#
# 정답: 남부발전,한국에너지정보문화재단,빛드림 사업,ESG 경영
# 예측: 에너지정보문화재단,남부발전,업무협약 체결
#
# 정답: 이선빈,라디오 방송,이광수 목소리
# 예측: ,이선빈,이광수,라디오 방송
#
# 정답: 여자배구 KGC인삼공사,크리스마스 스페셜 유니폼,배구
# 예측: 배구,KGC인삼공사,크리스마스 스페셜 유니폼,출시,IBK전,IBK전,IBK전,KGC기프트패키지,판매,기부행사,대전 홈 경기장,이벤트,이벤트,대전 홈 경기장,팬들
#
# 정답: 대도시권광역교통위원회,김규철,국토교통부,항공정책관,광역교통정책국장,국장급,
# 예측: 교통부,광역교통정책,국장급 전보
#
# 정답: 내차팔기 홈서비스,최다 판매 모델,케이카 내차팔기,국내 중고차 기업
# 예측: 차 팔 때,K Car,내차팔기 홈서비스,모바일 앱,판매 견적 신청,K Car,스마트폰,차량평가사,PC,스마트폰,차량 매입 서비스,개인 매입 서비스,스마트폰,차량
#
# 정답: 꿀벌,코스모스
# 예측: ,코스모스,비,평택시,농업생태원
#
# 정답: 부산시,건축물 철거공사,분별해체 의무화,건설폐기물,재활용 극대화,폐합성수지,폐보드류,폐콘크리트,건설폐기물 재활용 촉진 법률,공공구조물,연면적 500m2 이상,환경영향평가대상사업
# 예측: 시,500m2 이상 건축물 철거공사,분별해체 의무화,건설폐기물 재활용 촉진에 관한 법률,건설폐기물의 재활용 촉진에 관한 법률,건설폐기물의 재활용 촉진에 관한 법률,공공구조물
#
# 정답: 사이클론 '타우크태',폭우,인도 뭄바이,침수된 거리,신종 코로나바이러스 감염증 대확산,대형 사이클론,최소 16명 사망,인명과 재산 피해
# 예측: 론,타우크태,침수,인도 뭄바이
#
# 정답: 반도체,생산,가동률,메모리 가격 한파,파운드리,수출,코로나19,통계청,산업활동,삼성전자,db
# 예측:  반도체 생산,대만 1등 기업,위기,반도체 칩 위탁생산
#
# 정답: 함지훈,모비스,골밑 돌파,프로농구
# 예측:  함지훈,골밑 돌파
#
# 정답: 이기영
# 예측: ,선물,이기영,마지막 선물
#
# 정답: 김지민,박영진,김준호,JDB엔터테인먼트,유민상,김민경,유쾌한 웃음,오나미,박나래,새해인사
# 예측: ,박나래,유민상,김민경,새해 웃음 폭탄
#
# 정답: 검수완박,검찰공화국,프레임,한동훈,논문 등재,
# 예측: 훈,검찰공화국,검수완박,윤석열 대통령,야권 공세,윤석열 라인 검사 중용,여론전 주도 인사,노골적인 특수통 회전문 인사,윤석열 라인 검사 중용,윤석열 라인 검사
#
# 정답: 합의,문제,초부자,예산안,박홍근,사업,감액
# 예측: 근,예산안,감액,예결위,예결위,예결위
#
# 정답: 엘리엇 페이지,유방절제,성전환,눈물,오프라 컨버제이션,오프라 페이지,애플TV+
# 예측: 전환,엘리엇 페이지,유방절제,커밍 아웃
#
# 정답: 이홍정,한국기독교교회협의회 총무,27일 오전,경기도 파주시 장단면,통일부 남북출입사무소 북단 DMZ 통문,4.27 판문점선언 3주년 기념행사,발언
# 예측: 정 한국기독교교회협의회 총무,4.27 판문점선언 3주년 기념행사
#
# 정답: 루카 모드리치,안첼로티,레알마드리드,카세미루
# 예측: 첼로티,베테랑,카세미루,루카 모드리치,카세미루,이탈리아,유럽축구연맹 챔피언스리그,2022-2023시즌,유럽축구연맹 챔피언스리그,유럽축구연맹 챔피언스리그,
#
# 정답: 역투하는 삼성 문용익
# 예측: 투,삼성 문용익,프로야구
#
# 정답: 테러지원국,북한,2020년도 국가별 테러 보고서,테러행위
# 예측: 지원국 명단 잔류,북한,테러 활동,미국 국무부,테러 지원국 재지정,국제 테러 행위,북한 국무위원장,이복형 김정남 암살,테러 행위,국제 테러 행위,북한 국가 단체,일본 항공
#
# 정답: 로베르트 레반도프스키,발롱도르,메시,악감정
# 예측: 도르 메시,로베르트 레반도프스키,기자회견
#
# 정답: 홍경·최정운,영화부문 남녀신인상 수상,백상예술대상
# 예측: 경,최정운,백상예술대상,영화부문,남녀신인상
#
# 정답: 윤석열,TK 방문,장애인,정책 점검,이재명,재건축
# 예측: ,TK 방문,윤석열,장애인,재건축 정책 점검
#
# 정답: 박상기,조국,안양지청 수사외압,이광철,김학의 전 법무부 차관,이성윤,긴급출국금지 요청서,불법출국금지
# 예측: 지청,수사 외압,이성윤,조국,이광철,각본,주연,연출,각본,주연,주연,연출,각본,주연,주연,연출,
#
# 정답: 새해 첫날,질롱 코리아 야구팀
# 예측: 롱 코리아 야구팀,박수민 앵커
#
# 정답: covid-19,pandemic,vaccination,indonesia
# 예측: onesia,pandemic,covid19,vaccination
#
# 정답: 이태원 핼러윈 참사,뇌사판정,국군장병,장기기증
# 예측:  참사,사망자,장기기증,중대본,중대본,뇌사,장기기증,국군장병,중대본,중대본,뇌사 판정,장기기증,국군장병,이대목동병원,중환자실,회복 가능성,이대목동병원,장기이식센터,
#
# 정답: 학교 풍경,등교,코로나19
# 예측: ,학교 풍경,코로나19,등교 확대
#
# 정답: 다주택자 양도세,홍남기
# 예측: ,다주택자 양도세 완화,부동산 담보대출 규제,주택담보대출 규제,주택담보대출 규제,주택담보대출 규제,주택담보대출 규제,다주택자 양도세 완화
#
# 정답: k리그,전적
# 예측: 리그2,전적 종합
#
# 정답: 저신다 아던 뉴질랜드 총리,데이비드 시모어 액트당 대표,국회 속기록 사본,경매,8000만원,발언
# 예측:  총리,막말,속기록 사본,8000만원,트레이드미 온라인 경매,저신다 아던 뉴질랜드 총리,데이비드 시모어 액트당 대표,
#
# 정답: 김부겸,국무총리,17일 오후,서울,여의도,국회,송영길,더불어민주당 대표,대화
# 예측: ,김부겸 총리
#
# 정답: 술 취해 성추행,말리자 주먹질까지,현직 경찰
# 예측: ,경찰관,경찰관,강제추행,부산 연제경찰서,강제추행,a 경위,조사,경찰
#
# 정답: 이베이코리아 인수전,롯데 신세계
# 예측: 코리아,롯데-신세계,인수전,이르면 오늘 윤곽,미국 이베이 본사,본입찰,지분 교환,네이버,컨소시엄,롯데쇼핑,본입찰,롯데쇼핑,네이버,컨소시엄,롯데쇼핑,네이버,컨소시엄,롯데쇼핑,네이버,컨소시엄,네이버,경쟁
#
# 정답: 장민호,비주얼,여심,미스터트롯,남성미,top6
# 예측: 민호,여심,트롯 신사,미스터트롯,top6,상남자,매력 전쟁
#
# 정답: 컴투스,블록체인 게임 플랫폼,투자,블록체인,미씨컬 게임즈
# 예측: ,블록체인 게임 플랫폼 기업,미씨컬 게임즈
#
# 정답: 기보,'중소기업 혁신기술,사업화,기술보증기금,'기술평가세미나
# 예측: ,중소기업 혁신기술,사업화,기술보증기금,기술평가세미나,서울 신도림동 라마다호텔,정부 연구개발 과제,R&D사업화 지원 프로그램,기술평가 세미나,기술보증기금,
#
# 정답: 국립서울현충원,김정숙,문재인
# 예측: 서울현충원,문재인 대통령,김정숙 여사
#
# 정답: 우루과이,엘 파이스,한국,2002년,판정,4강
# 예측:  최대 매체 엘 파이스,한국,월드컵 4강 신화,평가절하
#
# 정답: 석탄,생산,북한,노동당,결정,관철
# 예측: ,당 결정,석탄 생산,당 결정
#
# 정답: 한국 여자핸드볼,세계선수권 결선리그
# 예측:  여자핸드볼,세계선수권 결선리그 진출,8강 도전,대한핸드볼협회
#
# 정답: 박수홍,김다예,박수홍,손헌수,상견례,결혼,편스토랑,신상 서바이벌
# 예측: ,아내 김다예,최초공개
#
# 정답: 탈울산,인구유출,역대 최고,20대 젊은 층,대책 마련,시급한,울산 인구,2015년,감소,1분기,동남지방통계청 조사결과,순유출 규모,모든 연령대,일자리,주력 산업,울산시
# 예측: 울산,인구유출,울산,인구유출
#
# 정답: 직원 절반 해고 계획,머스크,트위터
# 예측: ,일론 머스크,직원 절반 해고 계획
#
# 정답: 법제사법위원회,진상 규명,민주당,윤석열 게이트,국민의힘,고발 사주 의혹,김웅 의원
# 예측:  게이트,총공세,이준석,당무감사 검토,민주당,국기 문란 정치공작,민주당,국민의힘,자체 조사,박범계 법무부 장관,박범계 법무부 장관,박범계 법무부 장관,
#
# 정답: 항저우아시안게임,인도사격연맹,아시안게임,코로나19
# 예측: 사격연맹,아시안게임,항저우아시안게임,코로나19
#
# 정답: 독일,첫 한국계 연방의원
# 예측: ,한국계 연방의원,이예원,감사,독일 연방하원 총선
#
# 정답: 맨시티 감독,아스널,과르디올라
# 예측:  시티,아스널,스승의 아쉬움,맨체스터 시티,맨체스터 시티,미켈 아르테타,맨체스터 시티,FA컵,맨체스터 시티,미켈 아르테타,
#
# 정답: 핫이슈 형신,무대 사로잡는 카리스마 눈빛,ISSUE MAKER
# 예측:  형신,쇼케이스,서울 광장동 예스24라이브홀,데뷔 앨범,ISSUE MAKER
#
# 정답: 꿀벌,꿀벌 실종 사건
# 예측: 들,실종사건,봄,봄 봄,꿀벌 농장,
#
# 정답: 기관 거래소,KODEX 코스닥 150선물인버스,고려아연,한화에어로스페이스,
# 예측: 아연,KODEX 코스닥150선물인버스,한화에어로스페이스,기관 순매수
#
# 정답: 명낙회동,이재명,이낙연,송영길,드림팀,용광로 선대위,문재인 정부,새로운 물결
# 예측: ,명낙회동,드림팀,용광로 선대위,이재명,이낙연,선대위
#
# 정답: MBC 놀면뭐하니,MSG워너비,유야호,활동곡
# 예측:  뭐하니,유야호,MSG워너비,활동 후보,눈물 나려고 해
#
# 정답: 드라큘라,코로나,뮤지컬,코로나19,신성록,전동석,강태을,김준수
# 예측: ,코로나19,공연계,코로나 비상
#
# 정답: 조유리,미니홈피,일촌,신청,걸그룹,아이즈원,화제,싸이월드,도토리,음원,프로젝트,메인보컬
# 예측: ,조유리,미니홈피,일촌신청
#
# 정답: 이재명,윤석열,5·18 메시지,더불어민주당,경기지사,노무현 전 대통령,서거 12주기,추모전시,정세균,부동산 정책,조세 부담,금융 혜택,합리적 방향,서울 종로구 인사동
# 예측: ,5·18 메시지,윤석열,민주당,문재인,윤석열,국민의 한 사람,민주당,부동산 정책 조정,조세 부담 강화,금융 혜택,조세 부담
#
# 정답: 추가 확진,원주,유흥업소발,춘천,확산
# 예측: 업소발,n차 감염,춘천·원주
#
# 정답: 포커스에이치엔에스,비즈니스구조,유진스팩5호,합병
# 예측: 스팩5호,포커스에이치엔에스,합병,주총,승인
#
# 정답: 이경옥,엄영수,스타다큐 마이웨이,TV조선 예능
# 예측: 영수,삼혼의 아이콘,결혼,아이들,반대
#
# 정답: 임한별,공식 유튜브,크리스마스,콘서트,무료 온라인 콘서트
# 예측: 한별,크리스마스 무료 콘서트,연습실 비하인드
#
# 정답: 위드 코로나,씀씀이,소비쿠폰,카드캐시백
# 예측:  코로나,방역체계,소비쿠폰,한은,위드 코로나,소비 촉진,한은,소비쿠폰
#
# 정답: 독도,독도 수호 퍼포먼스,김동욱,서예가
# 예측: ,우리 손으로 지킨다,서예가,쌍산 김동욱씨
#
# 정답: 민변 (민주사회를 위한 변호사모임),감사원,LH (한국토지주택공사),국토교통부,투기 의혹,철저한 감사,참여연대,농지법 위반 감독 실태,공직자들의 개발정보 보안관리
# 예측: 원,LH,국토부,투기 의혹,철저한 감사,민주사회를 위한 변호사모임,감사원,농지거래 위반 감독 실태,감사원 측,감사원 감사 촉구,참여연대,공동 논평,개발정보 보안
#
# 정답: 국민의힘,원내대표,김기현,윤호중,원내대표 선거,윤석열,대표 권한대행
# 예측:  전략,김기현,윤호중,국민의힘,원내대표,선거
#
# 정답: 삼성전자,고용주,포브스,ibm,마이크로소프트,아마존,애플
# 예측: 전자,세계 최고 고용주,포브스 선정,2년 연속 1위
#
# 정답: 날씨,폭우,내일
# 예측: ,기록적인 폭우
#
# 정답: 남해대교,문화 이벤트,관광지
# 예측: 대교,문화이벤트,남해군,국민관광지,국민참여형 이벤트,국민관광지 어게인,2022 남해군 방문의 해,버스킹 공연,리마인드 포토,버스킹 공연,남해군 방문의
#
# 정답: 서건창,통산 1200안타,대기록 달성,2021 KBO리그,한화 이글스,키움 히어로즈,경기,2루타,리그 7위,설욕전,단독 9위,2연승 도전
# 예측: 건창,통산 1200안타,대기록 달성
#
# 정답: 종전선언,비핵화,이도훈
# 예측: 훈,한반도평화교섭본부장,비핵화 논의,종전선언,정치 선언,문재인 정부,북핵 총괄,외교부 한반도평화교섭본부장,
#
# 정답: 애덤스,뉴욕시장,3개월,월급,비트코인
# 예측: 스 뉴욕시장 당선인,3개월 월급,비트코인,뉴욕시장 취임
#
# 정답: 전소미,가요광장,배트맨,안무,프로듀서 테디
# 예측: 광장,전소미,배트맨 안무,프로듀서 테디,아이디어
#
# 정답: 언론자율규제,더불어민주당,윤석열,국민의힘,가짜뉴스,국기자협회,사법적 절차,이재명,심상정
# 예측: ,안철수,심상정,언론자율규제기구,언론자유 침해
#
# 정답: 김미연,집 공개,서초,여의도,SNS,새 집,높은 층고,갤러리,MBC 13기 공채 코미디언,음치 미녀 캐릭터,드라마 '노란 복수초',2019년 결혼,첫 아이
# 예측: 으리 서초 집 공개,김미연,으리으리한 집,여의도,서초,코미디언,백년가약,아내,아이,결혼,
#
# 정답: 박나래,베트남 라이딩,장 시그널,화장실 찾기
# 예측: ,베트남 라이딩,장 시그널,일촉즉발,화장실 찾기
#
# 정답: 무임승차 논쟁,기준 논의,운영의 묘,손실 분석
# 예측: 승차,노인,초고령 사회,기준 논의,운영,손실 분석,서울시,노인복지법,경로 우대,지하철 수익 손실,서울 지하철 무임승차,노인 복지 효과,수익 악화,서울 2025년,초고령
#
# 정답: 프리미엄 자산관리,하나금융투자,Club1한남WM센터
# 예측: 금융투자,프리미엄 자산관리,Club1한남WM센터,오픈
#
# 정답: social crisis,protests,Panama,Laurentino Cortizo,
# 예측: ANAMA,PROTESTS,Laurentino Cortizo,request
#
# 정답: 고농도 미세먼지,서울광장 스케이트장,운영 중지
# 예측:  미세먼지,서울광장 스케이트장,운영 중단
#
# 정답: 윌리엄스,'2021 신한은행 SOL KBO리그
# 예측:  감독,선수들 훈련
#
# 정답: 장병 급식비 인상,국방부
# 예측:  하루 급식비,만3천 원 인상,만3천 원,국방부
#
# 정답: 김단비,우리은행,FA,여자농구
# 예측: 농구 FA 김단비,우리은행,이적
#
# 정답: 알버트 비어만 사장,현대차그룹,피터 슈라이어 사장,퇴진,인사
# 예측: 차그룹,인사,피터 슈라이어,알버트 비어만 퇴진
#
# 정답: 자동차 AI,스마트폰,AI비서,음성인식기술
# 예측: I비서,자동차 AI시장,2017년 7억8000만달러,2025년 105억7000만달러,음성형 AI 비서,자율주행,ICT이노베이션스퀘어,연구개발특구진흥재단,스마트폰,음성
#
# 정답: 낮 최고 25도,밤부터 먹구름,내일 전국 비소식,기상청,수도권 충청권 전라권 제주도,낮 기온 20도 내외,일교차 큼,건강관리 유의,미세먼지 청정,동해상 높은 물결,
# 예측:  최고 25도,먹구름,내일 전국 비소식,기상청,미세먼지,전국 맑음
#
# 정답: 김기현,국민의힘,신임 원내대표,기자간담회,국회
# 예측: ,국민의힘,신임 원내대표,기자간담회
#
# 정답: 친환경 셋톱박스,LG화학,KT,ESG 경영,
# 예측: T,LG화학,친환경 셋톱박스 확산,ESG 경영,친환경 임대 단말 생산,업무협약,친환경 임대 단말 생산,2027년까지,2000만대 생산,친환경 임대 단말 생산,
#
# 정답: 윤석열,기 소르망,대통령실 용산이전,대통령집무실,
# 예측: 이미지커뮤니케이션연구원,대통령실 용산 이전,긍정적 결정
#
# 정답: 전통 성년례 재현,남산골 한옥마을
# 예측:  성년례 재현,서울,중구,남산골 한옥마을,가례 의식,족두리 착용
#
# 정답: 코로나19,확진자,추가발생,증가
# 예측: ,코로나19,확진자,18명,추가 발생,확진자 수,확진자 양성판정,소독,사북읍,남면,남면 거주자,역학조사,소독,소독
#
# 정답: 김정섭 공주시장,유구 채석단지 지정,피해 우려
# 예측: 섭 공주시장,채석단지 지정,광범위한 피해 우려
#
# 정답: 국가보훈처,2023년 호국보훈의 달 포상,포상신청
# 예측: 보훈의 달,포상,보훈관서,신청
#
# 정답: 김종민,유병재,전현무,김재희,선을넘는 녀석들,실미도
# 예측: ,김종민,유병재,선넘은 인터뷰,실미도,선녀들,MBC,마스터-X,6회,지옥훈련,실미도 부대,
#
# 정답: 엔하이픈,남성 그룹,Drunke-dazed,앨범 판매량,BORDER : CARNIVAL
# 예측: 하이픈,새 앨범 판매량,초동,4세대 핫 아이콘,BORDER : CARNIVAL,미니 2집,BORDER : CARNIVAL,데뷔 앨범
#
# 정답: 목에 철끈 묶고,난입 프랑스 여성,1028일,프랑스 테니스 단식 준결승,환경단체
# 예측: 오픈,난입,여성,철끈,1028일,환경운동가,1028일
#
# 정답: 블랙핑크,로제,자태,치명적,풀썩
# 예측: 핑크 로제,호텔 침대,풀썩 초미니,각선미,치명적
#
# 정답: 충북,먹깨비,정체기,대대적인 홍보,돌파구,배달앱,활성화 지원사업,수수료,소상인들,가맹점,가입자,주문 건수,상승세,홍보 마케팅,지속 가능한 유통 플랫폼
# 예측: ,먹깨비,홍보,정체기
#
# 정답: 터키,외교장관,김부겸,총리,기념촬영
# 예측:  외교장관,김부겸 총리
#
# 정답: 유라시아 경제통합,광역두만강협력 프로젝트,
# 예측: 두만강협력 프로젝트,유라시아 경제통합 플랫폼 실현
#
# 정답: 당대당 통합,합당,안철수,주호영
# 예측: 당 통합,주호영,국민의힘,안철수,합당,원칙,정강 정책,합당 논의,합당 의사,당명,로고,정강 정책,합당 추진,중도·실용,정강 정책,합당
#
# 정답: 나이벡,노인성 질환,조기 선별인자,발굴,국제학술지,sci급,바이오머티리얼즈
# 예측: 벡,노인성 질환,조기 선별인자 발굴 논문,국제학술지 게재
#
# 정답: ,구해줘 홈즈,이하이,이현우
# 예측: 줘 홈즈,이하이,한강뷰,우울해져
#
# 정답: 반여농산물시장,센텀2지구,풍산이전,대체부지확보,환경영향평가,산업단지
# 예측: 2 산단조성,풍산이전,대체부지,부산시,환경영향평가,산업단지 승인,낙동강유역환경청,협의,산업단지 승인,부산도시공사,부산시,낙동강유역환경청,협의,산업단지 승인,산업단지 승인 절차,부산
#
# 정답: 청문보고서 채택 시한,고위당정청회의,장관 후보자 3명,여야,송영길 대표,유영민 대통령 비서실장,홍남기 국무총리 직무대행,청문 정국,낙마 압박,국민의힘,김부겸 총리 후보자
# 예측: 보고서 채택 시한,오늘 저녁,고위당정청회의,민주당 송영길 대표,윤호중 원내대표,유영민 대통령 비서실장,홍남기 국무총리 직무대행,청와대,기류 변화,야당 낙마 압박,청와대,
#
# 정답: 미래에셋자산운용,연기금 투자풀,출범,주간운용사,경쟁입찰,복수 주간사 체제,투자풀 참여 기금,정부부처 산하 기금,공공기관,통합 운용,계약기간,안정성,수익성,공공성 제고
# 예측: 에셋자산운용,연기금 투자풀 출범
#
# 정답: -> 수출입은행,본부장 선임
# 예측: 은행,상반기 정기인사,본부장 선임
#
# 정답: 시그널플래너,위매치다이사,가전 고장보험 이벤트
# 예측: 플래너,위매치다이사,가전 고장보험 이벤트,이사업체 매칭플랫폼,위매치다이사,가전 고장보험
#
# 정답: 안정환,이혜원,리원,리환
# 예측: ,이혜원,콧날,코성형
#
# 정답: 엔하이픈,켈리 클락슨 쇼,퍼포먼스,인기,미국,
# 예측: 하이픈,켈리 클락슨 쇼,미국 토크쇼,'켈리 클락슨 쇼',
#
# 정답: usa,minnesota,trial,derek chauvin,george floyd
# 예측: aselect,usa,minnesota
#
# 정답: 국회,행안위 전체회의,전해철 장관,행정안전부,서울 여의도,행정안전위원회,출석,발언,공감언론 뉴시스,제보
# 예측: 철 장관,행안위 전체회의,출석
#
# 정답: 금리인하요구권,대출,농협·수협·신협 등 상호금융업권
# 예측: ·수협,대출,금리인하요구권,신용협동조합법 개정안,상호금융업권,중앙회,금리인하 요구권
#
# 정답: 허참,간암 투병,별세
# 예측: 오락관 MC,허참,간암 투병,별세
#
# 정답: 2022 LoL챔피언스코리아,담원 기아,세트스코어,넥서스,프레딧 브리온,라인전
# 예측: 원 기아,7승 신고,3위 재탈환,LCK 아레나,2022 LoL 챔피언스 코리아,프레딧 브리온,세트스코어 2대 0,드래곤 버프로 드래곤 영혼 흡수,드래곤 버프로
#
# 정답: 누모리,촘촘,복수,김주리,무대,경연,극찬
# 예측: 대장,누모리,촘촘,대결,top10,소리꾼들의 전쟁,top10,김주리,조선 그루브 유닛,촘촘,복수,top10,노래꾼들의 전쟁,top10,소리꾼들의 전쟁,
#
# 정답: 우먼스 폰탄카 와플 베얼리 그린',나이키,11일 국내 발매
# 예측: ,폰탄카 와플 베얼리 그린,국내 발매
#
# 정답: kbo,기장 · 보은 · 횡성군,야구센터 운영
# 예측: o,기장 · 보은 · 횡성군,야구센터 운영 협약
#
# 정답: 김효문,klpga,실력을 보여준다
# 예측: 문,klpga,klpga
#
# 정답: 여자 100m,메이저 대회 여자 100m,프레이저-프라이스,세계육상선수권 여자 100m,금매달
# 예측: 레이저-프라이스,여자 100m,우승,10초67,세계육상선수권
#
# 정답: 가산산단 산업단지,산업용지 분양
# 예측: 산단,산업용지,분양,양산시,경남개발공사,분양,분양가,분양 어려움,지역사회,항노화 특화산업단지,분양
#
# 정답: 롯데 자이언츠,5연패 탈출,KBO리그,KIA 타이거즈,17-9 승리,안치홍,딕슨 마차도,8타점,한화 이글스,삼성 라이온즈,연장 혈투,6-5 승리,박정현,끝내기 안타,N
# 예측: ,5연패 탈출,KBO리그,KIA 타이거즈,17-9,5연패 늪,KIA 타이거즈,홈런,폭투,마차도,승부 예측,한화 이글스,SSG랜더스,SSG랜더스,
#
# 정답: 기안84,복근84,다이어트,나 혼자 산다
# 예측: 84,기안84,초콜릿 복근,복근 다이어트
#
# 정답: 민주당,작은 정부론,논쟁,작은 정부,이준석,폐기,여성가족부,통일부
# 예측: ,수명 다한 부처,민주,박근혜 키즈
#
# 정답: 취업자 수,6년 8개월 만에 최대 폭 증가,기저효과,고령층,공공일자리,30대·40대 취업자 수 감소,자영업자 증가,사회복지서비스업,대면서비스업,고용 취약계층,일자리 창출
# 예측: 자 수,기저효과,고령층,공공일자리,취업자 수,취업상황,일자리 창출,일자리 창출
#
# 정답: 정무보좌관 사직,음주운전 징계
# 예측: 도 정무 보좌관 사직,음주운전 징계
#
# 정답: 한국형 예보,기상청,수치예보모델,2023년,상위권,태풍,폭염,장맛비,예측 정확도,세계 2위,영국통합모델,한반도,진로예측,강도예측,고온 예측성,평균 강수 예측정확도,12시간 누적
# 예측: 형 예보,세계 9위 수준,수치예보 기술,세계 2위 수준,태풍·폭염·장맛비 예측 정확도,영국통합모델,한국형 모델 운영 1주년,자체 모델로 수치예보 기술 자립,
#
# 정답: 리듬체조,국가대표 선수,신수지,골프
# 예측: 체조,신수지,골프,미모,심쿵
#
# 정답: 서울랜드,스프링 카니발,봄 축제
# 예측: 랜드,봄 축제,스프링 카니발
#
# 정답: 황교익,자진사퇴
# 예측: 익,자진사퇴,시사
#
# 정답: 이찬혁,뮤직 토크쇼,더 시즌즈-박재범의 드라이브
# 예측:  시즌즈-박재범의 드라이브,전통성,트렌드,뮤직토크쇼,KBS 2TV,새 뮤직 토크쇼,전국 기준 시청률 1.5%,수도권 기준 시청률 2.0%,2049 시청
#
# 정답: 알고 있다는 착각,낯익은 것,낯설게 봐라,질리언 테트
# 예측:  있다는 착각,질리언 테트,어크로스,트럼프,인종학,빅데이터,인공지능,탈
#
# 정답: 사회관계장관회의,유은혜 부총리
# 예측: 관계장관회의,유은혜 부총리
#
# 정답: 아스널,라힘 스털링,미켈 아르테타,영국 hitc,손흥민,토트넘,조세 무리뉴,크로아티아,칼빈 필립스,
# 예측: ,아스널,아르테타,맨시티,라힘 스털링,맨체스터 시티,맨시티,토트넘,해리 케인,칼빈 필립스,토트넘,해리 케인,토트넘,손흥민,토트넘,유로 리뷰,무리뉴 감독,전술,포그바,알렉상드르 라카제트,아스널,
#
# 정답: 윤 대통령,엘리자베스 2세,장례식,조문록
# 예측:  2세 여왕 장례식,윤 대통령
#
# 정답: 위기 속 '숨멎' 동기화,지진희
# 예측: ,위기,숨멎
#
# 정답: 책임규명,대형 압사,군중 유체화
# 예측:  유체화,대형 압사,윗선,책임 규명
#
# 정답: 메신저리보핵산 백신,화이자 회장,백신 외교,문 대통령,한미 협약
# 예측:  협약,백신 외교,문재인 대통령,화이자 회장,접견,한미 글로벌 백신 파트너십 합의,백신 물량,도입,미국 백신 원부자재 기업,싸이티바,백신 물량,부스터샷 시행,5세 어린이,백신 접종
#
# 정답: 충북도,종교시설,특별점검
# 예측: ,방역,종교시설,특별점검
