# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "0"  # Set the GPUs to use

# %%
import os
import re
import random
import warnings
from tqdm import tqdm

import numpy as np
import pandas as pd
import torch

from transformers import (
    AutoConfig, AutoTokenizer, 
    AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq, 
    AutoModelForCausalLM, TrainingArguments, Trainer, DataCollatorForLanguageModeling
)

from peft import PeftModel, PeftConfig

from datasets import load_from_disk

from src.metrics import rouge_for_batch, f1_score_at_k_for_batch, jaccard_similarity_for_batch

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda116.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so.11.0
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 116
# CUDA SETUP: Loading binary /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda116.so...
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/nvidia/lib64'), PosixPath('/usr/local/nvidia/lib')}
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: /usr/local/nvidia/lib:/usr/local/nvidia/lib64 did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('Asia/Seoul')}
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('vs/workbench/api/node/extensionHostProcess')}
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('["/tmp/vscode-ssh-auth-8ffe51ad-1b46-4269-83e7-35eea85c9f7c.sock","/root/.gnupg/S.gpg-agent"]')}
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//matplotlib_inline.backend_inline'), PosixPath('module')}
#   warn(msg)
# /workspace/news-topic-keyphrase-generation-model-dev/.venv/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: Found duplicate ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] files: {PosixPath('/usr/local/cuda/lib64/libcudart.so.11.0'), PosixPath('/usr/local/cuda/lib64/libcudart.so')}.. We'll flip a coin and try one of these, in order to fail forward.
# Either way, this might cause trouble in the future:
# If you get `CUDA error: invalid device function` errors, the above might be the cause and the solution is to make sure only one ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] in the paths that we search based on your env.
#   warn(msg)

# %%
NGPU = torch.cuda.device_count()
NCPU = os.cpu_count()
NGPU, NCPU
# Out:
# (1, 64)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Paths and Names

# %%
### paths and names

TRAIN_DATA_PATH = 'data/model_dev/model_dev_v4_polyglot_1.3b_train.hf'
EVAL_DATA_PATH = 'data/model_dev/model_dev_v4_polyglot_1.3b_eval.hf'

PEFT_MODEL_ID = '.log/eleutherai_polyglot_ko_1.3b_v4_run_13'

# %%
torch_dtype = torch.float16

# %% [markdown]
# # Load PEFT Model & Tokenizer

# %%
peft_config = PeftConfig.from_pretrained(PEFT_MODEL_ID)

# %%
model = AutoModelForCausalLM.from_pretrained(PEFT_MODEL_ID, torch_dtype=torch_dtype, load_in_8bit=True, device_map='auto')
model = PeftModel.from_pretrained(model, PEFT_MODEL_ID, torch_dtype=torch_dtype)
model.eval()
# Out:
# Some weights of the model checkpoint at .log/eleutherai_polyglot_ko_1.3b_v4_run_13 were not used when initializing GPTNeoXForCausalLM: ['gpt_neox.layers.13.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.9.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.7.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.10.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.3.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.8.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.16.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.4.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.1.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.19.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.23.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.14.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.0.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.3.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.12.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.15.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.17.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.7.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.23.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.18.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.6.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.13.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.6.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.22.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.8.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.19.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.4.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.11.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.2.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.11.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.9.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.15.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.21.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.5.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.1.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.12.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.5.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.22.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.20.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.20.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.14.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.0.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.16.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.18.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.2.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.10.attention.query_key_value.lora_B.weight', 'gpt_neox.layers.21.attention.query_key_value.lora_A.weight', 'gpt_neox.layers.17.attention.query_key_value.lora_B.weight']
# - This IS expected if you are initializing GPTNeoXForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPTNeoXForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPTNeoXForCausalLM(
#       (gpt_neox): GPTNeoXModel(
#         (embed_in): Embedding(30005, 2048)
#         (layers): ModuleList(
#           (0): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (1): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (2): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (3): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (4): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (5): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (6): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (7): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (8): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (9): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (10): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (11): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (12): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (13): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (14): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (15): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (16): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (17): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (18): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (19): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (20): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (21): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (22): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#           (23): GPTNeoXLayer(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): MergedLinear8bitLt(
#                 in_features=2048, out_features=6144, bias=True
#                 (lora_dropout): Dropout(p=0.1, inplace=False)
#                 (lora_A): Linear(in_features=2048, out_features=16, bias=False)
#                 (lora_B): Conv1d(16, 4096, kernel_size=(1,), stride=(1,), groups=2, bias=False)
#               )
#               (dense): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#               (act): GELUActivation()
#             )
#           )
#         )
#         (final_layer_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#       )
#       (embed_out): Linear(in_features=2048, out_features=30005, bias=False)
#     )
#   )
# )

# %%
tokenizer = AutoTokenizer.from_pretrained(PEFT_MODEL_ID)

# %%
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30005, 2048)

# %%
model.dtype, model.peft_config.inference_mode
# Out:
# (torch.float16, True)

# %% [markdown]
# # Load Data

# %%
eval_dataset = load_from_disk(EVAL_DATA_PATH)
print(eval_dataset)
# Out:
# Dataset({
#     features: ['id', 'create_date', 'title', 'input_text', 'len_tokenized', 'target_text', 'len_tokenized_target_text', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 3000
# })

# %%
# rand_idx = random.randint(0, len(eval_dataset)-1)
# tokenizer.decode(eval_dataset['input_ids'][rand_idx])
# # tokenizer.decode(eval_dataset['labels'][rand_idx])

# %% [markdown]
# # Generate

# %% [markdown]
# ## CLM

# %%
inputs = eval_dataset['input_text']
inputs = ['[generate keyphrases]' + input_ + '[keyphrases generated]' for input_ in inputs]
labels = eval_dataset['target_text']

# %%
tokenizer.padding_side = 'left'

# %%
generation_args = {
    'do_sample': True, 
    'top_k': 50, 
    'top_p': 0.7, 
    'num_beams': 5, 
    'no_repeat_ngram_size': 3, 
    'num_return_sequences': 1, 
    # 'num_beam_groups': 3,
    'early_stopping': True,
}
generation_args = {}

# %%
batch_size = 12
predictions = None

with torch.no_grad(), torch.autocast("cuda"):
    start = 0
    range_end = len(inputs) if len(inputs) % batch_size == 0 else len(inputs) + batch_size
    for idx in tqdm(range(batch_size, range_end+1, batch_size)):

        tokenized = tokenizer(inputs[start:idx], truncation=False, padding=True, return_tensors='pt')
        tokenized = {k:v.to(device) for k, v in tokenized.items() if k != 'token_type_ids'}

        prediction = model.generate(
            **tokenized, 
            max_new_tokens=64, 
            eos_token_id=tokenizer.eos_token_id, 
            pad_token_id=tokenizer.pad_token_id,
            **generation_args, 
        )
        if predictions == None:
            predictions = prediction.detach().cpu().tolist()
        else:
            predictions.extend(prediction.detach().cpu().tolist())
        start = idx
# Out:
# 100%|██████████| 250/250 [32:18<00:00,  7.75s/it]

# %%
tokenizer.encode('[keyphrases generated]')
# Out:
# [30004]

# %%
predictions_only = []
for prediction in predictions:
    idx = prediction.index(30004)
    predictions_only.append(prediction[idx+1:])

# %%
predictions_decoded = tokenizer.batch_decode(predictions_only, skip_special_tokens=True)

# %%
for prediction_decoded, label in zip(predictions_decoded, labels):
    print(label)
    print(prediction_decoded)
    print()
# Out:
# 보드게임콘; 2023 보드게임콘; 국내 최대 보드게임 축제; SETEC; 자유롭고 다채로운 행사; 최대 할인율; 국내외 유명 보드게임 600여 종; 무료 체험; 작가존; 대학교 동아리존
# 보드게임콘; 2023 보드게임콘; SETEC; 자유롭고 다채로운 행사; 최대 할인율; 보드게임; 작가존; 대학교 동아리존; 무료 체험; 사전등록; 포토존; 현장 이벤트; 가족; 친구; 연인; 남녀노소 다양한 사람들; 보드게임을 즐기는 사람
#
# 벤제마; 레알 마드리드; 발롱도르 수상자; 라리가 득점왕; UCL 득점왕; 더블 우승; 선수 계약 연장; 재계약 합의; 이번 시즌 출전; 스타 엘링 홀란드
# 벤제마; 레알 마드리드; 1년 연장; 구두 합의; 2022 발롱도르 수상자; 유럽축구연맹(UFEA) 챔피언스리그(UCL); 득점왕; 리그에서 활약; 엘링 홀란드; 1년 더 계약 연장; 주장인 벤제마와 레알은 1년 더
#
# 50억 클럽; 특검법안; 국회; 법제사법위원회; 상정; 정의당; 원내대변인; 김도읍 법사위원장; 국민의힘; 주호영 원내대표
# 국회 법사위; 50억 클럽; 특검법안; 상정; 정의당; 원내대변인; 국민의힘; 주호영; 원내대표; 논의; 검찰 수사; 패스트트랙; 진실규명; 사법 정의; 법사위 안건 지정; 신속처리 안건; 검찰 수사; 진실 은폐; 윤석열 정치 검찰; 증인 보호; 진실 은폐
#
# 박현주 회장; 미래에셋그룹; 배당금 전액 기부; 미래에셋자산운용; 누적기부액; 이 땅의 젊은이들을 위해; 미래에셋박현주재단; 인재 육성 프로그램; 사회복지 사업; 나만의 책꿈터 지원
# 박현주 미래에셋 회장; 배당금 전액 기부; 미래에셋자산운용; 박현주 미래에셋그룹 회장; 2010년부터; 미래에셋에서 받은 배당금; 2010년부터; 미래에셋박현주재단; 미래에셋희망재단; 인재 육성 프로그램; 미래에셋해외 교환 장학생;
#
# 집권여당; 원내대표; 윤재옥; TK 정치권; 구심점; 꼼꼼함; 치밀함; 구원투수; 주호영 전 원내대표
# 윤재옥; 원내대표; TK 정치권; 협상 분위기; 경찰 출신; 의정 활동; 드루킹 특검법; 대선; 여당 지도부; 신공항 건설; 특별법; 원내대표 선출; TK 홀대론; 원내대표 인선; 국회 본회의 통과; 의정 활동; 원내대표 후보군; 원내수석부대표; TK 신공항
#
# 산불; 서천; 진화; 대원; 산불방지대책본부; 충남; 바람; 불법 소각행위; 건조주의보; 순간풍속
# 산불; 충남; 천안; 대피; 산림청; 진화; 산불방지대책본부; 건조주의보; 불법 소각행위 단속; 제보; 제보로 세상을 바꿉니다; 산림청; 충남권 대부분 지역; 건조주의보; 산림으로부터 100m 이내의 농업부산물 및 쓰레기 소각 등 불법 소각행위 단속;
#
# 손흥민; 토트넘; 풋볼 레퓨테이션 어워즈; 세계스포츠협회; 수상자; 유럽 축구계; 프리미어리그; 득점왕; 아시아 최고의 축구 선수; 유엔 세계식량계획
# 손흥민; 토트넘; 풋볼 레퓨테이션 어워즈; 세계스포츠협회; 수상; 프리미어리그; 선수; 지도자; 심판; 유엔 세계식량계획; 글로벌 친선대사; 온실가스 배출량; 친환경적인 활동; 경제 관련 기여; 빈곤 문제 해결; K리그 명예의 전당; 어드바이저 차두리
#
# 신상출시 편스토랑; 남보라; 13남매 장녀; 대가족; 반찬 만들기; 식재료; 배우; 대용량 요리; VCR; 편셰프 도전기
# 남보라; 13남매 장녀; 기본이 10인분; 김밥 50줄; 대용량 요리; 반찬 만들기; 자연스러운 요리법 개발; 동생들과 부모님 집으로 반찬 배달; 스페셜MC 아이브 이서; KBS 2TV ‘신상출시 편스토랑’; 편셰프 남보라;
#
# 큐텐; 인터파크 커머스; 위메프; 인수; 합병; e커머스; 지각변동; 야놀자; SPA; 1500억 규모
# 큐텐; 티몬; 인터파크; 위메프; 인수합병; e커머스; 지각변동; 인수 금액; 쇼핑; 도서 부문; 인수합병 계약; 경영권 매각; 자금 수혈; 경영권 인수; 직구·역직구 전문 플랫폼; 해외 직구·역직구 전문 플랫폼; 국내·외를 아우르
#
# 오타니; 투타 겸업; WBC; B조 MVP; 타율 0.500; 4이닝 완벽투; 일본 대표팀; 전승; OPS 1.684; 8강전
# 오타니 쇼헤이; WBC B조 MVP; 타율 0.500; 4이닝 완벽투; 일본 대표팀; 전승으로 8강; 타자로는 타율 0.500 1홈런 8타점 5득점 OPS 1.684; 투수로는 중국전 1경기 등판; 이탈리아전에 선발투수로 마운드
#
# LG엔솔; 애리조나 공장; 투자; LFP 배터리 공장; ESS LFP; 규모; 북미 생산 네트워크; 생산능력; 북미 지역; 전용 배터리
# LG에너지솔루션; 미국 애리조나; 원통형; ESS; 배터리 공장; 생산능력; 투자금액; 생산규모; 배터리 독자 생산 공장; 글로벌 생산기지; 북미지역; 전기차; ESS 전용 배터리 생산 공장; 글로벌 생산 역량; 제품 경쟁력; 차별화된 글로벌 생산 역량; 북미지역 내 생산기지
#
# 박치기; 셀틱 위민; 레인저스 위민; 스코틀랜드 위민 챔피언십 그룹; 승점 57; 승점 56; 프랜 알론소; 크레이그 맥퍼슨; 뒷통수; 아수라장
# 박치기; 셀틱 위민; 레인저스 위민; 스코틀랜드 위민 챔피언십 그룹(1부)리그; 무승부; 감독; 크레이그 맥퍼슨; 스카치스포츠; 비난; 선수; 훈련법; 독일식; 경기 후 축하; 박치기; 비난; 경기 후 축하; 스카치
#
# 효성티앤씨; 친환경; 스판덱스 브랜드; 크레오라; 바이오베이스드; 리젠; 크레오라 바이오베이스드 블랙; 크레오라 리젠 블랙; SGS; 에코 프로덕트 마크
# 효성티앤씨; 친환경 블랙 스판덱스; 크레오라 바이오베이스드; 리젠; 크레오라 리젠 블랙; 크레오라 바이오베이스드 블랙; 크레오라 리젠 블랙; 크레오라 리젠 블랙; 지속가능성; 기능성; 글로벌 바이어들; 친환경 섬유 메이커
#
# 이상민 탄핵; 이태원 참사; 책임; 헌재; 재판; 국회; 소추위원; 증거; 쟁점; 공무원법상 성실의무
# 이상민 탄핵; 행정안전부 장관; 이태원 참사; 탄핵 심판; 국회; 소추위원; 대리인; 변론 절차; 쟁점; 증인 채택; 국가의 기본적 인권 보장 의무; 파면 결정; 공무원이 될 수 없다; 파면 결정; 공무원이 될 수 없다; 파면 결정; 파면 결정
#
# 세비야 FC; 카디스 CF; 승리; 2022/23시즌 스페인 프리메라리가; 선제골; 후반; 라키티치; 힐; 오캄포스; 엔 네시리
# 세비야 FC; 카디스; 승리; 세비야; 카디스에 위치한 에스타디오 누에보 미란디야; 2022/23시즌 스페인 프리메라리가 27라운드; 세비야 FC; 엔 네시리; 힐; 오캄포스; 상대 진영 중앙; 골망; 후반; 후반
#
# 충남 아산; 폐공장; 화재; 진화; 폐자재; 발화 지점; 포크레인; 동원; 밤샘 작업; 폐전선
# 충남 아산; 폐공장; 화재; 진화; 포크레인; 폐자재; 철거 작업; 불씨; 완진; 수일; 대응 단계; 포크레인; 소방당국; 인력; 장비; 화재 진압 작업; 포크레인; 폐자재 등 제거; 포크레인 동원; 화재 현장; 소방당국; 포크레인
#
# 런닝맨; 필리핀; 팬미팅; 열기; 케이팝 그룹; 베트남; 관심; SNS; 복싱 영웅; 매니 파퀴아오
# 런닝맨; 필리핀; 팬미팅; 케이팝 그룹; 유재석; 지석진; 김종국; 양세찬; 전소민; 아시아 아레나 SM몰; 케이팝 그룹; 팬미팅; 리메이크 프로그램; 현지 팬미팅; 추가 공연; 베트남; 말레이시아; 케이팝 그룹; 유재석; 지석진;
#
# 성스러운 아이돌; 김민규; 고보결; 고백; 입맞춤; 램브러리; 김달; 신성력; 사감재; 선택
# 성스러운 아이돌; 김민규; 고백 키스; 고보결; 김달; 사감재; 신의 자리; 거짓; 김달의 진심; 램브러리; 어장관리; 물고기처럼 어장에 날 가둬놓고 말만 사랑한다고 하면서 밑밥 주면서 일부러 신성력 유지시키
#
# 이찬원; 옥탑방의 문제아들; MC; 민경훈; 송은이; 김숙; 김종국; 정형돈; 퀴즈 프로그램; KBS2
# 이찬원; 옥탑방의 문제아들; MC; KBS2; 예능; 송은이; 김숙; 김종국; 정형돈; 민경훈; 트로트 대세; 예능감; 최연소 막내 멤버; KBS의 아들; 색다른 케미; KBS의 아들다운 탁월한 예능감; 색다른 케미를 선보일
#
# 증시 풍향계; 미국 소비자물가지수(CPI); 연방준비제도(Fed); 연방공개시장위원회(FOMC); 코스피; 코스닥; 인플레이션; 기준금리 인상; 영업이익; 어닝 시즌
# 미국; 물가; 실적; 경기 침체; 코스피; 코스닥; FOMC; CPI; 실적 발표; 어닝 시즌; 영업이익 전망치; NH투자증권; 개별 종목; 코스피 변동폭; 변동성; 경기 침체 우려; 실적 개선 기대; 코스피 변동폭; FOMC 의사록; 미국 3월 소비자
#
# 미국 지역기반 중소형은행주; 유동성 위기; 퍼스트리퍼블릭 주가; 은행주; 실리콘밸리은행(SVB); 매각 입찰; 대형은행들; 예금; 한 달새; 상승 안정세
# 미국 지역 기반; 중소형 은행주; 퍼스트리퍼블릭은행; 유동성 위기; SVB 파산; 뉴욕커뮤니티뱅코프; 주가 폭락; 은행주 주가 변동성; UBS 인수; 크레디트스위스 인수; 은행주에 대한 낙관적인 전망; 투자은행 KWB(Keefe
#
# 전광인; 최태웅 감독; 대한항공; 챔피언결정전; 현대캐피탈; 한국전력; 플레이오프; 선수들; 열정; 경기
# 최태웅 감독; 전광인; 챔피언결정전; 대한항공; 정규리그; 플레이오프; 김명관; 이시우; 이시우; 허수봉; 링컨; 정지석; 열정; 경험; 데이터; 링컨 이 아닌 정지석을 잡으러 갈 것이다; 정지석; 챔피언결정전; 현대캐피탈
#
# 신고리 4호기; 원전 80km 밖 주민; 대법원 판단; 운전 허가; 원고 패소; 비판; 대법원 상고 기각; 환경적 이익; 발전소; 대규모 소송
# 대법원; 원전; 신고리 4호기; 허가; 정당; 80km 밖; 원고적격; 피해; 소송; 방사선환경영향평가; 80km 이내 지역; 환경상 침해; 환경상; 환경적 이익; 환경적 이익 침해; 환경상 침해; 환경상 침해; 환경상 침해; 환경상
#
# 산불 완진; 인왕산; 화재 진압 활동; 종로구; 소방당국; 낙엽; 잔불; 인명피해 없음; 경찰; 특별감시체계
# 산불; 완진; 경찰; 소방; 화재원인; 합동조사; 인명피해; 대피; 잔불; 소방당국; 조사; 헬기; 인력 배치; 특별감시; 서울 종로구; 소방당국; 합동 조사; 화재 원인; 소방당국; 경찰; 소방당국; 인력 배치; 잔불 정리;
#
# 나폴리; 토리노 원정; 승리; 이탈리아; 세리에A; 포메이션; 오시멘; 선제골; 흐비차; 추가골
# 나폴리; 토리노; 이탈리아 세리에A; 빅터 오시멘; 득점; 포효; 나폴리 공격수; 빅터 오시멘; 김민재; 세리에A; 경기; 승점; 후반; 득점; 후반 23분; 후반 23분; 후반 23분; 후반 23분; 후반
#
# 부상 투혼; 박형식; 정웅인; 눈치싸움; tvN; 청춘월담; 왕세자; 이환; 조원보; 살수들
# 부상 투혼; 왕세자 이환; 조원보; 정적; 조원보; 살수들; 외척세력; 한성온; 삼정승; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 연기력; 월화드라마; 월화드라마; 월화드라마; 월화드라마; 월화드라마
#
# 손흥민; 토트넘; 감독; 브렌던 로저스; 레스터 시티; 포메이션; 해리 케인; 자유인; 선발 라인업; 크리스티안 스텔리니
# 손흥민; 토트넘; 감독; 레스터 시티; 경질; 선발 라인업; 포메이션; 수비; 선발 11명; 스텔리니 감독대행; 프리미어리그 4위; 남은 경기; 최선을 다하겠다; 스텔리니 감독대행; 4위; 에버턴 원정 경기; 크리스티안 스텔리
#
# 양산시립도서관; 올해의 책; 선정된; 신의 그릇; 저자 만남 행사; 책 소개; 국악 공연; 도자 문화; 내달 22일; 시민과의 만남
# 양산시립도서관; 올해의 책; 신의 그릇; 저자 만남 행사; 올해의 책 일반 부문; 신한균; 국악 공연; 도자 문화; 북토크 시간; 사기장의 애환; 역사·예술 소설; 일본의 도자 사에 미친 우리나라의 영향; 시민들의 많은 관심과 참여;
#
# 알바레스; 맨체스터 시티; 연장 계약; 이적시장; 이적료; 시즌; 과르디올라 감독; 아르헨티나 대표팀; 트로피; 별명
# 알바레스; 맨체스터 시티; 계약 연장; 이적료; 펩 과르디올라 감독; 득점 능력; 리오넬 메시; 최전방; 거미줄; UEFA 챔피언스리그; 트로피; 영상; 그림; 계약 연장 영상; UCL 역사상 세 번째 기록; 홀란드; 이적료;
#
# 강남 학원가; 마약 음료; 경찰; 100병 준비; 약 10병 유포; 고교생; 검거; 실제 나눠 준 것; 30병 회수; 자체 폐기
# 경찰; 강남 학원가; 마약 음료; 100병; 약 10병; 유포; 회수; 고교생; 마약류관리법 위반; 용의자 검거; 필로폰 성분; 음료 시음 행사; 피의자들의 진술; 추가 유포 여부; 추적 수사; 자녀 몸 이상; 음료 회수; 피의자 검거; 마약 음료
#
# 킬링 로맨스; 이선균; 이하늬; 배신; 큰일; 제작보고회; 롯데시네마; 작품; 감독님; 선택폭
# 킬링 로맨스; 이선균; 이하늬; 서로 배신; 작품 참여; 섬나라 재벌; 조나단; 운명적 사랑; 톱스타 여래; 팬클럽 3기 출신 사수생 범우; 컴백 작전; 작품 참여; 개봉; 섬나라 재벌 조나단; 운명적 사랑; 톱스타 여래;
#
# 이금민; 생일; 두 골; 대한민국 여자 축구대표팀; 이마트 초청 여자축구 국가대표팀 친선경기; 잠비아; 역전 결승골; 박은선의 높은 제공권; 월드컵; 대처; 각오
# 이금민; 생일; 대한민국 여자 축구대표팀; 잠비아전; 득점; FIFA 랭킹; 박은선; 제공권; 후반; 평가전; 후반 활약; 박은선의 높은 제공권; 후반 활약; 체력; 신체; 정신적 준비; 후반 활약; 후반 활약; 후반 활약; 후반 활약
#
# 전두환; 손자; 5·18 재단; 사죄; 도와달라; 광주; 반성; 5·18 기념 재단; 계엄군; 5·18 민주화 운동
# 전두환; 손자; 5·18 재단; 사죄; 광주; 도움; 5·18기념재단; 인스타그램; 사회관계망서비스; 피해자분들; 진심어린 사과; 5·18공법3단체; 항공편 일정표; 유가족; 사과; 5·18기념재단; 5·18민주
#
# 이상민; 소개팅; 데이트; 상대; 시장; 횟감; 킹크랩; 개인기; 고백; SBS
# 이상민; 소개팅; 데이트; 노량진 수산시장; 회; 킹크랩; 회감; 개인기; 회심의 고백; SBS; 미운 우리 새끼; 궁상민 모드; SBS 제공; SBS 제공; 궁상민의 면모; 회감; 개인기를 빙자한 회심의 고백; 궁
#
# 드림; 박서준; 아이유; 홍대; 열정리스; 축구단; 꿈; 포스터; 예고편; 개봉
# 드림; 박서준; 아이유; 국가대표; 꿈; 축구; 홈리스 축구단; 환장의 케미스트리; 이병헌 감독; 오합지졸 국대 선수들; 개봉; 이병헌 감독; 박서준; 이지은; 김종수; 고창석; 정승길; 이현우; 양현
#
# 국회미래연; 청년; 공공정책 결정; 참여 비율; 정책 설계자; 미래인식; 집중 인터뷰; 기대; 회의적; 일자리
# 국회미래연; 공공정책 결정 과정; 2030 참여 비율; 청년 세대; 미래에 비관적; 의사 결정; 일자리와 주거 문제; 성장의 기회; 정책 설계자; 정책 설계의 장; 정책 결정 과정; 경쟁지상주의; 갈등 조장; 수도권 집중; 대안; 미래정책의 국민선호 연구
#
# 박홍근; 더불어민주당; 원내대표; 장시간 노동제; 역주행; 대통령; 고용부; 시간표; 논란; 국민 문제
# 박홍근; 주 69시간; 장시간 노동제; 역주행; 대통령 말 한마디; 손바닥 뒤집듯; 고용노동부; 노동시간 개편안; 국민 삶; 윤석열 정부; MZ세대; 주69시간제; 원점 재검토; 철회; MZ세대; 국민 문제; 윤석열 정부; 노동시간제;
#
# 장광; 사위; 김태현; 독점; 책임; 노후; 먹방; 유튜브; 코미디언; 결혼
# 장광; 김태현; 장인; 한 마디; 노후 책임 질 것; TV조선; 허영만의 백반기행; 악역 계보; 악역; 먹방 콘텐츠; 사위 자랑; 노후 책임 질 것; 개그맨 김태현; 미자; 먹방 콘텐츠; TV조선; 허영만의 백반기행; 사위 자랑
#
# 카카오게임즈; 벨루가; 치매 관련; 기능성 게임; 공동 연구; 진단; 예방; 관리; 인지기능 측정; 인공지능
# 카카오게임즈; 벨루가; 치매 관련 기능성 게임 공동 연구; 업무 협약식; 인지기능 측정; 치매의 진단; 예방; 관리; 인공지능 기반 기술; 디지털 치료제; 게임 개발력; 글로벌 서비스 노하우; ESG(환경·사회·지배구조) 관련 조직; 장애인 게임 접근성 향상; 보조
#
# JMS; 정명석; 성범죄; 세뇌 교육; JMS 활동가; JMS 피해자 모임; 사이비; 범죄단체; 은밀하게 이뤄진다; 콘크리트 신도들
# JMS; 성범죄; 세뇌 교육; 정명석; 여신도; 성폭행; 자궁; 낙태; 콘크리트 신도들; 합동 결혼식; JMS 탈퇴; 월명동 자연성전; 압수수색; 교단 관계자들; 정명석의 범행을 감추려한 교단 관계자들; JMS 탈퇴; 월명동 자연성전;
#
# 벚꽃주말; 기온; 한파주의보; 내륙지역; 내일 아침기온; 서리; 얼음; 꽃샘추위; 경기 남양주시; 강원 횡성군
# 벚꽃주말; 기온; 내륙 3월 '한파주의보'; 꽃샘추위; 기상청; 경기 남양주시; 양평군; 강원 횡성군; 충북 괴산군; 영동군; 충주시; 진천군; 장수군; 무주군; 진안군; 무주군; 장수군; 충북 음성군; 음성군; 충북 진안군;
#
# 중증 응급환자; 적정 시간 내에 응급실 도착 못 해; 응급실; 국회 보건복지위원회; 최혜영 의원; 국립중앙의료원; 질환별 적정시간; 중증 외상환자; 미도착률; 골든타임
# 중증 응급환자; 적정시간 내에 응급실 도착; 응급실 미도착률; 응급실 적정시간; 심근경색; 뇌졸중; 중증 외상환자; 응급실 적정시간; 응급실 미도착률; 중증 외상환자의 적정시간; 응급실에 제시간에 도착하지 못한 환자들의 비율; 응급실에
#
# PCR; KAIST; 현장진단; 초고속; 초소형; 시스템; 코로나19; 나노; 마이크로; 열 순환기
# 병원가지 않아도; PCR; 초고속; 초소형; 현장진단; 바이러스 감염여부; 나노종합기술원; 오상헬스케어; 마이크로 나노기술; 대면적; 금속박막 카트리지; 마이크로렌즈 어레이 형광 현미경; 마이크로렌즈 어레이 형광 현미경; 초근
#
# 박수홍; 횡령 혐의; 기소; 출석; 취재진; 변호인; 수임료; 명란김; 남은 재산; 유명 기획사
# 박수홍; 변호사 선임; 재산 실체; 명란김 여섯 봉지; 친형 부부; 서울남부구치소; 무죄 주장; 출연료; 프로그램; 선후 관계; 리스크 관리; 유명 기획사; 박수홍 부부에 대한 안타까움; 선의로 돕는 사람들; 박수홍 부부에 대한 안타까움; 유명 기획사 리스크 관리
#
# 태백시; 공무원; 결원; 경력경쟁; 임용; 직원; 질병휴직; 명예퇴직; 부서별 인력난; 야근
# 태백시; 결원; 경력직; 35명; 신규 임용; 45명; 부족; 인력확충; 공무원; 경쟁; 선발; 추가 결원; 보건소장; 공모; 연령제한 완화; 보건소장 공모; 결원; 부족; 인력확충; 신규 공무원 채용; 부족한 인력; 보건
#
# 고려대; 천원의 아침밥; 학생 식당; 인원 제한; 취지; KUPC; 기금; 자체 운영; 통합 운영; 학기 중
# 고려대; 천원의 아침밥; 학생 식당; 농림축산식품부; 농림수산식품교육문화정보원; 국내 쌀 소비 촉진; 대학생들의 아침밥 문화 확산; 마음든든 아침; 네티즌들의 호평; 졸업생들의 소액 기부 캠페인; 마음든든 아침 프로그램; 선배들의 기부금
#
# 한일 재계; 미래 파트너십 기금; 일제 강제징용 배상 소송; 일본 기업들; 참여 여부; 명확한 입장; 전국경제인연합회; 전경련; 일본경제단체연합회; 기금 조성 방안
# 한일 재계; 미래 파트너십 기금; 일제 강제징용 배상 소송; 피고 일본 기업들; 전경련; 일본경제단체연합회; 게이단렌; 한일; 일한; 공동 사업; 연구; 젊은 인재의 교류; 강제징용 배상 소송의 피고 기업들; 기금 조성 방안; 한일 양국의
#
# 딜리버리맨; 신이준; 학폭; 연기; 최미라; 출연; 중심; 최하율; 악역; 연기력
# 딜리버리맨; 신이준; 학교 폭력 가해자; 최미라; 일진 연기; 서영민; 학교 폭력; 연기; 딕션; 안정적인 톤; 연기 임팩트; 연기력; 악역 연기; 학교 폭력 가해자; 최미라 역; 학교 폭력 피해자; 학교 폭력 가해자; 연기력; 악역 연기
#
# 5G 중간요금제; 이동통신; 데이터; 요금제; 협의; LG유플러스; 시니어 요금제; 통신비; 과기정통부; 최근 공개 토론회
# 5G 중간요금제; 데이터 40~100GB 구간; 이동통신사; 요금제; 소비자 사용량; 비례 원칙; 세분화; 이동통신 서비스; 시니어 요금제; 경쟁 활성화; 신규 사업자 발굴; 요금은 내려올 수 있다; 경쟁 활성화; 요금은 내릴 수 있다; 이동통신사; 요금제
#
# 벚꽃; 봄; 여의도; 석촌호수; 노마스크; 영등포구; 인파; 마스크; 롯데월드; 안전 관리
# 벚꽃; 여의도; 석촌호수; 노마스크; 봄; 인파; 마스크; 봄나들이; SNS; 벚꽃축제; 안전관리; 방문객; 축제 기간; 안전관리; 석촌호수 진출입로 관리; SNS에 올라온 게시물[keyphrases generated]벚꽃; 여의도; 석촌호수; 노마스크; 봄
#
# 고학수; 개인정보보호위원장; 데이터 활용; 기업 서비스 개발; 산업 생태계; 인공지능; 한국 개인정보 정책; 신기술; 유럽연합; 프라이버시 쟁점
# 고학수; 개인정보보호위원회; 데이터 활용; 기업 서비스 개발; 실리콘밸리; 현지 데이터 산업; 인공지능 분야; 세계 석학; 대니얼 호; 스탠포드 대학교 초청 세미나; 개인정보 처리 관련 사업 활동; 신기술; 개인정보 보호법 개정 내용; 행정처분 사례; 민관협력 자율규제;
#
# SK텔레콤; AI 안부 든든 서비스; 인공지능 기술; 통신 빅데이터; 사회적 고립가구; 안전문제; 통신; NUGU bizcall; 안전체계; 고립가구 지원 정책
# SKT; AI 안부 든든 서비스; 사회 안전망 강화; 인공지능; 통신 빅데이터; 안전문제 해결; 고립가구; 안전체계 강화; 서울시 고립가구 지원 정책; 원격검침이 가능한 AMI; 돌봄 대상자 선정과 돌봄 대상자를 위한 조치; ESG 경영; ESG 경영에 앞장서기 위해 최선을
#
# 에이티즈; 윤호; 생일; 전광판; 축하; 팬앤스타; 도쿄; 광고; 서포트; 메시지
# 에이티즈; 윤호; 생일; 전광판; 팬들; 서포트; 팬앤스타; 전광판 광고; 스페셜 애즈; 글로벌 애즈; 영상 제작; 제보; 더팩트; 팬앤스타; 전광판 서포트; 팬들의 응원 메시지; 전광판 영상; 팬앤스타에는 팬들의
#
# 디바; 가수 현미; 향년 85세; 밤안개; 팬들; 자택; 병원; 노래 교실 공연; 중저음을 가진 재즈풍 보컬; 생이별을 했습니다
# 가수 현미; 별세; 디바; 밤안개; 노래 교실; 대구; 밤안개; 떠날 때는 말 없이; 몽땅 내 사랑; 몽땅 내 사랑; 보고 싶은 얼굴; 전쟁 이후 상처받은 국민; 실향민 1세대; 미국에 살고 있는 두 아들; 목소리
#
# 5·18기념재단; 전두환 전 대통령의 손자 전우원; 광주 방문; 학살자; 피해자들에게 사과; SNS 메시지; 유족회·부상자회·공로자회; 5·18 민주묘지 참배; 추모승화공간 방문; 인스타그램
# 5·18기념재단; 전두환 손자; 광주 방문; 전우원; 인스타그램 계정; 연락; 광주 5·18기념재단; SNS; 사과; 피해자들; 5·18민주묘지; 광주민주화운동; 유가족; 정신적 피해; 5·18 기념 문화센터; 5·18 기념
#
# 외부 진료; 구치소 수용자; 교도관; 폭행; 경찰 조사; 보호장비; 직장인 소셜플랫폼 블라인드; 수원구치소; 공권력; 복역 중인 A씨
# 외부진료; 폭행; 경찰 조사; 교도관; 외부진료; 외부진료 중; 외부진료 나왔다가 폭행; 112 신고; 스마트이미지; 외부진료 나왔다가 폭행; 보호장비; 교도관 폭행; 보호장비; 교도관 폭행; 외부진료 나왔다가 폭행; 보호장비; 교도관 폭행; 외부
#
# 아이엠; 몬스타엑스; 솔로앨범; LP; 등장일; 듀얼리티; 이중성; 아이튠즈; 앨범 차트; 글로벌 팬들
# 몬스타엑스; 아이엠; 솔로앨범; LP; 발매; 글로벌 팬들; 성공적인 첫 솔로 활동; 벅스 실시간 음원 차트; 멜론 최신 24hits 차트 상위권; 글로벌 팬들의 사랑; 자체 콘텐츠 '몬 먹어도 고'; 몬베베(공식 팬클럽명)
#
# 생산; 소비; 투자; 반도체 부진; 제조업 생산; 서비스업 생산; 대면 업종; 운수창고 숙박음식; 소매판매; 설비투자; 동행종합지수
# 생산; 소비; 투자; 생산; 소비; 투자; 서비스업; 제조업; 서비스업; 제조업 생산; 서비스업 생산; 선행종합지수; 소비자심리지수; 기업심리지수; 광공업 생산; 자동차 생산; 설비투자; 건설기성액; 선행종합지수 순환변동치; 선행종합지수 하락; 선행종합
#
# 로봇 동화; 알마; 스타니스와프 레이; SF; 공상과학; 삶; 미덕; 존재론적 관점; 죽음; 그로운
# 로봇 동화; 그로운; 삶; 미래; 삶의 교훈; 웃음; 삶의 지혜; 농담; 강간과 학대; 성차별; 그루밍 성폭력; R. 켈리; 코리 필즈; 살인 용의자; 잭슨; 취약성; 탈출구; 삶의 교훈; 웃음; 삶의 지혜; 성적
#
# 잡월드; 국민 참여 예산; 청소년 체험관; 스마트팜 랜드; 빅데이터 분석가; 스마트팜 농업기술자; 빅데이터랩(Big Data Lab); 정보통신기술(ICT); 농·축산업 기술자; 스마트 축사 시설
# 잡월드; 빅데이터 분석가; 스마트팜 체험; 국민 참여 예산; 직업인; 빅데이터 랩; 스마트팜 랜드; 데이터 분석가; 스마트팜 농업기술자; 농축산 분야; 스마트 축사 시설; 자동화 기술; 4차 산업혁명 시대; 체험 콘텐츠; 직업 정보; 체험 콘텐츠;
#
# 수젠텍; 디지털 헬스케어 플랫폼; 슈얼리 스마트; 미국 식품의약국(FDA) 허가; 여성 호르몬; 모바일 앱; 세계 펨테크 시장; 인류 절반이 여성; 77조 전망; 체외진단
# 수젠텍; 디지털 헬스케어; 플랫폼; FDA; 허가; 여성 호르몬; 모바일 앱; 완경 듀오; 체외진단 의료기기; 펨테크 제품; 여성호르몬 측정; 글로벌 마켓 인사이츠; 제약·바이오 기업; 주가; 거래량; 바이오 기업; 주가 상승; 거래량 상승; 제약
#
# 런닝맨; 전소민; 유재석; 에피소드; 순천 딱지치기 캠핑; 시청률; 캠핑; 조개 술찜 만들기; 홍합 게임; 딱지치기
# 런닝맨; 레전드; 에피소드로 큰 웃음; SBS; 순천 딱지치기 캠핑; ‘우당탕탕’의 연속; ‘젊은이 게임’; ‘방귀 게임’; ‘최고의 1분’; ‘최고의 1분’; ‘최고의 1분’; ‘최고의 1분
#
# 의뢰인; 대학교; 수능; 의과대학; 수학; 진로; 꿈; 자신감; 직업; 조언
# 의뢰인; 의대생; 서울대 수학과; 수능; 수학 강사; 서울대 수학과; 자신감; 서장훈; 이수근; 의뢰인 맞춤 조언; KBS Joy; Skylife 1번; SK Btv 80번; LG U+tv 1번; KT olleh tv 41번; KBS
#
# 기획사 사기; 금잔디; 마홍도; 아이돌 데뷔; 금강산; 경찰 신고; 걸그룹; 소리치며 반항; 싱글대디; 옥미래
# 기획사; 사기; 금잔디; 마홍도; 기획사; 아이돌; 데뷔; 보증금; 경찰; 신고; 금잔디의 반항; 가족들의 이야기; 연기력; 배우들의 열연; KBS 1TV 일일드라마; 가족들의 이야기; 탄탄한 연기력; 연기력; KBS 1TV 일일드라마; 금
#
# 삼성전자; 비스포크 제트 AI; 초강력 청소; 더 제트 워크; 흡입력; 인공지능; 대용량 배터리; 자율주행; 해양 폐기물 업사이클링 패션 브랜드; 지속가능한 일상
# 삼성전자; 비스포크 제트 AI; 2023년형 청소기; 최대 280와트(W) 흡입력; 3천970밀리암페어(mAh)의 대용량 배터리; 자율주행 로봇 청소기; 해양 폐기물 업사이클링 패션 브랜드; 재활용 페트병들로 만든 샹들리에; 청정스테이션;
#
# 던전 앤 드래곤; 도적들의 명예; 액션 어드벤처; 블록버스터; 롤플레잉 액션 어드벤처 무비; 보도스틸; 바드 에드긴; 홀가; 영주 포지; 소피나
# 던전 앤 드래곤: 도적들의 명예; 액션 어드벤처 블록버스터; 도적들의 위기; 유쾌한 팀플레이; 롤플레잉 액션 어드벤처 무비; 2차 보도스틸; 액션 어드벤처 블록버스터; 롤플레잉 액션 어드벤처 무비; 액션 어드벤처 블록버스터; 액션 어드벤처 블록버스터; 액션
#
# 눈썹 결; 메이크업; 내추럴; 고급스러운; 블랙핑크 지수; 뉴진스 다니엘; 브로우 픽서; 한 올 한 올; 스크류 브러쉬; 대표적으로
# 눈썹 결; 내추럴 메이크업; 눈썹 결 연출; 눈썹; 눈썹; 뉴진스; 메이크업; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹; 눈썹;
#
# 백제시대; 지방세력; 고분군; 백제한성기; 발견; 고대사 연구; 평가; 고분; 부장품; 대규모 고분
# 세종시; 백제 한성기; 고분군; 한솔동; 전의면; 백제시대; 지방세력; 독립적으로 활동; 중요한 자료; 고분군; 대형 고분군; 적석분 내부; 부장품; 환두대도; 역사 공원화; 매장문화재 지정 추진; 역사 공원화; 고분
#
# 인천공항; 실탄; 몽골 남성; 수하물; 100발; 22구경 권총탄; 50발씩 2개 상자; 경찰; 국군방첩사령부; 합동조사
# 인천공항; 실탄; 몽골 남성; 수하물; 경찰; 국군방첩사령부; 합동조사; X-ray 검사; 실탄 발견; 출국 조치; 안보위해물품; 필리핀 마닐라; 70대 남성; 미국 라스베이거스; 인천국제공항 경유하는 과정에서 실탄 발견; 경찰과 국군방첩사령부
#
# 신예은; 런닝맨; 예능 인재; 맑눈광 댄스; 강훈; 꽌당; 꽝선비; 레이스; 댄스 메들리; 같은 수묵화
# 신예은; 런닝맨; 강훈; 맑눈광 댄스; 댄스 메들리; 댄스 인재; 허당기; 꽝선비; 꽝선비 힌트; 꽝선비의 정체; 물따귀; 예능 폼; 예능 폼; 과민 반응; 예능 폼; 물따귀
#
# 홈쇼핑 송출수수료; 가이드라인; 현장선 갈등; 송출수수료 두고 유료방송-홈쇼핑 업계 갈등; 과기정통부; 방송채널 사용계약 가이드라인; 개정안; 대가산정 기준; 물건을 판매할 채널; 유료방송사와 홈쇼핑사간 협상
# 홈쇼핑 송출수수료; 유료방송; 홈쇼핑; 갈등; 가이드라인; 과학기술정보통신부; 대가산정 요소; 유료방송사; 홈쇼핑사; 모바일; 인터넷; 협상; 수수료; 협상 과정; 변칙; 협상 과정을 누설하지 않는다는 조항; 협상 과정을 누설하지 않는다는 조항
#
# 클리퍼스; 골든스테이트; NBA; 이비카 주바치; 카와이 레너드; 스테픈 커리; 서부 컨퍼런스; 더블더블; 상승세; 4연승
# 클리퍼스; 골든스테이트; NBA; 6명 10점; 득점분포; 승리; 서부 컨퍼런스; 이비카 주바치; 클레이 탐슨; 3점슛; 4연승; 추격전; 커리; 골든스테이트 워리어스; 승리; 상승세; 4연승; 5위; 서부 컨퍼런스 5
#
# 대구시; 대구교도소 후적지; 문화예술허브 조성 사업; 문체부; 요청; 국립근대미술관; 뮤지컬컴플렉스; 경북도청 후적지; 윤석열 대통령; 지역 공약
# 대구시; 대구교도소; 국립근대미술관; 뮤지컬콤플렉스; 문화예술허브 조성사업; 윤석열 대통령; 경북도청 후적지; 문화체육관광부; 문화예술허브 조성사업; 대구교도소 후적지; 문화예술 랜드마크; 지역 균형 발전; 문화분권 촉진; 문화예술 랜드마크 건립; 대구 미래
#
# 청년 전세대출; 허점; 악용; 대출금; 사기; 브로커; 가짜 임차인; 은행; 증빙 서류; 관련 첩보
# 청년 전세대출; 대출금; 사기; 경찰; 브로커; 허위 임대차 계약서; 무주택 청년; 주택 소유자; 대출금 회수; 편취금; 유흥비; 경찰 수사; 여죄 수사; 허위 임대차 계약; 편취금 회수; 추가 범행; 집 주인 추적; 대출금 회수; 여죄 수사; 주택
#
# 국내 주유소; 휘발유 판매 가격; 1600원; 상승세; 예상; 18일; 한국석유공사 유가정보시스템; 평균 판매가격; 리터당; 1596.8원; 전주 대비 9.8원 올랐다; 평균 휘발유 가격; 4주 연속 올라; 1600원에 근접했다
# 휘발유 가격; 국내 주유소; 판매 가격; 리터당; 1600원; 소폭 상승세; GS칼텍스 주유소; 알뜰주유소; 경유 판매가격; 국제 유가; 배럴당; 2주 정도 시차; 국내 판매 가격; 2주 정도 시차; 국제 휘발유 평균 가격; 국내 최고가 지역; 제주의 이번
#
# 탈ZOO; 얼룩말 세로; 동물원 탈출; AI 스타트업 라이언 로켓; 이미지 생성 인공지능; UN 콘퍼런스; CNN·BBC·NBC; 광진구 주택가와 도로; 두살배기 얼룩말 세로; 어린이대공원 동물복지팀장
# 탈ZOO; 세로; 동물원; 탈출기; 외신 주목; 패러디; 이미지 생성 인공지능; 라이언 로켓; AI 스타트업; UN 콘퍼런스; 배달기사; 주택가; 반항기; 부모 사랑; 안정; 짝지어둔 암컷 얼룩말; 내년 중 가족으로 만들어줄 예정; 사육사들; 밥도
#
# 하나로마트; 강화농협; 매출; 조합원 배당금; 경제사업장; 주유소; 사업시설; 고객 유치; 연계 할인; 지역경제
# 하나로마트; 강화농협; 매출 300억원; 지역경제; 사업시설 집적; 사업 동반상승효과; 경제사업장; 조합원 배당금; 종합시설 신축; 도시농협; 자매결연; 주말농장; 경제사업장; 경제사업장 이용 고객; 종합시설 신축; 경제사업장 이용 고객; 경제사업장 이용 고객;
#
# 서울어린이대공원; 얼룩말; 부모; 반항; 캥거루; 사육사; 도심 활보; 사과; 손밥; 나무 데크
# 부모 잃고; 반항 시작; 도심 활보; 캥거루와 싸우기도; 사육사들과 친밀감 높인 뒤; 가출 안 해; 사육사들과 친밀감 높인 뒤; 탈출; 서울시설관리공단 유튜브 채널; 손밥; 블루건; 마취 장비; 대공원 수의사 및
#
# 한화 이글스; 카를로스 수베로 감독; 투타; 조화; 야구; 위기; 마운드; 빅 이닝; 타선; 집중력
# 한화 이글스; 시범경기; 삼성 라이온즈; 투타 조화; 타선; 홈런; 득점; 노시환; 주루 플레이; 대구; 경기; 승리; 타선의 조화; 높은 퀄리티의 야구; 투수들; 득점; 경기를 자력으로 매듭짓는; 높은 퀄리티의 야구; 대구=
#
# 김기현; 이재명; 첫 회동; 여야 수장 회동; 잘하기 경쟁; 100% 공감; 정쟁 아닌 경쟁하자; 취임 인사차; 봉고파직 발언; 민생 문제 해결
# 김기현; 이재명; 여야 수장; 회동; 경쟁; 국민의힘; 대표; 더불어민주당; 대표; 민생 문제; 국민을 잘살게 하고 행복하게 하고 나라를 부강하게 하는 것; 여야 간 범국가 비상경제회의; 여야 간 비상경제회의; 민생 문제;
#
# 르세라핌; 정규앨범; 공식; 앨범 트레일러; 레이블즈; 유튜브; 쏘스뮤직; 불태우는 장면; 다섯 멤버; 눈을 뜨는 마지막 장면
# 르세라핌; 정규앨범; 컴백; 트레일러; UNFORGIVEN TRAILER; Burn the Bridge; 압도적인 영상미; 감각적인 스토리텔링; 다섯 멤버; 신보에 대한 기대; 배수의 진; 팀이 원하는 방향; 컴백
#
# 토트넘; 세비야; 브리안 힐; 임대; 축구; 시즌; 수입; 자신감; 프리미어리그; 안토니오 콘테
# 토트넘; 세비야; 임대; 브리안 힐; 시즌; 이적; 선수; 이적 시장; 이적; 이적 시장; 프리미어리그; 성장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 이적 시장; 프리미어리그;
#
# 컴투스; 크로니클; 서머너즈워; 글로벌 출시; 매출 300억; 매출 목표 1000억; 앱스토어; 구글플레이스토어; PC 플랫폼 스팀; 매출 상위권
# 컴투스; 크로니클; 서머너즈워: 크로니클; 매출; 목표 초과 달성; PC 플랫폼 스팀; 매출 TOP10; 아시아와 유럽의 여러 국가; 일평균 매출 10억 원; 선풍적 인기몰이; 야구 게임 라인업; 연간 3000억 원 이상; 데일리e스포츠; 게임사업부문
#
# 한빛-TLV; 우주 발사체; 이노스페이스; 엔진 검증용 시험발사체; 브라질 공군; 알칸타라 우주센터; 국내 첫 위성 발사 서비스 기업; 하이브리드 엔진; 상공 500㎞; 소형 위성 발사
# 국내 첫 민간발사체; 한빛-TLV; 브라질; 이노스페이스; 엔진 검증용 시험 발사체; 알칸타라 우주센터; 추력 15톤급 하이브리드 엔진; 국내 첫 상업 발사 서비스 기업; 소형 위성 발사 서비스 기업; 이륙 10초; 배터리 과냉각 문제;
#
# 누누티비; URL 차단; 강력 대응; 한국 OTT; 일괄 삭제; 불법 동영상 스트리밍; 국내 외 OTT 플랫폼; 수익; ISP; 부산경찰청
# 누누티비; OTT; 영상; 일괄 삭제; URL 차단; 정부; 강경 대응; 불법 동영상 스트리밍 사이트; 수익; MAU; 피해액; TF; 대응; 문화체육관광부; 방송통신심의위원회; 불법 사이트 문제; 대응할 방침; OTT 사업자들의 우려가 증폭되자
#
# 민간임대 아파트; 안성 영무예다음; 견본주택; 분양; 민간임대 주택특별법; 대형 도시개발사업지; 피트니스센터; 키즈카페; 키즈도서관; 경부고속도로
# 민간임대 아파트; 안성 영무예다음; 견본주택; 안성 당왕지구; 대단지 아파트; 10년 후 분양전환; 취득세; 보유세; 종부세; 커뮤니티 시설; 교통환경; 평택부발선; 평택부발선; 평택부발선 등의 교통호재; 합리적인
#
# 롯데백화점; 저탄소 한우; 판로 확보; 탄소 배출량; 친환경 소비; 친환경 식품; 국내 친환경·유기농 식품 시장; 전북대학교; 고창부안축협; ESG 경영
# 저탄소 한우; 롯데백화점; 친환경; 한우; 판매; 탄소 배출량; 전북대학교; 동물복지; ASC 활전복; 보랭가방 회수 프로모션; ESG 경영; 전북대학교 및 고창부안축협; 지속적인 노력; 친환경 상품; 지속적인 노력; ESG 경영; 지속적
#
# 한국석유공사; UAE; ADNOC; 원유; 여수비축기지; 국제 공동비축 계약; 저장 물량; 국가 에너지 위기 상황; 국내 원유 도입
# 한국석유공사; UAE; ADNOC; 원유; 여수비축기지; 저장 물량; 국제 공동비축 계약; 400만 배럴; 국내 수급 비상 상황; 원유 공급; 중동 산유국; 석유 분야 협력 노력; 수소·암모니아 공급; 저탄소 신·재생에너지 분야 협력; 비축유 확보;
#
# 검정 고무신; 이우영 작가; 이우진 작가; 사업자; 형설앤; 저작권 분쟁; 인천 자택; 이우영작가사건대책위원회; 이선민; 제도 개선
# 이우영작가사건대책위원회; 이우영작가; 검정 고무신; 이우진작가; 만화; 검정 고무신 사태; 저작권 분쟁; 이우영작가사건대책위원회; 이우진작가사건대책위원회; 이우영작가사건대책위원회; 이우영작가사건대책위원회; 이우진작가사건대책
#
# 이채영; 한기웅; 최재성; 불륜 발각; 비밀의 여자; 의심; 외도; 남유진; 주애라; 정현태
# 이채영; 한기웅; 불륜; 정현태; 주애라; 남유진; KBS 2TV; 비밀의 여자; 의심; 오세린; 제보; 정현태; 출장; 화장품; 정현태의 의심; 정현태의 의심; 정현태의 의심; 정현태의 의심; 정현태의
#
# 부산시교육청; 검정고시; 초졸; 중졸; 고졸; 고사장; 코로나19; 응시자; 수험표; 합격자
# 부산시교육청; 검정고시; 초졸; 중졸; 고졸; 응시자; 시험실; 수험표; 합격자; 중앙방역대책본부; 컴퓨터용 수성사인펜; 수험표 재발급; 스포츠동아(부산) | 김태현 기자 localbuk@donga.com[keyphrases generated]부산시교육청
#
# 대마 혐의; 남양유업 창업주; 손자; 1심 실형; 불복; 쌍방 항소; 검찰; 홍씨 측; 지난해 10월 대마초; 판매
# 대마 혐의; 남양유업 창업주 손자; 1심 판결; 항소; 대마 소지; 흡연; 매도 혐의; 초범; 실형; 검찰; 홍모씨 측; 1심 판결; 징역 2년; 추징금 3510만원; 대마 매수인; 매수인; 매수인; 대마 매도; 대마 소지; 흡연
#
# 한동훈; 송파병; 국회 대정부질문; 법무부 장관; 김규완 논설위원장; 주소지 이전; 송파구; 정부공직자윤리위원회; 총선; 한 장관
# 한동훈; 송파병; 법무부 장관; 김근식; 송파병 출마설; 재산등록; CBS 라디오; 국민의힘 서울 송파병 당협위원장; 총선 출마; 부동산; 서초구 아파트; 오피스텔; 보유 건물; 서초구 오피스텔; 경기 부천 건물; 재산신고; 재산변동사항; 재산등록;
#
# 대구시의원; 엑스코선; 노선 변경; 대구 도시철도; 조속한 재검토; 조기 착공; 코스트코선; 동서관 방향; AGT; 사업계획 적정성 재검토
# 엑스코선; 노선 변경; 조속히 착공; 대구시의회; 건설교통위원회; 도시철도 엑스코선; 노선 변경 계획안; 조속한 재검토; 조기 착공; AGT(철제차량); 도시철도 엑스코선; 도시경관 훼손; 대구 미래 100년; 주민 편의성; 관광자원화;
#
# KNVB 대응; 클라센 부상; 물건으로 인한 유혈사태; 경기 중단; 라이터 범인 체포; 상처; 경기 종료 예고; 경기장 구역 폐쇄; 체포자 수; 클라센 골과 결승전
# 경기; 유혈 사태; 네덜란드 축구협회; 아약스; 페예노르트; 클라센; 경기장; 경찰; 유로파리그; UEFA; PSV 에인트호번; 경질 러시; 라이트 팬도 쉽고 재밌게 읽을 수 있는 기사; BBC; FIFA; UEFA컵
#
# 경기도; GPT 창작단; AI 활용 사업; 경바시; 혁신포럼; 지피티; 시대의 변화와 기회; 발달장애인의 예술 활동; 미래산업 펀드; GPT 스타트업 투자 사업
# 경기도; GPT; 생성형 인공지능; AI; 활용 사업; 김동연 경기도지사; 경바시; 지피티; 혁신포럼; 윤리; 비즈니스; 인공지능; 스타트업 투자; GPT 산학연 기업협의회; GPT 산학연 기업협의회; AI 기술 발전과 활용에 따른 사회적 영향과 윤리적
#
# 브렌트포드 FC; 유럽 무대; 승리; 승점 3점; 뉴캐슬 유나이티드와의 승점 차; 순위; 원정 경기; 아이반 토니; 하부리그; 성장
# 브렌트포드 FC; 유럽 무대; 승점; 세인트 메리즈 스타디움; 잉글리시 프리미어리그; 아이반 토니; 에이스; 세인트 메리즈 스타디움; 유럽 대회 진출; 세인트 메리즈 스타디움; 브렌트포드의 성장; 유럽 대회 진출 가능성; 세인트 메리즈 스타디움; 브렌트포드의 성장;
#
# 외국인 커플; 서울~부산; 히치하이킹; 인종차별; 한국; 여행; 논란; 홈페이지; 정보; 반응
# 서울→부산; 히치하이킹; 인종차별; 외국인 커플; 서울 만남의 광장 휴게소; 부산→'서울→부산'; 외국인을 태워주지 않음; 버스; 히치하이킹 관련 정보; 인종차별은 무리한 지적; 발로 뛰는 더팩트; 제보를 기다립니다
#
# 결혼 말고 동거; 박시원; 조나윤; 스몰 웨딩; 꽃과 케이크; 속옷; 1시간 정도 DJ 파티; 광란의 결혼식; 예산; 집 구하기
# 한중 커플; 결혼식; 동거; 박시원; 조나윤; 결혼 말고 동거; 웨딩드레스; 대관료; 턱시도; 결혼 예산; 웨딩의 중요성; 결혼식 준비; 동거남; 웨딩의 중요성; 결혼 준비; 동거남의 결혼 준비하는 모습; 결혼 준비하면서
#
# 호남권 반도체 특화단지; 광주; 전남; 입법지원 토론회; 반도체 산업; 차세대 후공정; 경쟁력; 광주과학기술원; 에너지반도체산업; 인공지능
# 호남권 반도체 특화단지; 광주·전남 공동 유치; 국회; 경쟁력 방안; 국회 법제실; 양향자 의원실; 시스템반도체용 차세대 후공정(패키징) 특화단지; 광주·전남 상생 1호 협력사업; 시스템반도체용 차세대 후공정(패키징) 특화단지;
#
# 민주당; 반도체 시설투자 세액공제율; 대기업; 중견기업; 중소기업; 일몰기한; 탄소중립산업; 미래형 이동수단; 선진국; 첨단전략산업
# 민주당; 반도체 세액공제; 개정안; 대기업; 중견기업; 중소기업; 수소; 탄소중립산업; 미래형 이동수단; 국가전략기술; 세액공제 품목; 미국; 선진국; 국가전략산업; 세액공제율 상향안; 정부안; 국가전략기술산업; 세액공제율 상향안; 정부안; 국가
#
# GLN; 간편결제; 해외여행객; 현지결제; 현지송금; 국내외 핀테크 플랫폼 대연합; 선불충전 띳머니; 수수료 절감; KB스타뱅킹 앱; 카카오페이; 글로벌 결제 시장
# 글로벌 간편결제; GLN; 하나은행; 분사; 핀테크; 대연합; 해외 결제; 현지화; 서비스; 카카오페이; 금융사; 결제건수; 결제액; 해외 여행객; 현지화; 핀테크 기업; 결제 시장; 해외 결제 시장; 해외 결제 시장; 해외 결제 시장; 해외 여행객
#
# 재외공관장들; 부산; 2030 세계박람회; 유치; 결의대회; 성공; 활동; 경쟁력; 도시; 대표
# 재외공관장들; 부산 방문; 2030 세계박람회; 유치; 부산; 이도훈 2차관; 부산상공회의소 회장; 부산 세계박람회 유치 성공 결의대회 겸 특별 점검 회의; 이도훈 2차관; 부산 세계박람회 유치 교섭; 부산 세계박람회 유치 경쟁력; 부산으로 오이소; 재외
#
# 여자배구; 도로공사; 역전 우승; 흥국생명; 2연패; 3연승; 0% 기적; 김종민 감독; 캣벨; MVP
# 도로공사 역전 우승; 여자배구 챔피언 결정 5차전; 사상 최초; 2연패 뒤 3연승; 박정아의 서브 에이스; 캣벨의 공격; 김종민 감독; MVP; 여자배구 역대 최고의 흥행; 도로공사의 기적 같은 역전 우승; 캣벨의 현역 연장과 은퇴 사이 고민;
#
# 포르쉐; 돼지; 핑크피그; 스포츠카; 911 RSR; 917/20; 콘셉트카; 비전 357; 르망 대회; 프랑스 디자인회사
# 포르쉐; 핑크피그; 911 RSR; 911 RSR 핑크피그; 포르쉐 356; 917/20; 911 RSR 핑크피그; 포르쉐 356 레이싱머신; 포르쉐 이코넨, 서울 -스포츠카 레전드; 못생겨도 달리는 맛은 출중
#
# 서울 원정; 최원권 감독; 초반 실점; 대구FC; FC서울; 하나원큐 K리그1; 프리킥 골; 전방 압박; 페널티킥 득점; 이진용
# 서울월드컵경기장; 최원권 감독; 대구FC; FC서울; 무패 행진; 전반 11분; 나상호; 추가실점; 이진용; 프리킥 골; 이진용에 대한 최원권 감독의 생각; 이진용이 중원에서 잘 버텨주었다; 대구의 수비 숫자가 분명 많은 상황이
#
# 클레이; 코트 대회; 노박 조코비치; 매치 플레이; 경기; ATP 투어 마스터스; 클레이코트; 상대; 리듬; 표면
# 조코비치; 클레이코트 대회; 랭킹; 이반 가코프; 개인통산; 적응; 리듬; 경기; 몬테카를로 마스터스; 이반 가코프; 첫 단계; 리듬; 경기; ATP 투어; 이반 가코프; 첫 단계; 적응; 리듬; 경기; ATP 투어
#
# 음식점; CCTV; 냉장고; 소주; 경찰; 무단침입; 범행; 주방; 돈통; 홀 의자
# 도둑질; 소주; 음식점; CCTV; 범행; 현금; 냉장고; CCTV 영상; 범행을 시도; CCTV 분석; 방화 시도; 피해; CCTV 영상; 범행을 시도하다; CCTV 분석; CCTV 영상; 범행을 시도하다 소주를 마시다 떠나는 CCTV 영상; CCTV 영상; 범행을
#
# 한돈자조금; 한돈페스타; 한돈협회; 태동; 50주년; 한돈자조금 창립 20주년; K-포크 한돈 페스타; ESG 경영; 전시; 판매; 공연; 쿠킹클래스; 콘테스트
# 한돈자조금; 한돈페스타; 미래 비전; 대한한돈협회; 태동 50주년; 한돈협회 창립 20주년; K-포크 한돈 페스타; 한돈산업의 미래 비전; ESG 경영 실천; 한돈박람회; 한돈 브랜드사; 한돈인증점; 한
#
# 혈당지수; 저혈당 식품; 고혈당 식품; 탄수화물; 혈당지수 비교; 혈당지수 측정; 혈당지수 참고; 농촌진흥청; 섭취 칼로리; 당뇨병
# 혈당지수; 혈당지수(GI); 혈당지수(혈당지수); 혈당지수(혈당지수); 혈당지수(혈당지수); 혈당지수(혈당지수); 혈당지수(혈당지수); 혈당지수(혈당지수); 혈당지수(혈당지수
#
# 샤이니 태민; 제대 소감; 값진 시간; 내 자신; 지난 시간들; 감사하고 행복했었다; 보고싶다; 여러분 마음; 더 힘이 나게 해주고; 사명감을 갖고 나아가겠다
# 샤이니 태민; 제대 소감; 값진 시간; 사명감; 나아갈 것; 손편지; 감사; 행복; 사명감; 여러분의 행복; 보답해가며 나아갈게요; 감사합니다; 여러분의 행복에 보탬이 되는 제가 될게요; 앞으로 잘 부탁해요; 특별한 사람이 되
#
# 여야; 선거제 개편안; 국회의원 전원; 전원위원회; 의견 수렴; 개편까지 시간; 의원총회; 후속 논의; 정당의 입장; 결론을 내지 못함
# 여야; 선거제 개편안; 의원 전원 토론; 전원위원회; 국회의원; 전원 의견 수렴; 김진표 국회의장; 전원위원회; 선거제 개편안; 비례성 강화; 비례대표 의원 정수; 국회 정치개혁특위; 결의안 초안; 연합뉴스TV; 전원위원회; 의견 수렴; 결론; 국회의원 전원; 전원
#
# 오은영 박사; 자해 행동; 금쪽이; 육아; 게임; 벽; 늦둥이 아들; 근황; 소변; 화장실
# 오은영; 금쪽이; 자해 행동; 자해 행동; 금쪽같은 내새끼; 게임; 소변; 엄마 추모목; 블랙커피; 자해 행동; 자해 행동; 자해 행동 멈추기; 자해 행동 멈추기 진단; 자해 행동 멈추기 행동; 자해 행동
#
# 토트넘; 에버튼; 축구하는 법 잊은팀; 축구할 줄 모르는 팀; 해리 케인; 선제 페널티킥; 크리스티안 스텔리니; 맨체스터 유나이티드; 금세 다른 팀에게 공격권을 빼앗김; 압둘라예 두쿠레
# 토트넘; 에버튼; 축구하는 법; 축구할 줄 모르는 팀; BBC 맹비난; 2022-2023 프리미어리그; 승점; 맨체스터 유나이티드; 수적 우위; 손흥민; 페널티킥; 선제골; 마이클 킨; 철기둥; 전북 김상식 감독; 감독으로 큰 책임; 전북 김상식 감독
#
# 유로파 2호; 독일 크루즈선; 인천항; 승선객; 관광객; 승무원; 입항; 일본; 약 13시간; 한국관광
# 크루즈선; 유로파(Europa)2호; 인천항; 독일; 관광객; 승무원; 한국관광; 입항; 관광버스; 관광버스; 승선객; 관광버스; 관광버스; 유로파(Europa)2호; 관광버스; 관광버스; 관광버스;
#
# 윤석열 대통령; 국정지지율; 강제동원 배상; 부정평가; 국민의힘; 민주당; 근로시간 개편안; 찬성; 반대; 주52시간제
# 윤석열 대통령; 국정 지지율; 부정평가; 노조 대응; 외교; 경제·민생; 물가; 노동 정책; 근로시간 개편안; 주52시간제; 적정하다; 응답률; 국민의힘; 더불어민주당; 정부 근로시간 개편안; 응답률; 여론조사 결과; 긍정 평가;
#
# 같이 삽시다; 박원숙; 살림9단; 혜은이; 오천시장; 자매들; 동태; 코다리찜; 시장의 정; 떡볶이
# 박원숙; 같이 삽시다 시즌3; 혜은이; 살림살이; 코다리찜; 시장; 살림살이에 맛을 들였다; 떡볶이; 떡; 쌀; 스타들의 동거 생활; 후반전; 혼자 사는 중년 여자 스타들의 동거 생활을 담은 프로그램; 화려했던 전성기를 지나 인생
#
# 양곡관리법; 대통령실; 당정협의; 한총리; 주례회동; 농민단체; 재의요구; 정부; 초과 생산량; 거부권
# 양곡관리법 대응 방안; 당정 협의; 대통령실; 한 총리; 주례회동; 농민단체 의견; 윤석열 대통령; 재의 요구; 거부권 행사; 국무회의; 당정 협의 강화; 정책 조정 기능 강화; 당정회의 강화; 정책 조정 기능 강화; 능동적인 일; 윤석열 대통령; 한덕수
#
# 애플 팀쿡; 혼합현실 헤드셋; 증강현실; 디지털 세계; 의사소통; 협력; 창의력; 공동 작업; MR 헤드셋; 스티브 잡스
# 애플; 혼합현실 헤드셋; GQ 인터뷰; 증강현실 기술; Mixed Reality; 창의력; 의사소통; 공동 작업; 가상현실 제품; 구글의 안경; 스마트 안경; 구글과 메타의 가상현실 제품이 시장에서 큰 반향; 핵심 기술 컨트롤; 위험한 일을 하는 것; 혁신의
#
# 슬램 덩크; 북산 vs 산왕공고; 농구; 스포츠안전재단; 부상; 족부; 족저근막염; 발; 운동; 발바닥
# 슬램 덩크; 농구; 족저근막염; 부상; 발뒤꿈치; 발바닥 앞쪽; 아치; 근막; 발바닥; 발바닥 자극; 보존치료; 발바닥 통증; 검사; 검사를 받아보는 것이 중요하다; 발바닥 통증이 잦은 편이라면; 발바닥 통증이 잦은 편
#
# 문희준; 결혼 7주년; 이벤트; 소율; 플라잉 요가 클래스; 인생 사진 투어; 결혼 6주년; 럭셔리한 식당; 케이크; 감동의 눈물
# 문희준; 결혼; 이벤트; 소율; 괌; 플라잉 요가 클래스; 인생 사진 투어; 전문 사진작가; 케이크; 감동의 눈물; 결혼 7주년; 괌 여행; 럭셔리한 식당; 결혼 7주년 이벤트; 결혼 7주년 이벤트; 결혼 7주년 이벤트; 인생 사진 투어; 전문 사진
#
# 살균제; 세척; 중국; 붕사; 해삼; 전복; 식약처; 수출; 수산물; 중독
# 살균제로 세척한; 중국; 해삼; 전복; 국내 유입 없다; 식약처 확인; 붕사; 공업용; 붕산; 인체 내 장기에 축적; 구토, 설사, 홍반, 의식불명; 가공한 해삼과 전복의 양; 수출 여부 확인; 국내 ‘해외제조
#
# 엔씨소프트; R&D; 테크 스탠다드; 게임 기술; 연구개발; 리니지W; IT 서비스 연속성; 인프라 기술력; 디지털 휴먼; 인터랙션
# 엔씨소프트; R&D; 테크 스탠다드; 게임 기술; 연구개발; 영상 시리즈; 기술력; 인터랙션; 디지털 휴먼; AI(인공지능); 오픈형 R&D; 변화를 위한 노력; 기술 비전; 변화를 위한 노력; 변화를 위한 노력; 진정성 있는 인터뷰
#
# ABL바이오; 이중항체; ABL102; ROR1; 4-1BB; 항체; 암종; 면역항암제 후보물질; 단백질; 임상 데이터
# 에이비엘바이오; ABL바이오; AACR; ROR1; 이중항체; ADC; AACR; ASCO; ESMO; 암 연구 학회; ABL202; ABL202; ABL202; ABL202; AACR;
#
# 사순절; 생명나눔; 장기기증; 예배; 성도; 이규현 목사; 박진탁 목사; 교회; 사랑의장기기증운동본부; 설교
# 장기기증 서약; 생명나눔운동; 사랑의장기기증운동본부; 생명나눔예배; 이규현 목사; 생명나눔예배 기념패; 생명나눔예배; 장기기증 희망등록; 장기이식 대기자; 생명나눔운동본부; 박진탁 이사장; 장기이식; 생명나눔운동본부; 생명나눔예배
#
# 위생 논란; 나 홀로 정리; 공용 거실; ENA; SBS PLUS; 리얼 데이팅 프로그램; 영식; 출연진; 호감도; 프러포즈
# 나는 솔로; 영식; 공용 거실; ENA; SBS PLUS; 리얼 데이팅 프로그램; 출연진; 식사; 꽃; 편지; 영숙; 프러포즈; 영철; 눈물; 예고; ENA; SBS PLUS; 리얼 데이팅 프로그램; 나 홀로 정리; 공용 거실
#
# 수출입은행; 중남미 신시장 개척; 금융지원 강화; 윤희성; 전대금융 보증계약서; 미주투자공사; IDB Invest; 중남미 탈탄소화 산업구조 전환; 에너지·기후변화 분야 진출 방안; 금융협력 방안
# 수출입은행; 한국 기업; 중남미 신시장 개척; 금융지원 강화; 제임스 스크리븐; IDB Invest; 미주투자공사; 전대금융 보증계약서; 에너지·기후변화 분야; 수출금융; 대외경제협력기금(EDCF); 금융협력 방안; 수출금융과 대외경제협력기금
#
# 프로야구 개막; 검찰 압수수색; KBO 간부; TV채널 해택준 혐의; KBO 내 사건사고; 이어지며 비판 여론 확산; 서준원 투수 기소; 장정석 기아 단장 경질; 중계권 판매; 뒷돈 받고
# 프로야구 개막; KBO 압수수색; 검찰; KBO 간부; TV채널; 중계권; 배임수재 혐의; 스포츠 마케팅 업체; 서준원; 아동청소년의성보호에관한법률위반; 장정석 기아 단장; KBO 리그; 검찰의 요청으로 아무런 말을 해줄 수 없다; KBO 간부 피의자 A
#
# 퀸메이커; 이미지 메이킹; 황도희; 하이힐; 비주얼; 의상; 미술 프로덕션; 오경숙; 세련된 쇼 비즈니스; 은성그룹
# 퀸메이커; 황도희; 오경숙; 인권변호사; 서울 시장; 쇼 비즈니스; 의상; 미술 프로덕션; 은성그룹; 백재민; 쇼 비즈니스의 귀재; 쇼 비즈니스의 귀재; 쇼 비즈니스의 귀재; 은성그룹; 은성그룹의 손영심;
#
# 김민재; 나폴리 폭격기; 빅터 오시멘; 유럽챔피언스리그; 결장; AC밀란; 공백; 부상; 지오반니 시메오네; 명단
# 김민재; 나폴리 폭격기; 챔스 1차전; AC밀란; 빅터 오시멘; 유럽챔피언스리그; 공격수; 지오반니 시메오네; 라스파도리; 마티아스 올리베라; 풀백 마티아스 올리베라; 선발 출격; 선발
#
# 조현천 전 기무사령관; 계엄 문건; 귀국; 수사; 입국시 체포영장 집행; 박근혜 대통령 탄핵; 작성; 의혹; 군·검 합동수사단; 기무사 요원
# 조현천; 기무사령관; 계엄 문건; 수사; 귀국; 체포영장; 검찰; 박근혜; 탄핵 정국; 촛불집회; 계엄령; 군·검 합동수사단; 참고인 중지 처분; 군사기밀보호법 위반; 송영무 전 국방부 장관; 이석구 전 기무사령관; 임태훈 군
#
# 여성 연상 부부; 경제적 자립; 초혼 부부; 가치관 변화; 사회진출; 선택적 결혼; 만혼 추세; 혼인 건수 감소; 인구 고령화; 출산 기피 현상
# 여성 연상 부부; 결혼; 경제적 자립; 연상 부부; 결혼; 만혼; 여성 연상 부부; 만혼; 결혼; 가치관 변화; 저출생; 인구 고령화; 저출생; 인구 고령화; 저출생; 결혼; 경제적 자립; 경제적 자립; 결혼; 만혼; 저
#
# 부동산 시장 침체기; 돈 벌 수 있는 기회요인; 특수물건 경매; 경매 전문가; 투자 성공사례; 고수익; 구조; 투자방법; 교육과정 할인 혜택; 블루문인베스트
# 한경부동산; 시장 침체기; 경매; 돈 버는 부동산; 설명회; 수익 창출 구조; 특수물건 경매; 초보자도 안정적으로 고수익; 블루문인베스트; 유치권; 법정지상권; 교육과정 할인 혜택; 한경닷컴 집코노미(한경부동산); 한국경제신문사빌딩
#
# 민주당; 국정조사; 대일외교; 국익; 극비사항; 국가안보; 윤석열; 정상회담; 방탄 의혹; 형사처벌
# 여당; 외통위; 대일외교; 국정조사 요구; 심각한 유감; 국민의힘; 민주당; 윤석열 대통령; 기시다 총리; 한일정상회담; 국정조사 요구서; 민주당; 한일관계 정상화; 이재명 대표 방탄; 형사처벌; 민주당의 막가파식 행태; 국민
#
# 렌던; 출장 정지; 메이저리그; 주먹 휘두름; 오클랜드 팬; 유니폼; 언쟁; 감독; 에인절스; 타율
# 팬 멱살 잡고; 주먹 휘두른; 앤서니 렌던; 메이저리그; 출장 정지 징계; 오클랜드 애슬레틱스; 2023 메이저리그 개막전; 3타수 무안타; 에인절스; 관중; 풀 타임 소화; 발목 부상; 타율 0.252 20홈런 89타점; 기특한 외
#
# 사이클론 여파; 페루; U-17 월드컵; 개최권 박탈; FIFA; 기상이변; 인명 피해; 재산 피해; 인프라; 개최국
# 사이클론; 페루; FIFA; U-17 월드컵; 기상이변; 대회; 개최권; 인프라; 이스라엘; 인도네시아; 반이스라엘 여론; 이슬람 형제국; 밀란; 작심 발언; 작심 발언; 포포투 FourFourTwo 잡지 정기 구독하기; FIFA 평의회
#
# 코오롱; 한빛-TLV; 우주산업; 투자; 발사체 부품; 공급사; 이노스페이스; 추진 시스템; 복합 소재 부품; 투자액
# 코오롱; 한빛-TLV; 우주산업; 투자; 발사체; 부품 공급사; 추진 시스템; 복합재 연소관; 노즈콘 페어링; 위성; 민간 우주산업; 영역 확장; 민간 우주산업 투자; 코오롱그룹 계열사; 민간 우주산업 투자; 위성; 관제; 통신; 국내
#
# 뇌물수수; 공직선거법 위반; 구속영장; 임종식 경북도교육감; 피의자 심문; 대구지법 포항지원; 증거자료; 선거운동; 경찰청; 검찰
# 임종식; 경북도교육감; 구속영장; 공직선거법 위반; 뇌물수수; 불구속; 대구지법 포항지원; 피의자 심문; 선거운동; 선거; 경북경찰청; 압수수색; 검찰; 선거운동; 뇌물수수; 경북도교육감; 구속영장 청구; 불구속; 경북경찰청; 선거운동; 선거;
#
# 신문; 자유민주주의; 생산 역할; 책임; 허위 정보; 선동; 정확한 정보; 발전; 토대; 노력
# 신문의 날; 윤석열 대통령; 자유민주주의; 팩트; 생산; 역할; 책임; 제67회 신문의 날 기념대회; 김은혜 대통령실 홍보수석; 정보 생산의 역할과 책임; 온라인을 타고 빠르게 이뤄지는 미디어 환경의 변화 속에서 신문의 역할은 그 어느 때보다 중요하다
#
# 이원욱; 원내대표; 통합 지도부; 이재명; 체포동의안; 더불어민주당; 국회 외교통일위원회; 강제동원 배상안; 굴욕 해법; 해(解)법
# 이원욱; 민주당; 유승민; 원내대표; 통합 지도부; 원내대표 선거; 이재명; 체포동의안; 물증 없으면; 계속 부결될 것; 더불어민주당; 친명계; 비명계; 정치적 공동체; 부결될 것; 물증 없이 심증적 문제; 정치적 공동체; 이재명
#
# 정읍시; 구제역 예방백신; 관내 소; 염소; 구제역 유입 방지; 축산청정; 대상 소; 대상 염소; 백신항체 형성; 모니터링 검사
# 정읍시; 구제역; 예방백신; 소; 염소; 사육농가; 일제접종; 백신항체; 항체 양성률; 정기 접종; 사육 기간; 예방접종 누락 개체; 철저한 예방접종; 축사 소독; 축사 점검; 축사 관리; 백신항체 형성 여부 확인; 정기 접종; 개체 수
#
# 머릿니 감염; 초등학생; 유병률; 집단생활; 미취학 아동; 의용절지곤충; 발진티푸스; 참호열; 재귀열; 국내 초등학생
# 머릿니; 초등학생; 유병률; 집단생활; 의용절지곤충; 피; 피부질환; 발진티푸스; 참호열; 재귀열; 지역별; 건강과 위생; 모니터링; 기생충, 숙주, 질병(Parasites, Hosts and Dise
#
# 모범택시2; 배유람; 코믹 연기; 무지개 운수 엔지니어 박진언; 매력; 사이비 종교; 척하면 척; 웃음 책임; 박주임; 멤버들과 꿀잼 관계성
# 모범택시2; 배유람; 코믹 연기; SBS 금토극; 무지개 운수 엔지니어; 박주임; 클럽 블랙썬; 불법 대리 수술; 사이비 종교; 척하면 척; 착한 서열 꼴찌; 무지개 운수 팀의 착한 서열 꼴찌; 배우람; 모범 감초 역할; 활약상; 에피소드별
#
# 방탄소년단; 지민; Set Me Free Pt.2; 빌보드; 핫 100; 메인 차트; 솔로 앨범; FACE; 기록; 추가
# 방탄소년단; 지민; Set Me Free Pt.2; 빌보드; 핫 100; 메인 싱글 차트; 디지털 송 세일즈; 월드 디지털 송 세일즈; 글로벌200; 약속; filter; Proof; Indigo; R&B/힙합 디지털 송 세일즈; 월드 디지털 송 세일즈
#
# 사람인; 커리어매칭 플랫폼; 신입·인턴 페이지; 구직자; 정보 허브; AI 기반; 추천 공고; 매칭 적합도; 이벤트; 커리어 성장
# 사람인; 신입; 인턴 페이지; 구직자; 커리어 성장; 기업; 채용 일정; 공고; Ai 매칭 리포트; 이벤트; 커리어 시장; 커리어 성장; 커리어 시장; 커리어 성장; 커리어 성장; 커리어 시장; 커리어 성장; 구직자들의 가장 가까운 곳에서 함께하며 커리어 성장을 이끄는 다양
#
# 제주; 봄; 서귀포시; 보롬왓 농장; 튤립; 유채꽃; 기상청; 최고기온; 관광객; 봄꽃 향연
# 제주; 보롬왓; 봄꽃 향연; 튤립; 유채꽃; 봄의 정취; 기상청; 제주의 낮 최고기온; 보롬왓; 관광객들; 유채꽃과 튤립; 봄의 정취; 관광객들; 제주의 낮 최고기온; 보롬왓; 관광객들; 제주의
#
# 폼즈; 가상인간; 셀럽 마케팅; 얼굴인식; 인공지능; 버추얼 인플루언서; AI 딥러닝; 페이스폼; 라이브 커머스; 구독서비스
# 폼즈; 버추얼 휴먼; AI 딥러닝 기술; 가성비; 패션모델; 브랜드; 버추얼 인플루언서; 인플루언서 마케팅; 돌하르; e커머스 사업; SaaS 형태; 버추얼 휴먼; 버추얼 인플루언서 계정; 현대백화점; 버
#
# 국민의힘; 최고위원회; 전북 전주; 재선거; 보궐선거; 후보 지원; 현장 최고위; 호남 공략; 5·18 기념식; 참석하는 방안
# 국민의힘; 지도부; 전주; 최고위; 현장; 전북; 전주을; 국회의원; 선거; 김경민; 5·18 민주화운동 기념식; 보수정당 역사상 최초; 윤석열 대통령; 김재원 최고위원; 5·18 민주화운동 기념식 참석; 보수정당 역사상 최초 100명 참석; 김재원
#
# 드레스; 수제 티아라; 이승기; 이다인; 결혼식; 서울 강남구; 삼성동 그랜드 인티컨티넨탈 서울 파르나스 호텔; 웨딩홀; 화려한 생화 장식; 2부 드레스; 오프숄더 시스루 드레스
# 이승기; 이다인; 결혼식; 화려함; 드레스; 2부 드레스; 티아라; 유미언니; LA에서 직접 만든 티아라; 신혼여행; 연인; 아시아 투어 콘서트; 안방극장 복귀; 연인; 결혼식 후 신혼여행; MBC 새 드라마 '연인'; 화려함의 끝
#
# 두산 베어스; 주말 위닝시리즈; 광주기아챔피언스필드; SOL KBO리그; KIA 타이거즈전; 선취점; 호투; 승리; 시즌 첫 승; 기사제공 스포티비뉴스
# 두산 베어스; 광주기아챔피언스필드; KIA 타이거즈전; 3-2; 승리; 선취점; 최형우의 좌익선상 2루타; 강승호의 2타점 2루타; 김재환의 2타점 2루타; 홍건희의 호투; 시즌 첫 승; 메디나의 호투; 스포티비뉴스
#
# 민주 권리당원; 이재명; 직무정지; 가처분; 더불어민주당 대표; 이 대표; 당헌 80조; 권리당원; 당무위; 결정
# 민주당; 권리당원; 이재명; 직무정지; 가처분; 민주당 당헌 80조; 대표직; 가처분 신청서; 당무위원회; 비명계; 검찰; 압수수색; 체포영장 쇼; 정치보복; 대표직 유지 결정; 비명계 의원; 검찰의 정치적 활용; 기소된 이 대표; 대표직 유지 결정에
#
# 재일 조선인; 학교; 간첩 양성소; MBS 라디오; 발언; 조넨 쓰카사; 북한의 일본인 납치; 인권; 사과문; 유튜브
# 일본의 혐한 시위대; 조선학교; 간첩 양성소; 항의하는 시민들; 조선학교; 스파이; 조넨 쓰카사; 인권; 일본 경제평론가; 사과; 대응; 불성실한 대응; 성실한 대응을 요구할 것; 김태균 기자; 밀리터리 인사이드; 일본의 혐
#
# 루카 모드리치; 재계약 협상; 불만; 레알 마드리드; 대표팀; 나이; 유로 2024; FA; 자유 계약; PSG
# 모드리치; 레알 마드리드; 재계약 협상; 불만; 나이; 대표팀; 자유 계약; 자유 계약 신분; 올여름; PSG; 올 시즌 첫 실점; 4G 무패; 4위 도약; 이적설; 대표팀 생활 연장; 자유 계약 신분; 올 시즌 첫 실점; 이적설; 불만
#
# 셀트리온; 1분기; 역대 최대 매출; 전망; 한국투자증권; 기업 가치; 목표주가; 매수; 실적; 바이오시밀러
# 셀트리온; 1분기; 매출; 영업이익; 바이오시밀러; 램시마SC; 신약개발; 자체 파이프라인; M&A; 기업가치(밸류에이션) 매력; 주가 하락; 기업가치(밸류에이션) 매력; 상반기 기업가치(밸류에이션) 매력; 바이오시
#
# 초거대 AI 개발사; 챗GPT; GPT 성능을 뛰어넘는 모델; 투자와 개발; 국내 초거대 인공지능(AI) 개발기업; 한국어 특화 모델; 챗GPT 장벽을 뛰어넘는 모델 개발전략; AI 모델 업데이트; 오픈AI; 정부 부처별로 AI 전담팀
# 이경전 교수; 초거대 인공지능; 챗GPT; GPT 성능; 모델; 투자; 전략; 생성 AI; AI 모델 업데이트; AI 활성화; 정부 노력; AI 전담팀; 정부 노력; 초거대 AI 모델 경쟁; AI 모델 업데이트; AI 활성화; 정부 노력; 초
#
# 영화감독들; 저작권법 개정; 정당한 보상; 보장; 거리 시위; 영상창작자; 권리 보호; 창작자; 간담회; 문제 해결
# 저작권법 개정; 정당한 보상; 영상창작자; 한국영화감독조합; 게릴라 시위; 창작자 권리 보호; DGK; SGK; 법안 발의; 창작자 단체; 저작권 보호 운동; 정당한 보상 캠페인; 저작권법 개정 요구; 저작권법 개정 요구 게릴라 시위;
#
# 원주 산업단지; 신성장산업 유치; 부론일반산단 상반기 착공; 박차농공단지 조성; 기존 산단 활성화 추진; 반도체 메가클러스터 연장 기대; 새로운 도약 발판; 부론국가산업단지 건설; 추가 산단 및 농공단지 조성; 구조 고도화 추진
# 원주 산업단지; 신성장 산업 유치; 부론 일반산단; 기존 산단 활성화; 반도체 메가 클러스터 연장; 산업단지 기본계획 수립; 산업단지 중장기 조성 로드맵; 첨단산업 육성; 수도권 취업 동방한계선 확장; 반도체 산업 육성; 부론국가산업단지 건설; 부론IC 개설; 산업단지 기본계획 수립;
#
# SK스퀘어; 쉴더스 매각대금; 자사주 매입; 소각; 주주환원; 박정호 부회장; 주주총회; 경상배당 수입; 하베스트 성과; SK쉴더스 지분
# SK스퀘어; 주주환원 정책; 자사주 매입; 소각; 주주환원; SK쉴더스; 매각대금; EQT파트너스; 자사주 매입; 투자전문회사; 박성하 사장; 주가 상승; 주주 가치; 신규 선임된 박성하 SK쉴더스 사장; 인앤아웃; 주가
#
# 아우디; 서비스·정비 기술 경진대회; 아우디 트윈컵 2023; 서비스 부문; 테크놀로지 부문; 고객 응대 역량; 정비 기술력; 적극적 A/S 서비스 체계 구축; 전기차 모델 전문 정비인력 양성; 출전 가능한 한국 대표팀
# 아우디 트윈컵 2023; 고객 서비스; 정비 기술 경진대회; 서비스 부문; 테크놀로지 부문; 서비스 부문 1위; 서비스 부문 2위; 서비스 부문 2위; 서비스 부문 2위; 서비스 부문 2위; e-모빌리티 전동화 전략 추진; 전기차 모델 전문 정비인력 양성; A/S 서비스
#
# 이철규; 공천 1순위; 지역 유권자; 지지; 신뢰받는 분; 내년 총선; 당 살림; 사무총장; 국민의힘
# 이철규; 공천; 지역 유권자; 지지; 신뢰; 총선; 당 대표; 김기현; 한일정상회담; 근로시간; 탄력 근무제; 노사 간 합의; 노동의 유연성; 당 대표의 총선 승리; 김기현 대표의 신뢰받는 모습; 국민의힘 사무총장; 지역 유권자들의
#
# 성매매; 외국인 여성; 제주; 구속; 성매매특별법; 단란주점; CCTV 영상; A씨; 불법체류자; 피해 여성들
# 식당인 줄 알았더니; 코리안드림; 외국인 여성; 성매매; 구속; 경찰; 단란주점; CCTV 영상; 불법체류자 신분; 통보의무 면제제도; 피해자 모집; 브로커; 외국인 범죄 관련 신고자의 신원은 철저히 보장되기 때문에 적극적인 제보를 부탁한다; 제주경찰청
#
# 한미동맹; 친목; 조약; 외교일기; 미사일록; 주미공사; 외교; 일동장유가; 국가기록원; 친선 외교 관계
# 한미동맹; 외교일기; 미사일록; 주미공사; 조선; 외교활동; 일동장유가; 국가등록문화재; 문화재청; 경기도 국가등록문화재 심의; 경기도 유형문화재 지정 공표 예정; 김수복; 외교활동; 외교일기 복원물; 외교활동; 외교일기 복원물; 외교활동 복원물;
#
# 새파란 119물결 운동; 경조사 관행; 경직된 분위기; 제복; 경기소방; MZ세대; 격식; 기성세대; 관료주의적 조직문화; 누리소통망
# 경기소방; 경조사 관행; 경직된 분위기; 제복; 새파란 119물결 운동; 경조사 소식; 누리소통망; 새파란 소통‧공감의 날; 소방 정책; 경기소방 혁신; 소방 조직 혁신문화; 본부 내근 직원; 파란119; 신규정책; 소방 정책; 경기
#
# 뉴욕증시; 코스피; 약보합세; 환율; 상승 출발; 달러 대비; 급락분; 연준; 금리 인하; 네고물량 출회
# 코스피; 약보합세; 환율; 상승; 코스피; 약보합세; 출발; 종가; 환율; 상승 출발; 제롬 파월; 금리 인하; 은행발 불안; 경기 악화; 네고물량 출회; 환율 상단 제한 요인; 분기 말 네고물량 출회; 상승 출발;
#
# 윤재옥; 국민의힘; 국회; 전원위; 품격 있는 모습; 선당후사해야; 부적절한 언행; 상대방에 대한 배려와 존중; 본회의를 보거나 유튜브나 동영상 편집본으로 여러 차례 공유될 수 있다; 국민의 관심
# 윤재옥; 국민의힘; 원내대표; 품격 있는 모습; 국회; 전원위원회; 의원총회; 선거구제 개편; 의정활동; 선당후사; 말 한 마디; 행동 하나; 선당후사 정신; 국민 눈살; 말 한 마디, 행동 하나 할 때 개인 정치적 이익이
#
# 대통령실; 외교당국; 일본 매체의 왜곡 보도; 유감; 야당; 반일 팔이; 민주당; 후쿠시마 수산물 수입 문제; 한일관계 개선; 대한민국의 자주 독립
# 대통령실; 외교당국; 일본 왜곡 보도; 유감; 한일 정상회담; 윤석열 대통령; 기시다 총리; 위안부 문제; 독도 영유권 문제; 국민의힘; 민주당; 국회 문화체육관광위원회; 정치권의 공방; 한일 정상회담 결과; 정치권의 신경전; 한일 정상회담 결과
#
# 그랜저 하이브리드; 순수 전기차; 친환경차; 판매량; 하이브리드 모델; 올해 판매된 현대자동차의 7세대 신형 그랜저; 내수 판매량; 국산 친환경차; 경제성; 국내 하이브리드차 등록 대수
# 전기차; 그랜저; 하이브리드; 친환경차; 판매량; 현대차; 기아; 그랜저 하이브리드; 하이브리드차; 국토교통부; 하이브리드차 등록 대수; 그랜저 하이브리드 판매량; 투싼 하이브리드; 싼타페 하이브리드; 판매량 증가; 현대차의 2월 국내 하이브리드 판매량; 국토교통부에 따르면 국내 하이브리드차 등록 대수는 작년 말 기준
#
# 레드벨벳; 단독 콘서트; R to V; Red Velvet 4th Concert; 레드; Red; 벨벳; Velvet; 강렬한 댄스 퍼포먼스; 무대 브레이크 타임
# 레드벨벳; 단독 콘서트; R to V; Pose; Beg For Me; Beg For Me; Psycho; 피카부; 빨간 맛; Celebrate; 러시안 룰렛; You Better Know; Cele
#
# 위르겐 클린스만 감독; 대표팀; 소집; 해외파; 평가전; K리그; 훈련; 컨디션 회복; 본격적인 훈련; 입소일정
# 위르겐 클린스만 감독; 대표팀 소집; 클린스만 감독 체제; 첫 소집; 선수들의 각오; 콜롬비아와의 평가전; 오현규와 이기제; 손흥민; 김민재; 해외파들; 컨디션 회복; 콜롬비아전; 대표팀 훈련; 대표팀 소집; 대표팀 소집
#
# 부산; 부산 아이파크; 부산엑스더스카이; 스폰서십; 협약; 전망대; 해운대; 엑스더스카이점; 스타벅스; 선발콘서트
# 부산; 최고 높이 전망대; 부산엑스더스카이; 스폰서십; 협약; 전망대; 스타벅스; 경관; 경기장; 팬들; 경품; 성적; 승격; 3G 무패 행진; 3위 도약; 경남; 충북청주; 선두 도약; 경기장; 경관; 상호 홍보; 팬들; 성적; 우승
#
# 블래스트; 버추얼 IP; 플레이브; 시장 선도; 20억 프리A 투자; DSC인베스트먼트; 슈미트; 컴퓨터 그래픽; 버추얼 스튜디오; 리얼타임 콘텐츠
# 버추얼 IP; 블래스트; 20억 프리A; 투자; 자체 IP; 시장 선도; DSC인베스트먼트; 슈미트; 버추얼 지식재산권(IP); 플레이브(PLAVE); 유튜브 조회수; 기술 경쟁력; 메타버스와 케이팝(K-
#
# 임신; 폭행; 갈비뼈; 아이; 경찰; 가스라이팅; 이혼; 골밀도; 징역; 직장 동료
# 아내 폭행; 남편; 상습 폭행; 임신한 상태; 갈비뼈 부러짐; 경찰 신고; 가스라이팅; 폭행; 징역 8월; 집행유예 2년; 탄원서 제출; 사과; 직장 동료; 상습적 폭행; 무차별적 폭행; 골밀도; 징역 8월; 집행유예 2년; 사과;
#
# 코트니 카다시안; 자동차 박살; 선루프; 구멍; 유리; L사 브랜드; 화장실에서 음식을 먹는 사진; 검은 가죽 코르셋; 가정교육; 트래비스 바커
# 코트니 카다시안; 자동차; 파손; 선루프; L사 브랜드; 18만 5000달러; 논란; 검은 가죽 코르셋; 가정교육; 트래비스 바커; 세 명의 자녀; 대가족; 결혼; 트래비스 바커; 전 남자친구; 세 명의 자녀; 대가족; 자동차
#
# 강효종; LG; 선발; 속구; 슬라이더; 커브; 5선발 후보; 무실점; 대구삼성라이온즈파크; 경기
# 강효종; 삼성전; 150㎞ 호투; 선발 한 자리; 대구삼성라이온즈파크; 시범경기; 속구 최고 구속; 슬라이더; 커브; 체인지업; 변화구로 헛스윙 삼진; 4선발까지 확정지었다; 김윤식; 월드베이스볼클래식(WBC) 대표팀; 선발
#
# 알리바바; 사업 그룹; CEO; 이사회; 상장; 외부 자금 조달; 미국 증시; 지주회사 체제; 마윈; 인공지능
# 알리바바; 6개의 사업 그룹; 분할; CEO; 이사회; 외부 자금 조달; 상장; 지주회사 체제; AI; 클라우드 인텔리전스 사업부; 수익성; 주주 가치; 중국 정부의 통제; 마윈의 귀국; 6개의 비즈니스 라인; 중국 거대 기술 기업; 비즈니스 모델에 근본
#
# 북한; 김정은; 선전선동; 노동당; 간부들; 확성기; 혁명; 사상사업; 당중앙; 노선
# 북한; 김정은; 국무위원장; 전쟁억제력; 선전; 확성기; 당 선전선동분야; 당 중앙군사위원회; 당 선전일군; 혁명사상; 평양문화어보호법; 혁명 성지; 백두산 답사; 혁명 성지; 혁명사상; 혁명성지; 혁명사상; 확성기; 증폭기; 출력 높
#
# PSG; 시즌 막바지; 홈 경기; 5패; 리오넬 메시; 스타드렌; 0-2; 칼코토에캄비; 2골; 리그 4번째 패배
# PSG; 리그앙; 리그앙; 리그; 경기; 패배; 감독; 승점; UCL; 경질론; 갈티에 감독; 인터뷰; VAR; 리버풀; 경기; 승점; UCL 탈락; 시즌 막바지 경기들; VAR이 날 살렸어; EPL 구단들의 구애; 김민
#
# 공안당국; 민노총 간부; 주한미군 시설; 사진 촬영; 북한에 전달; 국가보안법 위반; 구속 수감; 경기 평택 주한미군 기지; 대남 공작기구; 북한의 지령
# 민노총; 간부; 주한미군; 사진 촬영; 북한; 혐의; 국가보안법; 압수수색; 구속영장실질심사; 대북 통신 문건; 간첩단 조작; 종북 몰이; 여론 호도; 중요 범죄사실; 대남 공작기구; 공공의 안전; 대북 통신 문건; 압수수색; 핵심 간부; 대남 공작기구;
#
# 포항 스틸러스; 광주FC; 공격 축구; K리그1; 3연승; 상대전적; 포항 최대 천적; 물러섬 없는 축구; 화끈한 공격 축구; 3연승 달성
# 광주FC; 포항스틸러스; K리그1; 3연승; 공격 축구; 하나원큐 K리그1 2023; 천적; 김기동 감독; 고영준; 제카; 김종우; 백성동; 포항전; 난적; 승리; 광주FC 감독; 난적 포항을 잡고 3연승
#
# 엔코아; 시야인사이트; 데이터웨어 서브스크립션 영업 파트너 협약; 지능형 모니터링 솔루션; 자사의 데이터 통합관리 솔루션; 데이터웨어(DATAWARE); 구독형 패키지; 스탠더드/엔터프라이즈/플래티넘 타입; 강원지역; 챗GPT
# 엔코아; 데이터웨어 서브스크립션; 영업 파트너 협약; 지능형 모니터링 솔루션; 데이터 통합관리 솔루션; 데이터웨어 서브스크립션 멤버십 서비스; 강원 지역 기업; 데이터 관리; 인공지능 플랫폼; 디지털 헬스케어 시스템; 챗GPT; 디에이샵 에이아이 파워드 팩; 데이터
#
# 송갑석; 더불어민주당; 자치분권정책협의회; 무당파; 민심; 김대중컨벤션센터; 비명계; 최고위원; 극단; 정치로부터 소외된 그들
# 송갑석; 더불어민주당; 지명직 최고위원; 무당파; 전에 없이 넓은 바다가 있다; 최우선의 민심; 탕평의 궁극적 목표; 고르게 사람을 등용하는 것; 친명이든 비명이든 헌신적이고 열성적인 당원; 변화와
#
# GTA 온라인; 신규 임무; 후반부 스토리; 더욱 강렬한 액션; 지난 전반부 임무; 프리드랜더 박사; 전반부, 후반부 임무; 꽃무늬 구피 풀 슬라이더; 검은색 이네마 F 스키 가면; 라임색 호피 슬랩 모자
# GTA 온라인; 신규 임무; 락스타 게임즈; 후반부 스토리; 강렬한 액션; 스토리; 후반부 스토리; 마이클 드 산타; 프리드랜더 박사; 오셀럿 버츄; GTA 달러; RP; 카디건; 오버플로드 타이런트; 이동 수단; GTA 달러;
#
# 바이오프린팅 분야; 바이오프린팅재생의료연구회; 강대희 교수; 서울대 의대; 미래기술연구단장; 서울대학교 융합의학기술원; 심포지엄; 재생의료; 국내 의료계; 인공 심장
# 바이오프린팅재생의료연구회; 강대희 교수; 서울대 의대; 바이오프린팅; 연구회; 창립 기념 심포지엄; 바이오프린팅 기술; 의료산업 신기술; 바이오프린팅 기술; 오가노이드 기술; 바이오프린팅과 재생의료 분야; 바이오프린팅과 재생의료 분야; 바이오프린팅과 재생의료 분야;
#
# 당정; 일제 강제징용; 배상 해법; 피해자; 유가족; 소통; 수출 절차; 화이트리스트; 한일 군사정보보호협정; 남부 지방 가뭄
# 당정; 일제 강제징용 배상 해법; 피해자; 유족; 소통; 한국; 일본; 수출 절차 간소화 혜택; 화이트리스트; 한일 군사정보보호협정; 국가안전보장회의 NSC; 항구적인 물관리 방안; 수자원; 법 개정; 한일 차관 전략대화; 남부 지방 가뭄 문제
#
# 창녕군; 지적재조사사업; 토지; 실제현황; 지적공부; 지적불부합지; 문서 작성; 디지털 지적; 군민 재산권; 경계분쟁
# 창녕군; 지적재조사사업; 지적불부합지; 지적측량; 토지; 지적불부합지지구; 지적불부합지지구; 토지소유자; 지적불부합지지구; 지적재조사지구지정; 경계분쟁해소; 토지이용가치; 재산권범위 명확
#
# 젠트리피케이션 방지; 지방정부협의회; 상가임대차보호법 개정; 지역상권법 제정; 상생하는 도시; 정원오 성동구청장; 지방정부; 회장; 권리보호 강화; 개선방안 공론화
# 정원오; 성동구청장; 지방정부협의회; 젠트리피케이션 방지; 지속가능한 공동체; 상가임대차법 개정; 지역상권법 제정; 상생하는 도시; 지방정부협의회 회장; 법률 제·개정 촉구; 상가임차인 보호 강화; 지역 상권과 상생하는 도시; 젠트리피
#
# 이효리; 댄스가수 유랑단; 화사; 김완선; 엄정화; 보아; 전국 투어 콘서트; 멤버; 노래; 효리 언니
# 댄스가수 유랑단; 이효리; 멤버 조합; 흑발 변신; 댄스 아티스트; 전국 투어 콘서트; 김완선; 엄정화; 보아; 이효리의 변신; 댄스 여자 가수들의 긍정 에너지; 댄스 여자 가수들의 신나게 해주는 긍정 에너지; 댄스 여자 가수들의 긍정 에너지;
#
# 차준환; 이해인; 국제빙상경기연맹; 피겨스케이팅 세계선수권대회; 은메달; 김연아; 남자 싱글 최초; 많은 분들; 생각보다 많이; 메달을 목표
# 세계선수권; 차준환; 이해인; 은메달; 김포국제공항; 메달; 한국 선수; 남자 싱글 최초; 관중; 경기; 시즌; 세계선수권 메달; 시즌 마지막 경기; 대학가요제 참가신청; STN 스포츠; 은메달; 이해인; 경기; 메달; 관중; 한국 선수;
#
# KGC; 정규리그 우승; 스펠맨; 안양 외국선수상; 3점슛; 리바운드; 어시스트; 블록슛; 외국선수상 경쟁; 자밀 워니
# KGC 정규리그 우승; 스펠맨; 안양; 외국선수상; KGC; 외국선수상 경쟁; 자밀 워니; 라건아; 더블더블 머신; 챔피언결정전 우승 경험; 외국선수 역사; 안양 구단 최초의 외국선수상; 외국선수상 수상; 외국선수 역사; 외국
#
# 대통령실; 저출산 대책; 국민; 출산율; 대도시; 서울; 부산; 세종; 현금 지원; 육아휴직 제도
# 대통령실; 저출산 대책; 국민; 출산율; 서울; 부산; 광역 대도시; 세종; 현금 지원; 육아휴직; 교육; 부동산; 검토; 국민의힘; 현금 지원; 부동산; 교육; 육아휴직 제도; 대통령실 관계자; 저출산 대책; 국민의힘; 검토; 국민이 납득할
#
# 티맥스핀테크; 배달서비스공제조합 앱; SaaS; 라이더의 유상운송보험료 부담 완화; 이륜차 안전운전 환경 조성; 디지털 공제 플랫폼; 종사자의 업무시간에 따른 탄력적 보험 제도; 인공지능(AI) 챗봇 상담 및 교육 플랫폼; 모바일 퍼스트; 오픈 플랫폼
# 티맥스핀테크; 배달서비스공제조합; SaaS; 라이더; 유상운송보험료; 이륜차 안전운전 환경; 모바일 퍼스트; AI챗봇; 실시간 데이터 분석 환경; 공제 업무 관련한 업무 전반; AI챗봇; 실시간 데이터 분석 환경; 계약 및 보상; 재무 업무 구축; 9
#
# 스테이씨; 일본; 싱글 2집; Teddy Bear; 컴백 쇼케이스; POPPY; Stereotype; ASAP; RUN2U; So What
# 스테이씨; 일본 싱글 2집; Teddy Bear; 컴백; 쇼케이스; 일본 오사카; 도쿄; 일본 두 번째 싱글앨범; 타이틀곡; Teddy Bear; 앙코르 곡; 팬미팅; 일본 두 번째 싱글앨범; Teddy Bear; 일본 팬
#
# 서울 전셋값; 서울 아파트 매매가; 부동산R114; 고금리; 신규 입주 물량; 재건축; 일반 아파트; 전세시장; 중저가 대단지 아파트; 토지거래허가구역
# 서울; 전셋값; 하락; 부동산R114; 서울 아파트값; 하락폭; 재건축; 일반 아파트; 매수-매도 눈치싸움; 저가 급매물; 서울 주요 지역 전세가격 변동률; 중저가 대단지 아파트; 저가 급매물 위주로 거래되며 낙폭을 키웠다; 서울 주요 지역 전세
#
# 김하성; 수비수; 주전 유격수; 타율 0.251; 골드글러브 유격수 부문 최종 후보; DRS 12; UZR 8.7; 2루수; 제이크 크로넨워스; 보가츠와 함께 키스톤 콤비
# 김하성; 샌디에이고 파드리스; 수비수; 메이저리그; 핵심 수비수; 수비력; 투수; 금지 약물; 골드글러브 유격수 부문 최종 후보; DRS 8.7; 타티스; 외야수로 활약; 키스톤 콤비; 재능있는 키스톤 콤비; 샌디에이고 파드리스의 김하성; 수비
#
# 백종원; 효과; 예산시장; 재개장; 인파; 이용방법; 자리 착석 시스템; 대기 접수; 가격 신고; 주차타워
# 백종원 효과; 예산시장; 재개장; 인파; 더본코리아 대표; 김태흠 충남지사; 바가지 요금; 고객들; 자리 착석 시스템; 주차타워 건립 지원; 대규모 주차타워 건립 지원; 김태흠 충남지사; 예산시장 방문객 증가; 주차난 해소; 대규모 주차타워 건립
#
# 한강공원; 나들목; 승강장; 암사초록길; 연말 준공; 신설; 그레이트 한강 프로젝트; 나들목 리모델링; 승강기; 반응형 미디어 아트공간
# 한강공원; 나들목; 승강기; 한강공원 접근시설; 한강공원 보행접근시설 종합정비계획; 한강공원 보행접근시설 종합정비계획; 암사초록길; 한강공원 접근시설 개선; 나들목 리모델링; 승강기 증설; 한강공원 곳곳에 승강기도 증설; 한강을 방문하는 모든
#
# 맨시티; 리버풀; 홀란; 알바레스; 그릴리시; 마레즈; 경기; 선제골; 골; 평점
# 맨시티; 알바레스; 그릴리시; 마레즈; 리버풀; 홀란; 선제골; 역전골; 평점; 축구분석매체; 후스코어드닷컴; 오현규; 황의조; 조규성; 크로스; 드리블; 발리슛; 중앙에서 공격; 크로스; 평점; 축구소식; 풋
#
# 정다은; 아나운서; 퇴사; KBS; 동료; 미디어 환경; 15년 차; 워킹맘; 질문; 응원
# 정다은; KBS; 퇴사; 아나운서; 동료들; 미디어 환경; 변화; 도전; 워킹맘; 사랑; 응원; 질문; 결심; 감사 인사; KBS 공채 34기; 조우종; 결혼; 딸; KBS 아나운서 출신; KBS 공채 34기 아나운서; 15년 차 아나운서; 41세 워킹
#
# 에데르송; 안첼로티; 브라질 감독; 모로코; 대표팀; 친선 경기; 레알 마드리드; 카세미루; 비니시우스; 밀리탕
# 카세미루; 비니시우스; 밀리탕; 안첼로티 브라질; 브라질 국가대표 골키퍼; 모로코; 카타르 월드컵; 레알 마드리드; UEFA 챔피언스리그; 안첼로티 감독 부임설; 대표팀 소집; 위너; 빠른 시일 내에 알 수 있을 거라고 생각
#
# 포항; 농업 인프라 구축; 지속 가능한 신성장 농업; 청년농 육성; 친환경 농업; 생활자금; 농지 임대 지원; 환경친화적 농업; 농산물 생산 장려금; 고품질 쌀 생산
# 포항; 지속가능한 농업인프라; 청년농 육성; 친환경; 도시와 함께 성장; 농촌; 청년 창업; 농지; 교육; 친환경농업 비중; 무농약 지속 직불금; 명품 쌀 재배; 고부가가치 창출; 경영비 절감; 농촌 노동력 부족 대응; 고품질 쌀 생산시설; 신규 사업 발굴
#
# 김병현; 사장님 귀는 당나귀 귀; 차태현; 반지; 이찬원; 애리조나; 다이아백스; 구원 투수; 팬심; MLB
# 김병현; 사장님 귀는 당나귀 귀; 김병현; 이삿짐; 트렁크; 애리조나 다이아백스; 우승반지; 이찬원; 다이아몬드백스; 찐팬; 화려함; 김병현의 위상; 김병현의 위상; 김병현의 위상; 김병현의 위상; 김병현의 위상; 김병현
#
# 수분 섭취; 요로결석 예방; 요석 크기; 배뇨장애; 혈뇨; 통증; 체외충격파쇄석술; 요관내시경수술; 예방; 옥살산염
# 하루 2리터의 수분 섭취 노력; 요로결석 예방; 요로결석; 신장; 요관; 방광; 요도; 체외충격파쇄석술; 요관내시경수술; 나트륨 섭취량 조절; 옥살산염; 민간요법; 정밀 검사 및 치료; 요로결석
#
# 진짜가 나타났다; 백진희; 정의제; 이별; 임신; KBS 2TV; 주말드라마; 오연두; 김준하; 공태경
# 진짜가 나타났다; 백진희; 정의제; 이별; 임신; KBS 2TV; 주말드라마; 공태경; 오연두; 김준하; 바람난 정의제; 악연; 복수심; 반지; 장세진; 임신; 충격; KBS 2TV 주말드라마 '진짜가 나타났다'
#
# 미스터트롯2; 결승전; 미방송분; 스페셜 콘서트 전설의 시작; 최강 TOP7; 베스트 무대; 화제의 무대; 마스터; 인생곡 무대; 감성 가득 서정시
# 미스터트롯2; 송도현; 추혁진; 송민준; 결승전; 미방송분; 스페셜 콘서트; 화제의 인물; 인생곡; 트롯 대축제; 감동의 극찬; 정통 트롯; 명불허전; 명불허전; 명불허전; 명불허전; 명불허전의 눈물;
#
# 가루녹차; 우울증; 생쥐실험; 도파민성 신경회로; 개선; 시루; 찻잎; 카멜리아 시넨시스; 꼬리매달기시험; 항우울 효과
# 가루녹차; 우울증; 생쥐실험; 도파민성 신경회로; 시루; 카멜리아 시넨시스; 항우울제; 뇌의 도파민성 신경회로; 생쥐 몸무게 kg당 10mg; 100mg 용량의 가루녹차; 비디오카메라; 도파민성
#
# 베이비몬스터; 라스트 이밸류에이션; EP.5; 보컬 솔로 미션; 파리타; 올 오브 미; 로라; 섬원 유 러브드; 아사; 미, 마이셀프 & 아이; 치키타; 트레이터
# 베이비몬스터; 보컬 솔로 미션; 중간 점검 1위; YG엔터테인먼트; 파리타; 로라; 아현; 하람; 치키타; 보컬 역량; 중간 점검 1위; YG엔터테인먼트; 데뷔 리얼리티 '라스트 이밸류에이션'; 보컬 솔로 미션; 중간
#
# 마법사; EPL; 귀환; 19등 강등권; 협상 진행 중; 라파엘 베니테스; 레스터 시티 감독 후보; 리버풀; 레알 마드리드; UEFA 챔피언스리그
# 레스터 시티; 라파엘 베니테스; 리버풀; 레알 마드리드; 프리미어리그; UEFA 챔피언스리그; 뉴캐슬 유나이티드; 에버턴; 대한민국 축구대표팀; 레스터 감독 후보; 강등권; 명예회복; 제시 마치 옵션; 로마노; 유럽 축구 전문기자 파브리지오 로마노
#
# 길복순; 넷플릭스; 전 세계 3위; 영화; 플릭스패트롤; 498점; 청부살인업계; 킬러; 전도연; 액션
# 전도연; 액션; 길복순; 넷플릭스; 전 세계; 출발; 영화 부문; 전 세계 3위; 한국; 홍콩; 인도네시아; 필리핀; 대만; 베트남; 액션 영화; 변성현 감독; 전도연의 섬세한 연기력; 넷플릭스 영화 부문 1위; 길복순'; 변성
#
# 한국은행; 디지털화폐; CBDC; 총재 이창용; 가상자산; 대기업; 개인정보보호; 국경을 초월한 협력; 전통적인 규제 시스템; BIS 이노베이션 서밋 프로그램
# 이창용 한국은행 총재; CBDC 도입; 디지털화 수준; 중앙은행; 디지털화폐; 빅테크 회사; 개인; 이해 관계자들; 비트코인 거래; 대기업; 국경 초월한 협력; 개인정보 보호 문제; 암호화 기술; 디지털 기술 개발; 가상자산; 중앙은행 결제 시스템; 블록체인 지갑; 개인
#
# 테슬라; 중국 시장; 판매 기록; 전기차; 1분기; 가격 인하; 비야디; 시장점유율; 투자등급 상향조정; 무디스
# 테슬라; 중국; 전기차; 판매량; 가격 인하; 비야디; 신용평가사; 신용등급; 정크에서 투자 적격등급; 신용등급 상향조정; 신용평가사 무디스; 신용등급 투자 적격등급; 모델Y; 모델3; 모델Y의 가격 인하; 모델Y의 판매량; 모델
#
# 손흥민; EPL; 토트넘; 사우샘프턴; 출전; 도움; 골; 승리; 경기; 후반
# 손흥민; EPL; 통산 50호 도움; 토트넘; 사우샘프턴; 2022-23 EPL 28라운드; 선발 출전; 포로; 선제골; 동점골; 승점; 무승부; 토트넘은 4위; 최하위 사우샘프턴은 6위; 머니S설문; 여론확인; 머니S설문
#
# 케인; 이탈리아; 잉글랜드; 유로 2024; 예선; 대회; 루니; 수비; 경기; A매치
# 케인; 위대한 도전; 이탈리아; 잉글랜드; 유로 2024 예선; 유로 2020; 월드컵 예선; 북마케도니아; 몰타; 대회 첫 우승; A매치 최다골; 전설; 이탈리아 축구국가대표팀; 유로 2020 결승; 유로 2020 결승; 유로 2020 결승; 유로 2024 예선 주요 경기 생
#
# 출근길; 미세먼지; 안개; 서해안; 공기; 대중교통; 수도권; 미세먼지 비상저감조치; 기온; 건조 주의보
# 출근길; 미세먼지; 안개; 수도권; 대중교통; 마스크; 대기 상황; 미세먼지 비상저감조치; 기온; 건조주의보; 화재 사고; 연합뉴스TV; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스; 연합뉴스TV 뉴스
#
# KB라이프생명; 고객패널; KB스타지기; 발대식; 고객의 목소리; 경청; 금융소비자 보호; 제2기; 모집; MZ세대
# KB라이프생명; 고객패널; KB스타知己; 발대식; 이환주; 소비자보호본부; MZ세대; 라이프스타知己; 나름답게 스타知己; 신상품; 요양·시니어 시장; 소비자 보호 체계; 금융소비자 중심 보호 체계; 금융소비자 보호 제도 개선;
#
# 창원 의과대 설립; 경남도의회; 창원시의회; 의료서비스; 의사 인력난; 의료격차; 도내 의과대 정원; 의사 수; 비수도권 대도시 중 의과대 부재; 응급의료 취약지
# 창원 의과대; 경남도의회; 창원시의회; 공동 기자회견; 의료서비스; 필수의료; 의사 인력난; 지역 의료 불평등; 의사 선발; 교육; 응급의료 취약지; 대정부 건의안; 창원지역 의과대학 설립 촉구 대정부 건의안; 의사협회; 의대 정원 확대;
#
# 케인; 맨유; 영입; 라우타로 마르티네스; 공격수; 스트라이커; 연계 능력; 빅터 오시멘; 이적; 차선책
# 케인; 맨유; 공격수; 영입; 공격수 찾기; 득점; 연계 능력; 래쉬포드; 이적; 마르티네스; 스콜스; 인터밀란; 마르티네스 영입 추천; 이적 추천; 맨유 위기; 토트넘 영입 1순위; 세부 조항 발동; 이적 추천; 포포투
#
# 노조 설립; 무분규 타결; 코웨이 비결; 조합원 찬성; 임단협; 최단기간 타결; 노사 간 협력; 미래 경쟁력 확보; 고객 가치 극대화; 대내외 경영 환경
# 노조 설립; 무분규 타결; 코웨이; 조합원; 임단협; 노사 간 협력; 미래 경쟁력; 고객 가치 극대화; 업무용 차량 지급; 기본급 인상; AS; 공동 목표; 고객 가치 극대화; 노사 대표들; 협력을 바탕으로 공동 목표인 '고객 가치 극대화' 달성
#
# 국민연금; 수급자; 월 200만원 이상; 5410명; 4배로 늘어남; 200만원대 국민연금 수령자; 60대 이상; 15명; 국민연금 월 수령액이 100만원을 넘는 사람; 57만106명
# 국민연금; 월 200만원 이상; 수급자; 5410명; 1년 새 4배; 서울 서대문구; 국민연금공단; 서울북부지원본부; 은퇴 후; 월 200만원 이상; 수령액; 물가 상승률; 남성; 여성; 조기 수령자; 월평균 수급액; 57만
#
# 정제마진; 국내 정유사; 1분기 실적; 전년 동기 대비; 하락; 중국 리오프닝; 수요 회복 본격화 전망; 원유 가격; 정유업체들의 실적; SK에너지 영업이익
# 실적; 정제마진; 중국 리오프닝; 내수 대응; 2분기 수요 회복; 국내 정유사들의 실적; SK이노베이션; SK온; HD현대오일뱅크; GS칼텍스; S-OIL; 영업이익 감소; 정유사들의 실적 악화; 금융정보업체 에프앤가이드 컨
#
# 여의도; 디지털 국제금융중심지; 투자; 금융특구; 디지털금융지원센터; 핀테크기업 육성; 금융중심지 브랜딩 홍보; 금융교육 활성화; ICT 특정개발진흥지구; 인공지능(AI) 및 ICT 산업
# 여의도; 디지털 국제금융중심지; 593억500만원; 국제금융지수; GFCI; 글로벌 컨설팅그룹; 여의도 금융 특정개발진흥지구; 핀테크기업 육성; 금융교육 활성화; 용적률 등 건축 규제 완화; 권장업종; 인공지능 및 ICT 산업 제조·개발·서비스업; ICT 특정
#
# 소변량 감소; 전립선비대증; 신부전증; 방광 질환; 전립샘 질환; 음향 분석법; 초음파 검사; 비뇨의학; 배뇨 상태; 자가 진단
# 소리만 듣고; 소변량; 비뇨기계; 이상; 소변량; 전립선비대증; 신부전증; 방광; 요도; 음향 분석법; 배뇨 상태; 자가 진단; 건강한 사람; 범부처 의료기기 연구개발사업; 이상철 교수; 이상철 교수; 음향 기반 측정법
#
# 윤 대통령; 국정수행 지지율; 부정평가; 리얼미터; 윤석열 대통령; 전국; 조사; 긍정평가; 차이; 정당 지지도; 더불어민주당
# 윤 대통령; 국정수행; 지지율; 부정평가; 리얼미터; 여론조사; 긍정평가; 부정평가; 정당 지지도; 더불어민주당; 국민의힘; 정의당; 표본오차; 표본오차; 무선 97%·유선 3%; 표본오차; 중앙선거여론조사심의위원회 홈페이지; 여론
#
# 박동혁 감독; 충남아산; 부산아이파크; 하나원큐 K리그2 2023; 승점; 선수들; 경기; 무승부; 자원 정성훈; 득점
# 박동혁 감독; 무승부; 충남아산; 선수들; 부산아이파크; 승점; 전술 변화; 정성훈; 득점; 후반의 차이점; 공을 끊었을 때 재차 공을 빼앗기는 모습; 연계 보완; 숫자를 늘린 상대; 실점을 하지 않기 위해 뒤로 내렸다; 연계 보완
#
# 라온화이트햇; 세종대학교 정보보호학과; 분산ID(DID) 신원인증; 블록체인; 정보보호 전문 인력 양성; 정보보호 특성화 대학교; 정보보호 교육; 인턴십 프로그램; 산학협력; 정보보호 인재 양성
# 라온화이트햇; 세종대학교 정보보호학과; 분산ID(DID) 신원인증; 블록체인; 정보보호 전문 인재 양성; 사이버보안; 정보보호 특성화 대학교; 보안 소프트웨어(SW) 개발 능력; 인턴십 프로그램 운영; 산학협력 기반 인적 상호 교류; 정보보호 융합 인재 양성; 정보
#
# LG화학; 2차전지; LG에너지솔루션; 에코프로; LMFP 양극재; 첨단소재 분야; NH투자증권; 목표주가 상향; 인플레이션감축법; 양극재 출하량 증가
# LG화학; LG에너지솔루션; 2차전지; 에코프로; 삼성SDI; 코스닥; NH투자증권; LG에너지솔루션의 인플레이션감축법(IRA); 양극재 사업; 탄소나노큐브(CNT); 리사이클링; 분리막; CNT; LG에너지솔루션의 밸류체인 확대;
#
# 인공 수정; 성별 선택; 정자의 성; 인공수정; 자식 성별 선택; 윤리논쟁; 미국 뉴욕 웨일 코넬 의대 지안피에로 팔레르모 교수팀; Y 염색체 정자; X 염색체 정자; 성별 선택 윤리 논쟁
# 인공 수정; 성별 선택; 윤리논쟁; 정자의 성; 배아 선택; 자손의 성; 부모 기호; 배아의 성별; 윤리적 우려; 규제 필요; 피부색; 눈의 색깔; 규제 필요성; 자손의 성 조작; 규제 필요성; 피부색이나 눈의 색깔 같
#
# 홍경민; 불후의 명곡; 출연; 최다 출연자; 이찬원; 특집; 시간; 트로피; 알리; 아티스트
# 홍경민; 92회 출연; 불후의 명곡; 최다 출연자 기록; 이찬원; 트로피; 알리; 불후의 명곡; 특집; 무대 돌려막기 비법; KBS2TV; 예능 프로그램; 출연 횟수; 초대; 무대 돌려막기 비법; 불후의 명곡 출연; 트로피; 알리;
#
# 외국인 의사; 국민훈장; 전 국립소록도병원 의사; 샤를 나베(Charles Navez); 보건복지부; 1960년대 소록도병원; 치료 효과; 첨단 의료기술; 포장; 대통령 표창
# 외국인 의사; 국민훈장 모란장; 보건의 날 기념식; 샤를 나베; 국립소록도병원; 다미안 재단; 외과수술; 물리요법; 보건복지부; 보건의료 발전; 국민훈장 목련장; 노숙인; 장애인; 불법체류자; 건강한 대한민국; 보건의료인 여러분; 온
#
# EV9; 중고 카니발; 시세 하락; 케이카; 직영 중고차 플랫폼; 올 뉴 카니발; 더 뉴 카니발; 국내 중고차 시장 평균 시세; 2020년 카니발 4세대; 경유 차 약세
# 중고 카니발; 시세 하락; 케이카; 더 뉴 카니발의 시세; 가솔린(휘발유) 모델; 경유 차; 카니발 4세대; 공급 증가; 신형 카니발 출시; 대형 전기 스포츠유틸리티차(SUV) EV9 출시; 기아의 대형 전기 스포츠유틸리티차(SUV) EV9 출시;
#
# 민주당; 양곡관리법; 윤석열 대통령; 쌀값 정상화법; 국민의 뜻; 비판; 쌀 생산 조정; 남는 쌀 방지법; 농민들; 대통령에게 허위 보고
# 민주당; 양곡관리법; 윤석열 대통령; 국민의 뜻; 거부권; 쌀값 정상화법; 남는 쌀 방지법; 정황근 농림축산식품부 장관; 대통령에게 허위 보고; 쌀값 정상화법; 농민의 생존권 보장; 초과 생산량; 매입하도록 하는 내용; 쌀값 정상화법;
#
# 뷰민라; 라인업; 영케이; 하이키; 허회경; 밴드 데이식스; 음원 역주행; 선구자 밴드 솔루션스; 여성 싱어송라이터; 노리플라이
# 뷰티풀 민트 라이프 2023; 최종 라인업; 영케이; 하이키; 허회경; 뷰민라; 밴드 포맷; 데이식스; 영케이와 하이키; 노리플라이; 노리플라이; 밴드 포맷; 타임테이블; 민트페이퍼의 홈페이지; 민트페이퍼의 SNS; 아티스트들
#
# 딸; 친자식; 부모; 병원; 배상; 소송; 유전자 검사; 의무기록; 상대; 생물학적 친생자 관계
# 친자식; 딸; 산부인과 병원; 배상; 손해배상청구 소송; 유전자 검사; 의무기록; 반대로; 친부모; 생물학적 친생자 관계; 정신적 고통; 사고; 과실; 정신적 고통이 매우 클 것; 생물학적 친생자 관계가 아님을 알게 돼 받게 될
#
# 광주시; 1분기; 외국인직접투자; 유치; 역대 최고; 신고금액; 비수도권 1위; 앰코코리아; 대규모 증액투자; 첨단 소·부·장 반도체분야; 글로벌 거점
# 광주시; 외국인직접투자; 유치실적; 비수도권; 신고금액; 산업통상자원부; 전기전자; 식품; 부동산; 앰코테크놀로지코리아; 첨단 소·부·장; 인공지능; 미래 신산업; 투자환경; 산업별 글로벌 앵커기업; 투자유치; 산업기반시설 확충; 정책
#
# 박원순; 전 서울시장; 묘소; 이장; 모란공원; 민주열사묘역; 경기도 남양주시; 유족; 성범죄자; 국민의힘
# ...
# 케이팝 제너레이션; 여성 아티스트; 치열한 삶; 보아; 선미; 아이브; 르세라핌; IVE; Self Love; 밸런스 게임; 여성 솔로 아티스트; 케이팝 아티스트; 케이팝 아티스트; 케이팝 여성 솔로 아티스트; 케이팝 여성 솔로 아티스트; 케이팝 여성 솔로
#
# 공공기관 임원; 검찰 출신; 법조인 출신; 임명; 비상임이사; 감사; 정권 교체; 낙하산 인사; 선호; 정치권 연결; 출신; 검사; 상임감사
# 검찰 출신; 공공기관 임원; 법조인; 윤석열 정부; 검사 출신; 법조인; 공공기관 임원; 검사 출신; 법조인; 윤석열 대통령; 검찰 출신; 법조인; 정치권; 낙하산 인사; 정치권 출신; 정치권 출신; 정치권 출신; 정치권 출신; 정치권 출신; 정치권 출신;
#
# 애플; 보안 취약점; 보안 업데이트; 아이폰; 아이패드; CVE-2023-28205; CVE-2023-28206; IO서페이스엑셀러레이터; 웹킷; 개인정보
# 애플; 보안 취약점; iOS; 아이패드OS; 맥OS; 사파리 웹 브라우저; 커널 권한; 커널; iOS패치; 아이패드프로; 아이패드미니; iOS패치과정; 보안 업데이트; 해커 그룹; 유출된 개인정보; 데이터 훔침 가능성; 보안 업데이트
#
# 박진주‧이미주; 주주 시크릿; 놀면 뭐하니?; 대학교 행사; 첫 공식 스케줄; 밤이 무서워요; 데뷔 무대; 화려한 형광색 복고풍 의상; 실수 없이; 핫 신예
# 주주 시크릿; 대학교 행사; 데뷔 무대; JS 대표; 밤이 무서워요; 형광색 복고풍 의상; 스타킹; 실수 없이 첫 데뷔 무대; 음원 공개; 깜짝 데뷔 무대; MBC '놀면 뭐하니?'; 대학교 캠퍼스 행사; 주주 시크릿의 데뷔 무대; 깜짝 데뷔 무대; 대학교
#
# 2차전지 질주; 리튬주도; 상승률 높은 종목; 이엔플러스; 포스코엠텍; 하이드로리튬; 어반리튬; 미래나노텍; 금양; 강원에너지
# 2차전지; 리튬; 이엔플러스; 포스코엠텍; 하이드로리튬; 이브이첨단소재; 어반리튬; 미래나노텍; 금양; 강원에너지; 이브이첨단소재; LG화학; 탄산리튬; NH투자증권; 성장 가능성; NH투자증권; NH투자증권 연구원;
#
# 대법원; 한강 토막살인; 유족; 배상 판결; 계산; 기지급 유족구조금; 장씨 채무; 공제; 손해배상액; 피고들의 공동 배상 금액; 구조금
# 대법원; 한강 토막 살인 사건; 유족 배상 판결; 유족구조금; 장씨 채무; 공제; 모텔 업주; 손해배상 소송; 공동 배상; 채권자 지위; 모텔 업주의 배상 책임; 유족이 배상할 금액; 구조금을 받은 피해자; 모텔 업주의 부담분; 공동 부담하는 부분;
#
# 서울시; 1000원의 아침밥; 대학생; 지원 추진; 54개 대학; 청년표심; 정부; 여당; 사업 확대; 참여율
# 서울시내; 대학생; 1000원의 아침밥; 지원 추진; 서울시; 54개 모든 대학; 총선; 청년표심; 정부; 여당; 사업 확대; 예산 증액; 지원 인원 확대; 젊은층 환심; 아침 식사 지원; 정부의 움직임; 대학 학생들의 높은 정책 수요;
#
# 탬파베이 레이스; 개막 6연승; 패하지 않은 팀; 에이스 셰인 맥클라나한; 득점 마진; 메이저리그 최고 기록; 월드시리즈 우승; 캔자스시티 로열스; 8일부터 오클랜드 어슬레틱스; 각자의 지구에서 정상
# 탬파베이 레이스; 개막 6연승; 메이저리그; 유일한 무패의 팀; 완더 프랑코; 득점 마진; 메이저리그 최고 기록; 애틀란타 브레이브스; 밀워키 브루어스; 오클랜드 어슬레틱스; 지구에서 정상에 올라있다; 내셔널리그에서는
#
# 맨유; UEFA 챔피언스리그 결승; 바르셀로나; 승리; 16강 진출; 알레한드로 가르나초; 세리머니; 게시물; 아라우호; 겸손함
# 우에다; 가르나초; 맨유; UEFA 챔피언스리그; 바르셀로나; UEL; UEFA 유로파리그; 결승전; 16강행; 페드리; 세리머니 모션; 악감정; 페이지; 리그와 코파 델 레이 우승; 전달자; 해외축구의 소식; 포포투
#
# 르세라핌; ANTIFRAGILE; 스트리밍; 쏘스뮤직; 미니 2집; 타이틀곡; 재생수; K-팝; 레코드협회; 더블 플래티넘
# 르세라핌; ANTIFRAGILE; 스포티파이; 2억 스트리밍; 미니 2집 타이틀곡; 일간 톱 송; 글로벌 주간 톱 송; 누적 재생수; K-팝의 새 역사; 일본 데뷔 싱글; FEARLESS; K-팝 그룹; 현지 데뷔
#
# 엔싸인; 아이돌 라디오 라이브 인 재팬; MBC라디오; n.CH엔터테인먼트; 일본; 지프투어; 슈퍼주니어; 쏘리 쏘리; 프리 데뷔 미니 앨범; 솔티(Salty)
# 엔싸인; 아이돌 라디오 라이브 인 재팬; MBC라디오; 아이돌 라디오 라이브 인 재팬; 일본; 제프투어; 일본 5개 도시; 솔티(SALTY); Rising Sun(라이징 선); Woo Woo(이게 말이 돼?); 정식 데뷔
#
# 지구마불; 세계여행; 빠니보틀; 무인도; 주사위 게임; 원지; 원드리 헵번; 로마의 휴일; 곽튜브; 핀란드
# 지구마불 세계여행; 원지; 로마의 휴일 투어; 빠니보틀; 무인도; 주사위; 생존기; 오드리 헵번; 핀란드; 여행 크리에이터; 3인 3색 여행 콘텐츠; 노홍철; 주우재; 주현영; 3MC; 촬영 현장 에피소드;
#
# 별세; 현미; 이봉조; 슬픈 러브스토리; 연이어 히트곡; 이봉조와 인연; 방송된 TV조선; 스타다큐 마이웨이; 서울 동작구 중앙대학교병원 장례식장; 가수 고니로 활동
# 현미; 별세; 이봉조; 별세; 밤안개; 히트 가수; 히트곡; 이봉조와 인연; 이봉조; 별도로; 부부의 연; 이봉조와 인연; 별도로; 서울 동작구 중앙대학교병원 장례식장; 빈소; 조카; 노사연; 한상진;
#
# 유엔 무대; 남북 설전; 북한 대표; 미사일 발사; 한미 연합연습; 북한 대표 반박; 한반도; 전쟁 억지력; 미국의 도발적 군사행동; 북한의 무력도발
# 유엔 무대; 남북; 북한; 미사일 발사; 한미 연합연습; 방어적 조치; 반박권; 유엔; 군사환경; 북한 대표; 국제법 위반; 대량살상무기 프로그램; 방어적 조치; 국방력 강화; 대규모 군사훈련; 방어적 조치; 유엔 무대에서 설전; 한미 연합연습;
#
# 넥슨; 카트라이더: 드리프트; 메이플스토리; 캐릭터; 출시; 패키지; 이모션; 업데이트; 추첨; 이벤트
# 넥슨; 카트라이더: 드리프트; 메이플스토리; 제휴 업데이트; 마스코트 캐릭터; 이모션; 핑크빈 패키지; 루시드 패키지; 이벤트 페이지; 드림카 꾸미기; 3,000 루찌; 판도라스 박스; 메이브; 판도라스 박스; 메이브와 루시드의 드림
#
# 현진영; 아이 갖는 것에 대한 솔직한 마음; 시험관 시술; 걱정; 아버지의 나이; 아이 초등학교 들어갈 때 늘어나는 걱정; 일을 몇 살까지 해야 하는지; 오서운의 제안; 건강 챙기기; ‘살림하는 남자들 시즌2’
# 현진영; 살림하는 남자들 시즌2; 시험관 시술; 오서운; 아버지 학교; 건강; 마지막; 제안; 체력; 내년; 한 번만 하자; 살림하는 남자들 시즌2’ 방송 캡처; KBS2TV; KBS2TV; 시험관 시술; 오서운; 아버지
#
# 화학연; 적외선 투과 렌즈; 황 폐기물; 고부가가치; 역가황 고분자 소재; 고강성; 고투과; 응용 기대; 자율주행 나이트비전; 열감지 카메라
# 화학연; 황 폐기물; 역가황 고분자; 고강성; 고투과 적외선 렌즈; 적외선 투과; 적외선 광학 분야; 자율주행 나이트비전; 열감지 카메라; 군수용 야간 감시 카메라; TVB 가교제; 전기·전자; 에너지; 응용 분야; 연구 결과
#
# 진보당; 강성희; 후보; 전주을; 국회의원; 득표율; 진출; 무소속; 임정엽; 공직선거법
# 진보당; 강성희; 국회의원; 전주을; 당선; 원내 입성; 국회의원; 재선거; 득표율; 무소속 임정엽 후보; 진보당 후보; 녹색당; 연대; 김경민 후보; 득표율; 안해욱 후보; 김호서 후보; 호남 공략; 국민의힘 후보; 높은 문턱; 국회의원 선거;
#
# SK렌터카; 정기주주총회; 보통주; 배당금; 이사 보수한도; 재무제표 승인; 정관 변경; 이사 선임; 연결 기준 매출; 중고차 사업
# SK렌터카; 주주총회; 배당금; 이사 보수한도; 재무제표; 정관 변경; 중고차 사업; 단기 렌털 사업; 타고페이; ESG 경영; 전기차(EV) 렌털 사업자; 이사회 내 각종 위원회; 류성희; 황일문 대표이사; 전기차(EV) 렌털 사업; 배당금 지급
#
# KT 윤경림 대표 후보; KT 그룹트랜스포메이션부문장 사장; 대표이사 후보; 이사회; 공식 사퇴; 사장; 이해관계자들의 기대 수준; 지배구조 개선; 최고경영자; 경영 안정화
# KT; 윤경림; 대표 후보; 공식 사퇴; 이사회; 후보에서 사퇴; 지배구조 개선; 조기 경영 안정화; 대표이사 직무 대리; 대표 선임; 대표 선임하느라 올해 신규사업 계획; 대표 선임 실패; 정치권 낙하산; 민간기업에 대통령 낙하산; 대표 선임하느라 올해 신규
#
# 윤석열 대통령; 인도네시아 외교장관; 한·인도네시아 협력 방안; 조코위 대통령 친서; 민주주의 정상회의; 첨단산업 분야; 전략적 연대; 우리 기업의 투자; 인도네시아 수도이전 사업; 한·인니 간 협력
# 윤석열 대통령; 인도네시아 외교장관; 한·인도네시아 협력 방안; 한·인니 간 첨단산업 분야의 전략적 연대; 전기차; 배터리; 석유화학; 철강; 수도이전 사업; 스마트시티 건설; 인태지역회의; 인태지역회의 참석; 조코위 대통령 친서 전달; 한·아세안
#
# 배우 차주영; 전지적 참견 시점; 스튜어디스 혜정이; 더 글로리; 짜릿한 질주 본능; 사찰; 응원군; 화제작; 무장해제; 극과 극 매력
# 차주영; 전참시; 스튜어디스 혜정이; 스님들; 힐링 플레이스; 극과 극 매력; 더 글로리; 더 글로리; 비하인드 토크; 더 글로리; 스님들의 깜짝 선물; MBC ‘전지적 참견 시점’; MBC 예능 프로그램; 전지적 참견 시점 242
#
# 5·18기록관; 도청을 지킨 새벽의 전사들; 기증; 이상호 작가; 회화 작품; 80년 5월 숨진 16명의 열사; 광주광역시 5·18민주화운동기록관; 국가보안법혐의; 대동세상; 오월광주
# 5·18민주화운동기록관; 이상호 작가; 도청을 지킨 새벽의 전사들; 작품; 열사; 작품; 작품; 열사; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품; 작품
#
# LB인베스트먼트; 수요예측; 경쟁률; 국내외 기관투자자; 공모가; 상장 후 시가총액; 미래에셋증권; 유니콘 기업; LP; AUM
# LB인베스트먼트; 수요예측; VC; 코스닥; 상장; 경쟁률; 기관투자자; 유니콘 기업; 투자전문기업; LP 출자 비율; 수익성; 글로벌 벤처투자 명가로 평가받고 있다; IPO; AUM 확대; GP 출자 비율; 수익 극대화; 글로벌
#
# 고용부; 근로시간 개편; 보건전문가 사퇴; 건강권 보호; 연구회; 김인아 교수; 권고안; 논의; 사실 밝혀짐; 뉴스홈페이지
# 고용부; 근로시간 개편; 보건전문가; 사퇴; 사후적으로 확인; 건강; 보건 전문가; 연구회; 개편 방향; 대안; 노동자 건강 보호; 최종 권고문; 노동자 건강 보호 관련 전문가; 노동자 건강 보호 관련 전문가; 노동자 건강 보호 관련 전문가; 건강권 보호; 최종 권고문; 노동자
#
# 대통령; 사이버 공격; 에너지 분야; 대응 태세; 조태용; 안보실장; 점검 회의; 기반시설; 국가 안보; 위협
# 윤석열 대통령; 금융·에너지; 기반시설; 사이버 공격; 대응 태세; 안보실장; 에너지 분야; 국가 경제; 생명선; 하이브리드전; 대규모 해킹사고; 에너지 기반 시설; 복원력 확보; 범정부 차원의 점검 활동; 국가 안보 위협; 에너지 분야 사이버 공격 대비 기관별 대응 태세
#
# 안건조정위; 위원 선임; 법안처리; 민형배; 공동발의; 안건 심사; 쟁점법안; 사회적 경제 기본법; 최강욱; 김의겸
# 상임위원장; 법안지연; 민형배; 안건조정위; 법안발의; 상임위원회; 조정위원; 90일 이내; 위원장; 법안처리; 강성 초선모임; 법안 처리; 여당; 상임위; 민주당 발의 법안 처리; 법안 처리를 용이하도록 하기 위한 법안이 아니냐는 지적도 나온다;
#
# 넥슨; 메이플스토리; 20주년; 큐브 시스템; 개선안; 오프라인 행사; 큐브 등급 상승 시스템; 레드 큐브; 플레이; 획득; 주문의 흔적
# 넥슨; 메이플스토리; 20주년; 개선안; 오프라인 행사; 큐브 시스템; 천장 도입; 대규모 오프라인 쇼케이스; 이용자 의견; 에디셔널 잠재능력; 레드 큐브; 블랙 큐브; 수상한 에디셔널 큐브; 수상한 에디셔널 큐브; 메이프릴 아일랜드; 팬 페스트; 여름
#
# 윤종신; 홍자; 트로트 봄 캐럴송; 꽃놀이 가요; track by YOON; 미스틱스토리; 라틴 리듬; 섬세한 스트링 선율; 홍자의 보이스; 설레는 계절 봄
# 윤종신; 홍자; 트로트 봄 캐럴송; 꽃놀이 가요; 봄 캐럴송; 꽃놀이 가요 우리 같이 꽃놀이 가요; 봄을 맞이해 밝고 행복감 넘치는 메이저한 곡; 봄을 맞이해 밝고 행복감 넘치는 메이저한 곡; 봄을 맞이해 밝고 행복감 넘치는
#
# 주식기준성과보상제도; (주)아이비김영; 자기주식; 대학편입 교육사업; RSU제도; 스톡옵션; 보유중인 자사주; 동기부여; 김영편입; 교육사업
# 아이비김영; 주식기준성과보상제도; 자사주 교부; 임직원; 자기주식; 교육업계; RSU제도; 성장; 성과 보상; 스톡옵션; 대학편입 교육사업; 대학편입 교육사업; 대학편입 교육사업; 대학전공교육 유니스터디; 학점은행 및 평생교육
#
# 트와이스 정연; 공승연; 아이돌 출신; 여행 리포터; 드라마; 여행을 대신해 드립니다; 성공과 삶의 의미; 힐링 트립 감성 드라마; 일본 아마존 베스트셀러; 생활정보 프로그램
# 트와이스 정연; 공승연; 여행 리포터; 드라마; 힐링 트립; 강여름; 일본 아마존 베스트셀러; 강여름 역; 하루 여행; 제작진; 연기력; 자기만의 뚜렷한 색깔; 열정과 함께; 드라마의 본격적인 촬영 준비; 여행을 대신해 드립니다; 공승연 배우의
#
# 창원특례시; 산업기계 재제조 지원센터; 국내 최초; 고부가가치 신산업; 성산구 상복동 일원; 기계제품; 신품 수준; 이를 거친 기계제품; 7대 산업기계; 재제조 산업 생태계
# 창원특례시; 산업기계 재제조 지원센터; 국내 최초; 기후위기 대응; 고부가가치 신산업; 재제조 산업 생태계; 구축; 국내 최초; 성산구 상복동 일원; 6703㎡ 부지; 연구동; Reman인증; 재제조 기술개발; 산업기계 재제조
#
# 반도체 수출 부진; 경기 부진; 수출 위축; 글로벌 경기둔화; 내수 부진; 제조업; 수입 화물; 대(對)중국 수출; 반도체 재고율; 비제조업 업황 BSI
# 반도체; 수출; 내수; 금융시장; 제조업; 수출 부진; 대(對)중국 수출; 재고율; 서비스업 회복; 비제조업 업황 BSI; 경기 전망; 서비스업 회복; 제조업 재고율; 긍정적인 신호; 부정적일 것으로 예상하는 사람이 많다는 뜻; 지수
#
# 북한; 개성공단; 무단 사용; 북측 근로자; 에어로시티 버스; 개성 통근 버스; 통근용 버스; 국유화; 남북투자보장 합의서; 평양
# 북한; 개성공단; 버스; 무단 사용; 평양 시내; 현대자동차; 통근용; 개성공단; 무단 반출; 재산권 제한; 남북투자보장 합의서; 개성공단의 버스; 무단 사용 정황; 개성공단의 버스; 무단 사용 정황; 북한의 버스; 무단 사용 정황; 북한의
#
# 샌디에이고; 김하성; 4경기 연속 안타; 타율 0.289; 메츠; 제압; MLB; 2루수; 이어갔다; 1도루
# 김하성; 안타; 샌디에이고; 메츠; 4경기 연속; 타율; 2루수; 선발 출전; 3타수 1안타 1도루; 도루; 후속타; KBO리그; 브룩스 레일리; 역전 2타점 적시타; 잰더 보가츠; 메츠 타선; 라이언 웨더스; 승리;
#
# 서울대치과병원; 신한은행; 우즈베키스탄; 의료봉사단; 어린이; 구순구개열 수술; 치과진료; 현지 의료진; 발대식; 기부금
# 서울대치과병원; 신한은행; 우즈베키스탄; 의료봉사단; 구순구개열 수술; 치과진료; 현지 의료진; 어린이 구순구개열 수술; 구강악안면외과; 신한은행 임직원 봉사단; 구순구개열 수술 임상 지도; 글로벌 사회공헌; 구강 건강증진; 개발도상국의
#
# 축산물품질평가원; 신규 직원; 상반기 공채 계획; 정규직 9명; 계약직 2명; 청년인턴 33명; 직무능력 기반 블라인드 방식; 사회형평적 인력 확대; 구직 희망자; 최종 합격자 발표일
# 축산물품질평가원; 신규 직원; 원서 접수; 직무능력 기반 블라인드 방식; 축산 관련 학과; 블라인드 방식; 블라인드 방식; 채용접수 누리집; 면접전형; 최종 합격자 발표일; 공정한 절차; 능력 중심으로 지원자를 평가하는 등 공정한 절차를 통해 신규 직원을 뽑겠다; 축산물
#
# 진해군항제; 벚꽃; 여좌천; 연인; 상인; 경화역; 상춘객; 창원시; 인파; 안전
# 진해군항제; 벚꽃; 연분홍; 상춘객; 여좌천; 경화역; 상인들; 관광객; 코로나19; 안전; 안전사고; 안전관리; 인파집중; 안전사고 발생; 안전관리에 6000명 투입; 안전관리에 6000명 투입; 안전관리에 6000명 투입
#
# 홍김동전; BTS 지민; 위험한 초대; 멤버들 물폭탄; 워터플라잉; 예능 프로그램; 게스트; 월드 스타; 방탄; 지민의 말이나 행동
# BTS; 지민; 홍김동전; 멤버들; 위험한 초대; 워터플라잉; KBS2; 예능 프로그램; 게스트; 세계를 점령하고 돌아온 월드 스타; 예능을 잘 안 보는데; 예능의 중요한 인물; 예능의 중요한 인물; 예능의 중요한 인물; 1000억 자산의
#
# 서해수호; 윤석열 대통령; 전몰장병; 호명; 유족; 롤 콜; 국가보훈처; 대선 출마 선언문; 천안함; 분노하지 않는 나라
# 윤석열 대통령; 서해수호의 날; 기념식; 롤 콜; 유족; 눈물; 전몰장병; 호명; 유족; 대통령 비서실; 국가안보실 참모; 전사자 인적 사항; 보훈처; 대선 출마 선언문; 레드 카펫; 유튜브 채널; 최고치; 대통령실 공식 유튜브 채널; 서해 수호의 날
#
# 창원 전국사격대회; 창원특례시장배 전국사격대회; 선발전; 개막식; 경남사격연맹; 국제대회; 2023년 항저우아시아경기대회; 선수; 창원국제사격장; 제104회 전국체육대회
# 창원; 전국사격대회; 선수; 대회; 개막; 경남사격연맹; 국제대회; 선발전; 사격; 선수들; 창원시장배; 대회; 창원국제사격장; 도심형 사격장; 선수들의 경기력; 창원시민의 건강; 세계사격선수권대회; 오마이뉴스; 후원하
#
# 한강경찰대; 한강; 디즈니+; 권상우; 김희원; 이상이; 배다빈; 신현승; 한두진; 이춘석
# 한강; 권상우; 김희원; 이상이; 배다빈; 신현승; 배다빈; 권상우; 김희원; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대; 한강경찰대;
#
# 이경훈; 마스터스; 2라운드; 공동 18위; 프로골퍼; 5언더파; 대회; 3라운드; 진출; 한국 선수
# 이경훈; 마스터스 토너먼트; 2라운드; 5언더파; 공동 18위; 악천후; 2라운드 중단; 상위권 진입 가능성; 한국 선수 최다 컷 통과 기록; 3라운드 진출; 대회 사상 한국 선수 최다 컷 통과 기록; 3라운드 진출; 대회 사상 한국 선수 최다 컷 통과 기록;
#
# 연배; 신학; 교단; 배경; 목회자; 교회; 새로운 꽃; 죽음; 목회 여정; 편지
# 목사; 편지; 김관성 목사님; 편지글 모음집; 한국교회; 목사; 개척; 울산; 교회; 김관성 목사님의 죽음; 목회자들; 하나님의 편지; 성숙과 회복; 한국교회에 깊은 성숙과 회복이 꽃 피우기를 소망합니다.우성균 목사
#
# 놀면 뭐하니; 간식 요원들; 서울; 전국 간식 자랑; 봄 소풍; 유재석; 지하 세계의 맛; 의문의 게스트 요원; 길에서 탄생한 맛; 흥미 돋운다
# 유재석; 지하 세계 간식; 놀면 뭐하니; 간식 요원들; 봄맞이; 전국 간식 자랑; 서울 편; 유재석; 박진주; 이이경; 의문의 게스트 요원; MBC 예능; 간식 키워드; 의문의 게스트 요원; MBC 놀면 뭐하니?; 간식 요원들; MBC 예능
#
# 크리스티안 스텔리니; 임시 감독; 토트넘 훗스퍼; 잉글리시 프리미어리그; 콘테 감독; 클럽; 최선의 결과; 부상자; 이반 페리시치; 콘테 감독 아래에서
# 스텔리니 임시 감독; 콘테 경질; 클럽 위한 최선의 결과; 토트넘 훗스퍼; 잉글리시 프리미어리그; 에버턴; 2022-23시즌 잉글리시 프리미어리그; 29라운드; 첼시; 웨스트햄; 맨체스터 시티; 부상; 이브 비수마; 벤 데이비스; 라이언 세세뇽
#
# 부산시; 15분 도시; 지표; 개발; SK텔레콤; 업무협약; 위치정보; 빅데이터; 이용 현황; 분석
# 부산시; 15분 도시; 지표 개발; SK텔레콤; 업무협약 체결; 빅데이터 제공; 시설 이용 현황 분석; 15분 도시 사업; 성과 분석; 생활권 내 이동인구; 골목상권 활성화; 15분 도시 비전 선포식; 대중교통 이용 현황; 15분 도시 지표 개발; 데이터 기반 도시
#
# 현대자동차; 협력업체; 납품 비리; 미승인 부속품; 안전; 계획적; 하청업체; 허위 급여; 자동차 제조업체; 검은 비리
# 현대자동차; 협력업체; 납품 비리; 미승인품; 전선 뭉치; 1차 협력업체; A사 대표; 허위 급여; 용역업체; 아웃소싱; 지분의 1.1%; 검은 비리의 커넥션; 자동차 제조업체; 구조적인 검은 비리의 커넥션; 미
#
# 롯데 골프단; 원투펀치; 이소영; 황유민; 구단 대항전; KLPGA 투어; 개막전; 우승; 이번 대회; 23언더파의 합작
# 롯데 골프단; 원투펀치; 이소영; 황유민; KLPGA 투어; 대회; 우승; 버디; 대회; 우승; 이소영; 황유민; 동부건설; 우승; 롯데렌터카 여자오픈; 롯데렌터카 여자오픈; 대회; 롯데렌터카 여자오픈; 대회; 우승; 버디; 대회
#
# 한화커넥트; 커넥트플레이스 청량리역점; MZ세대; 디저트 팝업스토어; 온니당; 조개롱; 경기미당; 다비드슈; 지역별 핫한 디저트; 가정의 달
# 한화커넥트; 커넥트플레이스; MZ세대; 디저트 팝업스토어; 온니당; 조개롱; 경기미당; 다비드슈; 수제 쿠키; 제주바다샌드; 프리미엄 시설; 커넥트플레이스 서울역점; 지역 주민 및 역사 이용 고객들; 트렌디한 휴식 공간; 프리미엄 시설;
#
# 엄현경; FA; 연예기획사; 전속계약; 해피투게더3; 전참시; 결혼; 레인보우 로망스; 드라마; 몸매
# 엄현경; FA; 연예기획사 엔터세븐; 전속계약; 예능; 해피투게더3; 최윤영; 결혼이 목표; 일단 뛰어; 경성스캔들; 엄마의 정원; 비밀의 남자; 두 번째 남편; 청일전자 미쓰리; 모델 같은 몸매; 스타일리시 의상; 모델 같
#
# 정부 저출산 대책; 저출산고령사회위원회; 알맹이; 재탕 정책; 삼탕 정책; 맹탕 정책; 대통령 직속 저출산고령사회위원회; 돌봄·육아; 일·육아 병행; 경기도 선도
# 정부 저출산대책; 거창하게 발표; 알맹이는; 재탕; 삼탕; 맹탕 정책; 경기도청; 인구문제 기회 토론회; 돌봄; 육아; 일·육아 병행; 주거; 건강; 초저출생 인구 위기; 저출생 대책; 현장의 생생한 목소리; 경바시
#
# 미국 정부; 책임감 있는 인공지능(AI); 전문가 의견; 국가전기통신정보청(NTIA); AI 정책; AI 시스템에 대한 신뢰성; 가이드라인; 개인 정보 보호; 알고리즘 편향; AI 위험 규칙
# 미국 정부; 책임감 있는 인공지능; 정책 마련; 전문가 의견 수렴; AI 시스템; 신뢰성 확보; NTIA 소장; 금융 감사; 기업 재무제표 정확성; 개인 정보 보호; AI 제품 출시; 규칙; AI 위험 관리 프레임워크; 대중에게 미치는 AI 위험 분류법; AI 시스템 신뢰성
#
# 퓨리움; 남서울대학교; IPP형 일학습병행; 맞춤형 청년인재 양성; 취업확대; 인공지능 스마트 loT 에어샤워 게이트; 현장실무형 인력양성; 취업 연계 프로그램; 상호 발전; 우의 증진
# 퓨리움-남서울대학교; 에어샤워 게이트; IPP형 일학습병행; 맞춤형 청년인재 양성; 취업확대; 업무협약 체결; 인공지능 스마트 loT 에어샤워 게이트; 성암기념도서관; 바이러스와 미세먼지로부터 안전한 환경; 우수한 인력양성; 인적자원 교류
#
# 산불 3단계; 산림 당국; 충남 홍성; 대전 야산; 진화; 건물 소실; 주택; 대피; 인명피해; 화재
# 산불 3단계; 충남 보령시 청라면 내현리; 산불 진화율; 충남 홍성군 서부면 중리; 대전 서구 산직동; 대전 서구; 충남 금산군 복수면 신대리; 산불 발생; 산불 확산; 산불진화차량; 산불 상황; 드론 열화상 카메라; 산불 상황 감시;
#
# KB금융그룹; WM스타자문단; KB금융; 원펌; 맞춤형 자산관리 컨설팅; KB국민은행; KB증권; KB라이프생명; 거시경제; 중국 시장; 가상 자산
# KB금융; WM스타자문단; 자문위원; KB금융; 양종희 부회장; 최재영; KB증권; KB라이프생명; 고객들의 상담 니즈; 자산관리 컨설팅 서비스; 유튜브; KB금융의 고객뿐만 아니라 자산관리 컨설팅 서비스 제공; KB금융의 고객뿐만 아니라 자산관리
#
# 농협; ESG경영; ‘희망의 숲’ 조성; 농협경제지주; 제78회 식목일; 롯데칠성음료; 한국산림복지진흥원; 나무 심기 행사; 무라벨 ECO 상품; ESG 희망의 숲
# 농협; ESG경영; 희망의 숲; 조성; 나무 심기; 롯데칠성음료; 한국산림복지진흥원; 탄소중립; 자원; 나무심기 행사; ESG경영 활성화; 환경 보호; 지속가능한 ESG경영 실천; 나무심기 행사와 연계; ESG경영 활성화; 환경 보호; 관련
#
# KBL; 6강 플레이오프; 캐롯; 26승24패; 5위; KT; 매직넘버; 1997년 출범; 3점 슛; 대우조선해양건설
# 캐롯; PO 확정; 6강 플레이오프; 6위; 선수단; 3점 슛; 모기업; 네이밍 스폰서십; 자격; KBL; 팬들; 선수단; 팬들; 팬들; 선수단; 구단; 모기업; 모기업; 선수단; 팬들; 프로농구; 챔피언결정전; 최다-최초
#
# 내일날씨; 미세먼지; 황사; 건강 조심; 전국 흐림; 마스크; 낮 최고기온; 아침 최저기온; 비; 물결
# 미세먼지; 황사; 낮 최고기온; 건강관리; 마스크; 초미세먼지; 비; 강수량; 물결; 동해 앞바다; 서해 앞바다; 남해 앞바다; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청; 기상청
#
# 바르셀로나; 일카이 귄도안; 자유계약; 미드필더; 맨체스터 시티; 세르히오 부스케츠; 중원 보강; FA 선수; 사비 에르난데스 감독; 이적 요청
# 바르셀로나; 맨체스터 시티; 미드필더; 귄도안; 자유계약; FA; 이적; 중원 보강; 사비 에르난데스 감독; 재정난; 라리가 등록; 재정난 극복; 이적 준비됐다; 브라이튼; 핵심 코치; 투헬 따라 뮌헨 이적 유력; 첼시; 핵심 코치; 이적 준비됐다
#
# CS; 코코본드; 투자자 소송; CS주주; UBS주식; AT1; 채권 가치; 금융시장 신뢰 저하; ECB; BOE
# CS 코코본드; AT1 채권; 투자자 소송; UBS 주식; 금융시장 신뢰 저하; 구제책; CS 주주; AT1 보유자; 자본 비율; 금융시장 신뢰 저하; 유럽 채권 시장; 손실 부담; 주주 손실; 금융시장 혼란; ECB·BOE; 주주보다 채권자가 피해볼
#
# 경기북부특별자치도; 경기북부; 출범 목표; 경기도 청사; 설치 추진계획; 비전 수립; 공론화 과정; 특별법 제정; 주민투표; 공론화위원회
# 경기북부특별자치도; 출범 목표; 경기도; 청사진 발표; 경기도 청사; 경기북부특별자치도 설치 추진계획; 특별법 제정; 주민투표; 행정안전부; 경기북부 권역; 공론화위원회; 공론화위원회 위원장; 법안 발의; 총선 전 처리; 경기북부특별자치도 설치와 관련해 김성원 국민의힘
#
# 이은해; 고유정; 여자교도소; 싸움; 새 교도소; 주민 반발; 계곡살인; 청주여자교도소; 수용 인원 초과; 폭력
# 여성 전용 교도소; 수용 인원; 협소한 공간; 싸움; 교도소 건립; 폭력; 수감; 잠자리 순번; 수용자 상호 간 갈등; 새로운 교도소 건립; 화성직업훈련교도소; 외국인보호소; 화성직업훈련교도소와 외국인보호소; 교도소 건립 추진; 여성 수용자 과밀화 문제; 화성직업
#
# 한국전기연구원; 인공지능; 빅데이터; 의료·바이오 기기 산업; 창원; 진해첨단연구단지; 첨단기기 연구제조센터; 국비 포함 총 257억원; 의료기기 제조; 경제活性화
# 창원; 첨단 의료·바이오 기기 산업; 전기연구원; 의료·바이오 첨단기기 연구제조센터; 인공지능; 빅데이터 기술; 의료기기 개발기업 지원; 의료기기 제조; 의료기기 개발기업 지원; 정밀제조 기반; 의료기기 분야 업종 확대; 의료기기 제조를 위한 전반적인 기술 지원;
#
# 크루즈선; 인천항; 입항; 유로파2호; 관광객; 일본; 코로나19; 승무원; 기념촬영; 한국 관광
# 인천항; 크루즈; 유로파2호; 관광객; 입항; 크루즈선; 인천지방해양수산청; IPA; 인천관광공사; 꽃목걸이; 한글 캘리그라피 체험; 전통의상 체험; 인천항 방문의 의미; 크루즈선 입항; 마인 쉬프5호; 승객 2790명;
#
# 방탄소년단; 지민; 라면; 다이어트; SBS 파워 FM; 멤버들; 유머 감각; 목소리; 첫 솔로 앨범; 페이스; 신스 팝(Synth Pop)
# 지민; 라면; 다이어트; 최파타; 라면; 활동; 라디오; 솔로 앨범; 페이스; 라이크 크레이지; 앨범 판매량; 솔로 아티스트 초동 1위; 일본 오리콘 차트; 주간 디지털 앨범 랭킹; 주간 앨범 랭킹; 주간 음악 랭킹; 솔로 아티스트; 최화정의 파워타임; 라디오
#
# 이담외과; 성형외과; 고준걸 원장; 초빙; 진료; 가톨릭대학교 의과대학; 성형외과 전공의; 국군수도병원; 대한성형외과학회; 당뇨발
# 이담외과; 성형외과 전문의 고준걸 원장; 가톨릭대학교 의과대학; 가톨릭중앙의료원; 가톨릭대학교 인천성모병원; 대한성형외과학회; 대한미용성형외과학회; 대한화상학회; 대한수부외과학회; 대한화상학회; 당뇨발(당뇨병성 족부궤양
#
# 첼시; 세리에A; 손해; 이적; 선수 매각; FFP 규정; 로프터스 치크; 트레보 찰로바; 칼럼 허드슨 오도이; 마운트
# 첼시; 세리에A; 손실; FFP 위반; 선수 매각; 로프터스 치크; 멀티 플레이어; 칼럼 허드슨 오도이; 마운트; 멘디; AS 로마; 루벤 로프터스 치크; 마운트의 경우; AC 밀란; 마운트의 경우;
#
# 알리바바 클라우드; 대규모 언어모델; 통이치안웬; 생성형 AI; 클라우드 컴퓨팅; 기술적 전환점; 커뮤니케이션; 지능형 음성 비서; 전자상거래; 정보 검색·탐색
# 알리바바 클라우드; 대규모 언어모델; 통이치안웬; 생성형 AI; 클라우드 주도하는 기술적 전환점; 맞춤형 AI 기능; 알리바바 생태계; 사용자 경험; 통이치안웬 모델; 모델스코프; 모델링 서비스; 클라우드 컴퓨팅; AI 서비스; 생성형 AI; 클라우드 컴퓨팅;
#
# 전우원; 광주; 전두환; 5·18 단체; 민주화운동; 유가족; 5월 3단체; 민주묘지; 마약 투약 혐의; 사죄
# 전두환; 손자; 전우원; 5·18; 광주; 5·18 민주화운동; 마약 투약 혐의; 경찰 체포; 유족; 5·18 기념재단; 5·18 민주묘지; 사죄; 광주 서구 한 호텔; 휴식; 공식 일정 없이; 호텔에 도착해 공식 일정없이 휴식을
#
# 충남 천안시; 미래모빌리티 중심 국가산업단지; 성환 종축장; 국토교통부; 신규 국가산업단지 공모; 417만㎡에 총사업비 1조6000억원 투입; 스마트팩토리; 광역교통망; R&D; 배후 뉴타운 개발
# 천안시; 미래모빌리티; 국가산업단지; 성환 종축장; 총사업비; 1조6000억원; 국립축산과학원 축산자원개발부; 2027년 전남 함평군; 스마트팩토리; 반도체와 스마트모빌리티; R&D; 교육; 주거; 클러스터 생태계; 첨단국가산업단지; 배후
#
# Tdap 백신; 아다셀주; 재접종; 용법; 용량 변경 승인; 백일해; 파상풍; 디프테리아; 접종; 성인; 면역원성
# Tdap 백신; 아다셀주; 10년 간격 재접종; 영유아 시기; 소아용 DTP 기초접종; 재접종 간격; 오픈라벨; 다기관 임상 연구; 파상풍; 디프테리아; 성인 파상풍 예방; 동물 교상; 백일해; 감염성 질환
#
# 손흥민; 100호 골 도전; 브라이튼; 대기록; 리그 두 자릿수 득점; 골 감각; 결정적인 기회; 후반 37분; 로베르토 데 체르비 감독 밑에서; 11번의 맞대결
# 손흥민; 100호 골 도전; 브라이튼; 에버턴; 골 감각; 해리 케인; 데얀 쿨루셉스키; 호시탐탐 4위; 리그 26경기; 승리; 추가골; 브라이튼과 통산 11번의 맞대결; 추가 득점; 기록이 좋지 않기 때문
#
# 김히어라; 그램 엔터테인먼트; 전속계약; 매니저; 신뢰; 신생 소속사; 새 출발; 배우; 다채로운 스펙트럼
# 김히어라; 그램 엔터테인먼트; 전속계약; 매니저; 신생 소속사; 신뢰; 유대; 드라마 '이상한 변호사 우영우'; 더 글로리; 악귀 겔리; 카리스마 넘치는 모습; 액션; 드라마 '경이로운 소문2'; 신생 소속사;
#
# 조달청; 혁신 아이디어 공모전; 초·중·고생; 혁신조달; 일상생활속 아이디어; 응모; 우수상; 교육부장관상; 조달청장상; 공공수요 숙성지원
# 조달청; 초·중·고생; 혁신 아이디어 공모전; 혁신수요 아이디어; 일상생활속 아이디어; 교육부장관상; 우수상; 장려상; 공공수요 숙성지원; 아이디어 심사; 혁신제품 개발; 분리수거 병수거함; 배수관 역류 및 악취 차단 장치; 문제에 '마침표' 찍
#
# 유지태; 김준호; 대학 시절; 술; 회의; 얻어먹다; 나이트 음악; 자취방; 팬티; 월방
# 유지태; 김준호; 대학 시절; 추억; 회상; 자취방; 월방; TV; 자취방; 비누 냄새; 자취방 쟁여두기; 사이즈; 비누 냄새; 대학 시절 에피소드; 단국대 연극영화과 95학번 동기; 대학 시절 에피소드; 단국대 연극영화과 95학번 동기;

# %% [markdown]
# # Calculate Metrics

# %%
def compute_metrics(eval_pred):
    predictions, decoded_labels = eval_pred
    
    prediction_lens = [np.count_nonzero(np.array(pred) != tokenizer.pad_token_id) for pred in predictions]
    
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # ROUGE / Mean Generated Length
    print('Calculating ROUGE...')
    result = rouge_for_batch(decoded_labels, decoded_preds)

    # F1@K
    print('Calculating F1@10...')
    result["F1@10"] = f1_score_at_k_for_batch(decoded_labels, decoded_preds, 10)
    
    # Jaccard@K
    print('Jaccard F1@10...')
    result["jaccard_similarity"] = jaccard_similarity_for_batch(decoded_labels, decoded_preds, 10)
        
    result = {key: round(value * 100, 4) for key, value in result.items()}
    result["gen_len"] = round(np.mean(prediction_lens), 4)
    
    return result

# %%
metrics = compute_metrics((predictions_only, labels))
# Out:
# Calculating ROUGE...
# 100%|██████████| 3000/3000 [07:58<00:00,  6.27it/s]
# Calculating F1@10...
# 100%|██████████| 3000/3000 [00:00<00:00, 46326.45it/s]
# Jaccard F1@10...
# 100%|██████████| 3000/3000 [00:00<00:00, 76022.79it/s]

# %%
metrics
# Out:
# {'rouge1': 50.1822,
#  'rouge2': 35.8062,
#  'rougeL': 42.1194,
#  'rougeLsum': 42.1194,
#  'F1@10': 61.0273,
#  'jaccard_similarity': 25.3944,
#  'gen_len': 64.0}

# %% [markdown]
# #### Beam Search
# ```
# generation_args = {
#     'num_beams': 5,
#     'no_repeat_ngram_size': 3,
#     'num_return_sequences': 1,
#     'early_stopping': False,
# }
#
# {'rouge1': 65.9559,
#  'rouge2': 45.8405,
#  'rougeL': 53.5547,
#  'rougeLsum': 53.5547,
#  'F1@10': 58.2764,
#  'jaccard_similarity': 25.382}
# ```
#
# #### Diverse Beam Search
# ```
# generation_args = {
#     'num_beams': 15,
#     'no_repeat_ngram_size': 3,
#     'num_return_sequences': 1,
#     'num_beam_groups': 3,
#     'early_stopping': False,
# }
#
# {'rouge1': 65.9841,
#  'rouge2': 45.8601,
#  'rougeL': 53.5776,
#  'rougeLsum': 53.5776,
#  'F1@10': 58.2764,
#  'jaccard_similarity': 25.382}
# ```
#
# #### Sampling
# ```
# generation_args = {
#     'do_sample': True,
#     'top_k': 3,
#     'top_p': 0.95,
# }
#
# {'rouge1': 64.5375,
#  'rouge2': 43.5099,
#  'rougeL': 52.8016,
#  'rougeLsum': 52.8016,
#  'F1@10': 58.6438,
#  'jaccard_similarity': 24.1092}
# ```

# %% [markdown]
# # Inference on Eval Dataset

# %%
for data, pred in zip(eval_dataset, predictions):
    pred = np.where(pred != -100, pred, tokenizer.pad_token_id)
    context = tokenizer.decode(data['input_ids'], skip_special_tokens=True)
    summary = tokenizer.decode(data['labels'], skip_special_tokens=True)
    pred = tokenizer.decode(pred, skip_special_tokens=True)
    print(f'입력: {context}')
    print(f'정답: {summary}')
    print(f'예측: {pred}', end='\n\n')
